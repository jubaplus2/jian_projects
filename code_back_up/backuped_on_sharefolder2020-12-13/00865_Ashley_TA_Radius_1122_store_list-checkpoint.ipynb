# %%
# Steps below:
'''
1. Verify store location and find the lat/lng, QC with POI and Google
2. Find the zips by store within certain X miles, and label P/S
3. Combine stores into TA based on the overlap
4. Summarize to output
'''
# Out:
# '\n1. Verify store location and find the lat/lng, QC with POI and Google\n2. Find the zips by store within certain X miles, and label P/S\n3. Combine stores into TA based on the overlap\n4. Summarize to output\n'

# %%
import pandas as pd
import numpy as np
import datetime
from haversine import haversine
import googlemaps
from fuzzywuzzy import fuzz
import glob
import json

zip_centers=json.load(open("/mnt/clients/juba/hqjubaapp02/sharefolder/Docs/Geo_mapping/updated_zip_centers_JL_2019-05-23.json","r"))
GoogleMap_key='AIzaSyDxp8O8JKOvbuB6F5DfqyyJMYPPKwIXLdY'
gmaps = googlemaps.Client(key=GoogleMap_key)
# Out:
# /home/jliang/.local/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # 1. Store locations

# %%
# FW: Merkle Local Demand Toolkit Pilot for Ashley HomeStore
# From: Yoram Greener 2020-11-30 at 5:15 PM
'''
Hey Yoram and Lauren,

This list is actually from last week.  Filter to US locations and make sure they’re not labeled in M as a corporate office or warehouse and we should be good to go.
 
Thanks,
Brad
'''

df_all_stores=pd.ExcelFile("./Ashley GMB 11-22-2020.xlsx")
print(df_all_stores.sheet_names)
df_all_stores=df_all_stores.parse("Ungrouped locations-20201122-15",dtype=str)
df_all_stores=df_all_stores[df_all_stores['Country / Region']=="US"]
df_all_stores=df_all_stores[~df_all_stores['Primary category'].isin(['Warehouse','Corporate office'])]

print(df_all_stores.shape)
df_all_stores.head(2)
# Out:
# ['Ungrouped locations-20201122-15']
# (662, 26)
#   Store code     Business name           Address line 1 Address line 2  \
# 0         40  Ashley HomeStore            19820 West Rd            NaN
# 1         39  Ashley HomeStore  35120 Central City Pkwy            NaN
#
#   Address line 3   Locality Administrative area Country / Region Postal code  \
# 0            NaN  Woodhaven                  MI               US       48183
# 1            NaN   Westland                  MI               US       48185
#
#     Primary phone  ... Tuesday hours Wednesday hours Thursday hours  \
# 0  (734) 589-1200  ...   10:00-21:00     10:00-21:00    10:00-21:00
# 1  (734) 589-0700  ...   10:00-21:00     10:00-21:00    10:00-21:00
#
#   Friday hours Saturday hours  \
# 0  10:00-21:00    10:00-21:00
# 1  10:00-21:00    10:00-21:00
#
#                                        Special hours  \
# 0  2020-11-25: 10:00-00:00, 2020-11-26: x, 2020-1...
# 1  2020-11-25: 10:00-00:00, 2020-11-26: x, 2020-1...
#
#                                    From the business Opening date  \
# 0  Retail chain with a variety of signature home ...          NaN
# 1  Retail chain with a variety of signature home ...          NaN
#
#                     Labels AdWords location extensions phone
# 0  PaidSearch, DSGLocation                   +1 734-725-2144
# 1  PaidSearch, DSGLocation                   +1 734-672-3511
#
# [2 rows x 26 columns]

# %%
df_all_stores=df_all_stores[['Store code','Business name','Address line 1', 'Locality', 'Administrative area',
                             'Postal code','Country / Region']]
df_all_stores['Postal code']=df_all_stores['Postal code'].apply(lambda x: x.split("-")[0].split(" ")[0].zfill(5))
for col in df_all_stores.columns.tolist()[2:-1]:
    print(col)
    df_all_stores[col]=df_all_stores[col].apply(lambda x: x.strip().lower())
df_all_stores['client_address']=df_all_stores[df_all_stores.columns.tolist()[2:-1]].values.tolist()
df_all_stores['client_address']=df_all_stores['client_address'].apply(lambda x: ", ".join(x))
# Out:
# Address line 1
# Locality
# Administrative area
# Postal code

# %%
df_all_stores['Postal code'].apply(len).unique()
# Out:
# array([5])

# %%
# QC with POI
df_brand_POI=pd.read_csv("/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/brand_info/07/02/brand_info.csv",dtype=str)
[x for x in df_brand_POI['brand_name'].tolist() if "ashley" in x.lower()]
# Out:
# ['Ashley Furniture HomeStore', 'Ashley Stewart']

# %%
brand_name='Ashley Furniture HomeStore'

list_poi_files=glob.glob("/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/*.csv.gz")
df_POI=pd.DataFrame()
for f in list_poi_files:
    df=pd.read_csv(f,dtype=str,nrows=None,compression="gzip")
    df=df[df['brands']==brand_name]
    df_POI=df_POI.append(df)
print(df_POI.shape)
df_POI.head(2)
# Out:
# (690, 29)
#                  placekey                   safegraph_place_id  \
# 791   226-222@5z4-r3s-9pv  sg:32d4bd6b4a2c4041a8cba15f4ccdec99
# 9828  zzw-222@627-rwf-xkf  sg:a2c5301fce3e4ad898c3353645616efa
#
#                 parent_safegraph_place_id  \
# 791   sg:34889a49a9cd4dae83cd38c11b0aaa02
# 9828  sg:72a86ef480dd498ebb7de74a56ed1e98
#
#                             safegraph_brand_ids               location_name  \
# 791   SG_BRAND_46f27ef73712065fc801247705bf2f3b  Ashley Furniture HomeStore
# 9828  SG_BRAND_46f27ef73712065fc801247705bf2f3b  Ashley Furniture HomeStore
#
#                           brands      top_category      sub_category  \
# 791   Ashley Furniture HomeStore  Furniture Stores  Furniture Stores
# 9828  Ashley Furniture HomeStore  Furniture Stores  Furniture Stores
#
#      naics_code   latitude  ... tracking_opened_since tracking_closed_since  \
# 791      442110   33.55633  ...               2020-01               2019-07
# 9828     442110  40.867745  ...               2020-01               2020-01
#
#                                             polygon_wkt  polygon_class  \
# 791   POLYGON ((-117.20212720345438 33.5565415093911...  OWNED_POLYGON
# 9828  POLYGON ((-73.82818413967176 40.86793834361845...  OWNED_POLYGON
#
#      building_height enclosed  phone_number is_synthetic includes_parking_lot  \
# 791              NaN    false  +19518947988        false                  NaN
# 9828            6.68    false           NaN        false                false
#
#      iso_country_code
# 791                US
# 9828               US
#
# [2 rows x 29 columns]

# %%
df_POI.columns.tolist()
# Out:
# ['placekey',
#  'safegraph_place_id',
#  'parent_safegraph_place_id',
#  'safegraph_brand_ids',
#  'location_name',
#  'brands',
#  'top_category',
#  'sub_category',
#  'naics_code',
#  'latitude',
#  'longitude',
#  'street_address',
#  'city',
#  'region',
#  'postal_code',
#  'open_hours',
#  'category_tags',
#  'opened_on',
#  'closed_on',
#  'tracking_opened_since',
#  'tracking_closed_since',
#  'polygon_wkt',
#  'polygon_class',
#  'building_height',
#  'enclosed',
#  'phone_number',
#  'is_synthetic',
#  'includes_parking_lot',
#  'iso_country_code']

# %%
df_POI=df_POI[['safegraph_place_id','location_name','brands','latitude','longitude',
               'street_address','city','region', 'postal_code']]
print(df_POI['postal_code'].apply(len).unique())
list_add_poi=['street_address','city','region', 'postal_code']
df_POI['poi_address']=df_POI[list_add_poi].values.tolist()
df_POI['poi_address']=df_POI['poi_address'].apply(lambda x: ", ".join(x))
df_POI['poi_address']=df_POI['poi_address'].str.lower()
df_POI.head(3)
# Out:
# [5]
#                         safegraph_place_id               location_name  \
# 791    sg:32d4bd6b4a2c4041a8cba15f4ccdec99  Ashley Furniture HomeStore
# 9828   sg:a2c5301fce3e4ad898c3353645616efa  Ashley Furniture HomeStore
# 30250  sg:1f4c2732d64a44c6a1aed2014b2a8867  Ashley Furniture HomeStore
#
#                            brands   latitude   longitude  \
# 791    Ashley Furniture HomeStore   33.55633  -117.20169
# 9828   Ashley Furniture HomeStore  40.867745  -73.828389
# 30250  Ashley Furniture HomeStore  40.662451  -73.719303
#
#                   street_address                 city region postal_code  \
# 791    25125 Madison Ave Ste 106             Murrieta     CA       92562
# 9828     340 Baychester Ave Fl 2                Bronx     NY       10475
# 30250      2034 Green Acres Mall  South Valley Stream     NY       11581
#
#                                              poi_address
# 791       25125 madison ave ste 106, murrieta, ca, 92562
# 9828           340 baychester ave fl 2, bronx, ny, 10475
# 30250  2034 green acres mall, south valley stream, ny...

# %%
df_POI.shape,df_POI['poi_address'].nunique()
# Out:
# ((690, 10), 690)

# %%
dict_add_id=df_POI.set_index("poi_address").to_dict()['safegraph_place_id']
dict_add_lat=df_POI.set_index("poi_address").to_dict()['latitude']
dict_add_lng=df_POI.set_index("poi_address").to_dict()['longitude']

list_keys=df_POI['poi_address'].tolist()

df_all_stores['poi_match_add']=np.nan
df_all_stores['fuzzyratio']=np.nan
df_all_stores['poi_id']=np.nan
df_all_stores['poi_lat']=np.nan
df_all_stores['poi_lng']=np.nan

for ind, row in df_all_stores.iterrows():
    row_add=row['client_address']
    best_r=0
    best_match=""
    for poi_add in list_keys:
        r=fuzz.partial_ratio(row_add,poi_add)
        if r > best_r:
            best_r=r
            best_match=poi_add
    df_all_stores.loc[ind,'poi_match_add']=best_match
    df_all_stores.loc[ind,'fuzzyratio']=best_r
    df_all_stores.loc[ind,'poi_id']=dict_add_id[best_match]
    df_all_stores.loc[ind,'poi_lat']=dict_add_lat[best_match]
    df_all_stores.loc[ind,'poi_lng']=dict_add_lng[best_match]
    
df_all_stores.head(3)
# Out:
#    Store code     Business name           Address line 1          Locality  \
# 0          40  Ashley HomeStore            19820 west rd         woodhaven
# 1          39  Ashley HomeStore  35120 central city pkwy          westland
# 2  9000069082  Ashley HomeStore    1401 golden gate blvd  mayfield heights
#
#   Administrative area Postal code Country / Region  \
# 0                  mi       48183               US
# 1                  mi       48185               US
# 2                  oh       44124               US
#
#                                       client_address  \
# 0                19820 west rd, woodhaven, mi, 48183
# 1       35120 central city pkwy, westland, mi, 48185
# 2  1401 golden gate blvd, mayfield heights, oh, 4...
#
#                                        poi_match_add  fuzzyratio  \
# 0                19820 west rd, woodhaven, mi, 48183       100.0
# 1       35120 central city pkwy, westland, mi, 48185       100.0
# 2  1401 golden gate blvd, mayfield heights, oh, 4...       100.0
#
#                                 poi_id    poi_lat     poi_lng
# 0  sg:06159e1a322e47d8821a931e841796da   42.14252  -83.224249
# 1  sg:7a521ee0a2ee49edb5d0058ca08d7924   42.34453  -83.387354
# 2  sg:03006a11f70c4f16bb3026b0e64efe0f  41.526834  -81.446989

# %%
pd.options.display.max_rows=500
df_qc=df_all_stores[df_all_stores['fuzzyratio']>=90]
print(df_qc.shape)
df_qc
# Out:
# (513, 13)
#      Store code            Business name           Address line 1  \
# 0            40         Ashley HomeStore            19820 west rd
# 1            39         Ashley HomeStore  35120 central city pkwy
# 2    9000069082         Ashley HomeStore    1401 golden gate blvd
# 3    7710000477         Ashley HomeStore          1340 tapteal dr
# 4    7710000177         Ashley HomeStore            2534 s 9th st
# ..          ...                      ...                      ...
# 743  9000109026  Ashley HomeStore Outlet    3503 w gate city blvd
# 744  9000417563         Ashley HomeStore           6100 dobbin rd
# 745  7710000295         Ashley HomeStore         2500 n prince st
# 746  7710000063         Ashley HomeStore       3850 s mooney blvd
# 747  7710000353         Ashley HomeStore       63455 n highway 97
#
#              Locality Administrative area Postal code Country / Region  \
# 0           woodhaven                  mi       48183               US
# 1            westland                  mi       48185               US
# 2    mayfield heights                  oh       44124               US
# 3            richland                  wa       99352               US
# 4              salina                  ks       67401               US
# ..                ...                 ...         ...              ...
# 743        greensboro                  nc       27407               US
# 744          columbia                  md       21045               US
# 745            clovis                  nm       88101               US
# 746           visalia                  ca       93277               US
# 747              bend                  or       97703               US
#
#                                         client_address  \
# 0                  19820 west rd, woodhaven, mi, 48183
# 1         35120 central city pkwy, westland, mi, 48185
# 2    1401 golden gate blvd, mayfield heights, oh, 4...
# 3                 1340 tapteal dr, richland, wa, 99352
# 4                     2534 s 9th st, salina, ks, 67401
# ..                                                 ...
# 743       3503 w gate city blvd, greensboro, nc, 27407
# 744                6100 dobbin rd, columbia, md, 21045
# 745                2500 n prince st, clovis, nm, 88101
# 746             3850 s mooney blvd, visalia, ca, 93277
# 747                63455 n highway 97, bend, or, 97703
#
#                                          poi_match_add  fuzzyratio  \
# 0                  19820 west rd, woodhaven, mi, 48183       100.0
# 1         35120 central city pkwy, westland, mi, 48185       100.0
# 2    1401 golden gate blvd, mayfield heights, oh, 4...       100.0
# 3                 1340 tapteal dr, richland, wa, 99352       100.0
# 4                     2534 s 9th st, salina, ks, 67401       100.0
# ..                                                 ...         ...
# 743       3503 w gate city blvd, greensboro, nc, 27407       100.0
# 744                6100 dobbin rd, columbia, md, 21045       100.0
# 745                2500 n prince st, clovis, nm, 88101       100.0
# 746             3850 s mooney blvd, visalia, ca, 93277       100.0
# 747                63455 n highway 97, bend, or, 97703       100.0
#
#                                   poi_id    poi_lat      poi_lng
# 0    sg:06159e1a322e47d8821a931e841796da   42.14252   -83.224249
# 1    sg:7a521ee0a2ee49edb5d0058ca08d7924   42.34453   -83.387354
# 2    sg:03006a11f70c4f16bb3026b0e64efe0f  41.526834   -81.446989
# 3    sg:3a2371ef674943209f227fd7d57f5dd5  46.232317  -119.230554
# 4    sg:70339e7ec67b47ad847052a44fba4a15  38.794549   -97.614512
# ..                                   ...        ...          ...
# 743  sg:cc53544da61b41219056a93890c35b7e  36.038562   -79.848113
# 744  sg:615b93198c6c496da5b2ed8598069f3b  39.197906    -76.81039
# 745  sg:083ff55af6f84a89b5f536e7c391a7b2  34.422947  -103.197158
# 746  sg:5ea44983e63e4d00a963169b74a13e1f  36.295458  -119.310057
# 747  sg:6d0a4af166634fd2a80b7b7a4e4779e6  44.100428  -121.303699
#
# [513 rows x 13 columns]

# %%
df_qc=df_all_stores[df_all_stores['fuzzyratio']>=80]
df_qc=df_qc[df_qc['fuzzyratio']<90]
print(df_qc.shape)
df_qc
# Out:
# (64, 13)
#      Store code              Business name  \
# 23           74           Ashley HomeStore
# 27   7710000128           Ashley HomeStore
# 32   9000348259    Ashley HomeStore Outlet
# 35           25           Ashley HomeStore
# 38   7710000348           Ashley HomeStore
# 43   7710000394           Ashley HomeStore
# 48   9000109142           Ashley HomeStore
# 52   7710000501           Ashley HomeStore
# 61   7710000009           Ashley HomeStore
# 63           24           Ashley HomeStore
# 73   7710000316           Ashley HomeStore
# 84   9000169172           Ashley HomeStore
# 88   7710000089           Ashley HomeStore
# 104  7710000091           Ashley HomeStore
# 106  7710000199           Ashley HomeStore
# 135  7710000131           Ashley HomeStore
# 141  9000343876           Ashley HomeStore
# 142  9000037221           Ashley HomeStore
# 156  7710000309           Ashley HomeStore
# 158  7710000500           Ashley HomeStore
# 173  9000117944           Ashley HomeStore
# 178  7710000465           Ashley HomeStore
# 191  9000187561    Ashley HomeStore Outlet
# 205  7710000423           Ashley HomeStore
# 229          47           Ashley HomeStore
# 239  7710000272           Ashley HomeStore
# 241  7710000476           Ashley HomeStore
# 263  7710000472           Ashley HomeStore
# 270  7710000072           Ashley HomeStore
# 272  7710000450           Ashley HomeStore
# 277  9000450874    Ashley HomeStore Outlet
# 285  7710000342           Ashley HomeStore
# 288  9000467663           Ashley HomeStore
# 296  7710000311           Ashley HomeStore
# 299  7710000324           Ashley HomeStore
# 300  9000451595           Ashley HomeStore
# 328  9000451592           Ashley HomeStore
# 348          48           Ashley HomeStore
# 356  7710000248           Ashley HomeStore
# 377          81           Ashley HomeStore
# 384  7710000117           Ashley HomeStore
# 388  7710000099           Ashley HomeStore
# 392          33           Ashley HomeStore
# 408  7710000054           Ashley HomeStore
# 414          m1  Ashley HomeStore & Outlet
# 415  9000141225           Ashley HomeStore
# 426          72           Ashley HomeStore
# 444  7710000492           Ashley HomeStore
# 483  7710000368           Ashley HomeStore
# 523  9000038393           Ashley HomeStore
# 534  7710000325           Ashley HomeStore
# 536  9000170173           Ashley HomeStore
# 542  7710000462           Ashley HomeStore
# 580  7710000488           Ashley HomeStore
# 610  9000340837           Ashley HomeStore
# 611  9000076428           Ashley HomeStore
# 613  7710000384           Ashley HomeStore
# 620          m4           Ashley HomeStore
# 626  7710000145           Ashley HomeStore
# 657  7710000213           Ashley HomeStore
# 660  7710000468           Ashley HomeStore
# 676  7710000119           Ashley HomeStore
# 727  9000473730    Ashley HomeStore Outlet
# 728  7710000263           Ashley HomeStore
#
#                                       Address line 1      Locality  \
# 23                                1722 veterans blvd        mccomb
# 27                             98-107 kamehameha hwy          aiea
# 32                     9791 green park industrial dr     st. louis
# 35                                        2331 hwy k      o'fallon
# 38                           1130 boardman poland rd    youngstown
# 43                                 2003 n eastman rd     kingsport
# 48                                5503 w saginaw hwy       lansing
# 52                                 230 gihon village   parkersburg
# 61                                 1310 tingle cir e        mobile
# 63                               4432 lemay ferry rd      st louis
# 73                                   400 route 211 e    middletown
# 84                           101 wyoming valley mall  wilkes barre
# 88                              4360 w new haven ave     melbourne
# 104                     14250 tamiami trail north #1        naples
# 106                     6610 baltimore national pike   catonsville
# 135                            3750 williams blvd sw  cedar rapids
# 141                                   297 route 72 w    manahawkin
# 142                                  3964 plaza blvd   gainesville
# 156                              1648 broadhollow rd   farmingdale
# 158                   5010 university town centre dr    morgantown
# 173                                1418 westpark plz       ontario
# 178                              4410 s laburnum ave      richmond
# 191                                      1821 ny-110   farmingdale
# 205                            4520 san bernardo ave        laredo
# 229                                 5151 citrus blvd       harahan
# 239                                   1001 church rd   cherry hill
# 241                          1200 cooper point rd sw       olympia
# 263                               14250 smoketown rd    woodbridge
# 270                                1165 n dupont hwy         dover
# 272                                   2650 n main st         logan
# 277                                 2215 memorial dr      waycross
# 285                    919 n lexington springmill rd     mansfield
# 288                                 1400 nw 167th st   north miami
# 296                                  1960 w ridge rd     rochester
# 299                                    1895 south rd  poughkeepsie
# 300                                  14136 baxter dr        baxter
# 328                             200 upland square dr     pottstown
# 348                  1620 martin luther king jr blvd         houma
# 356                             3932 e franklin blvd      gastonia
# 377                            1330 n town east blvd      mesquite
# 384                     840 ernest w barrett pkwy nw      kennesaw
# 388                               4650 s tamiami trl      sarasota
# 392                            9018 n 121st east ave        owasso
# 408                                  6001 redwood dr  rohnert park
# 414                                9687 colerain ave    cincinnati
# 415                              201 n berkeley blvd     goldsboro
# 426                              6143 u s highway 98   hattiesburg
# 444                                   1525 e hwy 151   platteville
# 483                                2028 macarthur rd     whitehall
# 523                        2640 north reserve street      missoula
# 534                                3529 w genesee st      syracuse
# 536                                 8985 venice blvd   los angeles
# 542                              7378 stream walk ln      manassas
# 580                                    12185 77th st       kenosha
# 610                               340 baychester ave         bronx
# 611                               4850 us highway 67    farmington
# 613                           540 s. garfield avenue        pierre
# 620                               4530 eastgate blvd    cincinnati
# 626  600 east walnut street eastgate shopping center    carbondale
# 657                              1621 e. madison ave       mankato
# 660                              81 orchard hill cir      staunton
# 676                              2900 stonecrest cir      lithonia
# 727                            5203 bob bullock loop        laredo
# 728                           3201 32nd avenue south   grand forks
#
#     Administrative area Postal code Country / Region  \
# 23                   ms       39648               US
# 27                   hi       96701               US
# 32                   mo       63123               US
# 35                   mo       63368               US
# 38                   oh       44514               US
# 43                   tn       37660               US
# 48                   mi       48917               US
# 52                   wv       26101               US
# 61                   al       36606               US
# 63                   mo       63129               US
# 73                   ny       10940               US
# 84                   pa       18702               US
# 88                   fl       32904               US
# 104                  fl       34110               US
# 106                  md       21228               US
# 135                  ia       52404               US
# 141          new jersey       08050               US
# 142                  fl       32608               US
# 156                  ny       11735               US
# 158                  wv       26501               US
# 173                  or       97914               US
# 178                  va       23231               US
# 191                  ny       11735               US
# 205                  tx       78041               US
# 229                  la       70123               US
# 239                  nj       08034               US
# 241                  wa       98502               US
# 263                  va       22192               US
# 270                  de       19901               US
# 272                  ut       84341               US
# 277                  ga       31501               US
# 285                  oh       44906               US
# 288                  fl       33169               US
# 296                  ny       14626               US
# 299                  ny       12601               US
# 300                  mn       56425               US
# 328                  pa       19464               US
# 348                  la       70360               US
# 356                  nc       28056               US
# 377                  tx       75150               US
# 384                  ga       30144               US
# 388                  fl       34231               US
# 392                  ok       74055               US
# 408                  ca       94928               US
# 414                  oh       45251               US
# 415                  nc       27534               US
# 426                  ms       39402               US
# 444                  wi       53818               US
# 483                  pa       18052               US
# 523                  mt       59808               US
# 534                  ny       13219               US
# 536                  ca       90034               US
# 542                  va       20109               US
# 580                  wi       53142               US
# 610                  ny       10475               US
# 611                  mo       63640               US
# 613                  sd       57501               US
# 620                  oh       45245               US
# 626                  il       62901               US
# 657                  mn       56001               US
# 660                  va       24401               US
# 676                  ga       30038               US
# 727                  tx       78041               US
# 728                  nd       58201               US
#
#                                         client_address  \
# 23               1722 veterans blvd, mccomb, ms, 39648
# 27              98-107 kamehameha hwy, aiea, hi, 96701
# 32   9791 green park industrial dr, st. louis, mo, ...
# 35                     2331 hwy k, o'fallon, mo, 63368
# 38      1130 boardman poland rd, youngstown, oh, 44514
# 43             2003 n eastman rd, kingsport, tn, 37660
# 48              5503 w saginaw hwy, lansing, mi, 48917
# 52           230 gihon village, parkersburg, wv, 26101
# 61                1310 tingle cir e, mobile, al, 36606
# 63            4432 lemay ferry rd, st louis, mo, 63129
# 73              400 route 211 e, middletown, ny, 10940
# 84    101 wyoming valley mall, wilkes barre, pa, 18702
# 88          4360 w new haven ave, melbourne, fl, 32904
# 104    14250 tamiami trail north #1, naples, fl, 34110
# 106  6610 baltimore national pike, catonsville, md,...
# 135     3750 williams blvd sw, cedar rapids, ia, 52404
# 141      297 route 72 w, manahawkin, new jersey, 08050
# 142            3964 plaza blvd, gainesville, fl, 32608
# 156        1648 broadhollow rd, farmingdale, ny, 11735
# 158  5010 university town centre dr, morgantown, wv...
# 173              1418 westpark plz, ontario, or, 97914
# 178           4410 s laburnum ave, richmond, va, 23231
# 191                1821 ny-110, farmingdale, ny, 11735
# 205           4520 san bernardo ave, laredo, tx, 78041
# 229               5151 citrus blvd, harahan, la, 70123
# 239             1001 church rd, cherry hill, nj, 08034
# 241        1200 cooper point rd sw, olympia, wa, 98502
# 263          14250 smoketown rd, woodbridge, va, 22192
# 270                1165 n dupont hwy, dover, de, 19901
# 272                   2650 n main st, logan, ut, 84341
# 277              2215 memorial dr, waycross, ga, 31501
# 285  919 n lexington springmill rd, mansfield, oh, ...
# 288           1400 nw 167th st, north miami, fl, 33169
# 296              1960 w ridge rd, rochester, ny, 14626
# 299             1895 south rd, poughkeepsie, ny, 12601
# 300                 14136 baxter dr, baxter, mn, 56425
# 328         200 upland square dr, pottstown, pa, 19464
# 348  1620 martin luther king jr blvd, houma, la, 70360
# 356          3932 e franklin blvd, gastonia, nc, 28056
# 377         1330 n town east blvd, mesquite, tx, 75150
# 384  840 ernest w barrett pkwy nw, kennesaw, ga, 30144
# 388            4650 s tamiami trl, sarasota, fl, 34231
# 392           9018 n 121st east ave, owasso, ok, 74055
# 408           6001 redwood dr, rohnert park, ca, 94928
# 414           9687 colerain ave, cincinnati, oh, 45251
# 415          201 n berkeley blvd, goldsboro, nc, 27534
# 426        6143 u s highway 98, hattiesburg, ms, 39402
# 444             1525 e hwy 151, platteville, wi, 53818
# 483            2028 macarthur rd, whitehall, pa, 18052
# 523     2640 north reserve street, missoula, mt, 59808
# 534             3529 w genesee st, syracuse, ny, 13219
# 536           8985 venice blvd, los angeles, ca, 90034
# 542           7378 stream walk ln, manassas, va, 20109
# 580                  12185 77th st, kenosha, wi, 53142
# 610               340 baychester ave, bronx, ny, 10475
# 611          4850 us highway 67, farmington, mo, 63640
# 613          540 s. garfield avenue, pierre, sd, 57501
# 620          4530 eastgate blvd, cincinnati, oh, 45245
# 626  600 east walnut street eastgate shopping cente...
# 657            1621 e. madison ave, mankato, mn, 56001
# 660           81 orchard hill cir, staunton, va, 24401
# 676           2900 stonecrest cir, lithonia, ga, 30038
# 727           5203 bob bullock loop, laredo, tx, 78041
# 728     3201 32nd avenue south, grand forks, nd, 58201
#
#                                          poi_match_add  fuzzyratio  \
# 23        1722 veterans blvd ste f1, mccomb, ms, 39648        81.0
# 27           98 107 kamehameha hwy, waimalu, hi, 96701        89.0
# 32   9791 green park industrial dr, green park, mo,...        82.0
# 35                 2331 highway k, o fallon, mo, 63368        84.0
# 38        1130 boardman poland rd, boardman, oh, 44514        82.0
# 43      2003 n eastman rd ste 50, kingsport, tn, 37660        82.0
# 48              5503 w saginaw hwy, waverly, mi, 48917        84.0
# 52               230 gihon vlg, parkersburg, wv, 26101        89.0
# 61          1310 tingle cir e ste h, mobile, al, 36606        83.0
# 63           4432 lemay ferry rd, mehlville, mo, 63129        82.0
# 73           400 route 211 e, mechanicstown, ny, 10940        82.0
# 84   101 wyoming valley mall # 900, wilkes-barre, p...        85.0
# 88          4360 w new haven ave, june park, fl, 32904        86.0
# 104       14250 tamiami trl n ste 1, naples, fl, 34110        84.0
# 106  6610 baltimore national pike, woodlawn, md, 21228        82.0
# 135  3750 williams blvd sw ste 400, cedar rapids, i...        83.0
# 141              297 route 72 w, manahawkin, nj, 08050        81.0
# 142     3964 plaza blvd ste 10, gainesville, fl, 32608        82.0
# 156   1648 broadhollow rd, east farmingdale, ny, 11735        88.0
# 158  5010 university town centre dr, granville, wv,...        87.0
# 173        1418 westpark plz ste 2, ontario, or, 97914        84.0
# 178           4410 s laburnum ave, montrose, va, 23231        88.0
# 191           1821 ny 110, east farmingdale, ny, 11735        83.0
# 205    4520 san bernardo ave ste 1a, laredo, tx, 78041        82.0
# 229               5151 citrus blvd, elmwood, la, 70123        81.0
# 239        1001 church rd, cherry hill mall, nj, 08002        87.0
# 241  1200 cooper point rd sw ste 518, olympia, wa, ...        81.0
# 263           14250 smoketown rd, dale city, va, 22192        80.0
# 270          1165 n dupont hwy ste 3, dover, de, 19901        83.0
# 272                  1070 n main st, layton, ut, 84041        84.0
# 277       2215 memorial dr ste 22, waycross, ga, 31501        81.0
# 285  919 n lexington springmill rd, ontario, oh, 44906        86.0
# 288                 1400 nw 167th st, miami, fl, 33169        82.0
# 296                 1960 w ridge rd, greece, ny, 14626        82.0
# 299      1895 south rd ste 90, poughkeepsie, ny, 12601        82.0
# 300           14136 baxter dr ste 1, baxter, mn, 56401        82.0
# 328             200 upland sq dr, pottstown, pa, 19464        89.0
# 348  1620 martin luther king jr blvd, bayou cane, l...        86.0
# 356            3932 e franklin blvd, lowell, nc, 28056        82.0
# 377  1330 n town east blvd ste 300, mesquite, tx, 7...        81.0
# 384  840 ernest w barrett pkwy nw ste 400, kennesaw...        84.0
# 388      4650 s tamiami trl, south sarasota, fl, 34231        85.0
# 392   9018 n 121st east ave ste 300, owasso, ok, 74055        80.0
# 408     6001 redwood dr # 150, rohnert park, ca, 94928        85.0
# 414            9687 colerain ave, northgate, oh, 45251        82.0
# 415   201 n berkeley blvd # 211a, goldsboro, nc, 27534        83.0
# 426  6143 u s highway 98 ste 110, hattiesburg, ms, ...        81.0
# 444  1525 e business highway 151, platteville, wi, ...        84.0
# 483            2028 macarthur rd, fullerton, pa, 18052        82.0
# 523             2640 n reserve st, missoula, mt, 59808        84.0
# 534            3529 w genesee st, fairmount, ny, 13219        82.0
# 536    8985 venice blvd ste a3, los angeles, ca, 90034        82.0
# 542           7378 stream walk ln, bull run, va, 20109        82.0
# 580                  12185 77th st, bristol, wi, 53142        82.0
# 610          340 baychester ave fl 2, bronx, ny, 10475        86.0
# 611          4850 us highway 67, park hills, mo, 63640        83.0
# 613        540 s garfield ave ste a, pierre, sd, 57501        88.0
# 620  4530 eastgate blvd ste 432, cincinnati, oh, 45245        80.0
# 626  600 e. walnut st. eastgate shopping center, ca...        89.0
# 657         1621 madison ave ste c, mankato, mn, 56001        85.0
# 660           81 orchard hills cir, jolivue, va, 24401        82.0
# 676         2900 stonecrest cir, stonecrest, ga, 30038        82.0
# 727     5203 bob bullock loop # 510, laredo, tx, 78041        85.0
# 728            3201 32nd ave s, grand forks, nd, 58201        82.0
#
#                                   poi_id    poi_lat      poi_lng
# 23   sg:095fa341b02a42269a8cb8e4ea48af99  31.262958    -90.47637
# 27   sg:17fcf796b9de49179c14f6df2145fd13  21.383077  -157.946486
# 32   sg:e7629f94d7034eefa5b67bee76435c83   38.52495   -90.330832
# 35   sg:9b4714f930254bcd8db9bf06f343d03d  38.777611   -90.702335
# 38   sg:1fd4b9f322a34d3780ceee8a0b569992  41.026124   -80.633238
# 43   sg:3d2dbca0bb8c4d6688c845c223a5db64  36.543184   -82.516794
# 48   sg:d4b0572443d74f94a0857360c9bdb502   42.73826   -84.627868
# 52   sg:96d90948272b423dbb7ef3386cb9d22e  39.231562   -81.542965
# 61   sg:099f173708a245db8c2dd8dd1d69c47c  30.651478      -88.115
# 63   sg:10e401196317409eab3a1b01bc056741  38.499092   -90.331193
# 73   sg:291818c6c85549ad83c6344bab2ced7a  41.454309   -74.385056
# 84   sg:d3ea1789062d4c5db99bd6e45f486bb2  41.249902   -75.842815
# 88   sg:a7bb976d12804ae9a2f12f3c00e714fd  28.079841   -80.698891
# 104  sg:daf12001dbed48cd9e0fdca05bbc20be  26.300647   -81.802083
# 106  sg:32e49d9956a84886a79ac414d0f94850  39.287783   -76.766069
# 135  sg:2299f49a196e49a5b95f5e6ef6dee7b3  41.955596   -91.723678
# 141  sg:5dada4196adb44e49ec78ab7e9b1e121   39.69749   -74.269118
# 142  sg:cbe74c20fb47463f80599f1d73fa74ec  29.628878   -82.383402
# 156  sg:b3ab0b512b754e29acbb0b3c44c576d6  40.743879   -73.423519
# 158  sg:b93e8cc52887421590518ce2a9be71ad  39.648256   -80.003823
# 173  sg:eab91c89813b42979d07a1541d851725  44.023373  -116.984558
# 178  sg:2c7bec6ec41a4a5eb92d56456066f6f5  37.527713   -77.358668
# 191  sg:15789f67e3fa476685e33fb762edf4b2  40.745377   -73.421818
# 205  sg:04d96ae7294d4f9289bc51a1700a7401  27.541917   -99.504793
# 229  sg:662adc68968141a8834b4d3124022e01  29.966234    -90.18705
# 239  sg:3ae37fd43e054dd389c760aa64e04ee1  39.944433   -75.018775
# 241  sg:21d93c15f498451d86fe786b3196308a  47.037714  -122.938246
# 263  sg:9b300051f21e415caf10a94c92fcad83  38.639368   -77.302047
# 270  sg:325b439b22044dcd8484847bbb61711c  39.188746   -75.537214
# 272  sg:0c6d752dbc654aadbb77bf860ac5a510  41.076086  -111.980293
# 277  sg:5ca9a281a9f643e5a2085fad97e1aa37  31.199081   -82.325034
# 285  sg:19ed2c9afcfa40daa1912d3f532d41a7  40.777261   -82.593171
# 288  sg:52817b1c6f6a45279385a744d65f69fa  25.926208   -80.224302
# 296  sg:685ea0cbfec94430aba40a59ca9b64a8  43.209028   -77.679355
# 299  sg:2576031c9b994b31a6db581b4dadbf14  41.618062   -73.920137
# 300  sg:3b1fed50efce438db6de6d536cc73aeb  46.357039   -94.225514
# 328  sg:af8c1684c5ff4654831cffb21d848bcf  40.264771   -75.653304
# 348  sg:38ec9d8e32324219a09c51c9d0f4f25d  29.611515   -90.749849
# 356  sg:1acaac80b3b94ef2baa44a3a3136403f  35.258635    -81.11064
# 377  sg:7e2fc71788cd44518ce2bce9c46e21a2   32.80787   -96.615824
# 384  sg:3d291c2efaeb4fda9c6aa862aa5ff9d3  34.008517   -84.576674
# 388  sg:5aebaa5d78584e1f8eb97b5c53507435  27.286433   -82.531374
# 392  sg:46124736b46e4f40b683d4f723740b3c  36.290108    -95.84355
# 408  sg:a111ca2267e84778b887edc6ff738c63  38.351032  -122.717779
# 414  sg:5a0f13e7b21547eea28963c806b1710f  39.244413   -84.597869
# 415  sg:1daca1f38db54c61813a6546a83ea051  35.373671   -77.951112
# 426  sg:19ed6ce8755e465b8b34a5634b49682f  31.323789   -89.386268
# 444  sg:9093dfe3a44841408f098e818febc1be  42.731784   -90.452665
# 483  sg:03bb66f42e4148bfa0f53d7973fe876d  40.633706   -75.488318
# 523  sg:302e7f3ebe27474f8ecf18d93181f760  46.889476  -114.036591
# 534  sg:a206642cc41f46ccb4431fe3540be89c  43.046823   -76.232256
# 536  sg:91eb233197eb4e67b6083fc26cc76ea6  34.027957  -118.392529
# 542  sg:383c1789a66d4dd184449dee7cb6cfd4  38.796587   -77.523812
# 580  sg:7f5a44f1794c48b898e168b29f00e794  42.563776   -87.954704
# 610  sg:a2c5301fce3e4ad898c3353645616efa  40.867745   -73.828389
# 611  sg:69dc0466d6b64e748f57e764118d45ed  37.821107   -90.460611
# 613  sg:08fc5e4329ce40c88968c2fb7e4070d0  44.358815  -100.315837
# 620  sg:860221eeb7644ed293b5fd00d7788a43  39.103893   -84.271936
# 626  sg:b2d1de916866483cb75439d88f670d38  37.726608   -89.208009
# 657  sg:a0c6e228934f4da1baf75c2d0afa7813  44.166006   -93.962349
# 660  sg:1e6024d9302f45349cf27dac22b13611  38.125714   -79.067778
# 676  sg:3f166cc8940e465d9477d7114df10417  33.700224   -84.091859
# 727  sg:de15a1cd7a394056a65c9718e9746fad  27.544513   -99.449797
# 728  sg:9abff45e30f34c98aab371a297ad243e  47.887197   -97.075418

# %%
df_qc=df_all_stores[df_all_stores['fuzzyratio']>=70]
df_qc=df_qc[df_qc['fuzzyratio']<80]
print(df_qc.shape)
df_qc
# Out:
# (58, 13)
#      Store code                                      Business name  \
# 11           50                                   Ashley Homestore
# 16          NaN                   Ashley Furniture Customer Pickup
# 19          566                            Ashley HomeStore Outlet
# 31          210                                   Ashley HomeStore
# 49          NaN  Ashley HomeStore- Distribution Center/Corporat...
# 50           27                                   Ashley HomeStore
# 54          NaN                           Stoneledge Furniture LLC
# 55           38                                   Ashley HomeStore
# 75   7710000375                                   Ashley HomeStore
# 80           m7                            Ashley HomeStore Outlet
# 86   7710000156                                   Ashley HomeStore
# 105  7710000318                                   Ashley HomeStore
# 115  9000170254                                   Ashley HomeStore
# 123  9000473266                            Ashley HomeStore Outlet
# 166  7710000031                                   Ashley HomeStore
# 174  7710000060                                   Ashley HomeStore
# 177  7710000114                                   Ashley HomeStore
# 186  9000035153                                   Ashley HomeStore
# 208  7710000282                                   Ashley HomeStore
# 213         274                                   Ashley HomeStore
# 225  9000081607                                   Ashley HomeStore
# 233  7710000085                                   Ashley HomeStore
# 281  7710000380                                   Ashley HomeStore
# 289  7710000285                                   Ashley HomeStore
# 311  9000036741                                   Ashley HomeStore
# 321         m11                                   Ashley HomeStore
# 322         202                                   Ashley HomeStore
# 332  7710000023                                   Ashley HomeStore
# 335         m10                                   Ashley HomeStore
# 338  7710000004                                   Ashley HomeStore
# 370  7710000025                                   Ashley HomeStore
# 374  7710000326                                   Ashley HomeStore
# 378  7710000201                                   Ashley HomeStore
# 391          44                         Ashley HomeStore Warehouse
# 394  7710000048                                   Ashley HomeStore
# 404          71                                   Ashley HomeStore
# 421  9000187176                                   Ashley HomeStore
# 459  7710000078                                   Ashley HomeStore
# 481          88                                   Ashley HomeStore
# 498         205                                   Ashley HomeStore
# 502  9000451583                                   Ashley HomeStore
# 526         278                                   Ashley HomeStore
# 529  9000332022                                   Ashley HomeStore
# 541  7710000262                                   Ashley HomeStore
# 564  7710000537                                   Ashley HomeStore
# 572  7710000280                                   Ashley HomeStore
# 583  9000480971                            Ashley HomeStore Outlet
# 586  9000344331                                   Ashley HomeStore
# 591  7710000092                                   Ashley HomeStore
# 615  7710000457                                   Ashley HomeStore
# 635  7710000245                                   Ashley HomeStore
# 637          50                                   Ashley HomeStore
# 662  7710000491                                   Ashley HomeStore
# 675  7710000050                                   Ashley HomeStore
# 685  9000187971                                   Ashley HomeStore
# 715  7710000047                                   Ashley HomeStore
# 719  7710000206                                   Ashley HomeStore
# 723  9000130093                                   Ashley Homestore
#
#                Address line 1              Locality Administrative area  \
# 11                5029 us-130                delran                  nj
# 16     1501 east cooley drive                colton                  ca
# 19           5450 highway 153                hixson                  tn
# 31        651 n business i-35         new braunfels                  tx
# 49             12740 kenan dr          jacksonville                  fl
# 50        14101 manchester rd               ballwin                  mo
# 54           1601 e cooley dr                colton                  ca
# 55              6298 mills dr            whitestown                  in
# 75          108 harbison blvd              columbia                  sc
# 80              2800 brice rd          reynoldsburg                  oh
# 86    1711 ritchie station ct       capitol heights                  md
# 105            80 nardozzi pl          new rochelle                  ny
# 115            1540 s main st            blacksburg                  va
# 123  5267 bobby hicks highway                  gray                  tn
# 166         8915 rosedale hwy           bakersfield                  ca
# 174            2800 n main st             santa ana                  ca
# 177            3295 buford dr                buford                  ga
# 186           750 sunrise hwy         valley stream                  ny
# 208        545 route 17 south               paramus                  nj
# 213     17727 tomball parkway               houston                  tx
# 225              3900 sisk rd               modesto                  ca
# 233        4621 river city dr          jacksonville                  fl
# 281     1508b w o. ezell blvd           spartanburg                  sc
# 289               635 bay ave            toms river                  nj
# 311             3839 emery st            emeryville                  ca
# 321            2850 centre dr              fairborn                  oh
# 322        7919 pat booker rd           san antonio                  tx
# 332       100 w duval mine rd          green valley                  az
# 335         161 mall woods dr                dayton                  oh
# 338        4535 galleria blvd            birmingham                  al
# 370          3512 lockwood dr              lakeside                  az
# 374   1429 olean portville rd                 olean                  ny
# 378         801 e pulaski hwy                elkton                  md
# 391      1415 south 3200 west        salt lake city                  ut
# 394            9301 tampa ave            northridge                  ca
# 404           4936 baldwin rd        orion township                  mi
# 421              4500 16th st                moline                  il
# 459        2499 s ferdon blvd             crestview                  fl
# 481            9100 north fwy            fort worth                  tx
# 498              9900 s ih-35                austin                  tx
# 502                 590 nj 38  maple shade township                  nj
# 526                100 tx-332          lake jackson                  tx
# 529             7200 peach st                  erie                  pa
# 541    1600 45th street south                 fargo                  nd
# 564           4281 roswell rd              marietta                  ga
# 572        3730 route 1 north       north brunswick                  nj
# 583         2534 berryhill rd            montgomery                  al
# 586             2600 humes rd            janesville                  wi
# 591        3775 n federal hwy       fort lauderdale                  fl
# 615       5871 crossroads ctr          falls church                  va
# 635        6060 bayfield pkwy               concord                  nc
# 637           3625 highway 14          lake charles                  la
# 662             503 e ives st            marshfield                  wi
# 675        34740 monterey ave           palm desert                  ca
# 685  3797 osage beach parkway           osage beach                  mo
# 715         25125 madison ave              murrieta                  ca
# 719          8823 pulaski hwy             baltimore                  md
# 723           3160 28th st se          grand rapids                  mi
#
#     Postal code Country / Region  \
# 11        08075               US
# 16        92324               US
# 19        37343               US
# 31        78130               US
# 49        32258               US
# 50        63011               US
# 54        92324               US
# 55        46075               US
# 75        29212               US
# 80        43068               US
# 86        20743               US
# 105       10805               US
# 115       24060               US
# 123       37615               US
# 166       93312               US
# 174       92705               US
# 177       30519               US
# 186       11581               US
# 208       07652               US
# 213       77064               US
# 225       95356               US
# 233       32246               US
# 281       29301               US
# 289       08753               US
# 311       94608               US
# 321       45324               US
# 322       78233               US
# 332       85614               US
# 335       45449               US
# 338       35244               US
# 370       85929               US
# 374       14760               US
# 378       21921               US
# 391       84104               US
# 394       91324               US
# 404       48359               US
# 421       61265               US
# 459       32539               US
# 481       76177               US
# 498       78748               US
# 502       08052               US
# 526       77566               US
# 529       16509               US
# 541       58103               US
# 564       30062               US
# 572       08902               US
# 583       36117               US
# 586       53545               US
# 591       33308               US
# 615       22041               US
# 635       28027               US
# 637       70607               US
# 662       54449               US
# 675       92211               US
# 685       65065               US
# 715       92562               US
# 719       21237               US
# 723       49512               US
#
#                                         client_address  \
# 11                      5029 us-130, delran, nj, 08075
# 16           1501 east cooley drive, colton, ca, 92324
# 19                 5450 highway 153, hixson, tn, 37343
# 31       651 n business i-35, new braunfels, tx, 78130
# 49             12740 kenan dr, jacksonville, fl, 32258
# 50             14101 manchester rd, ballwin, mo, 63011
# 54                 1601 e cooley dr, colton, ca, 92324
# 55                6298 mills dr, whitestown, in, 46075
# 75              108 harbison blvd, columbia, sc, 29212
# 80              2800 brice rd, reynoldsburg, oh, 43068
# 86   1711 ritchie station ct, capitol heights, md, ...
# 105            80 nardozzi pl, new rochelle, ny, 10805
# 115              1540 s main st, blacksburg, va, 24060
# 123          5267 bobby hicks highway, gray, tn, 37615
# 166          8915 rosedale hwy, bakersfield, ca, 93312
# 174               2800 n main st, santa ana, ca, 92705
# 177                  3295 buford dr, buford, ga, 30519
# 186          750 sunrise hwy, valley stream, ny, 11581
# 208             545 route 17 south, paramus, nj, 07652
# 213          17727 tomball parkway, houston, tx, 77064
# 225                   3900 sisk rd, modesto, ca, 95356
# 233        4621 river city dr, jacksonville, fl, 32246
# 281      1508b w o. ezell blvd, spartanburg, sc, 29301
# 289                 635 bay ave, toms river, nj, 08753
# 311               3839 emery st, emeryville, ca, 94608
# 321                2850 centre dr, fairborn, oh, 45324
# 322         7919 pat booker rd, san antonio, tx, 78233
# 332       100 w duval mine rd, green valley, az, 85614
# 335               161 mall woods dr, dayton, oh, 45449
# 338          4535 galleria blvd, birmingham, al, 35244
# 370              3512 lockwood dr, lakeside, az, 85929
# 374          1429 olean portville rd, olean, ny, 14760
# 378               801 e pulaski hwy, elkton, md, 21921
# 391    1415 south 3200 west, salt lake city, ut, 84104
# 394              9301 tampa ave, northridge, ca, 91324
# 404         4936 baldwin rd, orion township, mi, 48359
# 421                    4500 16th st, moline, il, 61265
# 459           2499 s ferdon blvd, crestview, fl, 32539
# 481              9100 north fwy, fort worth, tx, 76177
# 498                    9900 s ih-35, austin, tx, 78748
# 502         590 nj 38, maple shade township, nj, 08052
# 526                100 tx-332, lake jackson, tx, 77566
# 529                     7200 peach st, erie, pa, 16509
# 541           1600 45th street south, fargo, nd, 58103
# 564               4281 roswell rd, marietta, ga, 30062
# 572     3730 route 1 north, north brunswick, nj, 08902
# 583           2534 berryhill rd, montgomery, al, 36117
# 586               2600 humes rd, janesville, wi, 53545
# 591     3775 n federal hwy, fort lauderdale, fl, 33308
# 615       5871 crossroads ctr, falls church, va, 22041
# 635             6060 bayfield pkwy, concord, nc, 28027
# 637           3625 highway 14, lake charles, la, 70607
# 662               503 e ives st, marshfield, wi, 54449
# 675         34740 monterey ave, palm desert, ca, 92211
# 685   3797 osage beach parkway, osage beach, mo, 65065
# 715             25125 madison ave, murrieta, ca, 92562
# 719             8823 pulaski hwy, baltimore, md, 21237
# 723           3160 28th st se, grand rapids, mi, 49512
#
#                                          poi_match_add  fuzzyratio  \
# 11            5029 us 130 suite 250, delran, nj, 08075        70.0
# 16                   855 ashley way, colton, ca, 92324        73.0
# 19            1354 highway 15 s, hutchinson, mn, 55350        71.0
# 31   651 n business ih 35 ste 110, new braunfels, t...        78.0
# 49         9317 atlantic blvd, jacksonville, fl, 32225        77.0
# 50          14101 manchester rd, manchester, mo, 63011        79.0
# 54                  1601 ashley way, colton, ca, 92324        79.0
# 55        6298 mills dr ste 400, whitestown, in, 46075        78.0
# 75                  108 harbison blvd, irmo, sc, 29212        79.0
# 80                  2800 brice rd, columbus, oh, 43068        76.0
# 86     1711 ritchie station ct, forestville, md, 20743        74.0
# 105          80 industrial ln, new rochelle, ny, 10805        77.0
# 115      1540 s main st ste 120, blacksburg, va, 24060        78.0
# 123      5267 bobby hicks hwy, johnson city, tn, 37615        73.0
# 166           8915 rosedale hwy, greenacres, ca, 93312        78.0
# 174  2800 n main st unit 2100 bldg 2810, santa ana,...        75.0
# 177          3295 buford dr ste 100, buford, ga, 30519        76.0
# 186  2034 green acres mall, south valley stream, ny...        78.0
# 208              545 n state rt 17, paramus, nj, 07652        76.0
# 213        17727 state highway 249, houston, tx, 77064        73.0
# 225           3900 sisk rd ste 300, modesto, ca, 95356        75.0
# 233      13265 city square dr, jacksonville, fl, 32218        74.0
# 281        300 w blackstock rd, spartanburg, sc, 29301        73.0
# 289        635 bay ave unit 215, toms river, nj, 08753        74.0
# 311       3839 emery st ste 300, emeryville, ca, 94608        78.0
# 321             2850 centre dr, beavercreek, oh, 45324        77.0
# 322            7919 pat booker rd, live oak, tx, 78233        77.0
# 332          100 w duval mine rd, sahuarita, az, 85614        73.0
# 335           161 mall woods dr, miamisburg, oh, 45449        75.0
# 338              4535 galleria blvd, hoover, al, 35244        76.0
# 370      3512 lockwood dr, pinetop-lakeside, az, 85929        78.0
# 374   1429 olean portville rd, weston mills, ny, 14760        76.0
# 378                  1174 pulaski hwy, bear, de, 19701        71.0
# 391            1773 s 300 w, salt lake city, ut, 84115        79.0
# 394    9301 tampa ave unit 1401, northridge, ca, 91324        73.0
# 404           4936 s baldwin rd, lake orion, mi, 48359        78.0
# 421            4500 16th st ste 600, moline, il, 61265        74.0
# 459  2499 s ferdon blvd crestview corners shopping ...        75.0
# 481      9100 north fwy ste 140, fort worth, tx, 76177        78.0
# 498      9900 s interstate 35 ste c, austin, tx, 78748        71.0
# 502                  590 nj 38, maple shade, nj, 08052        73.0
# 526     100 tx 332 suite 1095, lake jackson, tx, 77566        77.0
# 529            7200 peach st unit 300, erie, pa, 16509        70.0
# 541                   1600 45th st s, fargo, nd, 58103        75.0
# 564       4281 roswell rd ste 312, marietta, ga, 30062        78.0
# 572      3730 us highway 1, north brunswick, nj, 08902        78.0
# 583           2001 eastern blvd, montgomery, al, 36117        75.0
# 586       2600 humes rd ste 140, janesville, wi, 53545        78.0
# 591        3775 n federal hwy, oakland park, fl, 33308        77.0
# 615  5871 crossroads ctr, bailey's crossroads, va, ...        70.0
# 635          6060 bayfield pkwy, kannapolis, nc, 28027        76.0
# 637  3625 gerstner memorial blvd, lake charles, la,...        73.0
# 662       503 e ives st ste 300, marshfield, wi, 54449        78.0
# 675  34740 monterey ave desert gateway plaza, palm ...        71.0
# 685  3797 osage beach pkwy unit upper c, osage beac...        73.0
# 715     25125 madison ave ste 106, murrieta, ca, 92562        79.0
# 719          8823 pulaski hwy, middle river, md, 21237        76.0
# 723               3160 28th st se, kentwood, mi, 49512        72.0
#
#                                   poi_id    poi_lat      poi_lng
# 11   sg:dbcbd78d75dd48e6a61cde23e6d6328d   40.01792   -74.953969
# 16   sg:8566c7c414aa43bb925e8fb3d2b440e8  34.056882  -117.299505
# 19   sg:6d4967723edd4e36a159e67842e17051  44.868999   -94.378291
# 31   sg:2a85d11373f549a5bf7a7475585efbc8  29.697474    -98.10013
# 49   sg:c2f913a8c8ec4f82bafbefc776610f70  30.318829   -81.558217
# 50   sg:4f5a5f624f014031a7530809ea6c44c7  38.595628   -90.495967
# 54   sg:b655f00875fd4b60ac7088ce6424330e  34.056311  -117.301912
# 55   sg:e2c8e336f1d94518bca27e98163cd1d6  39.951626   -86.348222
# 75   sg:e10d7f8a7d6442ca95c16ed968da5e9f  34.066273   -81.168231
# 80   sg:1fc3038e1d4446e7a815130734ebe536  39.923872   -82.829138
# 86   sg:4b8339828f694bea93f4517bd264e090  38.868243   -76.854399
# 105  sg:2ba0c044e0414ead8c94e8aa1476ac54  40.897323   -73.796067
# 115  sg:6ee048f590a247d1963d1e2edea3c2c9  37.212481   -80.401131
# 123  sg:a3997a531e884281868596b9eca52352  36.414477   -82.471788
# 166  sg:12251e0549c9498b9586b383d7816063  35.382829  -119.101458
# 174  sg:6b3d8781ea1548efa613aa559bc3adef  33.774283  -117.868842
# 177  sg:aafac3bdf3f444559b3a372f887ec136  34.067964   -83.985404
# 186  sg:1f4c2732d64a44c6a1aed2014b2a8867  40.662451   -73.719303
# 208  sg:2ddfbc62e65349188d6649298b50df9a  40.957929   -74.075475
# 213  sg:68c8fcadb94c46e1b89c40fbe7e58684  29.957808   -95.548428
# 225  sg:1722e8c3ec72449c82c022bda9e0803c  37.695957  -121.065659
# 233  sg:f3f2e3d0be714cf4a38b00b0e7d48ffe  30.478605   -81.637774
# 281  sg:405363389c5a4904858711c04dba79ab  34.941092    -81.99061
# 289  sg:3f68694c8cd04280967e20402433f973   39.97546   -74.181104
# 311  sg:11e5375826414e208634d78dd83454cc  37.829039  -122.281754
# 321  sg:0c7e64a003784e4b85777d741fde7c1f  39.773165   -84.046758
# 322  sg:2e06bf442259400ca2c6a5f8af73ffc1  29.564877   -98.332058
# 332  sg:21bdd1f5dfec4ab0a0a8fccfb8839b53  31.906416  -110.989083
# 335  sg:28fe7f67ea29407b85c258ea6cd8be84  39.641698   -84.229334
# 338  sg:915935b12a62461ebe12206de4da5ce4  33.368583   -86.813204
# 370  sg:3852288425364c6492f3c4f757a28b02  34.171655  -110.006617
# 374  sg:53681ecdeee74ec8aaafba04666cbfc1  42.063781   -78.382099
# 378  sg:896db6df88204a558dedb30c155484fb  39.629303   -75.664627
# 391  sg:ae01277c7c3849289f9e1e38a68cf1e4  40.731373  -111.898985
# 394  sg:916eb9ba21654d949586e5ef620c8ae8  34.236445  -118.554397
# 404  sg:67fccd98093244659693d8ca6403e546  42.707377   -83.311109
# 421  sg:a79c67c5e8e346709627a5080e97c933  41.467188   -90.503097
# 459  sg:3a955f1036a94a8b9f332b28d20f8a68  30.734941   -86.563758
# 481  sg:0c24fa06edb840609d7c1fa2c8e56941  32.903628   -97.315003
# 498  sg:555d1750bb2e4d0f828a0ddebbc6a17f  30.158347   -97.792388
# 502  sg:60c1709ad0bd49bd91b5717e7982e6b0  39.941545   -74.969346
# 526  sg:4cad9a4d1d1149339a6218f45563e06e   29.04989   -95.457429
# 529  sg:fbf53382ff7d4023bf75064a90059ac5  42.053688   -80.089964
# 541  sg:96c29be8faa24518a21e7c306bc14763   46.85686   -96.860475
# 564  sg:d88e6dd836c242f4933b5f7f8e95b29b  33.986604   -84.424899
# 572  sg:61d49938fb844e889149e44da7590b9b  40.428399   -74.518489
# 583  sg:1404906c58e44448ad31a44473307d85  32.353395   -86.217746
# 586  sg:8c3054910e5a422681575023751784e8  42.717035   -88.990728
# 591  sg:a94b9b166d2544a8b2e6e4bd01d52d74  26.173529   -80.120033
# 615  sg:eb4e2a545b62466f9bdc02c11685e9e8  38.851799   -77.130065
# 635  sg:e252a0c444b6422b988902ffd6ba166c  35.419579   -80.676879
# 637  sg:491de914f8554c91aa9cd9ff47142064  30.190041   -93.178594
# 662  sg:05e3fba8921c49b38053bf39859ac631  44.678194   -90.161324
# 675  sg:689cef7dd6cc4d33815f444e400fbf29  33.796196  -116.384587
# 685  sg:0b73dab682dd44fbae57179bbc3abad6  38.160569    -92.60798
# 715  sg:32d4bd6b4a2c4041a8cba15f4ccdec99   33.55633   -117.20169
# 719  sg:96389a4aa8e742359868775a24942677   39.33793   -76.477933
# 723  sg:284602cd5202439fbbb7c48ce61bec37  42.911848   -85.589642

# %%
dict_POI_zip=df_POI.set_index("poi_address").to_dict()['postal_code']
df_all_stores['POI_zip']=df_all_stores['poi_match_add'].apply(lambda x: dict_POI_zip[x])
df_all_stores.head(2)
# Out:
#   Store code     Business name           Address line 1   Locality  \
# 0         40  Ashley HomeStore            19820 west rd  woodhaven
# 1         39  Ashley HomeStore  35120 central city pkwy   westland
#
#   Administrative area Postal code Country / Region  \
# 0                  mi       48183               US
# 1                  mi       48185               US
#
#                                  client_address  \
# 0           19820 west rd, woodhaven, mi, 48183
# 1  35120 central city pkwy, westland, mi, 48185
#
#                                   poi_match_add  fuzzyratio  \
# 0           19820 west rd, woodhaven, mi, 48183       100.0
# 1  35120 central city pkwy, westland, mi, 48185       100.0
#
#                                 poi_id   poi_lat     poi_lng POI_zip
# 0  sg:06159e1a322e47d8821a931e841796da  42.14252  -83.224249   48183
# 1  sg:7a521ee0a2ee49edb5d0058ca08d7924  42.34453  -83.387354   48185

# %%
df_all_stores.head(2)
# Out:
#   Store code     Business name           Address line 1   Locality  \
# 0         40  Ashley HomeStore            19820 west rd  woodhaven
# 1         39  Ashley HomeStore  35120 central city pkwy   westland
#
#   Administrative area Postal code Country / Region  \
# 0                  mi       48183               US
# 1                  mi       48185               US
#
#                                  client_address  \
# 0           19820 west rd, woodhaven, mi, 48183
# 1  35120 central city pkwy, westland, mi, 48185
#
#                                   poi_match_add  fuzzyratio  \
# 0           19820 west rd, woodhaven, mi, 48183       100.0
# 1  35120 central city pkwy, westland, mi, 48185       100.0
#
#                                 poi_id   poi_lat     poi_lng POI_zip
# 0  sg:06159e1a322e47d8821a931e841796da  42.14252  -83.224249   48183
# 1  sg:7a521ee0a2ee49edb5d0058ca08d7924  42.34453  -83.387354   48185

# %%
df_to_Google=df_all_stores[df_all_stores['POI_zip']!=df_all_stores['Postal code']]
df_to_Google=df_to_Google[df_to_Google['fuzzyratio']<80]
df_to_Google.shape
# Out:
# (22, 14)

# %%
list_addr_to_google=df_to_Google['client_address'].tolist()
df_all_stores['Google_Address']=np.nan
df_all_stores['Google_lat']=np.nan
df_all_stores['Google_lng']=np.nan

for i, row in df_all_stores.iterrows():
    search_kw=row['client_address']
    if search_kw in list_addr_to_google:
        response=gmaps.geocode(search_kw)[0]
        google_address=response['formatted_address']
        google_lat=response['geometry']['location']['lat']
        google_lng=response['geometry']['location']['lng']

        df_all_stores.loc[i,'Google_Address']=google_address
        df_all_stores.loc[i,'Google_lat']=google_lat
        df_all_stores.loc[i,'Google_lng']=google_lng

# %%
df_all_stores.head(2)
# Out:
#   Store code     Business name           Address line 1   Locality  \
# 0         40  Ashley HomeStore            19820 west rd  woodhaven
# 1         39  Ashley HomeStore  35120 central city pkwy   westland
#
#   Administrative area Postal code Country / Region  \
# 0                  mi       48183               US
# 1                  mi       48185               US
#
#                                  client_address  \
# 0           19820 west rd, woodhaven, mi, 48183
# 1  35120 central city pkwy, westland, mi, 48185
#
#                                   poi_match_add  fuzzyratio  \
# 0           19820 west rd, woodhaven, mi, 48183       100.0
# 1  35120 central city pkwy, westland, mi, 48185       100.0
#
#                                 poi_id   poi_lat     poi_lng POI_zip  \
# 0  sg:06159e1a322e47d8821a931e841796da  42.14252  -83.224249   48183
# 1  sg:7a521ee0a2ee49edb5d0058ca08d7924  42.34453  -83.387354   48185
#
#   Google_Address  Google_lat  Google_lng
# 0            NaN         NaN         NaN
# 1            NaN         NaN         NaN

# %%
df_all_stores['source']=np.where(df_all_stores['client_address'].isin(list_addr_to_google),"Google","POI")
df_all_stores['assigned_lat']=np.where(df_all_stores['client_address'].isin(list_addr_to_google),df_all_stores['Google_lat'],df_all_stores["poi_lat"])
df_all_stores['assigned_lng']=np.where(df_all_stores['client_address'].isin(list_addr_to_google),df_all_stores['Google_lng'],df_all_stores["poi_lng"])

df_all_stores.head(2)
# Out:
#   Store code     Business name           Address line 1   Locality  \
# 0         40  Ashley HomeStore            19820 west rd  woodhaven
# 1         39  Ashley HomeStore  35120 central city pkwy   westland
#
#   Administrative area Postal code Country / Region  \
# 0                  mi       48183               US
# 1                  mi       48185               US
#
#                                  client_address  \
# 0           19820 west rd, woodhaven, mi, 48183
# 1  35120 central city pkwy, westland, mi, 48185
#
#                                   poi_match_add  fuzzyratio  \
# 0           19820 west rd, woodhaven, mi, 48183       100.0
# 1  35120 central city pkwy, westland, mi, 48185       100.0
#
#                                 poi_id   poi_lat     poi_lng POI_zip  \
# 0  sg:06159e1a322e47d8821a931e841796da  42.14252  -83.224249   48183
# 1  sg:7a521ee0a2ee49edb5d0058ca08d7924  42.34453  -83.387354   48185
#
#   Google_Address  Google_lat  Google_lng source assigned_lat assigned_lng
# 0            NaN         NaN         NaN    POI     42.14252   -83.224249
# 1            NaN         NaN         NaN    POI     42.34453   -83.387354

# %%
print(df_all_stores.shape)
df_all_stores.groupby("source")['client_address'].count()
# Out:
# (662, 20)
# source
# Google     22
# POI       640
# Name: client_address, dtype: int64

# %% [markdown]
# # 2. Zips in X miles

# %%
P_radius=20
S_radius=40

df_all_stores['P_zips']=np.nan
df_all_stores['S_zips']=np.nan

for ind, row in df_all_stores.iterrows():
    store_loc=(float(row['assigned_lat']),float(row['assigned_lng']))
    list_P=[]
    list_S=[]
    for z, v in zip_centers.items():
        dist=haversine(store_loc, v, unit="mi")
        if dist<=S_radius:
            if dist<=P_radius:
                list_P.append(z)
            else:
                list_S.append(z)
    df_all_stores.loc[ind,'P_zips']=str(list_P)
    df_all_stores.loc[ind,'S_zips']=str(list_S)
df_all_stores['P_zips']=df_all_stores['P_zips'].apply(eval)
df_all_stores['S_zips']=df_all_stores['S_zips'].apply(eval)

# %%
df_all_stores
# Out:
#      Store code            Business name           Address line 1  \
# 0            40         Ashley HomeStore            19820 west rd
# 1            39         Ashley HomeStore  35120 central city pkwy
# 2    9000069082         Ashley HomeStore    1401 golden gate blvd
# 3    7710000477         Ashley HomeStore          1340 tapteal dr
# 4    7710000177         Ashley HomeStore            2534 s 9th st
# ..          ...                      ...                      ...
# 743  9000109026  Ashley HomeStore Outlet    3503 w gate city blvd
# 744  9000417563         Ashley HomeStore           6100 dobbin rd
# 745  7710000295         Ashley HomeStore         2500 n prince st
# 746  7710000063         Ashley HomeStore       3850 s mooney blvd
# 747  7710000353         Ashley HomeStore       63455 n highway 97
#
#              Locality Administrative area Postal code Country / Region  \
# 0           woodhaven                  mi       48183               US
# 1            westland                  mi       48185               US
# 2    mayfield heights                  oh       44124               US
# 3            richland                  wa       99352               US
# 4              salina                  ks       67401               US
# ..                ...                 ...         ...              ...
# 743        greensboro                  nc       27407               US
# 744          columbia                  md       21045               US
# 745            clovis                  nm       88101               US
# 746           visalia                  ca       93277               US
# 747              bend                  or       97703               US
#
#                                         client_address  \
# 0                  19820 west rd, woodhaven, mi, 48183
# 1         35120 central city pkwy, westland, mi, 48185
# 2    1401 golden gate blvd, mayfield heights, oh, 4...
# 3                 1340 tapteal dr, richland, wa, 99352
# 4                     2534 s 9th st, salina, ks, 67401
# ..                                                 ...
# 743       3503 w gate city blvd, greensboro, nc, 27407
# 744                6100 dobbin rd, columbia, md, 21045
# 745                2500 n prince st, clovis, nm, 88101
# 746             3850 s mooney blvd, visalia, ca, 93277
# 747                63455 n highway 97, bend, or, 97703
#
#                                          poi_match_add  fuzzyratio  ...  \
# 0                  19820 west rd, woodhaven, mi, 48183       100.0  ...
# 1         35120 central city pkwy, westland, mi, 48185       100.0  ...
# 2    1401 golden gate blvd, mayfield heights, oh, 4...       100.0  ...
# 3                 1340 tapteal dr, richland, wa, 99352       100.0  ...
# 4                     2534 s 9th st, salina, ks, 67401       100.0  ...
# ..                                                 ...         ...  ...
# 743       3503 w gate city blvd, greensboro, nc, 27407       100.0  ...
# 744                6100 dobbin rd, columbia, md, 21045       100.0  ...
# 745                2500 n prince st, clovis, nm, 88101       100.0  ...
# 746             3850 s mooney blvd, visalia, ca, 93277       100.0  ...
# 747                63455 n highway 97, bend, or, 97703       100.0  ...
#
#          poi_lng POI_zip Google_Address Google_lat Google_lng  source  \
# 0     -83.224249   48183            NaN        NaN        NaN     POI
# 1     -83.387354   48185            NaN        NaN        NaN     POI
# 2     -81.446989   44124            NaN        NaN        NaN     POI
# 3    -119.230554   99352            NaN        NaN        NaN     POI
# 4     -97.614512   67401            NaN        NaN        NaN     POI
# ..           ...     ...            ...        ...        ...     ...
# 743   -79.848113   27407            NaN        NaN        NaN     POI
# 744    -76.81039   21045            NaN        NaN        NaN     POI
# 745  -103.197158   88101            NaN        NaN        NaN     POI
# 746  -119.310057   93277            NaN        NaN        NaN     POI
# 747  -121.303699   97703            NaN        NaN        NaN     POI
#
#      assigned_lat assigned_lng  \
# 0        42.14252   -83.224249
# 1        42.34453   -83.387354
# 2       41.526834   -81.446989
# 3       46.232317  -119.230554
# 4       38.794549   -97.614512
# ..            ...          ...
# 743     36.038562   -79.848113
# 744     39.197906    -76.81039
# 745     34.422947  -103.197158
# 746     36.295458  -119.310057
# 747     44.100428  -121.303699
#
#                                                 P_zips  \
# 0    [48209, 48208, 48201, 48207, 48204, 48206, 481...
# 1    [48209, 48208, 48201, 48207, 48204, 48012, 480...
# 2    [44072, 44139, 44135, 44134, 44137, 44131, 441...
# 3    [99320, 99353, 99352, 99354, 99301, 99330, 993...
# 4    [67484, 67480, 67456, 67402, 67401, 67470, 674...
# ..                                                 ...
# 743  [27009, 27495, 27419, 27411, 27410, 27412, 274...
# 744  [20868, 20866, 20861, 20860, 20862, 21405, 211...
# 745  [88101, 79009, 88135, 88130, 88133, 88102, 793...
# 746  [93274, 93275, 93673, 93286, 93277, 93272, 932...
# 747  [97753, 97756, 97702, 97701, 97708, 97759, 977...
#
#                                                 S_zips
# 0    [48205, 49238, 48012, 48017, 48015, 48366, 480...
# 1    [48205, 49238, 48015, 48367, 48360, 48362, 483...
# 2    [44429, 44070, 44076, 44333, 44334, 44221, 442...
# 3    [99326, 97818, 99350, 98944, 97844, 97835, 978...
# 4    [67428, 67441, 67460, 67464, 67466, 67467, 674...
# ..                                                 ...
# 743  [24148, 27006, 27130, 27302, 27359, 27355, 270...
# 744  [21619, 20151, 20153, 20250, 20254, 17355, 214...
# 745  [79053, 88132, 79347, 88427, 88112, 88115, 881...
# 746  [93625, 93621, 93270, 93271, 93675, 93747, 937...
# 747  [97741, 97734, 97760, 97707, 97730, 97739, 97754]
#
# [662 rows x 22 columns]

# %% [markdown]
# # 3. Collapse

# %%
# Please refer to the other file "TA_creation_1st_version.ipynb"
# General steps:

'''
1. Extract store_id, location, P&S zips
2. Pair up 2 stores through iteration based on interaction of zips
3. Find out single store TA, and other combinations
4. Consider zip overlap and nearest store, continously combining stores into TA (conditions in the other script)
5. With the initial TA cores, put in others 
'''
# Out:
# '\n1. Extract store_id, location, P&S zips\n2. Pair up 2 stores through iteration based on interaction of zips\n3. Find out single store TA, and other combinations\n4. Consider zip overlap and nearest store, continously combining stores into TA (conditions in the other script)\n5. With the initial TA cores, put in others \n'

# %% [markdown]
# # 4. Summarize

# %%
# Easy, and can refer the other
