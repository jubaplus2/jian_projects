# %%
# Up to 2019-01-04

import pandas as pd
import sqlalchemy
import datetime
import os

os.getcwd()
# Out:
# '/home/jian/Projects/Big_Lots/Live_Ramp/Quarterly_Update_2020Q1'

# %%
def recursive_file_gen(root_path):
    for root, dirs, files in os.walk(root_path):
        for file in files:
            yield os.path.join(root,file)
            
BL_SQL_CONNECTION= 'mysql+pymysql://jian:JubaPlus-2017@localhost/BigLots' 
BL_engine = sqlalchemy.create_engine(
        BL_SQL_CONNECTION, 
        pool_recycle=1800
    )

# %%
pd.read_sql("show tables;",con=BL_engine)
# Out:
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
#      Tables_in_BigLots
# 0          BL_POS_Item
# 1      BL_POS_Subclass
# 2    BL_Rewards_Master
# 3       Pred_CRM_table
# 4  Pred_POS_Department

# %%
pd.read_sql("desc Pred_POS_Department;",con=BL_engine)
# Out:
#                     Field           Type Null  Key Default Extra
# 0             location_id        int(11)  YES  MUL    None
# 1          transaction_dt           date  YES  MUL    None
# 2          transaction_id    varchar(16)  YES         None
# 3      customer_id_hashed       char(64)  YES         None
# 4           department_id    varchar(16)  YES         None
# 5                   sales  decimal(10,2)  YES         None
# 6                   units        int(11)  YES         None
# 7  trans_order_since_18Q1        int(11)  YES         None

# %%
lastdate_date=datetime.date(2020,1,4)

# pd.read_sql("select max(transaction_dt) as last_date from Pred_POS_Department;",con=BL_engine)

Beginning_12_months_ago = str(lastdate_date-datetime.timedelta(days=52*7-1)) # Sunday
Beginning_18_months_ago=str(lastdate_date-datetime.timedelta(days=52*7*1.5-1)) # Sunday
Beginning_48_months_ago=str(lastdate_date-datetime.timedelta(days=52*7*4-1)) # Sunday

lastdate_str=str(lastdate_date)
print("Active Start on: "+Beginning_12_months_ago) #>=
print("Lapsed & Store_allocation Start on: "+Beginning_18_months_ago) #>=
print("Lapsed 19-48 Start on: "+Beginning_48_months_ago) #>=
# Out:
# Active Start on: 2019-01-06
# Lapsed & Store_allocation Start on: 2018-07-08
# Lapsed 19-48 Start on: 2016-01-10

# %%
df_id_list_example=pd.read_sql("select * from Pred_CRM_table limit 50;",con=BL_engine)
id_eg_1="'"+df_id_list_example['customer_id_hashed'].tolist()[11]+"'"
id_eg_1
# Out:
# "'000013ba448289fab54f20aef62fd838476da5d9ab2f10819c501ece1bc59871'"

# %%
df_qc_trans_id=pd.read_sql("select * from Pred_POS_Department where customer_id_hashed=%s;"% id_eg_1,con=BL_engine) 
df_qc_trans_id
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     165
# --> 166         result = self._query(query)
#     167         self._executed = query
#
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
# ...

# %%
df_top_store_18_POS=pd.read_sql(
"select customer_id_hashed, location_id, count(distinct concat(transaction_dt, transaction_id)) as distinct_comb_trans, \
count(disctinct trans_order_since_18Q1) as dist_trans, sum(sales) as sales from Pred_POS_Department \
gruop by customer_id_hashed, location_id \
where location_id!=6990 and customer_id_hashed is not null and transaction_dt >= %s;" % Beginning_18_months_ago
,con=BL_engine)
# Out:
#     location_id transaction_dt transaction_id  \
# 0          5137     2018-02-08           3863
# 1          5137     2018-02-08           3863
# 2          1875     2018-02-07            583
# 3          1875     2018-02-07            583
# 4           822     2018-02-09           5775
# 5           822     2018-02-09           5775
# 6           822     2018-02-09           5775
# 7          4568     2018-02-04           3624
# 8          5215     2018-02-08           6199
# 9          5215     2018-02-08           6199
# 10         5215     2018-02-08           6199
# 11         5215     2018-02-08           6199
# 12         5215     2018-02-08           6199
# 13         4393     2018-02-08           3696
# 14         4393     2018-02-08           3696
# 15         4108     2018-02-10           8126
# 16         4108     2018-02-10           8126
# 17          509     2018-02-06           9137
# 18          509     2018-02-06           9137
# ...

# %%
pd.read_sql("select * from Pred_POS_Department limit 20;",con=BL_engine)['customer_id_hashed'].unique().tolist()
# Out:
# ['0000355c755ac22a52bdcd0ff7bd29b87df5191a9c6a07442311e77abfd17073',
#  '00004d161929f36dc892fae11bff1c106d699e51daf5e0aca6c9dddfb5d74caa',
#  '00005467f85fb0c0fe7fe07ade6ae26f253557b00d85dd7c918cc184e569c68a',
#  '00005b58803e96908ce628f77ef5becbc47979a38de18d15f3a71a29bdcc77d0',
#  '0000784242afecb251c9cfe90d8d3c1246526071b87edeb661f75df8dece099b',
#  '00007ec4ed190457b3f336327cdaa39e98bb818c6ef907d7c1e5b247c9bfec48',
#  '0000a0023791cdc64bd0c39197e0865b6c69f0dca7b5c2da4ec7c4e7ddfad3ea',
#  '0000a146cfe1d87ecd92801ef984b72324a49cc5af429ed4ae261322e6d416ef',
#  '0000a4425aec2bd73e860c2e9ec7cfa662c8909cf399f045102f512702fa67c7']

# %%
pd.options.display.max_rows=100
df_check_1_id=pd.read_sql("select * from Pred_POS_Department where customer_id_hashed='00004d161929f36dc892fae11bff1c106d699e51daf5e0aca6c9dddfb5d74caa';",con=BL_engine)
df_check_1_id
# Out:
#     location_id transaction_dt transaction_id  \
# 0          1875     2018-02-07            583
# 1          1875     2018-02-07            583
# 2          1955     2018-02-17           7382
# 3          1955     2018-02-17           7382
# 4          1875     2018-03-03            543
# 5          1875     2018-03-03            543
# 6          1955     2018-04-07           9837
# 7          1955     2018-04-07           9837
# 8          1955     2018-04-07           9837
# 9          1955     2018-04-07           9837
# 10         1955     2018-04-07           9837
# 11         1955     2018-04-07           9843
# 12         1875     2018-04-14           1312
# 13         1875     2018-04-14           1312
# 14         1875     2018-04-14           1312
# 15         1955     2018-05-05            727
# 16         1955     2018-05-05            727
# 17         1955     2018-05-12           3121
# 18         1955     2018-05-12           3121
# ...

# %%
# Out:
#     location_id transaction_dt transaction_id  \
# 0          1875     2018-02-07            583
# 1          1875     2018-02-07            583
# 2          1955     2018-02-17           7382
# 3          1955     2018-02-17           7382
# 4          1875     2018-03-03            543
# ..          ...            ...            ...
# 71         1955     2019-10-26           3965
# 72         1875     2019-10-27           9727
# 73         1875     2019-10-27           9727
# 74         1955     2019-11-02           6116
# 75         1955     2019-11-02           6116
#
#                                    customer_id_hashed department_id  sales  \
# 0   00004d161929f36dc892fae11bff1c106d699e51daf5e0...           109   6.18
# 1   00004d161929f36dc892fae11bff1c106d699e51daf5e0...           120   5.82
# 2   00004d161929f36dc892fae11bff1c106d699e51daf5e0...           109   8.36
# 3   00004d161929f36dc892fae11bff1c106d699e51daf5e0...           110   3.14
# ...

# %%
pd.read_sql("show processlist;",con=BL_engine)
# Out:
#     Id  User             Host       db Command  Time     State  \
# 0  146  jian        localhost  BigLots   Sleep  3346
# 1  151  jian  localhost:46588  BigLots   Query     0  starting
#
#                Info
# 0              None
# 1  show processlist
