# %%
import pandas as pd
import os
import datetime
import numpy as np
import haversine
from google.cloud import bigquery
import glob
from fuzzywuzzy import fuzz

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/docs/merkle-gdyr-prod-9783607c77a1.json"

pd.options.display.max_columns=50

print(os.getcwd())
print(datetime.datetime.now())
# Out:
# /mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/jian/QC_store_list
# 2020-10-21 15:00:59.737483
# /home/jliang/.local/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
path_poi_data_folder="/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/"
path_brand_info="/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/brand_info/07/02/brand_info.csv"
client=bigquery.Client()

# %%
query_string='''
SELECT * from mdb.vw__installer_master as t1
left join mdb_cdl.store t2 on t1.store_num=t2.store_num;
'''
print("query: \n%s"%query_string)
df_storelist_BQ_org=client.query(query_string).result().to_dataframe()
print("df_storelist_BQ_org.shape",df_storelist_BQ_org.shape)
# Out:
# query:
#
# SELECT * from mdb.vw__installer_master as t1
# left join mdb_cdl.store t2 on t1.store_num=t2.store_num;
# /home/jliang/.local/lib/python3.7/site-packages/google/cloud/bigquery/client.py:441: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "
# df_storelist_BQ_org.shape (5872, 63)

# %%
list_cols_store_keep=['installer_store_num','store_num','installer_name','company_owned_store_ind','open_date','close_date',
                      'address_1','city','state','zip_cd','country','latitude','longitude']
df_storelist_BQ=df_storelist_BQ_org[list_cols_store_keep]

# remove closed stores
print(df_storelist_BQ.shape)
df_storelist_BQ=df_storelist_BQ[pd.isnull(df_storelist_BQ['close_date'])]
# keep coorparate only
print(df_storelist_BQ.shape)
df_storelist_BQ=df_storelist_BQ[df_storelist_BQ['company_owned_store_ind']=="Y"]
print(df_storelist_BQ.shape)

df_storelist_BQ.head(3)
# Out:
# (5872, 13)
# (4543, 13)
# (571, 13)
#     installer_store_num store_num               installer_name  \
# 2            0000908641      8641             JUST TIRES #8641
# 129          0000902356      2356             JUST TIRES #2356
# 770          0000902237      2237  GDYR AUTO SERVICE CTR #2237
#
#     company_owned_store_ind  open_date close_date              address_1  \
# 2                         Y 2015-06-25        NaT  9210 S Sepulveda Blvd
# 129                       Y 2015-08-20        NaT   4325 Glenwood Avenue
# 770                       Y 2015-10-01        NaT   5811 Atlanta Highway
#
#             city state      zip_cd country   latitude   longitude
# 2    Los Angeles    CA  90045-4805      US  33.953199 -118.395727
# 129      Raleigh    NC  27612-4532      US  35.837050  -78.675850
# 770   Montgomery    AL  36117-2109      US  32.382199  -86.198940

# %%
list_BQ_add_cols=['address_1','city','state','zip_cd','country','latitude','longitude']
for col in list_BQ_add_cols:
    df_storelist_BQ=df_storelist_BQ.rename(columns={col:col+"_BQ"})
    
df_storelist_BQ['zip_5_BQ']=df_storelist_BQ['zip_cd_BQ'].apply(lambda x: x.split("-")[0].zfill(5))
print(df_storelist_BQ['zip_5_BQ'].apply(len).unique())

for col in list_BQ_add_cols[:5]:
    df_storelist_BQ[col+"_BQ"]=df_storelist_BQ[col+"_BQ"].apply(lambda x: x.lower().strip())
print(df_storelist_BQ['country_BQ'].unique())
df_storelist_BQ['str_add_BQ']=df_storelist_BQ['address_1_BQ']+", "+df_storelist_BQ['city_BQ']+", "+df_storelist_BQ['state_BQ']+", "+df_storelist_BQ['zip_5_BQ']+", "+df_storelist_BQ['country_BQ']
df_storelist_BQ.head(5)
# Out:
# [5]
# ['us']
#     installer_store_num store_num               installer_name  \
# 2            0000908641      8641             JUST TIRES #8641
# 129          0000902356      2356             JUST TIRES #2356
# 770          0000902237      2237  GDYR AUTO SERVICE CTR #2237
# 771          0000902382      2382  GDYR AUTO SERVICE CTR #2382
# 774          0000906740      6740  GDYR AUTO SERVICE CTR #6740
#
#     company_owned_store_ind  open_date close_date                address_1_BQ  \
# 2                         Y 2015-06-25        NaT       9210 s sepulveda blvd
# 129                       Y 2015-08-20        NaT        4325 glenwood avenue
# 770                       Y 2015-10-01        NaT        5811 atlanta highway
# 771                       Y 2015-08-20        NaT   910 concord parkway north
# 774                       Y 2015-07-23        NaT  7320 north keystone avenue
#
#           city_BQ state_BQ   zip_cd_BQ country_BQ  latitude_BQ  longitude_BQ  \
# 2     los angeles       ca  90045-4805         us    33.953199   -118.395727
# 129       raleigh       nc  27612-4532         us    35.837050    -78.675850
# 770    montgomery       al  36117-2109         us    32.382199    -86.198940
# 771       concord       nc  28027-5943         us    35.424506    -80.615242
# 774  indianapolis       in  46240-3246         us    39.888791    -86.122685
#
#     zip_5_BQ                                         str_add_BQ
# 2      90045  9210 s sepulveda blvd, los angeles, ca, 90045, us
# 129    27612       4325 glenwood avenue, raleigh, nc, 27612, us
# 770    36117    5811 atlanta highway, montgomery, al, 36117, us
# 771    28027  910 concord parkway north, concord, nc, 28027, us
# 774    46240  7320 north keystone avenue, indianapolis, in, ...

# %%
# POI

df_POI_brand=pd.read_csv(path_brand_info,dtype=str)
list_GY_brand=[x for x in df_POI_brand['brand_name'].tolist() if "good" in x.lower() and "year" in x.lower()]
list_GY_brand
# Out:
# ['Goodyear Auto Service Centers',
#  'Goodyear Commercial Tire & Service Center',
#  'Goodyear Tire & Rubber Co']

# %%
list_poi_files=glob.glob(path_poi_data_folder+"*.csv*")
list_poi_files.sort()
list_poi_files
# Out:
# ['/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part1.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part10.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part11.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part2.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part3.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part4.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part5.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part6.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part7.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part8.csv.gz',
#  '/mnt/clients/juba/hqjubaapp02/sharefolder/GoodYear/POI/202010_POI/07/02/core_poi-geometry-part9.csv.gz']

# %%
df_POI_GY=pd.DataFrame()
for file in list_poi_files:
    df=pd.read_csv(file,compression="gzip",dtype=str)
    df=df[df['brands'].isin(list_GY_brand)]
    df_POI_GY=df_POI_GY.append(df)
print(df_POI_GY.shape)
print(df_POI_GY['safegraph_place_id'].nunique())
df_POI_GY.groupby("brands")['safegraph_place_id'].count().to_frame().reset_index()
# Out:
# (658, 29)
# 658
#                                       brands  safegraph_place_id
# 0              Goodyear Auto Service Centers                 464
# 1  Goodyear Commercial Tire & Service Center                 194

# %%
df_POI_GY=df_POI_GY[['safegraph_place_id','location_name','brands',
                     'street_address','city','region','postal_code','iso_country_code','latitude','longitude']]
df_POI_GY['zip_5_POI']=df_POI_GY['postal_code'].apply(lambda x: x.split("-")[0].zfill(5))
print(df_POI_GY['zip_5_POI'].apply(len).unique())

for col in ['street_address','city','region','zip_5_POI','iso_country_code']:
    df_POI_GY[col]=df_POI_GY[col].apply(lambda x: x.lower().strip())
print(df_POI_GY['iso_country_code'].unique())
df_POI_GY['str_add_POI']=df_POI_GY['street_address']+", "+df_POI_GY['city']+", "+df_POI_GY['region']+", "+df_POI_GY['zip_5_POI']+", "+df_POI_GY['iso_country_code']
df_POI_GY.head(5)
# Out:
# [5]
# ['us']
#                         safegraph_place_id                  location_name  \
# 6333   sg:b9e7806050a04aaf8125dca2dfc9f49c  Goodyear Auto Service Centers
# 7408   sg:072add95f12745469488aa871c4dee86  Goodyear Auto Service Centers
# 8983   sg:717c10aa66354be0b542557677718e59  Goodyear Auto Service Centers
# 26123  sg:1d47ef76ed434f05890c963c0840f6d7  Goodyear Auto Service Centers
# 31806  sg:9b07df2bb145457da30bf98db59f3fb7  Goodyear Auto Service Centers
#
#                               brands          street_address            city  \
# 6333   Goodyear Auto Service Centers      6411 old monroe rd    indian trail
# 7408   Goodyear Auto Service Centers  7138 s padre island dr  corpus christi
# 8983   Goodyear Auto Service Centers        1630 w alexis rd          toledo
# 26123  Goodyear Auto Service Centers      9927 atlantic blvd    jacksonville
# 31806  Goodyear Auto Service Centers      14275 collier blvd          naples
#
#       region postal_code iso_country_code   latitude   longitude zip_5_POI  \
# 6333      nc       28079               us  35.049561  -80.648456     28079
# 7408      tx       78412               us  27.694699  -97.342275     78412
# 8983      oh       43612               us  41.721714    -83.5844     43612
# 26123     fl       32225               us  30.323003  -81.541298     32225
# 31806     fl       34119               us  26.246843  -81.689046     34119
#
#                                              str_add_POI
# 6333     6411 old monroe rd, indian trail, nc, 28079, us
# 7408   7138 s padre island dr, corpus christi, tx, 78...
# 8983             1630 w alexis rd, toledo, oh, 43612, us
# 26123    9927 atlantic blvd, jacksonville, fl, 32225, us
# 31806          14275 collier blvd, naples, fl, 34119, us

# %%
dict_POI_add=df_POI_GY.set_index("safegraph_place_id").to_dict()['str_add_POI']
len(dict_POI_add)
# Out:
# 658

# %%
dict_POI_add
# Out:
# {'sg:b9e7806050a04aaf8125dca2dfc9f49c': '6411 old monroe rd, indian trail, nc, 28079, us',
#  'sg:072add95f12745469488aa871c4dee86': '7138 s padre island dr, corpus christi, tx, 78412, us',
#  'sg:717c10aa66354be0b542557677718e59': '1630 w alexis rd, toledo, oh, 43612, us',
#  'sg:1d47ef76ed434f05890c963c0840f6d7': '9927 atlantic blvd, jacksonville, fl, 32225, us',
#  'sg:9b07df2bb145457da30bf98db59f3fb7': '14275 collier blvd, naples, fl, 34119, us',
#  'sg:e48d227538de4f568502fe5225c064ee': '6820 old dominion dr, mclean, va, 22101, us',
#  'sg:2c0527b63cb54268ae4451b763dc163d': '5725 johnston st, lafayette, la, 70503, us',
#  'sg:b76fda323eba4ba7a3188d1b442cede0': '91 590 farrington highway, kapolei, hi, 96707, us',
#  'sg:486afe771e904a93a29393448fd9c852': '3815 nicols rd, eagan, mn, 55122, us',
#  'sg:aeb386808bc442898fc43f6a9fca7bf9': '1790 highway 160 w, fort mill, sc, 29708, us',
#  'sg:11ce8fba58f04291ac972925083c35f2': '3151 lincoln hwy, thorndale, pa, 19372, us',
#  'sg:5132b7e0ad124bbf990dbe141f0f13d2': '680 w ray rd, gilbert, az, 85233, us',
#  'sg:140cedd55e1944afbec9a5f9742b44fc': '155 reinhardt college pkwy, canton, ga, 30114, us',
#  'sg:0c3166c214e049c6a9d6b32f511e5f42': '6810 bardstown rd, louisville, ky, 40291, us',
#  'sg:7a8838488ccd455ca9178eeb2b973450': '1265 hamilton ave ste 100, university park, il, 60484, us',
#  'sg:44c680f386094620be3a1acf262fafe9': '1755 military rd, niagara falls, ny, 14304, us',
#  'sg:ecf61a85010040429d65a163f9446058': '11110 iraqi freedom dr, fort drum, ny, 13602, us',
#  'sg:5da124d62fa047779ae8ace154170ead': '714 s harrison st, shelbyville, in, 46176, us',
#  'sg:30a681ffab3f4d028c79d83549c1f789': '101 rockaway tpke, woodmere, ny, 11559, us',
#  'sg:5a8a4c1247a24053862071deaf58eedb': '2055 lebanon church rd, west mifflin, pa, 15122, us',
#  'sg:26a81405833a49338513188e2e465ce4': '2731 candler rd, panthersville, ga, 30034, us',
#  'sg:c5f7c90a31d5478bb6c986e4a44bc85a': '1613 shorter ave sw, rome, ga, 30165, us',
#  'sg:370aa0efaca643c3b0ec5f61d5914efa': '3514 s 27th st, milwaukee, wi, 53221, us',
#  'sg:41fac2dbbb254762a4aa6396a1c4ea0f': '2727 1st ave n, fargo, nd, 58102, us',
#  'sg:028c347036ff41d78b12bf97c5db5ebd': '5107 w saginaw hwy, waverly, mi, 48917, us',
#  'sg:584066e50e704a0c998626bf898b962b': '4411 homestead rd, houston, tx, 77028, us',
#  'sg:3fdc23d9ad6a49ba989d241cf990624a': '8460 navarre pkwy, navarre, fl, 32566, us',
#  'sg:8b3f600b3b994437b1d3e3085768c1a2': '601 college rd, greensboro, nc, 27410, us',
#  'sg:e7869ec335aa419fb1ef16a81beeca6d': '6930 walnut st, upper darby, pa, 19082, us',
#  'sg:61cb331cf69b40a0aa2bb95b1399c498': '105 jazie dr, whitemarsh island, ga, 31410, us',
#  'sg:2da883214ca84ee8b2d5a37951b5993f': '401 n lemon ave, sarasota, fl, 34236, us',
#  'sg:4a8a843586cd4b51afdccd7d7481ab77': '1303 s high school rd, indianapolis, in, 46241, us',
#  'sg:9ca8f39f67b04b12bf0c642ca759f525': '22231 interstate 35, kyle, tx, 78640, us',
#  'sg:b525be4e4e6d472d8d5ab144d4f6ecd6': '5700 e 56th ave unit i, commerce city, co, 80022, us',
#  'sg:2f189545c88e460e8f1e16cbe623b6bf': '13035 louetta rd, cypress, tx, 77429, us',
#  'sg:c429b5b2127f4facbabd6f10d4b12d0e': '3407 e cork st, kalamazoo, mi, 49001, us',
#  'sg:0cb6a4d659e54d3d924fcd29ddda66ef': '90 graham rd, cuyahoga falls, oh, 44223, us',
#  'sg:a52f2a347ef842b2baa72abb315a98f7': '515 eastern byp, richmond, ky, 40475, us',
#  'sg:d6c7bd12e60d442996c658708de6c3e7': '420 sw croix st, topeka, ks, 66611, us',
#  'sg:7d6d08a6e5ea48c5b33e3c0cea6068c0': '9180 baltimore national pike, ellicott city, md, 21042, us',
#  'sg:7e9f0a821dbe4d7c8b668c575a77c7b2': '4393 w maysfield dr, augusta, ga, 30909, us',
#  'sg:d2cfcd6dfb074561b507f7753c76d999': '462 state rd, smith mills, ma, 02747, us',
#  'sg:0bdc60108db24b5e9e4a23b7686aef24': '2950 richmond rd ste 7, lexington, ky, 40509, us',
#  'sg:15517b7b833e4384b2c5be4a711936d4': '8265 s john young pkwy, orlando, fl, 32819, us',
#  'sg:88518beec6324b78976f844ff4cd70fd': '46 wolf rd, colonie, ny, 12205, us',
#  'sg:2e118a452424458184d1814b905ca984': '3021 e 20th st, joplin, mo, 64801, us',
#  'sg:6fad7cea093643f8bfdddb97b8d5d6ab': '621 a st, greeley, co, 80631, us',
#  'sg:999fb845f846453fae2bca3977dacb2b': '4045 wilcox rd, stockton, ca, 95215, us',
#  'sg:a050681b5c554c2ebfd56c6ef435012e': '206 eastgate dr, aiken, sc, 29803, us',
#  'sg:0bf049cb9a23414ab29d6e8adb258e61': '143 thompson rd, webster, ma, 01570, us',
#  'sg:753e7416e9d448c9ae8d3f1065b00485': '113 alligood way, lebanon, tn, 37090, us',
#  'sg:cf8088e197e047d287d7ba039b439e81': '1900 old natchitoches rd, west monroe, la, 71292, us',
#  'sg:c071281fccca479488613dd7841181a3': '1240 arsenal st, watertown, ny, 13601, us',
#  'sg:5395e77e8fd5499d9b4aa232496df1da': '407 nw 75th st, gainesville, fl, 32607, us',
#  'sg:0aa69c74c1744821ac700d5165ac23f0': '3813 s dale mabry hwy, tampa, fl, 33611, us',
#  'sg:5905748bbbdf4c62bdb8fecf784ce67a': '2085 tamiami trl e, naples, fl, 34112, us',
#  'sg:46141cc3748944cdb676e61905ae4984': '678 monroeville mall, monroeville, pa, 15146, us',
#  'sg:7c1fa96ed8f848cfa29872a89892cb20': '1039 alleghany st, charlotte, nc, 28208, us',
#  'sg:a3231aeb38da466097a0956702cd9cba': '2801 brewerton rd, mattydale, ny, 13211, us',
#  'sg:01c053ae3e6b4d9bb6439f22edb79ec2': '6204 garners road, columbia, sc, 29209, us',
#  'sg:4f0f7e1da5354b028663b77af4155784': '2235 veterans memorial blvd, kenner, la, 70062, us',
#  'sg:0cdc435ca3a447318a6aff5f996ab62e': '3265 w market st ste 600, fairlawn, oh, 44333, us',
#  'sg:5f3e11ee544240fa9a90364379b979d8': '5200 johnson dr, mission, ks, 66205, us',
#  'sg:80078717d3a2434eafefb118737cf540': '114 rolling hills cir, easley, sc, 29640, us',
#  'sg:2b164a8132a147efb96a38e6941c4bfd': '17702 forest rd, forest, va, 24551, us',
#  'sg:08efebbb875a43f49690187873bef34c': '1355 main st, buffalo, ny, 14209, us',
#  'sg:6391c37df4fb4ddeb4a991218078fc0c': '1280 niagara falls blvd, tonawanda, ny, 14150, us',
#  'sg:3f29898d015840759b9f9c5d45bf14db': '12 broadway ave n, rochester, mn, 55906, us',
#  'sg:6671e55c917b46d9afdfec4514ca07ea': '13360 us highway 301 s, riverview, fl, 33578, us',
#  'sg:49dcad47733843289bac627e2df74207': '420 haywood rd, greenville, sc, 29607, us',
#  'sg:ce18d61c960b485fac688dd82ae19e53': 'box 253b, haubstadt, in, 47639, us',
#  'sg:7a6f6a23c858485e96a875020fd2c341': '681 fairview rd, simpsonville, sc, 29680, us',
#  'sg:2e3d6db14e2a4ac2b025b664869aaf76': '5949 bethelview rd, cumming, ga, 30040, us',
#  'sg:e4c532f4c912438a9c97d3b632fcaf15': '633 russell rd, lawrenceville, ga, 30043, us',
#  'sg:4583425d9ab2429f95351506f3fb5b99': '40 parsonage rd, edison, nj, 08837, us',
#  'sg:425cca6974554b588a52c724cc8fdbbe': '2841 greenbriar pkwy sw, atlanta, ga, 30331, us',
#  'sg:55248ddd1832413791abf54834c68725': '4906 arundel rd, meridian, ms, 39307, us',
#  'sg:4408e7eec39e48789e613e992fb7ba93': '14150 beach blvd, jacksonville, fl, 32250, us',
#  'sg:c128c42f92ff40efbc7d7a806afeccf8': '515 s dixie hwy, west palm beach, fl, 33401, us',
#  'sg:02a7f8d720a24286b16839b327604b84': '164 w 7th ave, eugene, or, 97401, us',
#  'sg:18e54461f83d4eee99edab3bef482306': '2615 celanese rd, rock hill, sc, 29732, us',
#  'sg:a5f7f17f1ae34f95898eef13351590e6': '1301 32nd st, kenner, la, 70065, us',
#  'sg:8b93b493a9ba484791a60ff5ba93c1ee': '2015 antonio st ste c, anthony, tx, 79821, us',
#  'sg:8d11dbbfa2ec4d1c882f71f51e38bc6b': '3605 chamblee tucker rd # road1, atlanta, ga, 30341, us',
#  'sg:0fdea20c667c43959d672541a848ca43': '70471 la 21, covington, la, 70433, us',
#  'sg:b57b7341d1474aa0a95917ace5465d84': '7620 wornall rd, kansas city, mo, 64114, us',
#  'sg:89851c6208d8448e8be893bcf2b7371c': '3807 washington rd, martinez, ga, 30907, us',
#  'sg:686bff6c2d1b458e947d8433fd0ba682': '9179 central ave, capitol heights, md, 20743, us',
#  'sg:6e271a513caa46eb8b0d7802940bc35c': '3708 s bagley ave, fresno, ca, 93725, us',
#  'sg:a27cad9a8e0e429c9c66b04ff79fc73f': '1 e nepessing st, lapeer, mi, 48446, us',
#  'sg:a602eae87e594b17ad324dbf50325c35': '1745 black river blvd n, rome, ny, 13440, us',
#  'sg:877e7cdc98174c3fba7be17c5802fe80': '9514 greenwood rd, greenwood, la, 71033, us',
#  'sg:6f49b5958e7548c6896fc444ea8fdaca': '336 n broadway, jericho, ny, 11753, us',
#  'sg:900f89c9573849eaaf96cc6e1d1c57dc': '101 n franklin st, hempstead, ny, 11550, us',
#  'sg:10cd105277294602a01fb1586259e9bd': '8105 kensington dr, waxhaw, nc, 28173, us',
#  'sg:b863049cbc7e4f048a3eb5f0175962c5': '4431 nw us highway 24, topeka, ks, 66618, us',
#  'sg:5f48b46100a248f59b7be1321c5a8702': '306 w walnut ave, dalton, ga, 30720, us',
#  'sg:5460dc562a834749adfb7ccfdf929f5a': '3928 lavista rd, tucker, ga, 30084, us',
#  'sg:a1ce1417a14d46ffae71a2cfbc678c22': '50300 woodward ave, pontiac, mi, 48342, us',
#  'sg:359122e1c244441fb6032b58c04a4c5c': '9921 w broad st, innsbrook, va, 23060, us',
#  'sg:cceb7fbf1e874cc3bbcdbcc5cc6b8ee1': '1789 us highway 80 e, abilene, tx, 79601, us',
#  'sg:cf17a65f739b4079a56978175d5c7ac0': '1405 jake alexander blvd w, salisbury, nc, 28147, us',
#  'sg:6374aa56d02b4e46ba67901f1cbfccb1': '2105 clemson rd, columbia, sc, 29229, us',
#  'sg:ef668c4cf6bc45af81dd41802cab81b3': '1459 bessemer dr, el paso, tx, 79936, us',
#  'sg:7c5e3b76b628446990b94412c495d4c2': '5406 indian head hwy, glassmanor, md, 20745, us',
#  'sg:dc2c05e0f99642858551aed371a9ec77': '11802 mines rd ste b, laredo, tx, 78045, us',
#  'sg:1dc0800746b245939e24824eb37dcc61': '12850 w dixie hwy, north miami, fl, 33161, us',
#  'sg:7b8f45b6a51645d18449184383b62cec': '6104 state route 30, greensburg, pa, 15601, us',
#  'sg:e8b7543379554ba296e4cc2701dbf9ac': '1127 north hurffville road, woodbury, nj, 08096, us',
#  'sg:13be0ae29d6a471e91a19d502299aa62': '590 n commerce st, tupelo, ms, 38804, us',
#  'sg:006f0cb090af49cba1365e76954c1397': '1809 25th ave, gulfport, ms, 39501, us',
#  'sg:a89bb2a6b6d249f39ac871ad27a8191f': '65 e sunrise hwy, freeport, ny, 11520, us',
#  'sg:8d78467a04bf43bcb0869a76822dafda': '7608 oswego rd ste 1, liverpool, ny, 13090, us',
#  'sg:57502f7aef8c489bb07fa93e4c976999': '280 us highway 202/31 n, flemington, nj, 08822, us',
#  'sg:085fd02c2f664e719dec938421547fe6': '14353 nw military hwy, san antonio, tx, 78231, us',
#  'sg:1dd213ffd5b141c7af6ca33007986ddb': '4000 durock rd, shingle springs, ca, 95682, us',
#  'sg:5599d6e8f03546f298bbc915a845eb55': '3075 e grand blvd, detroit, mi, 48202, us',
#  'sg:34648f9b4b0c43fcbf23915d136361f6': '6791 melton rd, portage, in, 46368, us',
#  'sg:441c1052acd0475894226596fcfddd01': '9411 8th ave s, boulevard park, wa, 98108, us',
#  'sg:5da4ef8a198b48d29d18af375f1c3ac7': '6880 state route 123, franklin, oh, 45005, us',
#  'sg:9483a76f2ecd421e99f1c3b3887589f2': '1099 easton ave, somerset, nj, 08873, us',
#  'sg:16c33c27d92d4a72ac2fa20b17dfbc7b': '601 n bumby ave ste a, orlando, fl, 32803, us',
#  'sg:4a6a86a6898a4f968cf309670eed040b': '11906 reisterstown rd, reisterstown, md, 21136, us',
#  'sg:5f4d688a017344b9a9e2ab480fe72203': '4455 kent rd, stow, oh, 44224, us',
#  'sg:2cfbb39719e848ddbd0223f6560fed1c': '3225 tamiami trl, punta gorda, fl, 33950, us',
#  'sg:0e6249edec71418b80b3411607b45346': '123 grey st, east aurora, ny, 14052, us',
#  'sg:60982ede15dc499d97195b9f26eb1d69': '10726 silverdale way nw ste 109, silverdale, wa, 98383, us',
#  'sg:ee1e62529d8640e185ca8ea9d3718fe1': '205 n main st, east peoria, il, 61611, us',
#  'sg:3541158384e746bc86cb863b34093e61': '3160 irving blvd, dallas, tx, 75247, us',
#  'sg:57baf0d15cd14b55b6b1ab2f1e234927': '4530 forest dr, forest acres, sc, 29206, us',
#  'sg:5b83b52c91cc4cd19564cc607bae8189': '721 montgomery hwy, vestavia hills, al, 35216, us',
#  'sg:149cca431b324689a905f467a637bc82': '5912 haase rd, deforest, wi, 53532, us',
#  'sg:871afaadc18d437c8372f5d5951e7943': '1301 roosevelt ct, whitsett, nc, 27377, us',
#  'sg:c1884577280a4c69b1293bc65baf5781': '306 market st, hartford, ct, 06120, us',
#  'sg:c2e1caa446aa449bbd7ed6aa45e4fff4': '250 mcwhirt loop, southern gateway, va, 22406, us',
#  'sg:9efa8db44ba746d5af04e25dc2cb1e9e': '105 halekuai st, kihei, hi, 96753, us',
#  'sg:6f33b5626f3644f0b97c9c260527f24e': '418 boardman canfield rd, boardman, oh, 44512, us',
#  'sg:e08d7fac78674f0485a670e70877299c': '3312 dooling st, fort worth, tx, 76111, us',
#  'sg:6b3e44381a884c0d8f7ef1d4c11265d0': '1325 massaro blvd, tampa, fl, 33619, us',
#  'sg:baf06a0f131f456086fc1531251179cb': '4201 n 23rd st, mcallen, tx, 78504, us',
#  'sg:62dd17220b084c8f8afe0feda07551f8': '3216 alton park blvd, chattanooga, tn, 37410, us',
#  'sg:68db33716b0f4024b5135f09fcc6e287': '4600 s creyts rd, lansing, mi, 48917, us',
#  'sg:f26777f170464d7b95b91f95cfb8b403': '5884 e circle dr, cicero, ny, 13039, us',
#  'sg:23a3e958499344bfa47007d469bb5ac4': '2701 airline dr ste 11, metairie, la, 70001, us',
#  'sg:503b0b8a37c8474889f45bcd758feb05': '505 patriot dr, dandridge, tn, 37725, us',
#  'sg:0800e2e3b3cb4f198a7e5957e3afb63d': '6551 winchester rd, memphis, tn, 38115, us',
#  'sg:65bebb9d611348d99217ffbbdda17139': '2998 texas ave s, college station, tx, 77845, us',
#  'sg:07a22dc437c6484db5e199bb64bde5fb': '102 old cherokee rd, lexington, sc, 29072, us',
#  'sg:d0725e21c44f4d5eb3c0ab31eb7588b1': '433 state road 930 w, new haven, in, 46774, us',
#  'sg:576d9b00d4814c5cb2a2d27f41aa6c1e': '125 s nevada ave, colorado springs, co, 80903, us',
#  'sg:c9b09001bebb4b9fa5028d4f09173dba': '114 milestone way, greenville, sc, 29615, us',
#  'sg:665de744d0f04b919bdc35b6ee28e979': '1700 veterans blvd, del rio, tx, 78840, us',
#  'sg:914a838f148b43b998f83bf3e39434b9': '1337 old freedom rd, cranberry township, pa, 16066, us',
#  'sg:6f1b5fa8960a4453a11645e9f9892975': '5785 beneva rd, south gate ridge, fl, 34233, us',
#  'sg:a4c6266b04de49d38369e78f79ed6718': '715 co op dr, van buren, ar, 72956, us',
#  'sg:78314ef3cc4b401482d305e78e5a367d': '8038 e 12 mile rd, warren, mi, 48093, us',
#  'sg:04111e1d287949a69e69c66063cd7b77': '1202 sun valley rd, robinson, tx, 76706, us',
#  'sg:620956a027a440a8953f013bd3077071': '1663 penfield rd, rochester, ny, 14625, us',
#  'sg:3bfb1e08bd1d462e845a1e11df59b19f': '999 route 9, castleton on hudson, ny, 12033, us',
#  'sg:ae02cc825fe846e7a68c1287975135f9': '2721 lackland dr, waterloo, ia, 50702, us',
#  'sg:1cdae1723ab44808b6de6642f802bc8f': '396 southland dr, lexington, ky, 40503, us',
#  'sg:9f1330dee81e4514aaca27369da6d859': '4130 dowlen rd, beaumont, tx, 77706, us',
#  'sg:98e38e30500749ad8c7de40cb0d2b179': '2264 w 4th st, ontario, oh, 44906, us',
#  'sg:54a4bae39e0d4236bddfd790ee7cd1c8': '7128 transit rd, buffalo, ny, 14221, us',
#  'sg:244ff59ba964486fa3f8bd696eea23d3': '3594 state route 31, baldwinsville, ny, 13027, us',
#  'sg:2e0f68f856704096815b3c90aa221916': '40 girvin rd, jacksonville, fl, 32225, us',
#  'sg:4281594fec50478cb031bb327cc8f58a': '1611 wicomico st, baltimore, md, 21230, us',
#  'sg:3ac165287aa6459b9eebff67a71854a1': '3651 belmont ave, youngstown, oh, 44505, us',
#  'sg:25b1e8aacce940f7a75c131df5a87bcd': '131 gateway cir, jacksonville, fl, 32259, us',
#  'sg:25a6a06fff6047a4a36c1f9d6374b4c5': '11021 northcliffe blvd, spring hill, fl, 34608, us',
#  'sg:c8d6d8ed6fb641a290bbdf2cf7a437d5': '1818 collins blvd, covington, la, 70433, us',
#  'sg:7087a1c406bc4159a27c69cf986e4a1d': '3156 bladensburg rd ne, washington, dc, 20018, us',
#  'sg:6ab9c53aa88c4126bdb8eaeee299e1f6': '1102 walker st, walcott, ia, 52773, us',
#  'sg:55cf118af26d4167bf80fe55806d1f4b': '8415 old statesville rd, charlotte, nc, 28269, us',
#  'sg:3408c3254ae04e94abdffe155dd6d476': '12902 w indian school rd, litchfield park, az, 85340, us',
#  'sg:252b4b84622645f0b2b8053efc0d4e5f': '5154 charlotte hwy, lake wylie, sc, 29710, us',
#  'sg:51b4dc9b60f74c9f8999d0eb37bcccaa': '1503 bienville blvd, ocean springs, ms, 39564, us',
#  'sg:15fca8847e4b48948a967d8decf6c191': '368 e main st, east patchogue, ny, 11772, us',
#  'sg:1e44edfc82bc4177806bc1cd349c2a7c': '675 skymarks dr, jacksonville, fl, 32218, us',
#  'sg:52e69cd257ab4c899d36a719c35506f3': '2001 parkway dr, west bend, wi, 53095, us',
#  'sg:7ac473e03575405493053a59230d8d31': '4510 salt lake blvd, halawa, hi, 96818, us',
#  'sg:0d0b92d393bf4de5aa66d5086511ac30': '20110 w catawba ave, cornelius, nc, 28031, us',
#  'sg:3a4f7419369244279e890530385dfa40': '8590 concord mills blvd, concord, nc, 28027, us',
#  'sg:4af0b14fa82f44258d9172d913307424': '6616 lonetree blvd, rocklin, ca, 95765, us',
#  'sg:44e276d88faa41bfa42328c8d2cf28f7': '20 traders way, pooler, ga, 31322, us',
#  'sg:79356b93edb94146b2512bc9e87307eb': '2518 deans bridge rd, augusta, ga, 30906, us',
#  'sg:0c8ccc3d780a49f0ad357e4c2f08cb49': '11957 douglas pkwy, urbandale, ia, 50323, us',
#  'sg:cefa3af5845547fb98328e6bd76d0bd9': '1151 mae st, hershey, pa, 17036, us',
#  'sg:39283bc077a24cb0bc60c64c8f048e4c': '411 elmira rd, ithaca, ny, 14850, us',
#  'sg:8665125f6c644ec49d3bc4f4ae81ab90': '15498 e 14th st, ashland, ca, 94578, us',
#  'sg:51e469a2020048c0adab0c7ec33d0ca0': '124 e spring st, columbus, oh, 43215, us',
#  'sg:24390e007ecf4408bea4e1e212843272': '100 peachtree industrial blvd, sugar hill, ga, 30518, us',
#  'sg:3478ca965d7041a6b3d2b469c3666118': '1255 w cardinal dr, beaumont, tx, 77705, us',
#  'sg:6f2742fe66454c65b853fffa3b70c6ca': '2539 burr st, gary, in, 46406, us',
#  'sg:0cdefde651af4cbfb23bc7ed8e616055': '2930 allied st, green bay, wi, 54304, us',
#  'sg:7524bd955be54356b76b45a66286844f': '1810 highway 3 s, league city, tx, 77573, us',
#  'sg:8bdffe42322e47af879a1cb763684521': '2699 ne 52nd ter, kansas city, mo, 64119, us',
#  'sg:9df2e7ad06e84b09bbfbf91e0ab15161': '271 pilot ln, brunswick, ga, 31523, us',
#  'sg:6a524ca543e945b58b21c33903d6b58a': '4126 chef menteur hwy, new orleans, la, 70126, us',
#  'sg:3790361d458f47fb997c73588cc3fecf': '2585 pass rd, biloxi, ms, 39531, us',
#  'sg:9309852e53f54668ac25b77b6c719798': '1002 n westgate dr, weslaco, tx, 78596, us',
#  'sg:1c8f5f8327f54d00a653b8260919ecb9': '27342 wesley chapel blvd, wesley chapel, fl, 33544, us',
#  'sg:6d4a21f73a0249ecb32bba4fb0d50487': '5100 piper station dr, charlotte, nc, 28277, us',
#  'sg:1d5fe08fcbb64913b91fdf5baac766dc': '3515 w union hills dr ste 100, glendale, az, 85308, us',
#  'sg:009e6c94af474d898d9af2e7eed2b5ab': '8100 pembroke oak grove rd, oak grove, ky, 42262, us',
#  'sg:1681c39613cf41e2b545cce7ebc62e46': '94 822 moloalo st, waipahu, hi, 96797, us',
#  'sg:747b71d7e97049b8b127a818fcceefae': '2522 s gallatin st, jackson, ms, 39204, us',
#  'sg:840179bff130424fbaa14f6ecda079c6': '2021 swift ave, north kansas city, mo, 64116, us',
#  'sg:e014ec181c96425dab6f2319a5bd6247': '300 busse rd, elk grove village, il, 60007, us',
#  'sg:2a31ec24ee654809b96890652e00499b': '1585 island ln ste a, fleming island, fl, 32003, us',
#  'sg:66dd37e5d87c4822b6759adb01ef9c8f': '6601 everhart rd ste a1, corpus christi, tx, 78413, us',
#  'sg:1b202c7674294d5e976b21382f2b6ce0': '8922 elk grove blvd, elk grove, ca, 95624, us',
#  'sg:4e7f2e78ca684ee295747a97ab65ff86': '4 timber ct, bolingbrook, il, 60440, us',
#  'sg:58ba2c1e07674b4c81c49a6992c17a40': '6501 n expressway 281 unit e, edinburg, tx, 78542, us',
#  'sg:8e07cbd931824871a8cabadaa7c30bc2': '3108 n stone ave, colorado springs, co, 80907, us',
#  'sg:84eec691d7564bc7b8ded1edaca8c18c': '1010 black horse pike, pleasantville, nj, 08232, us',
#  'sg:e60fa38e8abe4a0981576e18b6fd6a51': '2453 s highway 14, greer, sc, 29650, us',
#  'sg:7e2aa32ba08d41658e83248313845c46': '3013 w 66th st, richfield, mn, 55423, us',
#  'sg:68564338fba34974b08c4aee1549a3c9': '1093 central ave, clark, nj, 07066, us',
#  'sg:c93a55401da14f6090994ca8a9329c49': '8893 three flags ave, hesperia, ca, 92344, us',
#  'sg:e40c71a9594745fd86efe4b7793139a5': '28581 dequindre rd, madison heights, mi, 48071, us',
#  'sg:005ef6b86ce644e4ab6b41f60d75634c': '10927 barker cypress rd, cypress, tx, 77433, us',
#  'sg:214abb56d0154d09a4c52fff3dc94f0a': '7635 e arapahoe rd, centennial, co, 80112, us',
#  'sg:1ff14ab90ba7470a81403545a21023d9': '297 w meighan blvd, gadsden, al, 35901, us',
#  'sg:25c7bac1e9694c04be228e2c843afce6': '100 maxcy plaza cir, haines city, fl, 33844, us',
#  'sg:5b20893e842d4c9d95f83aa08a0741c3': '901 nw 31st ave, lauderhill, fl, 33311, us',
#  'sg:a4d4cb0bf6f04f1b8c1086a3a45399a2': '86 s main st, concord, nh, 03301, us',
#  'sg:4b929698f839402a9a47c8b3e47af2ba': '2948 center rd, brunswick, oh, 44212, us',
#  'sg:1ba89ae4df6840ceb4b139e97e53cce6': '145 great oaks trl, wadsworth, oh, 44281, us',
#  'sg:78deabbf5fd446b0be6d4f25bcb47e30': '11601 47th st n, clearwater, fl, 33762, us',
#  'sg:1339143781c646fb8d4ebd8926fc711d': '9738 san jose blvd, jacksonville, fl, 32257, us',
#  'sg:6f54e5bfa7b242dc82ff2ddc95336273': '3085 w capitol ave, west sacramento, ca, 95691, us',
#  'sg:02cc278ed6d249ff943a68481a2491b9': '1570 state rt 23, butler, nj, 07405, us',
#  'sg:0824b0aee91e42ba86da6417e0b84878': '450 lane ave n, jacksonville, fl, 32254, us',
#  'sg:796eb498a96c4b768bfaaa3bc219843d': '755 21st st, vero beach, fl, 32960, us',
#  'sg:79f6aa8d7a294ca89fc958640d79c3db': '1825 ne argyle st, portland, or, 97211, us',
#  'sg:8bcc4ceeb54f412cba273c26da76995f': '307 w coal ave, gallup, nm, 87301, us',
#  'sg:56e05798b4214b27a954ad055b115d78': '3209 kirby dr, pearland, tx, 77584, us',
#  'sg:9a85467e36c24656ac5bb91fcf80b39c': '701 state highway 80, matthews, mo, 63867, us',
#  'sg:3261de822c8847e2ba94ac89b1d8b859': '8011 bandera rd, san antonio, tx, 78250, us',
#  'sg:378e588f6a30483799f7497598843a95': '456 main st, stoneham, ma, 02180, us',
#  'sg:176b4fa05f8e4748849119ebde1f4cdd': '233 glendale rd, shoal creek drive, mo, 64804, us',
#  'sg:1e5e65a6ebbc48fdb0e0d491fc84b9fc': '11800 san jose blvd, jacksonville, fl, 32223, us',
#  'sg:2af2b8e9ee4b45ddae7aa63e4a830692': '620 w main st, tupelo, ms, 38804, us',
#  'sg:32d8fe36fd3e439da33f3e280a061662': '4358 s state road 7, lake worth, fl, 33449, us',
#  'sg:39829a404070415da68e1a93eae69617': '512 w geoffrey st, saint augustine, fl, 32086, us',
#  'sg:6903d05a53be4cbea175779eb4e6764d': '1108 marlton pike e, kingston estates, nj, 08034, us',
#  'sg:feb0d109640d43529f16ce38f81faa91': '410 s morgan rd, oklahoma city, ok, 73128, us',
#  'sg:2f8f5dc1bf5747dd846e45b08ef66d15': '971 w taft vineland rd, orlando, fl, 32824, us',
#  'sg:0a7f6f5af020425289b98cf826be6356': '1501 richmond rd, williamsburg, va, 23185, us',
#  'sg:1de9eb34505c42d588c1911eb94f3fe2': '1056 john sims pkwy e, niceville, fl, 32578, us',
#  'sg:6437cd3f83344ba2b3623c632252a8ca': '86 120 farrington hwy ste k, waianae, hi, 96792, us',
#  'sg:59a898be14b6430a8a40aba4ed420519': '12882 brown bridge rd, covington, ga, 30016, us',
#  'sg:b7e2a22487de47649120fd282f9f5e27': '7991 us highway 51 n, millington, tn, 38053, us',
#  'sg:31bfcd94278a4e268a8d614b07a6ec76': '95 390 kuahelani ave, mililani town, hi, 96789, us',
#  'sg:67a92a20318f40f9bae0cca152711159': '295 middle country rd, coram, ny, 11727, us',
#  'sg:4ab184f8aa7f42c599debde4e425f546': '604 w state route 92, kearney, mo, 64060, us',
#  'sg:7fbfcb2141244edd8d13b31a85caf6a5': '132 maple st, carrollton, ga, 30117, us',
#  'sg:7a1d591c1e33483881ebecd9ce0952eb': '907 e 41st st, austin, tx, 78751, us',
#  'sg:2822fb0fd9584314894d8b5befc092ca': '10089 brook rd, glen allen, va, 23059, us',
#  'sg:b136e3bd9f7c420c8765de6b4ef6289a': '5470 pacific st, rocklin, ca, 95677, us',
#  'sg:7f1994a8d3044da9b3d1bbb96b5ad606': '5071 s jellison way, littleton, co, 80123, us',
#  'sg:ae5e6ab2a2034a3e857a3c7ac6798526': '1920 58th ave, vero beach, fl, 32966, us',
#  'sg:99d58bf72b884d008947d10ea96e155b': '185 interstate ave, russellville, ar, 72802, us',
#  'sg:37e5245170e343d1866c4efb0b8cbd0d': '904 e tarpon ave, tarpon springs, fl, 34689, us',
#  'sg:76d7e96e332e482bb31fef508fcccdd3': '1982 n highland ave, jackson, tn, 38305, us',
#  'sg:3c28eff56472464e82b9ceb5ec5200d2': '527 vauxhall st, new london, ct, 06320, us',
#  'sg:05e0263b223d4cc4a2944cf403b9b210': '1060 s havana st, aurora, co, 80012, us',
#  'sg:3b3c8f9ba70844bfa545498560eb3851': '1024 silas deane hwy, wethersfield, ct, 06109, us',
#  'sg:0dcd82d0524b438085d8a2415292ed6b': '16006 state road 54, odessa, fl, 33556, us',
#  'sg:5028189752dc40438246322646e1258d': '6130 n port washington rd, glendale, wi, 53217, us',
#  'sg:488c4eeec8284493b0febf35536e43e4': '15 burnett blvd, poughkeepsie, ny, 12603, us',
#  'sg:7b5a4b22f98541259f98894008e8d2d7': '2670 w 68th st, hialeah, fl, 33016, us',
#  'sg:293fef8290b34070a4944ad77cef4af7': '2260 w stadium blvd, ann arbor, mi, 48103, us',
#  'sg:02524f8784dc4db4954564a518f6a6f2': '2930 county rd 500 n., whiteland, in, 46184, us',
#  'sg:57f648c6f13a460f9bf8510b78dcb604': '501 portea cir, pine bluff, ar, 71601, us',
#  'sg:5c5cab99ac274b60a24fc01933dd7f12': '2101 s hiatus rd, miramar, fl, 33025, us',
#  'sg:2e10ff87310143c896929d77c5723ed1': '4 industrial park rd w, oxford, ma, 01540, us',
#  'sg:60f53c0493ff449ea03bcc11c1b878d3': '615 22nd ave s, meridian, ms, 39301, us',
#  'sg:ad54d096fbc94524b1293382c939620b': '20 denison pkwy e, corning, ny, 14830, us',
#  'sg:a20dcb1058d34f098376405c4a307e72': '2007 n broadway, denver, co, 80205, us',
#  'sg:10999a1417bf432e818360b377cbb134': '15751 los gatos blvd, los gatos, ca, 95032, us',
#  'sg:2af9977c2daa47a79c19fdb3f9f9c6c5': '4580 w broad st, lincoln village, oh, 43228, us',
#  'sg:56f5c789598b444bb713f8e8d9c46b5a': '10 ginn rd, scarborough, me, 04074, us',
#  'sg:6db46dd679e74531aa88da278c2b3205': '408 n main st, mauldin, sc, 29662, us',
#  'sg:0902956978b24de6a5233e8331701e17': '635 carrollton st, temple, ga, 30179, us',
#  'sg:59cb0272d8a7457682d7f3236b09bcad': '3007 north 31 st ave, phoenix, az, 85017, us',
#  'sg:80eb265ef118492ebba626cdc757c10f': '17226 s golden rd, golden, co, 80401, us',
#  'sg:b0cf5f3ebcf04dcc92b904ce6b9b1e39': '2906 e napoleon st, sulphur, la, 70663, us',
#  'sg:221b404014ba4dbb99eb90748f46ffe8': '3481 cattlemen rd, sarasota, fl, 34232, us',
#  'sg:0b2732ec4d954f519af9c32bdd3d6a82': '3773 e washington ave, madison, wi, 53704, us',
#  'sg:5cd35dc033fe49ccae77769cee224cc5': '3063 3091 bellbrook dr, memphis, tn, 38116, us',
#  'sg:5e91e63af936498c89de862c424f0af4': '302 s mckenzie st, foley, al, 36535, us',
#  'sg:07bfb01db70845fa91d6c4c1959a6041': '8667 philadelphia rd, rossville, md, 21237, us',
#  'sg:35005cf48a894188812cc41da7c8ebda': '5535 red bug lake rd, winter springs, fl, 32708, us',
#  'sg:5767aee2fb954c40b3fad22945208296': '5601 bosque blvd, waco, tx, 76710, us',
#  'sg:11647543f3d24ab4b198c7aaf6ef08c1': '2802 johnston st, lafayette, la, 70503, us',
#  'sg:579b4bf1dd4e4d4f8aacb34b16e9008f': '4699 volunteer rd, davie, fl, 33330, us',
#  'sg:3de4b55234d74454b12ef3708b0c99a2': '10885 n oracle rd, oro valley, az, 85737, us',
#  'sg:b619d351036b48188c2cba1da47553ee': '3101 pacific hwy e, fife, wa, 98424, us',
#  'sg:a38e5e4a78e84a6a8a9f73f88a8cbbe0': '6411 e 82nd st, indianapolis, in, 46250, us',
#  'sg:b1815d526837425397166e19b35bf505': '7036 highway 72 w, huntsville, al, 35806, us',
#  'sg:142292b9c946442a87c81736f865238f': '1200 route 112, coram, ny, 11776, us',
#  'sg:8d29db3aeb8242b39c404508b62ce924': '4512 maplecrest rd, fort wayne, in, 46835, us',
#  'sg:b36c2ba3eadf4a6ca32e92d7317da8c2': '1350 w indiantown rd, jupiter, fl, 33458, us',
#  'sg:1dbd5b09bba34a98947bd908a98c372c': '1887 fort campbell blvd, clarksville, tn, 37042, us',
#  'sg:4bb99b53035b40cbac0ef7c53de70da6': '148 s kennedy dr, bradley, il, 60915, us',
#  'sg:5c54bafcb82d4a65ad5c7425132c0b34': '2100 n expressway, brownsville, tx, 78521, us',
#  'sg:466c98b75acf429eac85e390e61e9eed': '101 barrel landing rd, bluffton, sc, 29909, us',
#  'sg:67dee841c62c4e8782c9887491d4df52': '2825 hollywood blvd, hollywood, fl, 33020, us',
#  'sg:794b833469114d3e8e56c07adb9b4029': '3181 hempstead tpke, levittown, ny, 11756, us',
#  'sg:4e60cf41e8214a2b840d382abbcfcd76': '2703 fairfax trfy, kansas city, ks, 66115, us',
#  'sg:70615ad0dde943cfa4d257912ff98f4b': '3838 s jog rd, greenacres, fl, 33467, us',
#  'sg:b0e039b2395b439c8e5ac67b480b9939': '1200 union ave, memphis, tn, 38104, us',
#  'sg:030cebc29703431e89d3c720b21d8df7': '863 n us highway 441, lady lake, fl, 32159, us',
#  'sg:8df5f2ae05dd4797aa39b142bd03fd4c': '1031 buenaventura blvd, kissimmee, fl, 34743, us',
#  'sg:e6409ba3bbf5420fa7f8314ca27ff310': '415 e main st, beaverdam, oh, 45808, us',
#  'sg:0bb487af91b544488e955235fd56860f': '1950 w edgewood ave, indianapolis, in, 46217, us',
#  'sg:8909640d83d049f7add2c09109df98ce': '3725 e loop dr, longview, tx, 75602, us',
#  'sg:8f285af3e17841338c96e0d54cd7a1c0': '1121 i st, sacramento, ca, 95814, us',
#  'sg:bad082d0f6374618942b31eb0a31b844': '293 main st, nashua, nh, 03060, us',
#  'sg:086886154ad2410daace2db1a615d288': '300 w beauregard ave, san angelo, tx, 76903, us',
#  'sg:161a61af9a014e2e9a7db32028c81db0': '2537 stuart ave, albany, ga, 31707, us',
#  'sg:19ac16baa70b41da841b68a164c76e18': '627 n delaware st, indianapolis, in, 46204, us',
#  'sg:eb37ea6d2e5b46b58a83b8b6960ad328': '2280 cook dr, doraville, ga, 30340, us',
#  'sg:6953a1d84bdf4f5089f2728460495740': '29444 woodward ave, royal oak, mi, 48073, us',
#  'sg:39116c999d4f44eab1875673e0af6b52': '16701 van dam rd, south holland, il, 60473, us',
#  'sg:3ea16adca27345ec94800a894d57acbd': '315 e innes st, salisbury, nc, 28144, us',
#  'sg:88c20467884c4e95b152740021cab5af': '1009 new britain ave, west hartford, ct, 06110, us',
#  'sg:55f71fc09fba4bac90bfdd4fe4ebde2a': '7680 103rd st, jacksonville, fl, 32210, us',
#  'sg:880762f3078b4f9ca8c1bc26e904e668': '724 main st, keokuk, ia, 52632, us',
#  'sg:02eac38c855e4325b01760261c46039d': '816 s saint marys st, san antonio, tx, 78205, us',
#  'sg:3856d22b52984dce9b2b5d088af0c834': '3001 hayneville rd, montgomery, al, 36108, us',
#  'sg:7da22a3d529a4f7d8cc8482acad45842': '1157 turnpike st, stoughton, ma, 02072, us',
#  'sg:c813a56c5f534a888d14e1b39b0c5a59': '1625 n missouri st, west memphis, ar, 72301, us',
#  'sg:76eb42e535074c019f77fb1fd95b7e08': '608 e washington ave, madison, wi, 53703, us',
#  'sg:4578ac4451d34123b2c59257a8516597': '645 main st, brookfield, wi, 53005, us',
#  'sg:22f8f35a34a541f99031187f9b398d99': '149 greenbag rd, morgantown, wv, 26501, us',
#  'sg:7c103daf0bd14fc780dc91af834b9336': '199 parris island gtwy, beaufort, sc, 29906, us',
#  'sg:0e0027e1bab94b188f7c999da33309dc': '3310 n holland sylvania rd, toledo, oh, 43615, us',
#  'sg:02e758bdf9284f5d9cb6f6e8903e8543': '7201 w alameda ave, lakewood, co, 80226, us',
#  'sg:126d006f7cc944088d1223fa0194f838': '11245 old 2243 west, leander, tx, 78641, us',
#  'sg:3f5610f49ad146b7a61bef9c02b321be': '3011 waialae ave, honolulu, hi, 96816, us',
#  'sg:1c0e59dfc11a4335bea6cff30ece4c24': '220 w gray st, elmira, ny, 14901, us',
#  'sg:1cb0104cb2d64629bfd44d2d16bc9a42': '9001 s dixie hwy, pinecrest, fl, 33156, us',
#  'sg:8d46f8c06f8c424e8f4981160c13ac08': '3136 erie blvd e, syracuse, ny, 13214, us',
#  'sg:0dc0bc69e6714ee08dbc25be4916c7d0': '95 town center pkwy, slidell, la, 70458, us',
#  'sg:b17cd4d9a5af431cb94bb8a00c0ed581': '107 s 111th east ave, tulsa, ok, 74128, us',
#  'sg:316a90b0ff8d48429e448f33969805b9': '3455 moreland ave, conley, ga, 30288, us',
#  'sg:0f8b06b58653442081cbf0692acf6b60': '410 oberlin ave sw, massillon, oh, 44647, us',
#  'sg:350893f1d5c64a4a875f48c5aac158fc': '8915 n knoxville ave, peoria, il, 61615, us',
#  'sg:d5f5ab4ae60c46bcbd89cd0fbce3db72': '101 e western ave, goodyear, az, 85338, us',
#  'sg:53303f9e2c6b45d8b81abaf8c23a28f0': '1120 sw 12th st, ocala, fl, 34471, us',
#  'sg:6668920b8a61472ea4397a8c8dc36e0c': '39 kinderkamack rd, westwood, nj, 07675, us',
#  'sg:22cf4c6564f74ccf964e81b1af79c8e6': '2407 wade hampton blvd, wade hampton, sc, 29615, us',
#  'sg:1510c60d732e45d6b566b762b0ad5f69': '502 w broad ave, albany, ga, 31701, us',
#  'sg:aeeb11de84e44b26834320be91d74abd': '9345 s 13th st, oak creek, wi, 53154, us',
#  'sg:cee61c26567545ca88454a39ef9a50ab': '555 highway 80 e, pearl, ms, 39208, us',
#  'sg:963c9b9b02854ac0bbf0ce4c8043325e': '5917 e 32nd st, joplin, mo, 64804, us',
#  'sg:e40e39f3bb44437a8784249dc052d56e': '1150 4th ave, huntington, wv, 25701, us',
#  'sg:4f2b60e70e3b41e0ab7df1ff5a1f0946': '800 fort duquesne blvd ste 1, pittsburgh, pa, 15222, us',
#  'sg:08dc8f58cb83446fb572b98316ddaef9': '9352 state road 16, onalaska, wi, 54650, us',
#  'sg:1b72764b27764bd586a0742cf50741ca': '3004 emmorton rd, bel air south, md, 21009, us',
#  'sg:02961f24490e48a6ae7aa509e912d7d5': '261 highway 35, eatontown, nj, 07724, us',
#  'sg:6f195194648e43b4bf15a9b5eb056402': '2604 s us highway 1, fort pierce, fl, 34982, us',
#  'sg:0a94eb0c5a94456c9da29b3c834a838e': '350 kamehameha hwy, pearl city, hi, 96782, us',
#  'sg:123821b4461248b6a7e0959b409d1371': '4115 e bay dr, clearwater, fl, 33764, us',
#  'sg:5e336fbc9415487fb5b2f5635da815d3': '20 mack walters rd, shelbyville, ky, 40065, us',
#  'sg:bdf2f75503cd46328c06f16b1fc2e9c3': '1480 canton mart rd, jackson, ms, 39211, us',
#  'sg:0c987e1eff5e497eba037ddb469022ac': '1815 w oregon ave, philadelphia, pa, 19145, us',
#  'sg:3f83f056d9094be28a1afa944b31da3d': '1203 saint patrick st, thibodaux, la, 70301, us',
#  'sg:4bdbb86f05f24daa8783f519841488fe': '4593 san juan ave, jacksonville, fl, 32210, us',
#  'sg:5e863ada2f9348d39c82dfd711a11ac6': '5407 highway 153, chattanooga, tn, 37343, us',
#  'sg:4d768c6ce85c4ef6999bbd3ff4abf3ea': '1020 silas deane hwy, wethersfield, ct, 06109, us',
#  'sg:d7fed26b037c4751bd59bc6a28ee15aa': '1352 trollingwood hawflds rd, mebane, nc, 27302, us',
#  'sg:c5bd43c953b548b481584702379af132': '409 w market st, lima, oh, 45801, us',
#  'sg:0cf94be8ce084a07a54b9deff343f8d4': '3938 powell rd, powell, oh, 43065, us',
#  'sg:714de6cfdd6f40518329490f5350b7d1': '8501 peterbilt blvd, dallas, tx, 75241, us',
#  'sg:03fe235eaae6495f9a6b7385290a2adc': '102 triport rd, georgetown, ky, 40324, us',
#  'sg:6767d765751e46ae8785cb130fdc5e2d': '981 grafton st, worcester, ma, 01604, us',
#  'sg:f4c4f2f6fec34382a78b29fda59627d2': '922 ulrich ave, louisville, ky, 40219, us',
#  'sg:7c57f25dd04e4d869ff77a75695ba2f3': '1320 union ave ne, renton, wa, 98059, us',
#  'sg:0ad31c8d48d74be68241991e41bb83f7': '740 s broad st, brooksville, fl, 34601, us',
#  'sg:7100b1abf1d9490d99410f0204d31f9d': '1527 middle country rd, centereach, ny, 11720, us',
#  'sg:12bd33f03ac5469d978c7f1c189d0ea5': '4106 coldwater rd, fort wayne, in, 46805, us',
#  'sg:2c42e1ce22dc4d4d9bca82afc3621f41': '497 s state road 7, hollywood, fl, 33023, us',
#  'sg:1ae825d9140f454a8263ecd718d5e6da': '9621 w 58th ave, arvada, co, 80002, us',
#  'sg:51a720a952e54b17aa7dc4abbce614d7': '480 n 40th st, springdale, ar, 72762, us',
#  'sg:22322f5ad0ad47ee8d10b9bc7672d1c4': '13351 12th st, chino, ca, 91710, us',
#  'sg:8787f12817dd484da1297c5630def8c3': '1167 n washington st, wilkes-barre, pa, 18705, us',
#  'sg:b25de1e897704419827943fb73f8c5df': '2052 homestead rd, bowman, sc, 29018, us',
#  'sg:0103326ca56448b98ae9e3c0746d587e': '1211 n main st, gainesville, fl, 32601, us',
#  'sg:9a51989091d540428f798facbb3f0fdc': '2011 sw h k dodgen loop, temple, tx, 76502, us',
#  'sg:36f1f81981e749cc970bbad04f3e475d': '144 carbondale rd sw, dalton, ga, 30721, us',
#  'sg:9603446697d24e1b9f78ef6e3ce25269': '619 s sunshine blvd ste b, eloy, az, 85131, us',
#  'sg:25c1fa8273984aeab6f173640035b5a0': '7986 greenback ln, citrus heights, ca, 95610, us',
#  'sg:ee0f793628ae40a884e42e1dc120c644': '16180 pearl rd, strongsville, oh, 44136, us',
#  'sg:d1881641eb24412486eabcd409564245': '2040 w ridge rd, greece, ny, 14626, us',
#  'sg:64dadf7063fc4ad4bff18a453ab37381': '917 e fort ave, baltimore, md, 21230, us',
#  'sg:5170f52d8fd64bc888dbc9620bcc7146': '2885 lowery st, winston salem, nc, 27101, us',
#  'sg:14dcdd7932e24b5bb440c1d0161e3173': '273 w baltimore ave ste 281, clifton heights, pa, 19018, us',
#  'sg:1bf21bf3424a477e9a0f1fd4ebd0b1dc': '1001 w 15th st, lynn haven, fl, 32401, us',
#  'sg:55c271baaca94e02b7e9b2dff2cfc298': '5400 industrial rd, fort wayne, in, 46825, us',
#  'sg:f766eef7199947b7a9c5c64383d3074b': '3912 holland blvd, chesapeake, va, 23323, us',
#  'sg:8142381dd0c846a99407b9cacc139577': '1020 shoppes ln, mcdonough, ga, 30253, us',
#  'sg:209e9f29b05946959d96ee9a2763d03f': '500 n main st, broken arrow, ok, 74012, us',
#  'sg:654bc29153fa4f5e81246b7ddac776da': '1015 morris st, fond du lac, wi, 54935, us',
#  'sg:d57dc719f1e642bcb7858b4ff0b08ad9': '1800 buchholzer blvd, akron, oh, 44310, us',
#  'sg:c08ae2fef087419eacbf8fb6c04562db': '37 e genesee st, auburn, ny, 13021, us',
#  'sg:2fb6355c81dd43ce95bb07cf33270f51': '8815 e interstate 40, amarillo, tx, 79118, us',
#  'sg:0c551ee555204312b48a107f24432c1d': '210 keystone rd, chester, pa, 19013, us',
#  'sg:0fa560517d5a45368720170049a78a1d': '612 cass st, la crosse, wi, 54601, us',
#  'sg:1c610abec7654316812cd817432aec04': '141 harbison blvd, columbia, sc, 29212, us',
#  'sg:f4bc59316520497d80587724caef15f9': '5380 nw cache rd, lawton, ok, 73505, us',
#  'sg:6b91d2a1bf074a03a765beb0d99376c2': '1128 lebanon pike, nashville, tn, 37210, us',
#  'sg:88e0d32cbdf34a09b9dfb04e39c7f37c': '300 orchard park rd, west seneca, ny, 14224, us',
#  'sg:44834665b6bc4a418747d509bea3a233': '226 s main st, rochester, mi, 48307, us',
#  'sg:4bfcf066d16647e394ae008a1dc4d957': '1295 w i65 service rd n, mobile, al, 36618, us',
#  'sg:3bf92fbf343d490c80073b31cbe6c122': '9075 yukon st, westminster, co, 80021, us',
#  'sg:90ef4ea9341f442089f09260a7317af0': '10213 w county road 127, midland, tx, 79706, us',
#  'sg:190b7e173d09418abb14b7c7b0caffaf': '3055 old atlanta rd, cumming, ga, 30041, us',
#  'sg:411c189618e1486085a3f9b0e0e65533': '2220 s reynolds rd, toledo, oh, 43614, us',
#  'sg:3ab6653a366b49f7b9cfb937c126647c': '1303 n academy blvd, colorado springs, co, 80909, us',
#  'sg:df6168e07f994831b6e3eeee6c1a3c37': '1709 royston lane round rock, round rock, tx, 78664, us',
#  'sg:eaa4946f8a7743718bf077c9e9fa35ff': '6249 n foster dr, baton rouge, la, 70805, us',
#  'sg:0c4f396dedd5441bbf4df14f71b8519f': '1302 e 7th st, joplin, mo, 64801, us',
#  'sg:0dcc9bc1c64f47218aca19f4c6eed836': '1232 garfield ave, parkersburg, wv, 26101, us',
#  'sg:435cc99a237c44f99789b42a7242ebaa': '3301 mound rd, joliet, il, 60436, us',
#  'sg:2613ba42ff5c4825bdc644174a9ad7be': '3016 bardstown rd, louisville, ky, 40205, us',
#  'sg:1f6244fd67534d8bb15aa6b81e7ebf7d': '500 us highway 80 w, garden city, ga, 31408, us',
#  'sg:5c566d93720e459ebed478bd2d059eaa': '10220 stevenson st, lenexa, ks, 66220, us',
#  'sg:0e5d750c5270436db728f1484be3be1f': '193 pronghorn st, casper, wy, 82601, us',
#  'sg:363006197d35463294db3b59817b2846': '7230 northfield rd, walton hills, oh, 44146, us',
#  'sg:18bc61538f4647d988504e78b4c564fc': '3713 state st, schenectady, ny, 12304, us',
#  'sg:5e623f1688a740d39b6fefbcff82e8ed': '100 e kennedy st, spartanburg, sc, 29306, us',
#  'sg:766eb9b4f6224c1aad4abdc11ac6139f': '11 n andrews ave, fort lauderdale, fl, 33301, us',
#  'sg:15f8e957563f4e6f82954e2023ce81fe': '3453 s arlington rd, green, oh, 44312, us',
#  'sg:4e35f8354466420397459b66099435a4': '1703 boulevard, colonial heights, va, 23834, us',
#  'sg:20ed89f934474a02b537c7bbe92a460d': '317 e 9th st, cincinnati, oh, 45202, us',
#  'sg:3508ee51506e40f8956995d91b3b19d5': '14923 ne 20th st, bellevue, wa, 98007, us',
#  'sg:52d416b193b84dfebf8c50277387382b': '9353 canal rd, gulfport, ms, 39503, us',
#  'sg:e8710a76fc9a408e832c9202475da32e': '7510 fluid dr, little rock, ar, 72206, us',
#  'sg:069125c8e25145e89b5dcce7f368b20a': '51 worthington rd, cranston, ri, 02920, us',
#  'sg:53c3ff90ec9d4988a2968ecfa5514504': '1740 3rd st s, jacksonville beach, fl, 32250, us',
#  'sg:cca416b4468840e5a9736a9481e0ea6b': '2820 market st, garland, tx, 75041, us',
#  'sg:b467dfd1b92a4447b128decc2efd589b': '7041 avenue 304, goshen, ca, 93291, us',
#  'sg:ab77bf6344354400a4aa8630de6c77a0': '19 town st ste 31, norwich, ct, 06360, us',
#  'sg:2f63397764d849a4b2af387bf364c8d8': '635 american legion hwy, roslindale, ma, 02131, us',
#  'sg:81c703ab113b46fcb8354a9916b5db21': '1950 hendrix dr, columbus, oh, 43123, us',
#  'sg:333480f14e874ea8b2cf7a7859946d94': '112 frontage rd, piedmont, sc, 29673, us',
#  'sg:6a5e280da1b044f498bb63d82de3bff6': '300 nw 172nd ave, pembroke pines, fl, 33029, us',
#  'sg:ecf1d749e08f454f8880f4ae587717ba': '300 edwards ave, elmwood, la, 70123, us',
#  'sg:bc52dc598ffb43478ab2002806ef4c76': '50 n dobson rd, mesa, az, 85201, us',
#  'sg:365550e111ac45ab804fd1ec24249672': '5900 fisher rd, east syracuse, ny, 13057, us',
#  'sg:9d06b03142504499af1a67479e93c38b': '10421 ford rd, dearborn, mi, 48126, us',
#  'sg:2be5d9e57ab64999a90726a1a53d4448': '8235 e 71st st, tulsa, ok, 74133, us',
#  'sg:2e9e5cc3c1ad422ca7cf734711cdea6b': '4535 silver hill rd, suitland, md, 20746, us',
#  'sg:6da4d055fe314d6e9cd90f31bc61c7a0': '801 new loudon rd ste 2, latham, ny, 12110, us',
#  'sg:0ca7378603a24fb4a6e644280900048b': '34721 emerald coast pkwy, destin, fl, 32541, us',
#  'sg:90347d1cb2154d94ad51466b4a0069f2': '10757 w national ave, west allis, wi, 53227, us',
#  'sg:37a864ad61904449b0a8850a53a416c2': '30405 bryant dr, evergreen, co, 80439, us',
#  'sg:794651be741b492a8038e9ce4e88122a': '5566 camp rd, hamburg, ny, 14075, us',
#  'sg:6db9f84f91834ae79547e928a4a073bb': '8875 siegen ln, village st. george, la, 70810, us',
#  'sg:c9b2a54ca3e040cb817891dbd49da9db': '1955 se federal hwy, stuart, fl, 34994, us',
#  'sg:0711f8c6d7c64058aeb31e250c427e24': '5435 n 131st st, butler, wi, 53007, us',
#  'sg:afe3e57e67b347e0a82a8438959b7fd1': '3601 highway 21 e, bryan, tx, 77808, us',
#  'sg:3981ce6076534aae8360da08f2d0422e': '10684 toepperwein rd, converse, tx, 78109, us',
#  'sg:2617ad0294fa4eeb9ef79e08c1aba757': '30100 s dixie hwy, homestead, fl, 33033, us',
#  'sg:43c0573d8a314bf3b3b3e000a03165b0': '29 lagrange st, newnan, ga, 30263, us',
#  'sg:8a51e20ead734c1d93f5b380c35777c7': '2625 s glenstone ave, springfield, mo, 65804, us',
#  'sg:0ec0e2b041a84836a07999f6d654fd4f': '18411 highland rd, baton rouge, la, 70809, us',
#  'sg:a1d72ad0a14246138d5642b3c7cf9112': '4520 saint andrews rd, irmo, sc, 29210, us',
#  'sg:07416325dac0419f9be2d59c606fb86d': '3925 dewey ave, rochester, ny, 14616, us',
#  'sg:43dd252d07d042f982e40ef042e57368': '5140 sw 21st st, topeka, ks, 66604, us',
#  'sg:5abe8cfed7d84c01b7c896290ceb77bb': '12645 eckel junction rd, perrysburg, oh, 43551, us',
#  'sg:694a4dc70c13419f8771890caade319e': '5235 e airport dr, ontario, ca, 91761, us',
#  'sg:73fbc044adf14bab8f0c1d2eff71654f': '543 e central st, franklin town, ma, 02038, us',
#  'sg:706e84a835024dbca381f8906678cd85': '19805 44th ave w, lynnwood, wa, 98036, us',
#  'sg:6a719b8c1ca14804a9a6ec103a723152': '14506 el camino ln, lenoir city, tn, 37771, us',
#  'sg:59a1d42b78f747a29821851562d2f407': '2 levitt pkwy, willingboro, nj, 08046, us',
#  'sg:29414336bea844fc863fc8a68210e600': '180 mendel dr sw, atlanta, ga, 30336, us',
#  'sg:6a18e772dd1a4afabb216f745103cec9': '14364 coursey blvd, shenandoah, la, 70817, us',
#  'sg:4014aa11e7464f79a2a63b103d8da2bb': '243 woodmont rd, milford, ct, 06460, us',
#  'sg:8c197ccc608541829fd016edc0ca712a': '103 sw 11th st, lawton, ok, 73501, us',
#  'sg:204ef9c1af1b4b1498c2b0515a924f34': '2575 w colonial dr, orlando, fl, 32804, us',
#  'sg:7a8a9e8339d14ca095791f5c37a0d1d0': '150 wiggins rd, candler, nc, 28715, us',
#  'sg:42a0c4426f6a49c2a64e2ebd8d13aa52': '901 n bradley rd, spokane valley, wa, 99212, us',
#  'sg:2e3c5c3e87aa4edebd3b679213c482b5': '912 31st st n, birmingham, al, 35203, us',
#  'sg:c4c2a84745724c9e83a4a9cf9162f63c': '317 plastic ave, tomah, wi, 54660, us',
#  'sg:5e551ab576314294b26fa76d05528f21': '42 memory ln, east york, pa, 17402, us',
#  'sg:04b67844d6204edc8fd3c83a21f2fb02': '4550 panther creek pne, the woodlands, tx, 77381, us',
#  'sg:2777c4a9d1e64e4c98bb3ee70f767d24': '4403 executive pkwy, westerville, oh, 43081, us',
#  'sg:0022ea9b1c6e49a5b8dad4f94f5e1fcf': '300 harrison ave, endicott, ny, 13760, us',
#  'sg:4278e15bc08845118e9fac21ac5f0f2b': '5704 ogeechee rd, savannah, ga, 31405, us',
#  'sg:067ca7af40504f7496318bc86643fce2': '603 n arkansas ave, russellville, ar, 72801, us',
#  'sg:018b4ca344974b979e51ffdc8b595ad6': '7004 three chopt rd, richmond, va, 23226, us',
#  'sg:4a2b001733744e0a98dd429ee65b3316': '626 perkins st, union city, tn, 38261, us',
#  'sg:2dc816ca19a8456b96822808a2ef44d5': '7051 ga highway 21, port wentworth, ga, 31407, us',
#  'sg:b50c525fa8ed48fba07ac59a74e08f73': '1134 s navigation blvd, corpus christi, tx, 78405, us',
#  'sg:a29e7779b1cd4b3091691805f6f09448': '27705 katy fwy, katy, tx, 77494, us',
#  'sg:35c0566f6e6e41cda15a59668aab8c4d': '4305 jonestown rd, colonial park, pa, 17109, us',
#  'sg:f3c072977dbc43d1b6bd19682b23ecac': '430 n dirksen pkwy, springfield, il, 62702, us',
#  'sg:7b150864e5844b73b60c6bf826f8205d': '30270 eastern shore ct, spanish fort, al, 36527, us',
#  'sg:24115e93bab3484699199d6d1693fd20': '405 harding pl, nashville, tn, 37211, us',
#  'sg:2b51c3f8ef4549568f4d5d19fb73480c': '147 morgan dr, howell, mi, 48843, us',
#  'sg:5bcbf0587f614b13b4b51e8d994ed10d': '225 lapalco blvd, timberlane, la, 70056, us',
#  'sg:100a5fde5ee249848345999bf8c26bbc': '9631 jefferson davis hwy, fredericksburg, va, 22407, us',
#  'sg:0341e12c4d724db3be11b5a67bf42df0': '10475 s us highway 1, port saint lucie, fl, 34952, us',
#  'sg:1ac80d3954814f7e9b9175fd61c732f1': '74 5488 kaiwi st, kailua, hi, 96740, us',
#  'sg:10b809f741e046e99cff3f8cbe9ad8b1': '3081 highway 32 n, hope, ar, 71801, us',
#  'sg:9d7ad600642f4c69bcc90d088ae2bbdb': '94 050 farrington hwy ste c1 5, waipahu, hi, 96797, us',
#  'sg:b2a7d09469b64774a9156674c8574960': '16067 willowbrook rd, south beloit, il, 61080, us',
#  'sg:e038ae74384c4cb0a56c2e0d5ff7634a': '1501 n corrington ave, kansas city, mo, 64120, us',
#  'sg:bc429e2cff0c4e4ea5e580f1f0a1dc1d': '450 mount cross rd, danville, va, 24540, us',
#  'sg:044a5d893264494abd965ef5b7ab5bae': '915 baltimore blvd, westminster, md, 21157, us',
#  'sg:3afc18d008e345db8159262f618e99c5': '1 bow st, somerville, ma, 02143, us',
#  'sg:83ff9579897a451ab3663ad5addf2b64': '2910 alt 19, palm harbor, fl, 34683, us',
#  'sg:05713920014840eca278c54fe7420a1c': '219 e hopkins st, san marcos, tx, 78666, us',
#  'sg:506fbe95c2544955beb2c22816b41ecc': '3029 moon station rd nw, kennesaw, ga, 30144, us',
#  'sg:01213d67f99e4e96a2afa862eb2c2746': '16101 ne 87th st ste b, redmond, wa, 98052, us',
#  'sg:6d2bce6ad4754b2b8e2fe2b3e4b8be43': '4655 24th ave, fort gratiot, mi, 48059, us',
#  'sg:b0ec7231e57b4d1a83995b4e4cdaef48': '7739 e state route 37, sunbury, oh, 43074, us',
#  'sg:10f94cc5be124130ad27f6d05f22ddeb': '1848 martin luther king jr blvd, bayou cane, la, 70360, us',
#  'sg:d9dcda65e1154692bc015fa06faed794': '54 ransier dr, west seneca, ny, 14224, us',
#  'sg:443d022bf2464bcea7ce242cd100dd87': '911 oak tree ave ste f, south plainfield, nj, 07080, us',
#  'sg:fae14178408545c0bd7bfebbb6db448c': '3101 pacific hwy e, fife, wa, 98424, us',
#  'sg:87e84cb2b30942d2b8a7fea6fc2ed9b1': '1269 w 103rd st, kansas city, mo, 64114, us',
#  'sg:ac2d5c2697144823b46d2740a9ce537d': '700 richard arrington jr blvd s, birmingham, al, 35233, us',
#  'sg:3465638f96ed4652bcea5aa344764713': '4020 silver lake rd ne, st. anthony, mn, 55421, us',
#  'sg:afb52ba755774b8084543fc1c13cada3': '6034 baltimore national pike, woodlawn, md, 21228, us',
#  'sg:0e838ae66ce949b5895d8a287c11cb9a': '820 33rd ave sw, cedar rapids, ia, 52404, us',
#  'sg:f228b1cbd98e499eb5750504c84d4c4d': '1200a s hillcrest dr, sulphur springs, tx, 75482, us',
#  'sg:22707a133f5d4748bb2cfb3d7d78d5c9': '1615 wells rd, bellair-meadowbrook terrace, fl, 32073, us',
#  'sg:a17f576446f54df3a215352ea506031a': '1840 highway 20 se, conyers, ga, 30013, us',
#  'sg:48e4a3413dec4e549ff31e59cd895667': '4830 monticello ave, williamsburg, va, 23188, us',
#  'sg:a71f72e72e7d4d9d92984c0e6dc41eeb': '13390 s unitec dr, laredo, tx, 78045, us',
#  'sg:bf91f5690dea4f1dad26fd077e6543d6': '41 s dean st, englewood, nj, 07631, us',
#  'sg:4a72960a20a44899864a3ce5037662ce': '6850 frank ave nw, north canton, oh, 44720, us',
#  'sg:202d4f82a07146829ba55a1a079d4450': '205 market st, lynn, ma, 01901, us',
#  'sg:89c9dd52c01248bfb1006cf8c5433f46': '121 alamaha st, kahului, hi, 96732, us',
#  'sg:8bf30f80ad2842c9b73af43ab3077427': '200 e sunflower rd, cleveland, ms, 38732, us',
#  'sg:4888290828b74ff1862f8e1b92fffe1f': '5913 station st, pittsburgh, pa, 15206, us',
#  'sg:be1c861947354787851dabac91108d39': '1265 us 127 south, frankfort, ky, 40601, us',
#  'sg:68cae84548ec458f8260117232e113a6': '6498 mission st, daly city, ca, 94014, us',
#  'sg:78bbff07dbee4797819357ebb9b76394': '712 e rickelman ave, effingham, il, 62401, us',
#  'sg:049074d6c5264f2a8279962a99fee575': '4400 skyland blvd e, tuscaloosa, al, 35405, us',
#  'sg:5b0f87f8e8784a9c96e56f59289b25c2': '1460 tremont pl, denver, co, 80202, us',
#  'sg:15199991ce964af98ea76a01dfe3b694': '7565 state route 30 ste 200, irwin, pa, 15642, us',
#  'sg:d700971fdc0b4d6eb0beac3ae0b0b26d': '971 eastgate loop, chattanooga, tn, 37411, us',
#  'sg:51d4a1e9896d4e569c0e2b3158be0bbd': '1281 piney forest rd, danville, va, 24540, us',
#  'sg:a6f04411dbb74c73bbbf50a8e5970a80': '624 broadway st, little rock, ar, 72201, us',
#  'sg:376dea8109384099b3125f0d01cfd49f': '12661 middlebelt rd, livonia, mi, 48150, us',
#  'sg:386f5cf15ef647799054247651827ab0': '46 047 kamehameha hwy, heeia, hi, 96744, us',
#  'sg:57c1ef35348a4aa6a34a2ad843ab01eb': '5785 old dallas rd, elm mott, tx, 76640, us',
#  'sg:591ff4185ef440cdbfce6c2ea8bb19f2': '2230 state route 45, austinburg, oh, 44010, us',
#  'sg:c26edd50e1ca4aa5abadf58fe76626d8': '2801 s southwest loop 323, tyler, tx, 75701, us',
#  'sg:945330e8bdb446f6b91e7103aa1cbd0a': '486 n winchester blvd, santa clara, ca, 95128, us',
#  'sg:b837594d5ea94ce9894462fc3d8f3b5e': '1985 e ridge rd, irondequoit, ny, 14622, us',
#  'sg:328ec81b977142aba4110a6c1f1a78a5': '4981 barthold rd, denton, tx, 76207, us',
#  'sg:bb027b5b88984cb2bd65e5994bf21b7a': '1417 lincoln hwy, levittown, pa, 19056, us',
#  'sg:4e120dc27fc84defbb2b82868437bedf': '10931 n de anza blvd, cupertino, ca, 95014, us',
#  'sg:9f1ca7fdf84d4bb2b438f7064a8a2bdb': '5210 w state highway 266, springfield, mo, 65802, us',
#  'sg:13361399ec214489ab5973c50b88ecdd': '1400 gervais st ste 2, columbia, sc, 29201, us',
#  'sg:a3182f069b154e5d9fb2c10b337d42c1': '1795 sheridan dr, tonawanda, ny, 14223, us',
#  'sg:b60d98327dab4e8c868dff1dbe04c630': '8881 samuel barton dr, van buren twp, mi, 48111, us',
#  'sg:b521f3fe6f8b456e95b1ef10d6b8301a': '460 reedy creek rd, cary, nc, 27513, us',
#  'sg:e0d45024a0fe416893bab0275beb3f38': '10224 highway 20/26, caldwell, id, 83605, us',
#  'sg:f61f4554f9a342ecacf2653b5f503532': '1137 verdant st, elkhart, in, 46516, us',
#  'sg:71d5f93e5bcb44e0a0da70e9353320e3': '8014 geyer springs rd, little rock, ar, 72209, us',
#  'sg:2f77eba053bf4f32a4fda49085c96605': '225 palladium dr, saint joseph, mi, 49085, us',
#  'sg:450ca1860e214643aacaeb34e973757b': '175 n delsea dr, vineland, nj, 08360, us',
#  'sg:3b88ca46ee6341cba62327c28add75dd': '1150b n canfield niles rd, mineral ridge, oh, 44515, us',
#  'sg:3052441e223a4cdfb2affd140fcb2d3c': '5110 service dr, goodview, mn, 55987, us',
#  'sg:c2740fe7c2e243f18b86240cf0d746e1': '215 clinton ave e, huntsville, al, 35801, us',
#  'sg:820db6df719d446cb9d25853b46d4afd': '4701 equipment dr, charlotte, nc, 28269, us',
#  'sg:4124e70a39be444480c6d41f388d2a59': '3200 division st, metairie, la, 70002, us',
#  'sg:7ca3cf3719764cfeb77a622fd34e7cc9': '3870 seville ave, vernon, ca, 90058, us',
#  'sg:874e3058ceca4c2ba3ce31deb959e99a': '10420 melody dr, northglenn, co, 80234, us',
#  'sg:c33e227ab8714bd5b06908f540212c70': '4119 avenue of the cities, moline, il, 61265, us',
#  'sg:f1949a754e4c49e7a3e5a41513cdbe50': '1810 princeton kenly rd, kenly, nc, 27542, us',
#  'sg:8d4f14cc5d514c7ab92640a10908b424': '800 martin luther king dr # 2, west memphis, ar, 72301, us',
#  'sg:f096b5784f5040d09337af5b0ed002f7': '6124 reading rd, rosenberg, tx, 77471, us',
#  'sg:3cee20f63ea54758b43ca23af30c05f1': '5029 s westnedge ave, portage, mi, 49002, us',
#  'sg:41dc8b703426486ba1a27aca6deb8422': '2515 n main st, belton, tx, 76513, us',
#  'sg:d58c9d704dff420d8f74c80263c28c10': '998 hammond dr, sandy springs, ga, 30328, us',
#  'sg:adb4b144d8c9413ab7b1919bf0322626': '5970 crawfordsville rd, speedway, in, 46224, us',
#  'sg:b8490b8c66da4c18b8c979690f029360': '424 e water st, syracuse, ny, 13202, us',
#  'sg:02f554cf26084f1f8ec1bd6e1fb0ad65': '3800 capitola rd, capitola, ca, 95010, us',
#  'sg:9f86185e34724f469bd246cbae145347': '11530 sw 147th ave, miami, fl, 33196, us',
#  'sg:0a43fe127afb4c9688a77e73f28262bc': '8301 pines blvd, pembroke pines, fl, 33024, us',
#  'sg:cb999b075cbe47e586fc146715b501d2': '1266 starlight dr, akron, oh, 44306, us',
#  'sg:246b284212f84cb9a769238392d08ac7': '2101 green ln ste d, levittown, pa, 19057, us',
#  'sg:1d815ca75c34439491d9a9607e721060': '7501 midlothian tpke, manchester, va, 23225, us',
#  'sg:46f7786f2e8741c3ac0e908e905b0bb5': '2186 empire blvd, webster, ny, 14580, us',
#  'sg:2a28e3ed121a4eb992356bfe67462aae': '5015 n high st, columbus, oh, 43214, us',
#  'sg:833b32bd80ec4c55a360d0ad635b227f': '3146 stevens creek blvd, san jose, ca, 95117, us',
#  'sg:133d7c2e7acb4c88b82d79b4c2b5e216': '4972 transit rd, depew, ny, 14043, us',
#  'sg:236633c57b234a6c82b84c881f1424df': '1317 w grand pkwy s, katy, tx, 77494, us',
#  'sg:3e3963f736c84ea0b30be8092fcd47b0': '4909 shelbyville rd, saint matthews, ky, 40207, us',
#  'sg:295a2760d27c4e00a44dfb8fc15dc26c': '338 merrimack st, lowell, ma, 01852, us',
#  'sg:799147b4c6824d12896e2305db1b0c1e': '5636 hedge lane ter, shawnee, ks, 66226, us',
#  'sg:54dc9cebbd2845a09be9e7991dd07087': '412 transcon ln, winslow, az, 86047, us',
#  'sg:61f4c552e6fb4627a650f222d55f488d': '724 kailua rd, kailua, hi, 96734, us',
#  'sg:565d1859d66f422fb0e7415fd3d12312': '1711 w ashley rd, boonville, mo, 65233, us',
#  'sg:af53027242a748d28f08bd29a711c382': '532 northlake blvd, lake park, fl, 33408, us',
#  'sg:459432c0ba4d480d960eed563824e2a5': '1953 rosebud rd, grayson, ga, 30017, us',
#  'sg:769e8050d6d54ebb9673e494699ea51b': '333 naamans rd ste 42, claymont, de, 19703, us',
#  'sg:2703b33f36b248fdaf94d0680f149dce': '632 grammes ln unit a, allentown, pa, 18104, us',
#  'sg:77dea8c067b2410a89fd7659d4c03b96': '2824 bee caves rd, rollingwood, tx, 78746, us',
#  'sg:87f783baf3d34beda384e32aca8b6984': '30 progress ave, cranberry township, pa, 16066, us',
#  'sg:381741f84b0741e7bac9b18b88623dfd': '3690 bird rd, miami, fl, 33133, us',
#  'sg:dcba4319bddd43eab1e30a368db8da2f': '4550 caterpillar rd, redding, ca, 96003, us',
#  'sg:61dd1c1a230e4edc8c4fd37e3fed19ec': '6950 lee hwy, chattanooga, tn, 37421, us',
#  'sg:bfdbf778a091448499ed0fd49514f66f': '23133 bothell everett hwy, bothell, wa, 98021, us',
#  'sg:f86829f325ee4afb8608203d0b693666': '6758 lake harbour dr, brandermill, va, 23112, us',
#  'sg:179a53a63f08493da7d2dba4883b2896': '25880 clawiter rd, hayward, ca, 94545, us',
#  'sg:86c9b1c90bba497fb2a4836b46570017': '2144 del prado blvd s, cape coral, fl, 33990, us',
#  'sg:0edcd35ad61d4d5882ee2357927b72f4': '6071 bayfield pkwy, kannapolis, nc, 28027, us',
#  'sg:1812e8afbfee44b8a7aba2e8b5e7831d': '3045 nw 119th st, miami, fl, 33167, us',
#  'sg:1bb0e1b9190f468f9454c99fd4ec8285': '1623 montgomery hwy, hoover, al, 35216, us',
#  'sg:581f267188ca445e83e01893a8217399': '665 n king rd, san jose, ca, 95133, us',
#  'sg:ecefc12141314cdabf7e5226a8e36b14': '1201 sheppard access rd, wichita falls, tx, 76306, us',
#  'sg:385de2c15e2f4320bcd3e5f68adb585e': '1717 arden way, sacramento, ca, 95815, us',
#  'sg:350ac12389864b07b6c58217b5de0a9b': '4601 interstate dr, macon, ga, 31210, us',
#  'sg:ee50a9ba82ad430382c71f9f15a19bbf': '301 wingfoot ct, bremen, ga, 30110, us',
#  'sg:87e81eeaf06f478a85973b8c410395f8': '9798 charlotte hwy, fort mill, sc, 29707, us',
#  'sg:5234deeb6793497ab69ce7a3ae2210b0': '12340 us highway 98 w, miramar beach, fl, 32550, us',
#  'sg:533a42375de545a68066393bc11598b2': '2123 w willow st, scott, la, 70583, us',
#  'sg:a8cb3eb751a94f7582fea465d941fc6d': '222 lee dr, baton rouge, la, 70808, us',
#  'sg:90bd9cd259f14f84be60220c555d4d4c': '1301 cusseta rd, columbus, ga, 31901, us',
#  'sg:b6f28bcd7d864a638a57439395a1ff50': '817 n clay st, jacksonville, fl, 32202, us',
#  'sg:178bcbd4078749abaadcda965ed56f26': '6400 jericho tpke, commack, ny, 11725, us',
#  'sg:8f9dad903dd2435aa2df497776f12ec3': '12555 w north ave, brookfield, wi, 53005, us',
#  'sg:a33d419942a546689a620eb0e01564c0': '3491 madison hwy, valdosta, ga, 31601, us',
#  'sg:4540d9e32e424249934bf46e8d7f03ee': '7791 alcoa rd, benton, ar, 72019, us',
#  'sg:3fc9d2575c5f481ea12654a75e306c8c': '475 kilauea ave, hilo, hi, 96720, us',
#  'sg:6389a5a78f71442a90a9f6374b878508': '4669 sandy hollow rd, rockford, il, 61109, us',
#  'sg:3975088879a44f30948bdb7248ca58ab': '378 kelly rd ste 1, vernon rockville, ct, 06066, us',
#  'sg:70166fada9f04aa09e9e43fad29caada': '61 e 2nd st, oswego, ny, 13126, us',
#  'sg:328e0eb26efe432d942b491a3043a1eb': '6014 fm 1488 rd, magnolia, tx, 77354, us',
#  'sg:a0562d560dd3484baa3f0d8bce578ab9': '1228 ingle rd, wayland, mi, 49348, us',
#  'sg:b2725c78d63d45b49c5ce329d6fb25db': '1872 east fwy, baytown, tx, 77521, us',
#  'sg:d4c11b093a49448a87db5d061496f38f': '1587 route 38, lumberton, nj, 08048, us',
#  'sg:0808bf1c1fa34dc6a361f8202b933fce': '3610 austin bluffs pkwy, colorado springs, co, 80918, us',
#  'sg:564baec51bf149eea79bd3de0dd03b38': '300 eastern ave, malden, ma, 02148, us',
#  'sg:c6ae0c55867247ecac40acaff1d29568': '11451 southern blvd, royal palm beach, fl, 33411, us',
#  'sg:7c891cfcdab94977919452228b58920e': '3712 battleground ave, greensboro, nc, 27410, us',
#  'sg:97229799149a4ba5838988da8076b22f': '10141 n eldridge pkwy, houston, tx, 77065, us',
#  'sg:13d596391b4844379b154271c4308a8f': '390 e van fleet dr, bartow, fl, 33830, us',
#  'sg:7fd0168568bb4780be5a55c26e153601': '301 a ave, lake oswego, or, 97034, us',
#  'sg:efc79f5335a1497ab4d24a997be03b3e': '11941 cutten rd ste 600, houston, tx, 77066, us',
#  'sg:56e3c75ecda64af9a72b89a5b9d5f283': '8530 sw 8th st, oklahoma city, ok, 73128, us',
#  'sg:601242fca9a14d40aaf730335317d395': '447 s goldenrod rd, orlando, fl, 32822, us',
#  'sg:33ff64d6b75345cb827cb4d7a14d9a54': '1298 n madison ave, greenwood, in, 46142, us',
#  'sg:f17f0b31bb0449808e936f63e086bfda': '108 glendale hodgenville rd w, glendale, ky, 42740, us',
#  'sg:7b0ac6b968b146eab677e3c4559d56a7': '8067 beckett center dr, beckett ridge, oh, 45069, us',
#  'sg:65539be44d3e4300afd0d29276fde0b2': '1612 w main st, salem, va, 24153, us',
#  'sg:5b397895db6449db94f8b26b4415086d': '4511 williamsburg rd, richmond, va, 23231, us'}

# %%
df_storelist_BQ.head(2)
# Out:
#     installer_store_num store_num    installer_name company_owned_store_ind  \
# 2            0000908641      8641  JUST TIRES #8641                       Y
# 129          0000902356      2356  JUST TIRES #2356                       Y
#
#      open_date close_date           address_1_BQ      city_BQ state_BQ  \
# 2   2015-06-25        NaT  9210 s sepulveda blvd  los angeles       ca
# 129 2015-08-20        NaT   4325 glenwood avenue      raleigh       nc
#
#       zip_cd_BQ country_BQ  latitude_BQ  longitude_BQ zip_5_BQ  \
# 2    90045-4805         us    33.953199   -118.395727    90045
# 129  27612-4532         us    35.837050    -78.675850    27612
#
#                                             str_add_BQ
# 2    9210 s sepulveda blvd, los angeles, ca, 90045, us
# 129       4325 glenwood avenue, raleigh, nc, 27612, us

# %%
df_storelist_BQ=df_storelist_BQ.reset_index()
del df_storelist_BQ['index']
df_storelist_BQ['poi_id']=np.nan
df_storelist_BQ['poi_add']=np.nan
df_storelist_BQ['fuzz_ratio']=np.nan

for ind,row in df_storelist_BQ.iterrows():
    add_BQ=row['str_add_BQ']
    temp_max_score=0
    best_match_k=np.nan
    best_match_v=np.nan
    
    for k,v in dict_POI_add.items():
        score=fuzz.ratio(add_BQ,v)
        if score>temp_max_score:
            temp_max_score=score
            best_match_k=k
            best_match_v=v
    if temp_max_score>95:
        del dict_POI_add[best_match_k]
    df_storelist_BQ.loc[ind,'poi_id']=best_match_k
    df_storelist_BQ.loc[ind,'poi_add']=best_match_v
    df_storelist_BQ.loc[ind,'fuzz_ratio']=temp_max_score
        
df_storelist_BQ.head(5)
# Out:
#   installer_store_num store_num               installer_name  \
# 0          0000908641      8641             JUST TIRES #8641
# 1          0000902356      2356             JUST TIRES #2356
# 2          0000902237      2237  GDYR AUTO SERVICE CTR #2237
# 3          0000902382      2382  GDYR AUTO SERVICE CTR #2382
# 4          0000906740      6740  GDYR AUTO SERVICE CTR #6740
#
#   company_owned_store_ind  open_date close_date                address_1_BQ  \
# 0                       Y 2015-06-25        NaT       9210 s sepulveda blvd
# 1                       Y 2015-08-20        NaT        4325 glenwood avenue
# 2                       Y 2015-10-01        NaT        5811 atlanta highway
# 3                       Y 2015-08-20        NaT   910 concord parkway north
# 4                       Y 2015-07-23        NaT  7320 north keystone avenue
#
#         city_BQ state_BQ   zip_cd_BQ country_BQ  latitude_BQ  longitude_BQ  \
# 0   los angeles       ca  90045-4805         us    33.953199   -118.395727
# 1       raleigh       nc  27612-4532         us    35.837050    -78.675850
# 2    montgomery       al  36117-2109         us    32.382199    -86.198940
# 3       concord       nc  28027-5943         us    35.424506    -80.615242
# 4  indianapolis       in  46240-3246         us    39.888791    -86.122685
#
#   zip_5_BQ                                         str_add_BQ  \
# 0    90045  9210 s sepulveda blvd, los angeles, ca, 90045, us
# 1    27612       4325 glenwood avenue, raleigh, nc, 27612, us
# 2    36117    5811 atlanta highway, montgomery, al, 36117, us
# 3    28027  910 concord parkway north, concord, nc, 28027, us
# 4    46240  7320 north keystone avenue, indianapolis, in, ...
#
#                                 poi_id  \
# 0  sg:10999a1417bf432e818360b377cbb134
# 1  sg:0bb487af91b544488e955235fd56860f
# 2  sg:3856d22b52984dce9b2b5d088af0c834
# 3  sg:3a4f7419369244279e890530385dfa40
# 4  sg:4a8a843586cd4b51afdccd7d7481ab77
#
#                                              poi_add  fuzz_ratio
# 0     15751 los gatos blvd, los gatos, ca, 95032, us        63.0
# 1   1950 w edgewood ave, indianapolis, in, 46217, us        61.0
# 2      3001 hayneville rd, montgomery, al, 36108, us        65.0
# 3    8590 concord mills blvd, concord, nc, 28027, us        75.0
# 4  1303 s high school rd, indianapolis, in, 46241...        69.0

# %%
dict_POI_lat=df_POI_GY.set_index("safegraph_place_id").to_dict()['latitude']
dict_POI_lng=df_POI_GY.set_index("safegraph_place_id").to_dict()['longitude']

df_storelist_BQ['POI_latitude']=df_storelist_BQ['poi_id'].apply(lambda x: dict_POI_lat[x])
df_storelist_BQ['POI_longitude']=df_storelist_BQ['poi_id'].apply(lambda x: dict_POI_lng[x])
df_storelist_BQ.head(2)
# Out:
#   installer_store_num store_num    installer_name company_owned_store_ind  \
# 0          0000908641      8641  JUST TIRES #8641                       Y
# 1          0000902356      2356  JUST TIRES #2356                       Y
#
#    open_date close_date           address_1_BQ      city_BQ state_BQ  \
# 0 2015-06-25        NaT  9210 s sepulveda blvd  los angeles       ca
# 1 2015-08-20        NaT   4325 glenwood avenue      raleigh       nc
#
#     zip_cd_BQ country_BQ  latitude_BQ  longitude_BQ zip_5_BQ  \
# 0  90045-4805         us    33.953199   -118.395727    90045
# 1  27612-4532         us    35.837050    -78.675850    27612
#
#                                           str_add_BQ  \
# 0  9210 s sepulveda blvd, los angeles, ca, 90045, us
# 1       4325 glenwood avenue, raleigh, nc, 27612, us
#
#                                 poi_id  \
# 0  sg:10999a1417bf432e818360b377cbb134
# 1  sg:0bb487af91b544488e955235fd56860f
#
#                                             poi_add  fuzz_ratio POI_latitude  \
# 0    15751 los gatos blvd, los gatos, ca, 95032, us        63.0    37.239784
# 1  1950 w edgewood ave, indianapolis, in, 46217, us        61.0    39.678604
#
#   POI_longitude
# 0   -121.961645
# 1     -86.19511

# %%
def cal_dist_in_miles(lat_1,lng_1,lat_2,lng_2):
    dist=haversine.haversine([lat_1,lng_1],[lat_2,lng_2],unit="mi")
    return dist
df_storelist_BQ['latitude_BQ']=df_storelist_BQ['latitude_BQ'].astype(float)
df_storelist_BQ['longitude_BQ']=df_storelist_BQ['longitude_BQ'].astype(float)
df_storelist_BQ['POI_latitude']=df_storelist_BQ['POI_latitude'].astype(float)
df_storelist_BQ['POI_longitude']=df_storelist_BQ['POI_longitude'].astype(float)

df_storelist_BQ['dist_diff']=df_storelist_BQ.apply(lambda x: cal_dist_in_miles(x['latitude_BQ'],x['longitude_BQ'],x['POI_latitude'],x['POI_longitude']),axis=1)

# %%
df_storelist_BQ
# Out:
#     installer_store_num store_num                        installer_name  \
# 0            0000908641      8641                      JUST TIRES #8641
# 1            0000902356      2356                      JUST TIRES #2356
# 2            0000902237      2237           GDYR AUTO SERVICE CTR #2237
# 3            0000902382      2382           GDYR AUTO SERVICE CTR #2382
# 4            0000906740      6740           GDYR AUTO SERVICE CTR #6740
# ..                  ...       ...                                   ...
# 566          0000900639      0639    GOODYEAR AUTO SERVICE - NEW LONDON
# 567          0000900358      0358  GOODYEAR AUTO SERVICE - WETHERSFIELD
# 568          0000900629      0629        GOODYEAR AUTO SERVICE - VERNON
# 569          0000900360      0360      GOODYEAR AUTO SERVICE - HARTFORD
# 570          0000900338      0338       GOODYEAR AUTO SERVICE - ELMWOOD
#
#     company_owned_store_ind  open_date close_date                address_1_BQ  \
# 0                         Y 2015-06-25        NaT       9210 s sepulveda blvd
# 1                         Y 2015-08-20        NaT        4325 glenwood avenue
# 2                         Y 2015-10-01        NaT        5811 atlanta highway
# 3                         Y 2015-08-20        NaT   910 concord parkway north
# 4                         Y 2015-07-23        NaT  7320 north keystone avenue
# ..                      ...        ...        ...                         ...
# 566                       Y 2015-07-31        NaT         527 vauxhall street
# 567                       Y 2015-07-31        NaT    1020 silas deane highway
# 568                       Y 2015-07-31        NaT      378 kelly road suite 1
# 569                       Y 2015-07-31        NaT           306 market street
# 570                       Y 2015-07-31        NaT     1009 new britain avenue
#
#               city_BQ state_BQ   zip_cd_BQ country_BQ  latitude_BQ  \
# 0         los angeles       ca  90045-4805         us    33.953199
# 1             raleigh       nc  27612-4532         us    35.837050
# 2          montgomery       al  36117-2109         us    32.382199
# 3             concord       nc  28027-5943         us    35.424506
# 4        indianapolis       in  46240-3246         us    39.888791
# ..                ...      ...         ...        ...          ...
# 566        new london       ct  06320-2624         us    41.369841
# 567      wethersfield       ct  06109-4231         us    41.694617
# 568  vernon rockville       ct  06066-3997         us    41.825132
# 569          hartford       ct  06120-2918         us    41.771720
# 570     west hartford       ct  06110-2238         us    41.730030
#
#      longitude_BQ zip_5_BQ                                         str_add_BQ  \
# 0     -118.395727    90045  9210 s sepulveda blvd, los angeles, ca, 90045, us
# 1      -78.675850    27612       4325 glenwood avenue, raleigh, nc, 27612, us
# 2      -86.198940    36117    5811 atlanta highway, montgomery, al, 36117, us
# 3      -80.615242    28027  910 concord parkway north, concord, nc, 28027, us
# 4      -86.122685    46240  7320 north keystone avenue, indianapolis, in, ...
# ..            ...      ...                                                ...
# 566    -72.122745    06320     527 vauxhall street, new london, ct, 06320, us
# 567    -72.656831    06109  1020 silas deane highway, wethersfield, ct, 06...
# 568    -72.498800    06066  378 kelly road suite 1, vernon rockville, ct, ...
# 569    -72.670842    06120         306 market street, hartford, ct, 06120, us
# 570    -72.722250    06110  1009 new britain avenue, west hartford, ct, 06...
#
#                                   poi_id  \
# 0    sg:10999a1417bf432e818360b377cbb134
# 1    sg:0bb487af91b544488e955235fd56860f
# 2    sg:3856d22b52984dce9b2b5d088af0c834
# 3    sg:3a4f7419369244279e890530385dfa40
# 4    sg:4a8a843586cd4b51afdccd7d7481ab77
# ..                                   ...
# 566  sg:3c28eff56472464e82b9ceb5ec5200d2
# 567  sg:4d768c6ce85c4ef6999bbd3ff4abf3ea
# 568  sg:3975088879a44f30948bdb7248ca58ab
# 569  sg:c1884577280a4c69b1293bc65baf5781
# 570  sg:88c20467884c4e95b152740021cab5af
#
#                                                poi_add  fuzz_ratio  \
# 0       15751 los gatos blvd, los gatos, ca, 95032, us        63.0
# 1     1950 w edgewood ave, indianapolis, in, 46217, us        61.0
# 2        3001 hayneville rd, montgomery, al, 36108, us        65.0
# 3      8590 concord mills blvd, concord, nc, 28027, us        75.0
# 4    1303 s high school rd, indianapolis, in, 46241...        69.0
# ..                                                 ...         ...
# 566         527 vauxhall st, new london, ct, 06320, us        95.0
# 567  1020 silas deane hwy, wethersfield, ct, 06109, us        96.0
# 568  378 kelly rd ste 1, vernon rockville, ct, 0606...        96.0
# 569             306 market st, hartford, ct, 06120, us        95.0
# 570  1009 new britain ave, west hartford, ct, 06110...        97.0
#
#      POI_latitude  POI_longitude   dist_diff
# 0       37.239784    -121.961645  302.771289
# 1       39.678604     -86.195110  488.768114
# 2       32.348236     -86.345430    8.865360
# 3       35.374168     -80.724518    7.069241
# 4       39.747850     -86.268722   12.445638
# ..            ...            ...         ...
# 566     41.370014     -72.122287    0.026587
# 567     41.694769     -72.656546    0.018069
# 568     41.824875     -72.498635    0.019685
# 569     41.771846     -72.670220    0.033213
# 570     41.729831     -72.722328    0.014326
#
# [571 rows x 21 columns]

# %%
df_storelist_BQ.to_csv("./matched_QC_address.csv",index=False)

# %%
df_storelist_BQ[(df_storelist_BQ['fuzz_ratio']>80) & (df_storelist_BQ['dist_diff']>3)]
# Out:
#     installer_store_num store_num  \
# 192          0000908022      8022
# 355          0000902369      2369
# 480          0000902844      2844
# 520          0000902251      2251
#
#                                         installer_name  \
# 192  GOODYEAR AUTO SERVICE - KANEOHE BAY SHOPPING C...
# 355                 GOODYEAR AUTO SERVICE - ST ANDREWS
# 480      GOODYEAR AUTO SERVICE - FREDERICKSBURG CORNER
# 520                     GOODYEAR AUTO SERVICE - DESTIN
#
#     company_owned_store_ind  open_date close_date  \
# 192                       Y 2015-07-09        NaT
# 355                       Y 2015-08-20        NaT
# 480                       Y 2015-06-15        NaT
# 520                       Y 2015-07-07        NaT
#
#                     address_1_BQ         city_BQ state_BQ   zip_cd_BQ  \
# 192    46-047 kamehameha highway         kaneohe       hi  96744-3736
# 355         4520 st andrews road        columbia       sc  29210-4100
# 480     9631 jefferson davis hwy  fredericksburg       va  22407-9407
# 520  34721 emerald coast parkway          destin       fl       32541
#
#     country_BQ  latitude_BQ  longitude_BQ zip_5_BQ  \
# 192         us    21.379420   -157.785080    96744
# 355         us    34.051571    -81.156804    29210
# 480         us    38.268799    -77.547600    22407
# 520         us    30.393594    -86.495783    32541
#
#                                             str_add_BQ  \
# 192  46-047 kamehameha highway, kaneohe, hi, 96744, us
# 355      4520 st andrews road, columbia, sc, 29210, us
# 480  9631 jefferson davis hwy, fredericksburg, va, ...
# 520  34721 emerald coast parkway, destin, fl, 32541...
#
#                                   poi_id  \
# 192  sg:386f5cf15ef647799054247651827ab0
# 355  sg:01c053ae3e6b4d9bb6439f22edb79ec2
# 480  sg:100a5fde5ee249848345999bf8c26bbc
# 520  sg:0ca7378603a24fb4a6e644280900048b
#
#                                                poi_add  fuzz_ratio  \
# 192        46 047 kamehameha hwy, heeia, hi, 96744, us        85.0
# 355         6204 garners road, columbia, sc, 29209, us        83.0
# 480  9631 jefferson davis hwy, fredericksburg, va, ...       100.0
# 520    34721 emerald coast pkwy, destin, fl, 32541, us        97.0
#
#      POI_latitude  POI_longitude  dist_diff
# 192     21.422306    -157.803035   3.180300
# 355     33.981959     -80.963815  12.053614
# 480     38.220726     -77.506817   3.991260
# 520     30.387416     -86.440517   3.321387

# %%
df_storelist_BQ[(df_storelist_BQ['fuzz_ratio']<80) & (df_storelist_BQ['dist_diff']<3)].shape
# Out:
# (25, 21)

# %%
df_storelist_BQ[(df_storelist_BQ['fuzz_ratio']<80) & (df_storelist_BQ['dist_diff']>=3)].shape
# Out:
# (115, 21)

# %%
df_storelist_BQ[(df_storelist_BQ['fuzz_ratio']<80) & (df_storelist_BQ['dist_diff']>=3)].shape
# Out:
# (115, 21)
