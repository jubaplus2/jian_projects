# %%
# Don't name the file with white space

import pandas as pd
import numpy as np
import datetime
import os
import glob
os.getcwd()
# Out:
# '/home/jian/Projects/Big_Lots/Live_Ramp/Quarterly_Update_2019Q2'

# %%
all_Q2_uploading_files=glob.glob("/home/jian/Projects/Big_Lots/Live_Ramp/Quarterly_Update_2019Q2/output_2019-04-12/by_group/*.csv")
all_Q2_uploading_files_test=[x for x in all_Q2_uploading_files if (os.path.basename(x)[:2]=="T_") & ("_T_" not in os.path.basename(x))]
print("test files: ",len(all_Q2_uploading_files_test))
all_Q2_uploading_files_control=[x for x in all_Q2_uploading_files if (os.path.basename(x)[:2]=="C_") & ("_T_" not in os.path.basename(x))]
print("control files: ",len(all_Q2_uploading_files_control))
# Out:
# test files:  24
# control files:  24

# %%
'''
host = "sftp.liveramp.com"
port = 22
password = "Biglots2018!"
username = "lr-big-lots"

transport = paramiko.Transport((host, port))

transport.connect(username = username, password = password)
sftp = paramiko.SFTPClient.from_transport(transport)
'''

# %%
i_counter=1
for file in all_Q2_uploading_files_control:
    base_name=os.path.basename(file)
    df_before=pd.read_csv(file,dtype=str)
    df_uploaded=pd.read_csv("/home/jian/Projects/Big_Lots/Live_Ramp/Quarterly_Update_2019Q2/output_2019-04-12/uploaded_on_LR/"+base_name.replace(" ","_"),dtype=str)
    print(i_counter,base_name,df_before.shape,df_uploaded.shape,df_before.shape==df_uploaded.shape)
    QC_df=df_before==df_uploaded
    for col in QC_df.columns.tolist():
        print(QC_df[col].unique())
    i_counter+=1
# Out:
# 1 C_Quadrant III_P_H_2019Q2.csv (24155, 3) (24155, 3) True
# [ True]
# [ True]
# [ True]
# 2 C_Quadrant III_P_L_2019Q2.csv (32324, 3) (32324, 3) True
# [ True]
# [ True]
# [ True]
# 3 C_Quadrant III_P_M_2019Q2.csv (19362, 3) (19362, 3) True
# [ True]
# [ True]
# [ True]
# 4 C_Quadrant III_S_H_2019Q2.csv (5417, 3) (5417, 3) True
# [ True]
# [ True]
# [ True]
# 5 C_Quadrant III_S_L_2019Q2.csv (7933, 3) (7933, 3) True
# [ True]
# [ True]
# [ True]
# 6 C_Quadrant III_S_M_2019Q2.csv (4979, 3) (4979, 3) True
# [ True]
# [ True]
# [ True]
# 7 C_Quadrant II_P_H_2019Q2.csv (22288, 3) (22288, 3) True
# [ True]
# [ True]
# [ True]
# 8 C_Quadrant II_P_L_2019Q2.csv (13557, 3) (13557, 3) True
# [ True]
# [ True]
# [ True]
# 9 C_Quadrant II_P_M_2019Q2.csv (15695, 3) (15695, 3) True
# [ True]
# [ True]
# [ True]
# 10 C_Quadrant II_S_H_2019Q2.csv (4038, 3) (4038, 3) True
# [ True]
# [ True]
# [ True]
# 11 C_Quadrant II_S_L_2019Q2.csv (2704, 3) (2704, 3) True
# [ True]
# [ True]
# [ True]
# ...

# %%
i_counter=1
for file in all_Q2_uploading_files_test:
    base_name=os.path.basename(file)
    df_before=pd.read_csv(file,dtype=str)
    df_uploaded=pd.read_csv("/home/jian/Projects/Big_Lots/Live_Ramp/Quarterly_Update_2019Q2/output_2019-04-12/uploaded_on_LR/"+base_name.replace(" ","_"),dtype=str)
    print(i_counter,base_name,df_before.shape,df_uploaded.shape,df_before.shape==df_uploaded.shape)
    QC_df=df_before==df_uploaded
    for col in QC_df.columns.tolist():
        print(QC_df[col].unique())
    i_counter+=1
# Out:
# 1 T_Quadrant III_P_H_2019Q2.csv (1139050, 3) (1139050, 3) True
# [ True]
# [ True]
# [ True]
# 2 T_Quadrant III_P_L_2019Q2.csv (1524224, 3) (1524224, 3) True
# [ True]
# [ True]
# [ True]
# 3 T_Quadrant III_P_M_2019Q2.csv (913038, 3) (913038, 3) True
# [ True]
# [ True]
# [ True]
# 4 T_Quadrant III_S_H_2019Q2.csv (255458, 3) (255458, 3) True
# [ True]
# [ True]
# [ True]
# 5 T_Quadrant III_S_L_2019Q2.csv (374070, 3) (374070, 3) True
# [ True]
# [ True]
# [ True]
# 6 T_Quadrant III_S_M_2019Q2.csv (234791, 3) (234791, 3) True
# [ True]
# [ True]
# [ True]
# 7 T_Quadrant II_P_H_2019Q2.csv (1050979, 3) (1050979, 3) True
# [ True]
# [ True]
# [ True]
# 8 T_Quadrant II_P_L_2019Q2.csv (639287, 3) (639287, 3) True
# [ True]
# [ True]
# [ True]
# 9 T_Quadrant II_P_M_2019Q2.csv (740113, 3) (740113, 3) True
# [ True]
# [ True]
# [ True]
# 10 T_Quadrant II_S_H_2019Q2.csv (190428, 3) (190428, 3) True
# [ True]
# [ True]
# [ True]
# 11 T_Quadrant II_S_L_2019Q2.csv (127530, 3) (127530, 3) True
# ...
