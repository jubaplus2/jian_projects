# %%
import pandas as pd
import os
import numpy as np
import glob

# %%
list_files=glob.glob("./output_No_DCM_2020-11-14_2020-12-13/*.csv")

# %%
list_files
# Out:
# ['./output_No_DCM_2020-11-14_2020-12-13/df_train_ids_labeled_2020-11-14_DV3_trans_1_only.csv',
#  './output_No_DCM_2020-11-14_2020-12-13/df_test_ids_labeled_2020-11-14_DV3_trans_1_only.csv',
#  './output_No_DCM_2020-11-14_2020-12-13/df_test_ids_labeled_2020-11-14_DV2_trans_2_plus.csv',
#  './output_No_DCM_2020-11-14_2020-12-13/df_train_ids_labeled_2020-11-14_DV2_trans_2_plus.csv']

# %%
df=pd.read_csv("./output_No_DCM_2020-11-14_2020-12-13/df_train_ids_labeled_2020-11-14_DV3_trans_1_only.csv",nrows=5000)

# %%
df.tail(30)
# Out:
#                                      customer_id_hashed     y_hat  \
# 4970  07c5a5db6841fa6d49bdbfc851f3190760785202939162...  0.014790
# 4971  07c5b0348b588fa32e27a8f006b245615405c25098534d...  0.022648
# 4972  07c5b869cc92b4de4bacb71ee71e4d365f06a514d95258...  0.035152
# 4973  07c64e2a02ede2676a459a1710e18bc35c7cf63ccaa508...  0.027333
# 4974  07c65bb35d9ce116b3877ac494c51756e85e90e157ff60...  0.032195
# 4975  07c6e26d1f2a9cf7875f98e8fdfa0280acdfd430bce680...  0.055058
# 4976  07c6edec2e809b8bb16ef795b62064c2211992fc76d6d2...  0.035403
# 4977  07c6fefccd288fd47f642f30d0fd6bff8a2c2fb26f3bf6...  0.070618
# 4978  07c720a9bdb324c67558c980641bfd33b35997bea0c008...  0.056725
# 4979  07c74c0b0c519d59cd20f1d7317219f859db62282ec3b4...  0.087597
# 4980  07c7dd2c1ae8d04ae0bbfc93f8d7de62e5f4c1dfc710b0...  0.035504
# 4981  07c7e9e16d03f78f4aeaccda5a3ffd9fd613aa252b94bd...  0.060850
# 4982  07c7f216e9f9362b346a0f092173a8506a235cfd1ecc4b...  0.027307
# ...
