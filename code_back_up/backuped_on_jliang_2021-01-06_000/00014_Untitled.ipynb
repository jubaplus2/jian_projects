# %%
import json
from urllib import request
import time
import datetime

import logging
logging.basicConfig(filename='/home/sharefolder/Weather/Json_data/weather_celery/openweathermap.log',level=logging.INFO,format='%(asctime)s %(message)s')


zip_list =json.load(open('/home/sharefolder/Weather/Json_data/weather_celery/zip_set.json', 'r'))

weather_by_zip = dict()

# %%
i_counter=0
for zip_code in zip_list:
    url = 'http://api.openweathermap.org/data/2.5/weather?zip=%s,us&appid=931f5e95a5c3b97de1c2fccdff056857'%zip_code
    time.sleep(1)
    try:
        req = request.urlopen(url)
        # response = urllib2.urlopen(req)
        result = req.read()

        weather_by_zip[zip_code] = eval(result)
        
        #logging.info('%s suceeded.'%zip_code)
    except Exception as e:
        logging.info('%s %s'%(zip_code, e))
    i_counter+=1
    if i_counter==100:
        break

# %%
weather_by_zip
# Out:
# {'34606': {'coord': {'lon': -82.6, 'lat': 28.47},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 302.71,
#    'feels_like': 310.45,
#    'temp_min': 300.15,
#    'temp_max': 303.71,
#    'pressure': 1016,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 70},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 20},
#   'dt': 1598998552,
#   'sys': {'type': 1,
#    'id': 3457,
#    'country': 'US',
#    'sunrise': 1598958544,
#    'sunset': 1599004310},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Spring Hill',
#   'cod': 200},
#  '72204': {'coord': {'lon': -92.34, 'lat': 34.73},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'},
#    {'id': 211,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm',
#     'icon': '11d'}],
#   'base': 'stations',
#   'main': {'temp': 296.15,
#    'feels_like': 297.27,
#    'temp_min': 296.15,
#    'temp_max': 296.15,
#    'pressure': 1011,
#    'humidity': 94},
#   'visibility': 805,
#   'wind': {'speed': 5.1, 'deg': 230},
#   'rain': {'1h': 8.38},
#   'clouds': {'all': 90},
#   'dt': 1598998564,
#   'sys': {'type': 1,
#    'id': 4717,
#    'country': 'US',
#    'sunrise': 1598960573,
#    'sunset': 1599006956},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Little Rock',
#   'cod': 200},
#  '60435': {'coord': {'lon': -88.13, 'lat': 41.55},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 294.68,
#    'feels_like': 295.54,
#    'temp_min': 294.15,
#    'temp_max': 295.15,
#    'pressure': 1011,
#    'humidity': 100},
#   'visibility': 8047,
#   'wind': {'speed': 5.14, 'deg': 192},
#   'rain': {'1h': 0.84},
#   'clouds': {'all': 90},
#   'dt': 1598998670,
#   'sys': {'type': 1,
#    'id': 4599,
#    'country': 'US',
#    'sunrise': 1598959160,
#    'sunset': 1599006348},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Joliet',
#   'cod': 200},
#  '12832': {'coord': {'lon': -73.3, 'lat': 43.38},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 295.56,
#    'feels_like': 297.04,
#    'temp_min': 294.82,
#    'temp_max': 296.48,
#    'pressure': 1018,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.98, 'deg': 194},
#   'clouds': {'all': 90},
#   'dt': 1598998935,
#   'sys': {'type': 3,
#    'id': 2007023,
#    'country': 'US',
#    'sunrise': 1598955475,
#    'sunset': 1599002916},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Granville',
#   'cod': 200},
#  '91977': {'coord': {'lon': -117, 'lat': 32.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.03,
#    'feels_like': 296.64,
#    'temp_min': 297.04,
#    'temp_max': 300.93,
#    'pressure': 1014,
#    'humidity': 51},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 290},
#   'clouds': {'all': 5},
#   'dt': 1598998672,
#   'sys': {'type': 1,
#    'id': 5800,
#    'country': 'US',
#    'sunrise': 1598966598,
#    'sunset': 1599012764},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Spring Valley',
#   'cod': 200},
#  '28501': {'coord': {'lon': -77.59, 'lat': 35.28},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 303.85,
#    'feels_like': 307.85,
#    'temp_min': 303.15,
#    'temp_max': 304.15,
#    'pressure': 1015,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 330},
#   'clouds': {'all': 40},
#   'dt': 1598998389,
#   'sys': {'type': 1,
#    'id': 4548,
#    'country': 'US',
#    'sunrise': 1598957001,
#    'sunset': 1599003449},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Kinston',
#   'cod': 200},
#  '89436': {'coord': {'lon': -119.71, 'lat': 39.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.42,
#    'feels_like': 297.28,
#    'temp_min': 299.15,
#    'temp_max': 301.15,
#    'pressure': 1024,
#    'humidity': 16},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998938,
#   'sys': {'type': 1,
#    'id': 5724,
#    'country': 'US',
#    'sunrise': 1598966865,
#    'sunset': 1599013797},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Sparks',
#   'cod': 200},
#  '40214': {'coord': {'lon': -85.78, 'lat': 38.16},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 301.25,
#    'feels_like': 302.63,
#    'temp_min': 300.37,
#    'temp_max': 302.15,
#    'pressure': 1012,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 160},
#   'clouds': {'all': 75},
#   'dt': 1598998570,
#   'sys': {'type': 1,
#    'id': 5801,
#    'country': 'US',
#    'sunrise': 1598958805,
#    'sunset': 1599005575},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Louisville',
#   'cod': 200},
#  '45236': {'coord': {'lon': -84.39, 'lat': 39.21},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 301.03,
#    'feels_like': 303.03,
#    'temp_min': 300.37,
#    'temp_max': 301.48,
#    'pressure': 1013,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 220},
#   'clouds': {'all': 20},
#   'dt': 1598998940,
#   'sys': {'type': 1,
#    'id': 4776,
#    'country': 'US',
#    'sunrise': 1598958409,
#    'sunset': 1599005304},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Cincinnati',
#   'cod': 200},
#  '44094': {'coord': {'lon': -81.41, 'lat': 41.63},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 300.13,
#    'feels_like': 302.72,
#    'temp_min': 299.15,
#    'temp_max': 301.48,
#    'pressure': 1013,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 1.46, 'deg': 216},
#   'clouds': {'all': 75},
#   'dt': 1598998678,
#   'sys': {'type': 1,
#    'id': 4728,
#    'country': 'US',
#    'sunrise': 1598957541,
#    'sunset': 1599004742},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Willoughby',
#   'cod': 200},
#  '89128': {'coord': {'lon': -115.26, 'lat': 36.2},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 307.84,
#    'feels_like': 304.37,
#    'temp_min': 305.37,
#    'temp_max': 309.15,
#    'pressure': 1014,
#    'humidity': 11},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 30},
#   'clouds': {'all': 1},
#   'dt': 1598998321,
#   'sys': {'type': 1,
#    'id': 6171,
#    'country': 'US',
#    'sunrise': 1598965996,
#    'sunset': 1599012531},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Las Vegas',
#   'cod': 200},
#  '93711': {'coord': {'lon': -119.83, 'lat': 36.83},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'},
#    {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 308.02,
#    'feels_like': 307.69,
#    'temp_min': 307.15,
#    'temp_max': 308.71,
#    'pressure': 1011,
#    'humidity': 28},
#   'visibility': 6437,
#   'wind': {'speed': 2.1, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998574,
#   'sys': {'type': 1,
#    'id': 4056,
#    'country': 'US',
#    'sunrise': 1598967059,
#    'sunset': 1599013662},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Fresno',
#   'cod': 200},
#  '65803': {'coord': {'lon': -93.29, 'lat': 37.26},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 298.61,
#    'feels_like': 300.37,
#    'temp_min': 298.15,
#    'temp_max': 299.26,
#    'pressure': 1009,
#    'humidity': 74},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 220},
#   'clouds': {'all': 40},
#   'dt': 1598998944,
#   'sys': {'type': 1,
#    'id': 5821,
#    'country': 'US',
#    'sunrise': 1598960661,
#    'sunset': 1599007323},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Springfield',
#   'cod': 200},
#  '78745': {'coord': {'lon': -97.8, 'lat': 30.21},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 308.5,
#    'feels_like': 310.27,
#    'temp_min': 307.04,
#    'temp_max': 310.15,
#    'pressure': 1008,
#    'humidity': 44},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 210, 'gust': 9.3},
#   'clouds': {'all': 20},
#   'dt': 1598998475,
#   'sys': {'type': 1,
#    'id': 3344,
#    'country': 'US',
#    'sunrise': 1598962112,
#    'sunset': 1599008037},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Austin',
#   'cod': 200},
#  '28403': {'coord': {'lon': -77.89, 'lat': 34.22},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 303.12,
#    'feels_like': 306.49,
#    'temp_min': 302.59,
#    'temp_max': 304.15,
#    'pressure': 1014,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 160},
#   'clouds': {'all': 75},
#   'dt': 1598998946,
#   'sys': {'type': 1,
#    'id': 4521,
#    'country': 'US',
#    'sunrise': 1598957130,
#    'sunset': 1599003464},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Wilmington',
#   'cod': 200},
#  '29678': {'coord': {'lon': -82.94, 'lat': 34.68},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 303.88,
#    'feels_like': 308.43,
#    'temp_min': 303.15,
#    'temp_max': 304.82,
#    'pressure': 1015,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 220},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 1},
#   'dt': 1598998948,
#   'sys': {'type': 1,
#    'id': 3596,
#    'country': 'US',
#    'sunrise': 1598958318,
#    'sunset': 1599004699},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Seneca',
#   'cod': 200},
#  '99352': {'coord': {'lon': -119.29, 'lat': 46.25},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 305.27,
#    'feels_like': 304.47,
#    'temp_min': 304.26,
#    'temp_max': 306.15,
#    'pressure': 1015,
#    'humidity': 26},
#   'visibility': 10000,
#   'wind': {'speed': 1.27, 'deg': 276},
#   'clouds': {'all': 1},
#   'dt': 1598998949,
#   'sys': {'type': 1,
#    'id': 5676,
#    'country': 'US',
#    'sunrise': 1598966312,
#    'sunset': 1599014150},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Richland',
#   'cod': 200},
#  '27127': {'coord': {'lon': -80.26, 'lat': 36.04},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 300.06,
#    'feels_like': 304.69,
#    'temp_min': 298.71,
#    'temp_max': 301.48,
#    'pressure': 1017,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 50},
#   'clouds': {'all': 40},
#   'dt': 1598998950,
#   'sys': {'type': 1,
#    'id': 4531,
#    'country': 'US',
#    'sunrise': 1598957601,
#    'sunset': 1599004130},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Winston Salem',
#   'cod': 200},
#  '32771': {'coord': {'lon': -81.28, 'lat': 28.8},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 302.98,
#    'feels_like': 307.59,
#    'temp_min': 301.15,
#    'temp_max': 303.71,
#    'pressure': 1016,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 50},
#   'clouds': {'all': 40},
#   'dt': 1598998509,
#   'sys': {'type': 1,
#    'id': 5811,
#    'country': 'US',
#    'sunrise': 1598958212,
#    'sunset': 1599004008},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Sanford',
#   'cod': 200},
#  '61611': {'coord': {'lon': -89.55, 'lat': 40.67},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 296.01,
#    'feels_like': 298.61,
#    'temp_min': 294.82,
#    'temp_max': 297.04,
#    'pressure': 1010,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 0},
#   'rain': {'1h': 0.51},
#   'clouds': {'all': 40},
#   'dt': 1598998436,
#   'sys': {'type': 1,
#    'id': 5354,
#    'country': 'US',
#    'sunrise': 1598959558,
#    'sunset': 1599006632},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'East Peoria',
#   'cod': 200},
#  '26241': {'coord': {'lon': -79.85, 'lat': 38.93},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 298.89,
#    'feels_like': 303.66,
#    'temp_min': 296.15,
#    'temp_max': 302.04,
#    'pressure': 1016,
#    'humidity': 94},
#   'visibility': 9656,
#   'wind': {'speed': 2.1, 'deg': 160},
#   'rain': {'1h': 1.27},
#   'clouds': {'all': 90},
#   'dt': 1598998953,
#   'sys': {'type': 1,
#    'id': 3966,
#    'country': 'US',
#    'sunrise': 1598957335,
#    'sunset': 1599004199},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Elkins',
#   'cod': 200},
#  '95608': {'coord': {'lon': -121.33, 'lat': 38.63},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 305.34,
#    'feels_like': 304.77,
#    'temp_min': 303.15,
#    'temp_max': 306.48,
#    'pressure': 1011,
#    'humidity': 31},
#   'visibility': 9656,
#   'wind': {'speed': 2.1, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998304,
#   'sys': {'type': 1,
#    'id': 4838,
#    'country': 'US',
#    'sunrise': 1598967315,
#    'sunset': 1599014126},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Carmichael',
#   'cod': 200},
#  '91942': {'coord': {'lon': -117.02, 'lat': 32.78},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.28,
#    'feels_like': 296.97,
#    'temp_min': 297.15,
#    'temp_max': 301.48,
#    'pressure': 1014,
#    'humidity': 51},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 290},
#   'clouds': {'all': 5},
#   'dt': 1598998586,
#   'sys': {'type': 1,
#    'id': 5800,
#    'country': 'US',
#    'sunrise': 1598966600,
#    'sunset': 1599012772},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'La Mesa',
#   'cod': 200},
#  '45750': {'coord': {'lon': -81.46, 'lat': 39.43},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 302.78,
#    'feels_like': 305.08,
#    'temp_min': 302.15,
#    'temp_max': 303.71,
#    'pressure': 1013,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 40},
#   'dt': 1598998956,
#   'sys': {'type': 1,
#    'id': 5365,
#    'country': 'US',
#    'sunrise': 1598957692,
#    'sunset': 1599004615},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Marietta',
#   'cod': 200},
#  '59405': {'coord': {'lon': -111.25, 'lat': 47.49},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.99,
#    'feels_like': 293.04,
#    'temp_min': 299.82,
#    'temp_max': 300.15,
#    'pressure': 1012,
#    'humidity': 21},
#   'visibility': 10000,
#   'wind': {'speed': 7.7, 'deg': 290, 'gust': 12.3},
#   'clouds': {'all': 1},
#   'dt': 1598998454,
#   'sys': {'type': 1,
#    'id': 4204,
#    'country': 'US',
#    'sunrise': 1598964283,
#    'sunset': 1599012320},
#   'timezone': -21600,
#   'id': 0,
#   'name': 'Great Falls',
#   'cod': 200},
#  '29303': {'coord': {'lon': -81.92, 'lat': 34.98},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 304.15,
#    'feels_like': 307.67,
#    'temp_min': 303.71,
#    'temp_max': 304.82,
#    'pressure': 1015,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 180},
#   'clouds': {'all': 40},
#   'dt': 1598998958,
#   'sys': {'type': 1,
#    'id': 5896,
#    'country': 'US',
#    'sunrise': 1598958057,
#    'sunset': 1599004471},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Spartanburg',
#   'cod': 200},
#  '43953': {'coord': {'lon': -80.68, 'lat': 40.35},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 301.26,
#    'feels_like': 303.05,
#    'temp_min': 300.37,
#    'temp_max': 302.15,
#    'pressure': 1014,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 150},
#   'clouds': {'all': 40},
#   'dt': 1598998959,
#   'sys': {'type': 1,
#    'id': 4384,
#    'country': 'US',
#    'sunrise': 1598957448,
#    'sunset': 1599004485},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Steubenville',
#   'cod': 200},
#  '89701': {'coord': {'lon': -119.75, 'lat': 39.15},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 302.4,
#    'feels_like': 295.31,
#    'temp_min': 302.04,
#    'temp_max': 303.15,
#    'pressure': 1022,
#    'humidity': 12},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 80},
#   'clouds': {'all': 1},
#   'dt': 1598998809,
#   'sys': {'type': 1,
#    'id': 3750,
#    'country': 'US',
#    'sunrise': 1598966904,
#    'sunset': 1599013778},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Carson City',
#   'cod': 200},
#  '21740': {'coord': {'lon': -77.74, 'lat': 39.63},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 294.39,
#    'feels_like': 296.43,
#    'temp_min': 293.15,
#    'temp_max': 295.37,
#    'pressure': 1016,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 2.52, 'deg': 147},
#   'rain': {'1h': 0.36},
#   'clouds': {'all': 97},
#   'dt': 1598998698,
#   'sys': {'type': 3,
#    'id': 2004643,
#    'country': 'US',
#    'sunrise': 1598956786,
#    'sunset': 1599003736},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Hagerstown',
#   'cod': 200},
#  '30087': {'coord': {'lon': -84.14, 'lat': 33.81},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 303.92,
#    'feels_like': 306.44,
#    'temp_min': 302.59,
#    'temp_max': 305.37,
#    'pressure': 1015,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 270},
#   'clouds': {'all': 20},
#   'dt': 1598998699,
#   'sys': {'type': 1,
#    'id': 5323,
#    'country': 'US',
#    'sunrise': 1598958652,
#    'sunset': 1599004941},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Stone Mountain',
#   'cod': 200},
#  '74075': {'coord': {'lon': -97.06, 'lat': 36.14},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.04,
#    'feels_like': 299.25,
#    'temp_min': 297.15,
#    'temp_max': 298.71,
#    'pressure': 1009,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1598998963,
#   'sys': {'type': 1,
#    'id': 3720,
#    'country': 'US',
#    'sunrise': 1598961629,
#    'sunset': 1599008164},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Stillwater',
#   'cod': 200},
#  '98270': {'coord': {'lon': -122.16, 'lat': 48.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.17,
#    'feels_like': 297.57,
#    'temp_min': 297.04,
#    'temp_max': 299.26,
#    'pressure': 1021,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998965,
#   'sys': {'type': 1,
#    'id': 3363,
#    'country': 'US',
#    'sunrise': 1598966856,
#    'sunset': 1599014982},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Marysville',
#   'cod': 200},
#  '33063': {'coord': {'lon': -80.21, 'lat': 26.27},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 305.01,
#    'feels_like': 306.29,
#    'temp_min': 304.26,
#    'temp_max': 306.15,
#    'pressure': 1016,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 110},
#   'clouds': {'all': 20},
#   'dt': 1598998598,
#   'sys': {'type': 1,
#    'id': 4167,
#    'country': 'US',
#    'sunrise': 1598958070,
#    'sunset': 1599003637},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Pompano Beach',
#   'cod': 200},
#  '45255': {'coord': {'lon': -84.34, 'lat': 39.06},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 300.98,
#    'feels_like': 302.95,
#    'temp_min': 300.37,
#    'temp_max': 301.48,
#    'pressure': 1013,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 220},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 20},
#   'dt': 1598998967,
#   'sys': {'type': 1,
#    'id': 4776,
#    'country': 'US',
#    'sunrise': 1598958406,
#    'sunset': 1599005283},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Cincinnati',
#   'cod': 200},
#  '14701': {'coord': {'lon': -79.24, 'lat': 42.09},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 295.74,
#    'feels_like': 297.06,
#    'temp_min': 294.15,
#    'temp_max': 297.04,
#    'pressure': 1016,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 160},
#   'clouds': {'all': 90},
#   'dt': 1598998466,
#   'sys': {'type': 1,
#    'id': 4588,
#    'country': 'US',
#    'sunrise': 1598956989,
#    'sunset': 1599004252},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Jamestown',
#   'cod': 200},
#  '91324': {'coord': {'lon': -118.55, 'lat': 34.24},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 303.55,
#    'feels_like': 302.38,
#    'temp_min': 299.82,
#    'temp_max': 305.93,
#    'pressure': 1013,
#    'humidity': 35},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 0, 'gust': 7.7},
#   'clouds': {'all': 1},
#   'dt': 1598998969,
#   'sys': {'type': 1,
#    'id': 6183,
#    'country': 'US',
#    'sunrise': 1598966892,
#    'sunset': 1599013214},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Northridge',
#   'cod': 200},
#  '39208': {'coord': {'lon': -90.09, 'lat': 32.26},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 306.38,
#    'feels_like': 307.6,
#    'temp_min': 305.15,
#    'temp_max': 307.59,
#    'pressure': 1013,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 200},
#   'clouds': {'all': 20},
#   'dt': 1598998742,
#   'sys': {'type': 1,
#    'id': 4568,
#    'country': 'US',
#    'sunrise': 1598960160,
#    'sunset': 1599006288},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Pearl',
#   'cod': 200},
#  '22630': {'coord': {'lon': -78.18, 'lat': 38.93},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 295.97,
#    'feels_like': 299.49,
#    'temp_min': 294.26,
#    'temp_max': 297.59,
#    'pressure': 1016,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 143},
#   'clouds': {'all': 90},
#   'dt': 1598998603,
#   'sys': {'type': 1,
#    'id': 4136,
#    'country': 'US',
#    'sunrise': 1598956934,
#    'sunset': 1599003798},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Front Royal',
#   'cod': 200},
#  '23294': {'coord': {'lon': -77.4, 'lat': 37.46},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.42,
#    'feels_like': 301.04,
#    'temp_min': 297.59,
#    'temp_max': 299.15,
#    'pressure': 1016,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 80},
#   'clouds': {'all': 75},
#   'dt': 1598998804,
#   'sys': {'type': 1,
#    'id': 5662,
#    'country': 'US',
#    'sunrise': 1598956834,
#    'sunset': 1599003525},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Henrico',
#   'cod': 200},
#  '31404': {'coord': {'lon': -81.05, 'lat': 32.05},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 305.42,
#    'feels_like': 308.2,
#    'temp_min': 304.26,
#    'temp_max': 307.15,
#    'pressure': 1013,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 150},
#   'clouds': {'all': 1},
#   'dt': 1598998973,
#   'sys': {'type': 1,
#    'id': 5948,
#    'country': 'US',
#    'sunrise': 1598958000,
#    'sunset': 1599004110},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Savannah',
#   'cod': 200},
#  '08753': {'coord': {'lon': -74.16, 'lat': 39.98},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 296.9,
#    'feels_like': 298.41,
#    'temp_min': 296.48,
#    'temp_max': 297.59,
#    'pressure': 1019,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 90},
#   'clouds': {'all': 75},
#   'dt': 1598998711,
#   'sys': {'type': 1,
#    'id': 4907,
#    'country': 'US',
#    'sunrise': 1598955905,
#    'sunset': 1599002899},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Toms River',
#   'cod': 200},
#  '62901': {'coord': {'lon': -89.22, 'lat': 37.72},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 295.69,
#    'feels_like': 297.27,
#    'temp_min': 295.15,
#    'temp_max': 296.15,
#    'pressure': 1011,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 150},
#   'clouds': {'all': 90},
#   'dt': 1598998476,
#   'sys': {'type': 1,
#    'id': 4858,
#    'country': 'US',
#    'sunrise': 1598959657,
#    'sunset': 1599006374},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Carbondale',
#   'cod': 200},
#  '95667': {'coord': {'lon': -120.8, 'lat': 38.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 305.84,
#    'feels_like': 303.57,
#    'temp_min': 304.82,
#    'temp_max': 307.04,
#    'pressure': 1017,
#    'humidity': 24},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 1},
#   'dt': 1598998750,
#   'sys': {'type': 1,
#    'id': 5440,
#    'country': 'US',
#    'sunrise': 1598967182,
#    'sunset': 1599014004},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Placerville',
#   'cod': 200},
#  '43055': {'coord': {'lon': -82.4, 'lat': 40.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.51,
#    'feels_like': 303.72,
#    'temp_min': 299.82,
#    'temp_max': 301.15,
#    'pressure': 1013,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 240},
#   'clouds': {'all': 1},
#   'dt': 1598998714,
#   'sys': {'type': 1,
#    'id': 6204,
#    'country': 'US',
#    'sunrise': 1598957878,
#    'sunset': 1599004880},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Newark',
#   'cod': 200},
#  '32308': {'coord': {'lon': -84.22, 'lat': 30.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 301.11,
#    'feels_like': 306.21,
#    'temp_min': 299.15,
#    'temp_max': 302.15,
#    'pressure': 1016,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1598998978,
#   'sys': {'type': 1,
#    'id': 6031,
#    'country': 'US',
#    'sunrise': 1598958838,
#    'sunset': 1599004793},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Tallahassee',
#   'cod': 200},
#  '76205': {'coord': {'lon': -97.13, 'lat': 33.19},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'},
#    {'id': 202,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm with heavy rain',
#     'icon': '11d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 295.77,
#    'feels_like': 295.92,
#    'temp_min': 295.37,
#    'temp_max': 296.15,
#    'pressure': 1009,
#    'humidity': 94},
#   'visibility': 3219,
#   'wind': {'speed': 6.2, 'deg': 130, 'gust': 9.3},
#   'rain': {'1h': 4.32},
#   'clouds': {'all': 90},
#   'dt': 1598998612,
#   'sys': {'type': 1,
#    'id': 3862,
#    'country': 'US',
#    'sunrise': 1598961803,
#    'sunset': 1599008024},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Denton',
#   'cod': 200},
#  '56425': {'coord': {'lon': -94.28, 'lat': 46.34},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 292.6,
#    'feels_like': 288.7,
#    'temp_min': 292.15,
#    'temp_max': 293.15,
#    'pressure': 1005,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 190},
#   'clouds': {'all': 90},
#   'dt': 1598998717,
#   'sys': {'type': 1,
#    'id': 3497,
#    'country': 'US',
#    'sunrise': 1598960297,
#    'sunset': 1599008162},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Baxter',
#   'cod': 200},
#  '92203': {'coord': {'lon': -116.27, 'lat': 33.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 313.56,
#    'feels_like': 312.76,
#    'temp_min': 312.59,
#    'temp_max': 314.26,
#    'pressure': 1006,
#    'humidity': 18},
#   'visibility': 10000,
#   'wind': {'speed': 1.8, 'deg': 200},
#   'clouds': {'all': 0},
#   'dt': 1598998614,
#   'sys': {'type': 3,
#    'id': 2006328,
#    'country': 'US',
#    'sunrise': 1598966370,
#    'sunset': 1599012642},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Indio',
#   'cod': 200},
#  '60110': {'coord': {'lon': -88.26, 'lat': 42.12},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.42,
#    'feels_like': 294.61,
#    'temp_min': 292.59,
#    'temp_max': 294.26,
#    'pressure': 1011,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 2.42, 'deg': 152},
#   'clouds': {'all': 90},
#   'dt': 1598998927,
#   'sys': {'type': 1,
#    'id': 2658,
#    'country': 'US',
#    'sunrise': 1598959154,
#    'sunset': 1599006417},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Carpentersville',
#   'cod': 200},
#  '20770': {'coord': {'lon': -76.88, 'lat': 39},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.25,
#    'feels_like': 299.87,
#    'temp_min': 297.04,
#    'temp_max': 299.82,
#    'pressure': 1017,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 2.9, 'deg': 111},
#   'clouds': {'all': 90},
#   'dt': 1598998983,
#   'sys': {'type': 1,
#    'id': 3614,
#    'country': 'US',
#    'sunrise': 1598956618,
#    'sunset': 1599003491},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Greenbelt',
#   'cod': 200},
#  '36571': {'coord': {'lon': -88.09, 'lat': 30.83},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 304.12,
#    'feels_like': 309.03,
#    'temp_min': 303.71,
#    'temp_max': 304.82,
#    'pressure': 1015,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 3.7, 'deg': 211},
#   'clouds': {'all': 26},
#   'dt': 1598998984,
#   'sys': {'type': 3,
#    'id': 2003944,
#    'country': 'US',
#    'sunrise': 1598959751,
#    'sunset': 1599005738},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Saraland',
#   'cod': 200},
#  '32609': {'coord': {'lon': -82.31, 'lat': 29.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 302.59,
#    'feels_like': 307.8,
#    'temp_min': 302.15,
#    'temp_max': 303.15,
#    'pressure': 1017,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 230},
#   'clouds': {'all': 1},
#   'dt': 1598998374,
#   'sys': {'type': 1,
#    'id': 4247,
#    'country': 'US',
#    'sunrise': 1598958417,
#    'sunset': 1599004298},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Gainesville',
#   'cod': 200},
#  '05641': {'coord': {'lon': -72.49, 'lat': 44.19},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 294.39,
#    'feels_like': 291.8,
#    'temp_min': 294.15,
#    'temp_max': 294.82,
#    'pressure': 1021,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 160},
#   'clouds': {'all': 90},
#   'dt': 1598998987,
#   'sys': {'type': 1,
#    'id': 4960,
#    'country': 'US',
#    'sunrise': 1598955223,
#    'sunset': 1599002779},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Barre',
#   'cod': 200},
#  '76801': {'coord': {'lon': -98.99, 'lat': 31.78},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 308.33,
#    'feels_like': 308.74,
#    'temp_min': 304.15,
#    'temp_max': 311.15,
#    'pressure': 1006,
#    'humidity': 39},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 180, 'gust': 8.7},
#   'clouds': {'all': 75},
#   'dt': 1598998578,
#   'sys': {'type': 1,
#    'id': 3535,
#    'country': 'US',
#    'sunrise': 1598962321,
#    'sunset': 1599008398},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Brownwood',
#   'cod': 200},
#  '54303': {'coord': {'lon': -88.08, 'lat': 44.55},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.03,
#    'feels_like': 292.07,
#    'temp_min': 292.15,
#    'temp_max': 293.71,
#    'pressure': 1010,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1598998939,
#   'sys': {'type': 1,
#    'id': 4258,
#    'country': 'US',
#    'sunrise': 1598958942,
#    'sunset': 1599006542},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Green Bay',
#   'cod': 200},
#  '33157': {'coord': {'lon': -80.34, 'lat': 25.61},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 304.78,
#    'feels_like': 305.58,
#    'temp_min': 303.71,
#    'temp_max': 305.93,
#    'pressure': 1016,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 130},
#   'clouds': {'all': 1},
#   'dt': 1598998726,
#   'sys': {'type': 1,
#    'id': 6041,
#    'country': 'US',
#    'sunrise': 1598958130,
#    'sunset': 1599003639},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Miami',
#   'cod': 200},
#  '06473': {'coord': {'lon': -72.86, 'lat': 41.38},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 295.99,
#    'feels_like': 294.33,
#    'temp_min': 294.82,
#    'temp_max': 297.15,
#    'pressure': 1020,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 120, 'gust': 9.3},
#   'clouds': {'all': 40},
#   'dt': 1598998623,
#   'sys': {'type': 1,
#    'id': 4445,
#    'country': 'US',
#    'sunrise': 1598955504,
#    'sunset': 1599002676},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'North Haven',
#   'cod': 200},
#  '19154': {'coord': {'lon': -74.98, 'lat': 40.09},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.21,
#    'feels_like': 298.84,
#    'temp_min': 297.59,
#    'temp_max': 298.71,
#    'pressure': 1018,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 140},
#   'clouds': {'all': 90},
#   'dt': 1598998581,
#   'sys': {'type': 1,
#    'id': 5384,
#    'country': 'US',
#    'sunrise': 1598956095,
#    'sunset': 1599003102},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Philadelphia',
#   'cod': 200},
#  '38122': {'coord': {'lon': -89.93, 'lat': 35.16},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 304.37,
#    'feels_like': 307.02,
#    'temp_min': 303.71,
#    'temp_max': 304.82,
#    'pressure': 1012,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 190},
#   'clouds': {'all': 75},
#   'dt': 1598998514,
#   'sys': {'type': 1,
#    'id': 4867,
#    'country': 'US',
#    'sunrise': 1598959971,
#    'sunset': 1599006401},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Memphis',
#   'cod': 200},
#  '45030': {'coord': {'lon': -84.78, 'lat': 39.26},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.47,
#    'feels_like': 303.25,
#    'temp_min': 299.82,
#    'temp_max': 300.93,
#    'pressure': 1012,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 200},
#   'clouds': {'all': 1},
#   'dt': 1598998994,
#   'sys': {'type': 1,
#    'id': 4476,
#    'country': 'US',
#    'sunrise': 1598958499,
#    'sunset': 1599005401},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Harrison',
#   'cod': 200},
#  '95240': {'coord': {'lon': -121.26, 'lat': 38.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 304.6,
#    'feels_like': 301.31,
#    'temp_min': 304.15,
#    'temp_max': 304.82,
#    'pressure': 1012,
#    'humidity': 31},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 300},
#   'clouds': {'all': 1},
#   'dt': 1598998628,
#   'sys': {'type': 1,
#    'id': 5789,
#    'country': 'US',
#    'sunrise': 1598967328,
#    'sunset': 1599014079},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Lodi',
#   'cod': 200},
#  '43015': {'coord': {'lon': -83.07, 'lat': 40.29},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 300.48,
#    'feels_like': 302.74,
#    'temp_min': 299.82,
#    'temp_max': 300.93,
#    'pressure': 1013,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 2.84, 'deg': 220},
#   'clouds': {'all': 75},
#   'dt': 1598998706,
#   'sys': {'type': 1,
#    'id': 3832,
#    'country': 'US',
#    'sunrise': 1598958025,
#    'sunset': 1599005054},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Delaware',
#   'cod': 200},
#  '45631': {'coord': {'lon': -82.23, 'lat': 38.81},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 303.77,
#    'feels_like': 307.68,
#    'temp_min': 302.15,
#    'temp_max': 305.93,
#    'pressure': 1013,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 250},
#   'clouds': {'all': 1},
#   'dt': 1598998997,
#   'sys': {'type': 1,
#    'id': 6138,
#    'country': 'US',
#    'sunrise': 1598957914,
#    'sunset': 1599004762},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Gallipolis',
#   'cod': 200},
#  '97459': {'coord': {'lon': -124.21, 'lat': 43.43},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.76,
#    'feels_like': 294.01,
#    'temp_min': 292.15,
#    'temp_max': 307.04,
#    'pressure': 1017,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 10.8, 'deg': 350},
#   'clouds': {'all': 1},
#   'dt': 1598998735,
#   'sys': {'type': 1,
#    'id': 5239,
#    'country': 'US',
#    'sunrise': 1598967699,
#    'sunset': 1599015123},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'North Bend',
#   'cod': 200},
#  '94520': {'coord': {'lon': -122.04, 'lat': 37.98},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.19,
#    'feels_like': 294.8,
#    'temp_min': 293.71,
#    'temp_max': 300.93,
#    'pressure': 1014,
#    'humidity': 44},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 270},
#   'clouds': {'all': 1},
#   'dt': 1598998632,
#   'sys': {'type': 1,
#    'id': 3581,
#    'country': 'US',
#    'sunrise': 1598967523,
#    'sunset': 1599014258},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Concord',
#   'cod': 200},
#  '19348': {'coord': {'lon': -75.7, 'lat': 39.85},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 296.6,
#    'feels_like': 298.48,
#    'temp_min': 295.37,
#    'temp_max': 297.59,
#    'pressure': 1018,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 90},
#   'clouds': {'all': 90},
#   'dt': 1598998631,
#   'sys': {'type': 1,
#    'id': 5209,
#    'country': 'US',
#    'sunrise': 1598956283,
#    'sunset': 1599003260},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Kennett Square',
#   'cod': 200},
#  '93010': {'coord': {'lon': -119.05, 'lat': 34.23},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 297.1,
#    'feels_like': 294.13,
#    'temp_min': 293.71,
#    'temp_max': 298.71,
#    'pressure': 1014,
#    'humidity': 47},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 240},
#   'clouds': {'all': 1},
#   'dt': 1598998634,
#   'sys': {'type': 1,
#    'id': 3649,
#    'country': 'US',
#    'sunrise': 1598967013,
#    'sunset': 1599013333},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Camarillo',
#   'cod': 200},
#  '38671': {'coord': {'lon': -90, 'lat': 34.98},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 304.41,
#    'feels_like': 307.09,
#    'temp_min': 303.71,
#    'temp_max': 305.37,
#    'pressure': 1012,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 190},
#   'clouds': {'all': 75},
#   'dt': 1598998642,
#   'sys': {'type': 1,
#    'id': 4867,
#    'country': 'US',
#    'sunrise': 1598959997,
#    'sunset': 1599006408},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Southaven',
#   'cod': 200},
#  '48604': {'coord': {'lon': -83.95, 'lat': 43.47},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 297.52,
#    'feels_like': 299.88,
#    'temp_min': 296.15,
#    'temp_max': 298.15,
#    'pressure': 1011,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 30},
#   'clouds': {'all': 75},
#   'dt': 1598998505,
#   'sys': {'type': 1,
#    'id': 4459,
#    'country': 'US',
#    'sunrise': 1598958026,
#    'sunset': 1599005475},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Saginaw',
#   'cod': 200},
#  '33777': {'coord': {'lon': -82.73, 'lat': 27.87},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 304.36,
#    'feels_like': 308.31,
#    'temp_min': 303.15,
#    'temp_max': 305.93,
#    'pressure': 1016,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 300},
#   'clouds': {'all': 40},
#   'dt': 1598998638,
#   'sys': {'type': 1,
#    'id': 5356,
#    'country': 'US',
#    'sunrise': 1598958603,
#    'sunset': 1599004313},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Seminole',
#   'cod': 200},
#  '28625': {'coord': {'lon': -80.89, 'lat': 35.87},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 299.61,
#    'feels_like': 303.42,
#    'temp_min': 298.71,
#    'temp_max': 300.15,
#    'pressure': 1016,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 90},
#   'clouds': {'all': 40},
#   'dt': 1598998552,
#   'sys': {'type': 1,
#    'id': 5941,
#    'country': 'US',
#    'sunrise': 1598957761,
#    'sunset': 1599004272},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Statesville',
#   'cod': 200},
#  '42431': {'coord': {'lon': -87.5, 'lat': 37.33},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 298.54,
#    'feels_like': 301.94,
#    'temp_min': 298.15,
#    'temp_max': 299.15,
#    'pressure': 1013,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.07, 'deg': 168},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 90},
#   'dt': 1598998640,
#   'sys': {'type': 1,
#    'id': 2815,
#    'country': 'US',
#    'sunrise': 1598959267,
#    'sunset': 1599005939},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Madisonville',
#   'cod': 200},
#  '22304': {'coord': {'lon': -77.12, 'lat': 38.81},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 298.62,
#    'feels_like': 298.99,
#    'temp_min': 297.04,
#    'temp_max': 300.15,
#    'pressure': 1016,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 130},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 75},
#   'dt': 1598998641,
#   'sys': {'type': 1,
#    'id': 3787,
#    'country': 'US',
#    'sunrise': 1598956687,
#    'sunset': 1599003537},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Alexandria',
#   'cod': 200},
#  '95678': {'coord': {'lon': -121.29, 'lat': 38.76},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 305.94,
#    'feels_like': 305.54,
#    'temp_min': 304.82,
#    'temp_max': 307.04,
#    'pressure': 1011,
#    'humidity': 31},
#   'visibility': 9656,
#   'wind': {'speed': 2.1, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998642,
#   'sys': {'type': 1,
#    'id': 4838,
#    'country': 'US',
#    'sunrise': 1598967297,
#    'sunset': 1599014124},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Roseville',
#   'cod': 200},
#  '39440': {'coord': {'lon': -89.13, 'lat': 31.71},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 306.26,
#    'feels_like': 307.69,
#    'temp_min': 306.15,
#    'temp_max': 306.48,
#    'pressure': 1014,
#    'humidity': 52},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 210},
#   'clouds': {'all': 1},
#   'dt': 1598998746,
#   'sys': {'type': 1,
#    'id': 4775,
#    'country': 'US',
#    'sunrise': 1598959957,
#    'sunset': 1599006031},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Laurel',
#   'cod': 200},
#  '91744': {'coord': {'lon': -117.94, 'lat': 34.03},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 302.23,
#    'feels_like': 301.62,
#    'temp_min': 300.93,
#    'temp_max': 303.71,
#    'pressure': 1013,
#    'humidity': 42},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 1},
#   'dt': 1598999010,
#   'sys': {'type': 1,
#    'id': 3971,
#    'country': 'US',
#    'sunrise': 1598966757,
#    'sunset': 1599013057},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'La Puente',
#   'cod': 200},
#  '32257': {'coord': {'lon': -81.61, 'lat': 30.19},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 302.27,
#    'feels_like': 305.53,
#    'temp_min': 301.48,
#    'temp_max': 302.59,
#    'pressure': 1015,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 160},
#   'clouds': {'all': 75},
#   'dt': 1598998748,
#   'sys': {'type': 1,
#    'id': 5093,
#    'country': 'US',
#    'sunrise': 1598958226,
#    'sunset': 1599004153},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Jacksonville',
#   'cod': 200},
#  '33764': {'coord': {'lon': -82.73, 'lat': 27.92},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 304.33,
#    'feels_like': 308.26,
#    'temp_min': 303.15,
#    'temp_max': 305.93,
#    'pressure': 1016,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 300},
#   'clouds': {'all': 40},
#   'dt': 1598998647,
#   'sys': {'type': 1,
#    'id': 5356,
#    'country': 'US',
#    'sunrise': 1598958601,
#    'sunset': 1599004316},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Clearwater',
#   'cod': 200},
#  '44202': {'coord': {'lon': -81.35, 'lat': 41.32},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.21,
#    'feels_like': 300.36,
#    'temp_min': 298.15,
#    'temp_max': 300.37,
#    'pressure': 1014,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 2.31, 'deg': 209},
#   'clouds': {'all': 1},
#   'dt': 1598999013,
#   'sys': {'type': 1,
#    'id': 5396,
#    'country': 'US',
#    'sunrise': 1598957547,
#    'sunset': 1599004708},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Aurora',
#   'cod': 200},
#  '90241': {'coord': {'lon': -118.13, 'lat': 33.94},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.79,
#    'feels_like': 298.31,
#    'temp_min': 296.15,
#    'temp_max': 302.59,
#    'pressure': 1014,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 310},
#   'clouds': {'all': 1},
#   'dt': 1598998649,
#   'sys': {'type': 1,
#    'id': 4699,
#    'country': 'US',
#    'sunrise': 1598966807,
#    'sunset': 1599013098},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Downey',
#   'cod': 200},
#  '37922': {'coord': {'lon': -84.12, 'lat': 35.86},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 303.05,
#    'feels_like': 305.13,
#    'temp_min': 301.48,
#    'temp_max': 304.15,
#    'pressure': 1014,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1598998515,
#   'sys': {'type': 1,
#    'id': 6098,
#    'country': 'US',
#    'sunrise': 1598958537,
#    'sunset': 1599005046},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Knoxville',
#   'cod': 200},
#  '92054': {'coord': {'lon': -117.36, 'lat': 33.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.33,
#    'feels_like': 295.99,
#    'temp_min': 296.15,
#    'temp_max': 300.15,
#    'pressure': 1014,
#    'humidity': 57},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 250, 'gust': 9.3},
#   'clouds': {'all': 1},
#   'dt': 1598998651,
#   'sys': {'type': 1,
#    'id': 5191,
#    'country': 'US',
#    'sunrise': 1598966660,
#    'sunset': 1599012875},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Oceanside',
#   'cod': 200},
#  '43081': {'coord': {'lon': -82.91, 'lat': 40.11},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 300.85,
#    'feels_like': 303.32,
#    'temp_min': 300.37,
#    'temp_max': 301.48,
#    'pressure': 1013,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 190},
#   'clouds': {'all': 75},
#   'dt': 1598998755,
#   'sys': {'type': 1,
#    'id': 3656,
#    'country': 'US',
#    'sunrise': 1598957998,
#    'sunset': 1599005005},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Westerville',
#   'cod': 200},
#  '02360': {'coord': {'lon': -70.64, 'lat': 41.91},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 293.77,
#    'feels_like': 291.14,
#    'temp_min': 292.59,
#    'temp_max': 295.15,
#    'pressure': 1021,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 110},
#   'clouds': {'all': 1},
#   'dt': 1598999018,
#   'sys': {'type': 1,
#    'id': 5456,
#    'country': 'US',
#    'sunrise': 1598954936,
#    'sunset': 1599002179},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Plymouth',
#   'cod': 200},
#  '30009': {'coord': {'lon': -84.3, 'lat': 34.08},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 303.32,
#    'feels_like': 308.5,
#    'temp_min': 302.59,
#    'temp_max': 304.26,
#    'pressure': 1015,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.18, 'deg': 296},
#   'clouds': {'all': 97},
#   'dt': 1598998758,
#   'sys': {'type': 3,
#    'id': 2007397,
#    'country': 'US',
#    'sunrise': 1598958676,
#    'sunset': 1599004993},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Alpharetta',
#   'cod': 200},
#  '80916': {'coord': {'lon': -104.74, 'lat': 38.81},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 296.89,
#    'feels_like': 293.91,
#    'temp_min': 295.15,
#    'temp_max': 298.15,
#    'pressure': 1018,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 0},
#   'clouds': {'all': 40},
#   'dt': 1598998657,
#   'sys': {'type': 1,
#    'id': 3678,
#    'country': 'US',
#    'sunrise': 1598963320,
#    'sunset': 1599010159},
#   'timezone': -21600,
#   'id': 0,
#   'name': 'Colorado Springs',
#   'cod': 200},
#  '85715': {'coord': {'lon': -110.82, 'lat': 32.25},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 307.67,
#    'feels_like': 305.09,
#    'temp_min': 306.48,
#    'temp_max': 308.71,
#    'pressure': 1014,
#    'humidity': 32},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 290},
#   'clouds': {'all': 20},
#   'dt': 1598998658,
#   'sys': {'type': 1,
#    'id': 3827,
#    'country': 'US',
#    'sunrise': 1598965138,
#    'sunset': 1599011259},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Tucson',
#   'cod': 200},
#  '93901': {'coord': {'lon': -121.66, 'lat': 36.67},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.12,
#    'feels_like': 289.65,
#    'temp_min': 291.48,
#    'temp_max': 296.15,
#    'pressure': 1016,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 330},
#   'clouds': {'all': 90},
#   'dt': 1598999024,
#   'sys': {'type': 1,
#    'id': 5885,
#    'country': 'US',
#    'sunrise': 1598967507,
#    'sunset': 1599014092},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Salinas',
#   'cod': 200},
#  '33629': {'coord': {'lon': -82.51, 'lat': 27.92},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 304.59,
#    'feels_like': 305.72,
#    'temp_min': 303.15,
#    'temp_max': 306.15,
#    'pressure': 1016,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 4.58, 'deg': 291},
#   'clouds': {'all': 1},
#   'dt': 1598998745,
#   'sys': {'type': 1,
#    'id': 6046,
#    'country': 'US',
#    'sunrise': 1598958548,
#    'sunset': 1599004263},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Tampa',
#   'cod': 200},
#  '91011': {'coord': {'lon': -118.21, 'lat': 34.22},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 301.48,
#    'feels_like': 300.63,
#    'temp_min': 299.82,
#    'temp_max': 303.15,
#    'pressure': 1013,
#    'humidity': 42},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 180},
#   'clouds': {'all': 1},
#   'dt': 1598998763,
#   'sys': {'type': 1,
#    'id': 3514,
#    'country': 'US',
#    'sunrise': 1598966811,
#    'sunset': 1599013132},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'La Canada Flintridge',
#   'cod': 200},
#  '32055': {'coord': {'lon': -82.63, 'lat': 30.27},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.03,
#    'feels_like': 305.23,
#    'temp_min': 299.15,
#    'temp_max': 301.15,
#    'pressure': 1016,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 220},
#   'clouds': {'all': 1},
#   'dt': 1598998662,
#   'sys': {'type': 1,
#    'id': 4685,
#    'country': 'US',
#    'sunrise': 1598958467,
#    'sunset': 1599004402},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Lake City',
#   'cod': 200},
#  '31206': {'coord': {'lon': -83.68, 'lat': 32.79},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 306.89,
#    'feels_like': 309.87,
#    'temp_min': 306.15,
#    'temp_max': 307.59,
#    'pressure': 1014,
#    'humidity': 49},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 220},
#   'clouds': {'all': 20},
#   'dt': 1598998640,
#   'sys': {'type': 1,
#    'id': 4849,
#    'country': 'US',
#    'sunrise': 1598958594,
#    'sunset': 1599004778},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Macon',
#   'cod': 200},
#  '85210': {'coord': {'lon': -111.84, 'lat': 33.39},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 311.06,
#    'feels_like': 309.34,
#    'temp_min': 309.15,
#    'temp_max': 312.04,
#    'pressure': 1010,
#    'humidity': 27},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 260, 'gust': 9.3},
#   'clouds': {'all': 1},
#   'dt': 1598998521,
#   'sys': {'type': 1,
#    'id': 4084,
#    'country': 'US',
#    'sunrise': 1598965325,
#    'sunset': 1599011561},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Mesa',
#   'cod': 200},
#  '46131': {'coord': {'lon': -86.06, 'lat': 39.49},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 298.71,
#    'feels_like': 301.73,
#    'temp_min': 298.15,
#    'temp_max': 299.26,
#    'pressure': 1013,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.75, 'deg': 180},
#   'clouds': {'all': 40},
#   'dt': 1598998665,
#   'sys': {'type': 1,
#    'id': 4345,
#    'country': 'US',
#    'sunrise': 1598958793,
#    'sunset': 1599005722},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Franklin',
#   'cod': 200},
#  '98374': {'coord': {'lon': -122.27, 'lat': 47.14},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.01,
#    'feels_like': 298.73,
#    'temp_min': 298.71,
#    'temp_max': 300.93,
#    'pressure': 1021,
#    'humidity': 42},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998666,
#   'sys': {'type': 1,
#    'id': 5366,
#    'country': 'US',
#    'sunrise': 1598966958,
#    'sunset': 1599014933},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Puyallup',
#   'cod': 200},
#  '79936': {'coord': {'lon': -106.3, 'lat': 31.77},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 306.62,
#    'feels_like': 300.63,
#    'temp_min': 305.93,
#    'temp_max': 307.15,
#    'pressure': 1013,
#    'humidity': 20},
#   'visibility': 10000,
#   'wind': {'speed': 7.7, 'deg': 300, 'gust': 12.3},
#   'clouds': {'all': 20},
#   'dt': 1598998770,
#   'sys': {'type': 1,
#    'id': 3974,
#    'country': 'US',
#    'sunrise': 1598964077,
#    'sunset': 1599010151},
#   'timezone': -21600,
#   'id': 0,
#   'name': 'El Paso',
#   'cod': 200},
#  '28805': {'coord': {'lon': -82.49, 'lat': 35.6},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.93,
#    'feels_like': 300.29,
#    'temp_min': 297.04,
#    'temp_max': 301.15,
#    'pressure': 1017,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 90},
#   'dt': 1598999033,
#   'sys': {'type': 1,
#    'id': 3351,
#    'country': 'US',
#    'sunrise': 1598958160,
#    'sunset': 1599004641},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Asheville',
#   'cod': 200},
#  '74012': {'coord': {'lon': -95.81, 'lat': 36.04},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 297.64,
#    'feels_like': 299.25,
#    'temp_min': 297.04,
#    'temp_max': 298.71,
#    'pressure': 1011,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 2.24, 'deg': 248, 'gust': 4.92},
#   'clouds': {'all': 100},
#   'dt': 1598998504,
#   'sys': {'type': 3,
#    'id': 2002717,
#    'country': 'US',
#    'sunrise': 1598961335,
#    'sunset': 1599007859},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Broken Arrow',
#   'cod': 200},
#  '41503': {'coord': {'lon': -82.29, 'lat': 37.67},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 301.42,
#    'feels_like': 306.08,
#    'temp_min': 299.15,
#    'temp_max': 303.15,
#    'pressure': 1015,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 0},
#   'clouds': {'all': 90},
#   'dt': 1598998671,
#   'sys': {'type': 1,
#    'id': 3082,
#    'country': 'US',
#    'sunrise': 1598957996,
#    'sunset': 1599004709},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'South Williamson',
#   'cod': 200}}

# %%
weather_by_zip
# Out:
# {'34606': {'coord': {'lon': -82.6, 'lat': 28.47},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 302.71,
#    'feels_like': 310.45,
#    'temp_min': 300.15,
#    'temp_max': 303.71,
#    'pressure': 1016,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 70},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 20},
#   'dt': 1598998552,
#   'sys': {'type': 1,
#    'id': 3457,
#    'country': 'US',
#    'sunrise': 1598958544,
#    'sunset': 1599004310},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Spring Hill',
#   'cod': 200},
#  '72204': {'coord': {'lon': -92.34, 'lat': 34.73},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'},
#    {'id': 211,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm',
#     'icon': '11d'}],
#   'base': 'stations',
#   'main': {'temp': 296.15,
#    'feels_like': 297.27,
#    'temp_min': 296.15,
#    'temp_max': 296.15,
#    'pressure': 1011,
#    'humidity': 94},
#   'visibility': 805,
#   'wind': {'speed': 5.1, 'deg': 230},
#   'rain': {'1h': 8.38},
#   'clouds': {'all': 90},
#   'dt': 1598998564,
#   'sys': {'type': 1,
#    'id': 4717,
#    'country': 'US',
#    'sunrise': 1598960573,
#    'sunset': 1599006956},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Little Rock',
#   'cod': 200},
#  '60435': {'coord': {'lon': -88.13, 'lat': 41.55},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 294.68,
#    'feels_like': 295.54,
#    'temp_min': 294.15,
#    'temp_max': 295.15,
#    'pressure': 1011,
#    'humidity': 100},
#   'visibility': 8047,
#   'wind': {'speed': 5.14, 'deg': 192},
#   'rain': {'1h': 0.84},
#   'clouds': {'all': 90},
#   'dt': 1598998670,
#   'sys': {'type': 1,
#    'id': 4599,
#    'country': 'US',
#    'sunrise': 1598959160,
#    'sunset': 1599006348},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Joliet',
#   'cod': 200},
#  '12832': {'coord': {'lon': -73.3, 'lat': 43.38},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 295.56,
#    'feels_like': 297.04,
#    'temp_min': 294.82,
#    'temp_max': 296.48,
#    'pressure': 1018,
#    'humidity': 77},
#   'visibility': 10000,
#   'wind': {'speed': 1.98, 'deg': 194},
#   'clouds': {'all': 90},
#   'dt': 1598998935,
#   'sys': {'type': 3,
#    'id': 2007023,
#    'country': 'US',
#    'sunrise': 1598955475,
#    'sunset': 1599002916},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Granville',
#   'cod': 200},
#  '91977': {'coord': {'lon': -117, 'lat': 32.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.03,
#    'feels_like': 296.64,
#    'temp_min': 297.04,
#    'temp_max': 300.93,
#    'pressure': 1014,
#    'humidity': 51},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 290},
#   'clouds': {'all': 5},
#   'dt': 1598998672,
#   'sys': {'type': 1,
#    'id': 5800,
#    'country': 'US',
#    'sunrise': 1598966598,
#    'sunset': 1599012764},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Spring Valley',
#   'cod': 200},
#  '28501': {'coord': {'lon': -77.59, 'lat': 35.28},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 303.85,
#    'feels_like': 307.85,
#    'temp_min': 303.15,
#    'temp_max': 304.15,
#    'pressure': 1015,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 330},
#   'clouds': {'all': 40},
#   'dt': 1598998389,
#   'sys': {'type': 1,
#    'id': 4548,
#    'country': 'US',
#    'sunrise': 1598957001,
#    'sunset': 1599003449},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Kinston',
#   'cod': 200},
#  '89436': {'coord': {'lon': -119.71, 'lat': 39.63},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.42,
#    'feels_like': 297.28,
#    'temp_min': 299.15,
#    'temp_max': 301.15,
#    'pressure': 1024,
#    'humidity': 16},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998938,
#   'sys': {'type': 1,
#    'id': 5724,
#    'country': 'US',
#    'sunrise': 1598966865,
#    'sunset': 1599013797},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Sparks',
#   'cod': 200},
#  '40214': {'coord': {'lon': -85.78, 'lat': 38.16},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 301.25,
#    'feels_like': 302.63,
#    'temp_min': 300.37,
#    'temp_max': 302.15,
#    'pressure': 1012,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 160},
#   'clouds': {'all': 75},
#   'dt': 1598998570,
#   'sys': {'type': 1,
#    'id': 5801,
#    'country': 'US',
#    'sunrise': 1598958805,
#    'sunset': 1599005575},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Louisville',
#   'cod': 200},
#  '45236': {'coord': {'lon': -84.39, 'lat': 39.21},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 301.03,
#    'feels_like': 303.03,
#    'temp_min': 300.37,
#    'temp_max': 301.48,
#    'pressure': 1013,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 220},
#   'clouds': {'all': 20},
#   'dt': 1598998940,
#   'sys': {'type': 1,
#    'id': 4776,
#    'country': 'US',
#    'sunrise': 1598958409,
#    'sunset': 1599005304},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Cincinnati',
#   'cod': 200},
#  '44094': {'coord': {'lon': -81.41, 'lat': 41.63},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 300.13,
#    'feels_like': 302.72,
#    'temp_min': 299.15,
#    'temp_max': 301.48,
#    'pressure': 1013,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 1.46, 'deg': 216},
#   'clouds': {'all': 75},
#   'dt': 1598998678,
#   'sys': {'type': 1,
#    'id': 4728,
#    'country': 'US',
#    'sunrise': 1598957541,
#    'sunset': 1599004742},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Willoughby',
#   'cod': 200},
#  '89128': {'coord': {'lon': -115.26, 'lat': 36.2},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 307.84,
#    'feels_like': 304.37,
#    'temp_min': 305.37,
#    'temp_max': 309.15,
#    'pressure': 1014,
#    'humidity': 11},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 30},
#   'clouds': {'all': 1},
#   'dt': 1598998321,
#   'sys': {'type': 1,
#    'id': 6171,
#    'country': 'US',
#    'sunrise': 1598965996,
#    'sunset': 1599012531},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Las Vegas',
#   'cod': 200},
#  '93711': {'coord': {'lon': -119.83, 'lat': 36.83},
#   'weather': [{'id': 711,
#     'main': 'Smoke',
#     'description': 'smoke',
#     'icon': '50d'},
#    {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 308.02,
#    'feels_like': 307.69,
#    'temp_min': 307.15,
#    'temp_max': 308.71,
#    'pressure': 1011,
#    'humidity': 28},
#   'visibility': 6437,
#   'wind': {'speed': 2.1, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998574,
#   'sys': {'type': 1,
#    'id': 4056,
#    'country': 'US',
#    'sunrise': 1598967059,
#    'sunset': 1599013662},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Fresno',
#   'cod': 200},
#  '65803': {'coord': {'lon': -93.29, 'lat': 37.26},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 298.61,
#    'feels_like': 300.37,
#    'temp_min': 298.15,
#    'temp_max': 299.26,
#    'pressure': 1009,
#    'humidity': 74},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 220},
#   'clouds': {'all': 40},
#   'dt': 1598998944,
#   'sys': {'type': 1,
#    'id': 5821,
#    'country': 'US',
#    'sunrise': 1598960661,
#    'sunset': 1599007323},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Springfield',
#   'cod': 200},
#  '78745': {'coord': {'lon': -97.8, 'lat': 30.21},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 308.5,
#    'feels_like': 310.27,
#    'temp_min': 307.04,
#    'temp_max': 310.15,
#    'pressure': 1008,
#    'humidity': 44},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 210, 'gust': 9.3},
#   'clouds': {'all': 20},
#   'dt': 1598998475,
#   'sys': {'type': 1,
#    'id': 3344,
#    'country': 'US',
#    'sunrise': 1598962112,
#    'sunset': 1599008037},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Austin',
#   'cod': 200},
#  '28403': {'coord': {'lon': -77.89, 'lat': 34.22},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 303.12,
#    'feels_like': 306.49,
#    'temp_min': 302.59,
#    'temp_max': 304.15,
#    'pressure': 1014,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 160},
#   'clouds': {'all': 75},
#   'dt': 1598998946,
#   'sys': {'type': 1,
#    'id': 4521,
#    'country': 'US',
#    'sunrise': 1598957130,
#    'sunset': 1599003464},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Wilmington',
#   'cod': 200},
#  '29678': {'coord': {'lon': -82.94, 'lat': 34.68},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 303.88,
#    'feels_like': 308.43,
#    'temp_min': 303.15,
#    'temp_max': 304.82,
#    'pressure': 1015,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 220},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 1},
#   'dt': 1598998948,
#   'sys': {'type': 1,
#    'id': 3596,
#    'country': 'US',
#    'sunrise': 1598958318,
#    'sunset': 1599004699},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Seneca',
#   'cod': 200},
#  '99352': {'coord': {'lon': -119.29, 'lat': 46.25},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 305.27,
#    'feels_like': 304.47,
#    'temp_min': 304.26,
#    'temp_max': 306.15,
#    'pressure': 1015,
#    'humidity': 26},
#   'visibility': 10000,
#   'wind': {'speed': 1.27, 'deg': 276},
#   'clouds': {'all': 1},
#   'dt': 1598998949,
#   'sys': {'type': 1,
#    'id': 5676,
#    'country': 'US',
#    'sunrise': 1598966312,
#    'sunset': 1599014150},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Richland',
#   'cod': 200},
#  '27127': {'coord': {'lon': -80.26, 'lat': 36.04},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 300.06,
#    'feels_like': 304.69,
#    'temp_min': 298.71,
#    'temp_max': 301.48,
#    'pressure': 1017,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 50},
#   'clouds': {'all': 40},
#   'dt': 1598998950,
#   'sys': {'type': 1,
#    'id': 4531,
#    'country': 'US',
#    'sunrise': 1598957601,
#    'sunset': 1599004130},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Winston Salem',
#   'cod': 200},
#  '32771': {'coord': {'lon': -81.28, 'lat': 28.8},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 302.98,
#    'feels_like': 307.59,
#    'temp_min': 301.15,
#    'temp_max': 303.71,
#    'pressure': 1016,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 50},
#   'clouds': {'all': 40},
#   'dt': 1598998509,
#   'sys': {'type': 1,
#    'id': 5811,
#    'country': 'US',
#    'sunrise': 1598958212,
#    'sunset': 1599004008},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Sanford',
#   'cod': 200},
#  '61611': {'coord': {'lon': -89.55, 'lat': 40.67},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 296.01,
#    'feels_like': 298.61,
#    'temp_min': 294.82,
#    'temp_max': 297.04,
#    'pressure': 1010,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 0},
#   'rain': {'1h': 0.51},
#   'clouds': {'all': 40},
#   'dt': 1598998436,
#   'sys': {'type': 1,
#    'id': 5354,
#    'country': 'US',
#    'sunrise': 1598959558,
#    'sunset': 1599006632},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'East Peoria',
#   'cod': 200},
#  '26241': {'coord': {'lon': -79.85, 'lat': 38.93},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 298.89,
#    'feels_like': 303.66,
#    'temp_min': 296.15,
#    'temp_max': 302.04,
#    'pressure': 1016,
#    'humidity': 94},
#   'visibility': 9656,
#   'wind': {'speed': 2.1, 'deg': 160},
#   'rain': {'1h': 1.27},
#   'clouds': {'all': 90},
#   'dt': 1598998953,
#   'sys': {'type': 1,
#    'id': 3966,
#    'country': 'US',
#    'sunrise': 1598957335,
#    'sunset': 1599004199},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Elkins',
#   'cod': 200},
#  '95608': {'coord': {'lon': -121.33, 'lat': 38.63},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 305.34,
#    'feels_like': 304.77,
#    'temp_min': 303.15,
#    'temp_max': 306.48,
#    'pressure': 1011,
#    'humidity': 31},
#   'visibility': 9656,
#   'wind': {'speed': 2.1, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998304,
#   'sys': {'type': 1,
#    'id': 4838,
#    'country': 'US',
#    'sunrise': 1598967315,
#    'sunset': 1599014126},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Carmichael',
#   'cod': 200},
#  '91942': {'coord': {'lon': -117.02, 'lat': 32.78},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.28,
#    'feels_like': 296.97,
#    'temp_min': 297.15,
#    'temp_max': 301.48,
#    'pressure': 1014,
#    'humidity': 51},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 290},
#   'clouds': {'all': 5},
#   'dt': 1598998586,
#   'sys': {'type': 1,
#    'id': 5800,
#    'country': 'US',
#    'sunrise': 1598966600,
#    'sunset': 1599012772},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'La Mesa',
#   'cod': 200},
#  '45750': {'coord': {'lon': -81.46, 'lat': 39.43},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 302.78,
#    'feels_like': 305.08,
#    'temp_min': 302.15,
#    'temp_max': 303.71,
#    'pressure': 1013,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 40},
#   'dt': 1598998956,
#   'sys': {'type': 1,
#    'id': 5365,
#    'country': 'US',
#    'sunrise': 1598957692,
#    'sunset': 1599004615},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Marietta',
#   'cod': 200},
#  '59405': {'coord': {'lon': -111.25, 'lat': 47.49},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.99,
#    'feels_like': 293.04,
#    'temp_min': 299.82,
#    'temp_max': 300.15,
#    'pressure': 1012,
#    'humidity': 21},
#   'visibility': 10000,
#   'wind': {'speed': 7.7, 'deg': 290, 'gust': 12.3},
#   'clouds': {'all': 1},
#   'dt': 1598998454,
#   'sys': {'type': 1,
#    'id': 4204,
#    'country': 'US',
#    'sunrise': 1598964283,
#    'sunset': 1599012320},
#   'timezone': -21600,
#   'id': 0,
#   'name': 'Great Falls',
#   'cod': 200},
#  '29303': {'coord': {'lon': -81.92, 'lat': 34.98},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 304.15,
#    'feels_like': 307.67,
#    'temp_min': 303.71,
#    'temp_max': 304.82,
#    'pressure': 1015,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 180},
#   'clouds': {'all': 40},
#   'dt': 1598998958,
#   'sys': {'type': 1,
#    'id': 5896,
#    'country': 'US',
#    'sunrise': 1598958057,
#    'sunset': 1599004471},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Spartanburg',
#   'cod': 200},
#  '43953': {'coord': {'lon': -80.68, 'lat': 40.35},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 301.26,
#    'feels_like': 303.05,
#    'temp_min': 300.37,
#    'temp_max': 302.15,
#    'pressure': 1014,
#    'humidity': 58},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 150},
#   'clouds': {'all': 40},
#   'dt': 1598998959,
#   'sys': {'type': 1,
#    'id': 4384,
#    'country': 'US',
#    'sunrise': 1598957448,
#    'sunset': 1599004485},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Steubenville',
#   'cod': 200},
#  '89701': {'coord': {'lon': -119.75, 'lat': 39.15},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 302.4,
#    'feels_like': 295.31,
#    'temp_min': 302.04,
#    'temp_max': 303.15,
#    'pressure': 1022,
#    'humidity': 12},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 80},
#   'clouds': {'all': 1},
#   'dt': 1598998809,
#   'sys': {'type': 1,
#    'id': 3750,
#    'country': 'US',
#    'sunrise': 1598966904,
#    'sunset': 1599013778},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Carson City',
#   'cod': 200},
#  '21740': {'coord': {'lon': -77.74, 'lat': 39.63},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 294.39,
#    'feels_like': 296.43,
#    'temp_min': 293.15,
#    'temp_max': 295.37,
#    'pressure': 1016,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 2.52, 'deg': 147},
#   'rain': {'1h': 0.36},
#   'clouds': {'all': 97},
#   'dt': 1598998698,
#   'sys': {'type': 3,
#    'id': 2004643,
#    'country': 'US',
#    'sunrise': 1598956786,
#    'sunset': 1599003736},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Hagerstown',
#   'cod': 200},
#  '30087': {'coord': {'lon': -84.14, 'lat': 33.81},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 303.92,
#    'feels_like': 306.44,
#    'temp_min': 302.59,
#    'temp_max': 305.37,
#    'pressure': 1015,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 270},
#   'clouds': {'all': 20},
#   'dt': 1598998699,
#   'sys': {'type': 1,
#    'id': 5323,
#    'country': 'US',
#    'sunrise': 1598958652,
#    'sunset': 1599004941},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Stone Mountain',
#   'cod': 200},
#  '74075': {'coord': {'lon': -97.06, 'lat': 36.14},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.04,
#    'feels_like': 299.25,
#    'temp_min': 297.15,
#    'temp_max': 298.71,
#    'pressure': 1009,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1598998963,
#   'sys': {'type': 1,
#    'id': 3720,
#    'country': 'US',
#    'sunrise': 1598961629,
#    'sunset': 1599008164},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Stillwater',
#   'cod': 200},
#  '98270': {'coord': {'lon': -122.16, 'lat': 48.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.17,
#    'feels_like': 297.57,
#    'temp_min': 297.04,
#    'temp_max': 299.26,
#    'pressure': 1021,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998965,
#   'sys': {'type': 1,
#    'id': 3363,
#    'country': 'US',
#    'sunrise': 1598966856,
#    'sunset': 1599014982},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Marysville',
#   'cod': 200},
#  '33063': {'coord': {'lon': -80.21, 'lat': 26.27},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 305.01,
#    'feels_like': 306.29,
#    'temp_min': 304.26,
#    'temp_max': 306.15,
#    'pressure': 1016,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 110},
#   'clouds': {'all': 20},
#   'dt': 1598998598,
#   'sys': {'type': 1,
#    'id': 4167,
#    'country': 'US',
#    'sunrise': 1598958070,
#    'sunset': 1599003637},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Pompano Beach',
#   'cod': 200},
#  '45255': {'coord': {'lon': -84.34, 'lat': 39.06},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 300.98,
#    'feels_like': 302.95,
#    'temp_min': 300.37,
#    'temp_max': 301.48,
#    'pressure': 1013,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 220},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 20},
#   'dt': 1598998967,
#   'sys': {'type': 1,
#    'id': 4776,
#    'country': 'US',
#    'sunrise': 1598958406,
#    'sunset': 1599005283},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Cincinnati',
#   'cod': 200},
#  '14701': {'coord': {'lon': -79.24, 'lat': 42.09},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 295.74,
#    'feels_like': 297.06,
#    'temp_min': 294.15,
#    'temp_max': 297.04,
#    'pressure': 1016,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 160},
#   'clouds': {'all': 90},
#   'dt': 1598998466,
#   'sys': {'type': 1,
#    'id': 4588,
#    'country': 'US',
#    'sunrise': 1598956989,
#    'sunset': 1599004252},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Jamestown',
#   'cod': 200},
#  '91324': {'coord': {'lon': -118.55, 'lat': 34.24},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 303.55,
#    'feels_like': 302.38,
#    'temp_min': 299.82,
#    'temp_max': 305.93,
#    'pressure': 1013,
#    'humidity': 35},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 0, 'gust': 7.7},
#   'clouds': {'all': 1},
#   'dt': 1598998969,
#   'sys': {'type': 1,
#    'id': 6183,
#    'country': 'US',
#    'sunrise': 1598966892,
#    'sunset': 1599013214},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Northridge',
#   'cod': 200},
#  '39208': {'coord': {'lon': -90.09, 'lat': 32.26},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 306.38,
#    'feels_like': 307.6,
#    'temp_min': 305.15,
#    'temp_max': 307.59,
#    'pressure': 1013,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 200},
#   'clouds': {'all': 20},
#   'dt': 1598998742,
#   'sys': {'type': 1,
#    'id': 4568,
#    'country': 'US',
#    'sunrise': 1598960160,
#    'sunset': 1599006288},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Pearl',
#   'cod': 200},
#  '22630': {'coord': {'lon': -78.18, 'lat': 38.93},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 295.97,
#    'feels_like': 299.49,
#    'temp_min': 294.26,
#    'temp_max': 297.59,
#    'pressure': 1016,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 1.54, 'deg': 143},
#   'clouds': {'all': 90},
#   'dt': 1598998603,
#   'sys': {'type': 1,
#    'id': 4136,
#    'country': 'US',
#    'sunrise': 1598956934,
#    'sunset': 1599003798},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Front Royal',
#   'cod': 200},
#  '23294': {'coord': {'lon': -77.4, 'lat': 37.46},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.42,
#    'feels_like': 301.04,
#    'temp_min': 297.59,
#    'temp_max': 299.15,
#    'pressure': 1016,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 80},
#   'clouds': {'all': 75},
#   'dt': 1598998804,
#   'sys': {'type': 1,
#    'id': 5662,
#    'country': 'US',
#    'sunrise': 1598956834,
#    'sunset': 1599003525},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Henrico',
#   'cod': 200},
#  '31404': {'coord': {'lon': -81.05, 'lat': 32.05},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 305.42,
#    'feels_like': 308.2,
#    'temp_min': 304.26,
#    'temp_max': 307.15,
#    'pressure': 1013,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 150},
#   'clouds': {'all': 1},
#   'dt': 1598998973,
#   'sys': {'type': 1,
#    'id': 5948,
#    'country': 'US',
#    'sunrise': 1598958000,
#    'sunset': 1599004110},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Savannah',
#   'cod': 200},
#  '08753': {'coord': {'lon': -74.16, 'lat': 39.98},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 296.9,
#    'feels_like': 298.41,
#    'temp_min': 296.48,
#    'temp_max': 297.59,
#    'pressure': 1019,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 90},
#   'clouds': {'all': 75},
#   'dt': 1598998711,
#   'sys': {'type': 1,
#    'id': 4907,
#    'country': 'US',
#    'sunrise': 1598955905,
#    'sunset': 1599002899},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Toms River',
#   'cod': 200},
#  '62901': {'coord': {'lon': -89.22, 'lat': 37.72},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 295.69,
#    'feels_like': 297.27,
#    'temp_min': 295.15,
#    'temp_max': 296.15,
#    'pressure': 1011,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 150},
#   'clouds': {'all': 90},
#   'dt': 1598998476,
#   'sys': {'type': 1,
#    'id': 4858,
#    'country': 'US',
#    'sunrise': 1598959657,
#    'sunset': 1599006374},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Carbondale',
#   'cod': 200},
#  '95667': {'coord': {'lon': -120.8, 'lat': 38.72},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 305.84,
#    'feels_like': 303.57,
#    'temp_min': 304.82,
#    'temp_max': 307.04,
#    'pressure': 1017,
#    'humidity': 24},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 1},
#   'dt': 1598998750,
#   'sys': {'type': 1,
#    'id': 5440,
#    'country': 'US',
#    'sunrise': 1598967182,
#    'sunset': 1599014004},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Placerville',
#   'cod': 200},
#  '43055': {'coord': {'lon': -82.4, 'lat': 40.07},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.51,
#    'feels_like': 303.72,
#    'temp_min': 299.82,
#    'temp_max': 301.15,
#    'pressure': 1013,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 240},
#   'clouds': {'all': 1},
#   'dt': 1598998714,
#   'sys': {'type': 1,
#    'id': 6204,
#    'country': 'US',
#    'sunrise': 1598957878,
#    'sunset': 1599004880},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Newark',
#   'cod': 200},
#  '32308': {'coord': {'lon': -84.22, 'lat': 30.48},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 301.11,
#    'feels_like': 306.21,
#    'temp_min': 299.15,
#    'temp_max': 302.15,
#    'pressure': 1016,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1598998978,
#   'sys': {'type': 1,
#    'id': 6031,
#    'country': 'US',
#    'sunrise': 1598958838,
#    'sunset': 1599004793},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Tallahassee',
#   'cod': 200},
#  '76205': {'coord': {'lon': -97.13, 'lat': 33.19},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'},
#    {'id': 202,
#     'main': 'Thunderstorm',
#     'description': 'thunderstorm with heavy rain',
#     'icon': '11d'},
#    {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 295.77,
#    'feels_like': 295.92,
#    'temp_min': 295.37,
#    'temp_max': 296.15,
#    'pressure': 1009,
#    'humidity': 94},
#   'visibility': 3219,
#   'wind': {'speed': 6.2, 'deg': 130, 'gust': 9.3},
#   'rain': {'1h': 4.32},
#   'clouds': {'all': 90},
#   'dt': 1598998612,
#   'sys': {'type': 1,
#    'id': 3862,
#    'country': 'US',
#    'sunrise': 1598961803,
#    'sunset': 1599008024},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Denton',
#   'cod': 200},
#  '56425': {'coord': {'lon': -94.28, 'lat': 46.34},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 292.6,
#    'feels_like': 288.7,
#    'temp_min': 292.15,
#    'temp_max': 293.15,
#    'pressure': 1005,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 190},
#   'clouds': {'all': 90},
#   'dt': 1598998717,
#   'sys': {'type': 1,
#    'id': 3497,
#    'country': 'US',
#    'sunrise': 1598960297,
#    'sunset': 1599008162},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Baxter',
#   'cod': 200},
#  '92203': {'coord': {'lon': -116.27, 'lat': 33.75},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 313.56,
#    'feels_like': 312.76,
#    'temp_min': 312.59,
#    'temp_max': 314.26,
#    'pressure': 1006,
#    'humidity': 18},
#   'visibility': 10000,
#   'wind': {'speed': 1.8, 'deg': 200},
#   'clouds': {'all': 0},
#   'dt': 1598998614,
#   'sys': {'type': 3,
#    'id': 2006328,
#    'country': 'US',
#    'sunrise': 1598966370,
#    'sunset': 1599012642},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Indio',
#   'cod': 200},
#  '60110': {'coord': {'lon': -88.26, 'lat': 42.12},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.42,
#    'feels_like': 294.61,
#    'temp_min': 292.59,
#    'temp_max': 294.26,
#    'pressure': 1011,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 2.42, 'deg': 152},
#   'clouds': {'all': 90},
#   'dt': 1598998927,
#   'sys': {'type': 1,
#    'id': 2658,
#    'country': 'US',
#    'sunrise': 1598959154,
#    'sunset': 1599006417},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Carpentersville',
#   'cod': 200},
#  '20770': {'coord': {'lon': -76.88, 'lat': 39},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.25,
#    'feels_like': 299.87,
#    'temp_min': 297.04,
#    'temp_max': 299.82,
#    'pressure': 1017,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 2.9, 'deg': 111},
#   'clouds': {'all': 90},
#   'dt': 1598998983,
#   'sys': {'type': 1,
#    'id': 3614,
#    'country': 'US',
#    'sunrise': 1598956618,
#    'sunset': 1599003491},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Greenbelt',
#   'cod': 200},
#  '36571': {'coord': {'lon': -88.09, 'lat': 30.83},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 304.12,
#    'feels_like': 309.03,
#    'temp_min': 303.71,
#    'temp_max': 304.82,
#    'pressure': 1015,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 3.7, 'deg': 211},
#   'clouds': {'all': 26},
#   'dt': 1598998984,
#   'sys': {'type': 3,
#    'id': 2003944,
#    'country': 'US',
#    'sunrise': 1598959751,
#    'sunset': 1599005738},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Saraland',
#   'cod': 200},
#  '32609': {'coord': {'lon': -82.31, 'lat': 29.7},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 302.59,
#    'feels_like': 307.8,
#    'temp_min': 302.15,
#    'temp_max': 303.15,
#    'pressure': 1017,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 230},
#   'clouds': {'all': 1},
#   'dt': 1598998374,
#   'sys': {'type': 1,
#    'id': 4247,
#    'country': 'US',
#    'sunrise': 1598958417,
#    'sunset': 1599004298},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Gainesville',
#   'cod': 200},
#  '05641': {'coord': {'lon': -72.49, 'lat': 44.19},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 294.39,
#    'feels_like': 291.8,
#    'temp_min': 294.15,
#    'temp_max': 294.82,
#    'pressure': 1021,
#    'humidity': 60},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 160},
#   'clouds': {'all': 90},
#   'dt': 1598998987,
#   'sys': {'type': 1,
#    'id': 4960,
#    'country': 'US',
#    'sunrise': 1598955223,
#    'sunset': 1599002779},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Barre',
#   'cod': 200},
#  '76801': {'coord': {'lon': -98.99, 'lat': 31.78},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 308.33,
#    'feels_like': 308.74,
#    'temp_min': 304.15,
#    'temp_max': 311.15,
#    'pressure': 1006,
#    'humidity': 39},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 180, 'gust': 8.7},
#   'clouds': {'all': 75},
#   'dt': 1598998578,
#   'sys': {'type': 1,
#    'id': 3535,
#    'country': 'US',
#    'sunrise': 1598962321,
#    'sunset': 1599008398},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Brownwood',
#   'cod': 200},
#  '54303': {'coord': {'lon': -88.08, 'lat': 44.55},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.03,
#    'feels_like': 292.07,
#    'temp_min': 292.15,
#    'temp_max': 293.71,
#    'pressure': 1010,
#    'humidity': 59},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1598998939,
#   'sys': {'type': 1,
#    'id': 4258,
#    'country': 'US',
#    'sunrise': 1598958942,
#    'sunset': 1599006542},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Green Bay',
#   'cod': 200},
#  '33157': {'coord': {'lon': -80.34, 'lat': 25.61},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 304.78,
#    'feels_like': 305.58,
#    'temp_min': 303.71,
#    'temp_max': 305.93,
#    'pressure': 1016,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 130},
#   'clouds': {'all': 1},
#   'dt': 1598998726,
#   'sys': {'type': 1,
#    'id': 6041,
#    'country': 'US',
#    'sunrise': 1598958130,
#    'sunset': 1599003639},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Miami',
#   'cod': 200},
#  '06473': {'coord': {'lon': -72.86, 'lat': 41.38},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 295.99,
#    'feels_like': 294.33,
#    'temp_min': 294.82,
#    'temp_max': 297.15,
#    'pressure': 1020,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 120, 'gust': 9.3},
#   'clouds': {'all': 40},
#   'dt': 1598998623,
#   'sys': {'type': 1,
#    'id': 4445,
#    'country': 'US',
#    'sunrise': 1598955504,
#    'sunset': 1599002676},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'North Haven',
#   'cod': 200},
#  '19154': {'coord': {'lon': -74.98, 'lat': 40.09},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.21,
#    'feels_like': 298.84,
#    'temp_min': 297.59,
#    'temp_max': 298.71,
#    'pressure': 1018,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 140},
#   'clouds': {'all': 90},
#   'dt': 1598998581,
#   'sys': {'type': 1,
#    'id': 5384,
#    'country': 'US',
#    'sunrise': 1598956095,
#    'sunset': 1599003102},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Philadelphia',
#   'cod': 200},
#  '38122': {'coord': {'lon': -89.93, 'lat': 35.16},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 304.37,
#    'feels_like': 307.02,
#    'temp_min': 303.71,
#    'temp_max': 304.82,
#    'pressure': 1012,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 190},
#   'clouds': {'all': 75},
#   'dt': 1598998514,
#   'sys': {'type': 1,
#    'id': 4867,
#    'country': 'US',
#    'sunrise': 1598959971,
#    'sunset': 1599006401},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Memphis',
#   'cod': 200},
#  '45030': {'coord': {'lon': -84.78, 'lat': 39.26},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.47,
#    'feels_like': 303.25,
#    'temp_min': 299.82,
#    'temp_max': 300.93,
#    'pressure': 1012,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 200},
#   'clouds': {'all': 1},
#   'dt': 1598998994,
#   'sys': {'type': 1,
#    'id': 4476,
#    'country': 'US',
#    'sunrise': 1598958499,
#    'sunset': 1599005401},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Harrison',
#   'cod': 200},
#  '95240': {'coord': {'lon': -121.26, 'lat': 38.12},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 304.6,
#    'feels_like': 301.31,
#    'temp_min': 304.15,
#    'temp_max': 304.82,
#    'pressure': 1012,
#    'humidity': 31},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 300},
#   'clouds': {'all': 1},
#   'dt': 1598998628,
#   'sys': {'type': 1,
#    'id': 5789,
#    'country': 'US',
#    'sunrise': 1598967328,
#    'sunset': 1599014079},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Lodi',
#   'cod': 200},
#  '43015': {'coord': {'lon': -83.07, 'lat': 40.29},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 300.48,
#    'feels_like': 302.74,
#    'temp_min': 299.82,
#    'temp_max': 300.93,
#    'pressure': 1013,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 2.84, 'deg': 220},
#   'clouds': {'all': 75},
#   'dt': 1598998706,
#   'sys': {'type': 1,
#    'id': 3832,
#    'country': 'US',
#    'sunrise': 1598958025,
#    'sunset': 1599005054},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Delaware',
#   'cod': 200},
#  '45631': {'coord': {'lon': -82.23, 'lat': 38.81},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 303.77,
#    'feels_like': 307.68,
#    'temp_min': 302.15,
#    'temp_max': 305.93,
#    'pressure': 1013,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 250},
#   'clouds': {'all': 1},
#   'dt': 1598998997,
#   'sys': {'type': 1,
#    'id': 6138,
#    'country': 'US',
#    'sunrise': 1598957914,
#    'sunset': 1599004762},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Gallipolis',
#   'cod': 200},
#  '97459': {'coord': {'lon': -124.21, 'lat': 43.43},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.76,
#    'feels_like': 294.01,
#    'temp_min': 292.15,
#    'temp_max': 307.04,
#    'pressure': 1017,
#    'humidity': 63},
#   'visibility': 10000,
#   'wind': {'speed': 10.8, 'deg': 350},
#   'clouds': {'all': 1},
#   'dt': 1598998735,
#   'sys': {'type': 1,
#    'id': 5239,
#    'country': 'US',
#    'sunrise': 1598967699,
#    'sunset': 1599015123},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'North Bend',
#   'cod': 200},
#  '94520': {'coord': {'lon': -122.04, 'lat': 37.98},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.19,
#    'feels_like': 294.8,
#    'temp_min': 293.71,
#    'temp_max': 300.93,
#    'pressure': 1014,
#    'humidity': 44},
#   'visibility': 10000,
#   'wind': {'speed': 5.7, 'deg': 270},
#   'clouds': {'all': 1},
#   'dt': 1598998632,
#   'sys': {'type': 1,
#    'id': 3581,
#    'country': 'US',
#    'sunrise': 1598967523,
#    'sunset': 1599014258},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Concord',
#   'cod': 200},
#  '19348': {'coord': {'lon': -75.7, 'lat': 39.85},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 296.6,
#    'feels_like': 298.48,
#    'temp_min': 295.37,
#    'temp_max': 297.59,
#    'pressure': 1018,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 90},
#   'clouds': {'all': 90},
#   'dt': 1598998631,
#   'sys': {'type': 1,
#    'id': 5209,
#    'country': 'US',
#    'sunrise': 1598956283,
#    'sunset': 1599003260},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Kennett Square',
#   'cod': 200},
#  '93010': {'coord': {'lon': -119.05, 'lat': 34.23},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 297.1,
#    'feels_like': 294.13,
#    'temp_min': 293.71,
#    'temp_max': 298.71,
#    'pressure': 1014,
#    'humidity': 47},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 240},
#   'clouds': {'all': 1},
#   'dt': 1598998634,
#   'sys': {'type': 1,
#    'id': 3649,
#    'country': 'US',
#    'sunrise': 1598967013,
#    'sunset': 1599013333},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Camarillo',
#   'cod': 200},
#  '38671': {'coord': {'lon': -90, 'lat': 34.98},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 304.41,
#    'feels_like': 307.09,
#    'temp_min': 303.71,
#    'temp_max': 305.37,
#    'pressure': 1012,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 190},
#   'clouds': {'all': 75},
#   'dt': 1598998642,
#   'sys': {'type': 1,
#    'id': 4867,
#    'country': 'US',
#    'sunrise': 1598959997,
#    'sunset': 1599006408},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Southaven',
#   'cod': 200},
#  '48604': {'coord': {'lon': -83.95, 'lat': 43.47},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 297.52,
#    'feels_like': 299.88,
#    'temp_min': 296.15,
#    'temp_max': 298.15,
#    'pressure': 1011,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 30},
#   'clouds': {'all': 75},
#   'dt': 1598998505,
#   'sys': {'type': 1,
#    'id': 4459,
#    'country': 'US',
#    'sunrise': 1598958026,
#    'sunset': 1599005475},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Saginaw',
#   'cod': 200},
#  '33777': {'coord': {'lon': -82.73, 'lat': 27.87},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 304.36,
#    'feels_like': 308.31,
#    'temp_min': 303.15,
#    'temp_max': 305.93,
#    'pressure': 1016,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 300},
#   'clouds': {'all': 40},
#   'dt': 1598998638,
#   'sys': {'type': 1,
#    'id': 5356,
#    'country': 'US',
#    'sunrise': 1598958603,
#    'sunset': 1599004313},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Seminole',
#   'cod': 200},
#  '28625': {'coord': {'lon': -80.89, 'lat': 35.87},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 299.61,
#    'feels_like': 303.42,
#    'temp_min': 298.71,
#    'temp_max': 300.15,
#    'pressure': 1016,
#    'humidity': 78},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 90},
#   'clouds': {'all': 40},
#   'dt': 1598998552,
#   'sys': {'type': 1,
#    'id': 5941,
#    'country': 'US',
#    'sunrise': 1598957761,
#    'sunset': 1599004272},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Statesville',
#   'cod': 200},
#  '42431': {'coord': {'lon': -87.5, 'lat': 37.33},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 298.54,
#    'feels_like': 301.94,
#    'temp_min': 298.15,
#    'temp_max': 299.15,
#    'pressure': 1013,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.07, 'deg': 168},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 90},
#   'dt': 1598998640,
#   'sys': {'type': 1,
#    'id': 2815,
#    'country': 'US',
#    'sunrise': 1598959267,
#    'sunset': 1599005939},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Madisonville',
#   'cod': 200},
#  '22304': {'coord': {'lon': -77.12, 'lat': 38.81},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 298.62,
#    'feels_like': 298.99,
#    'temp_min': 297.04,
#    'temp_max': 300.15,
#    'pressure': 1016,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 130},
#   'rain': {'1h': 0.25},
#   'clouds': {'all': 75},
#   'dt': 1598998641,
#   'sys': {'type': 1,
#    'id': 3787,
#    'country': 'US',
#    'sunrise': 1598956687,
#    'sunset': 1599003537},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Alexandria',
#   'cod': 200},
#  '95678': {'coord': {'lon': -121.29, 'lat': 38.76},
#   'weather': [{'id': 721,
#     'main': 'Haze',
#     'description': 'haze',
#     'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 305.94,
#    'feels_like': 305.54,
#    'temp_min': 304.82,
#    'temp_max': 307.04,
#    'pressure': 1011,
#    'humidity': 31},
#   'visibility': 9656,
#   'wind': {'speed': 2.1, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998642,
#   'sys': {'type': 1,
#    'id': 4838,
#    'country': 'US',
#    'sunrise': 1598967297,
#    'sunset': 1599014124},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Roseville',
#   'cod': 200},
#  '39440': {'coord': {'lon': -89.13, 'lat': 31.71},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 306.26,
#    'feels_like': 307.69,
#    'temp_min': 306.15,
#    'temp_max': 306.48,
#    'pressure': 1014,
#    'humidity': 52},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 210},
#   'clouds': {'all': 1},
#   'dt': 1598998746,
#   'sys': {'type': 1,
#    'id': 4775,
#    'country': 'US',
#    'sunrise': 1598959957,
#    'sunset': 1599006031},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Laurel',
#   'cod': 200},
#  '91744': {'coord': {'lon': -117.94, 'lat': 34.03},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 302.23,
#    'feels_like': 301.62,
#    'temp_min': 300.93,
#    'temp_max': 303.71,
#    'pressure': 1013,
#    'humidity': 42},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 1},
#   'dt': 1598999010,
#   'sys': {'type': 1,
#    'id': 3971,
#    'country': 'US',
#    'sunrise': 1598966757,
#    'sunset': 1599013057},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'La Puente',
#   'cod': 200},
#  '32257': {'coord': {'lon': -81.61, 'lat': 30.19},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 302.27,
#    'feels_like': 305.53,
#    'temp_min': 301.48,
#    'temp_max': 302.59,
#    'pressure': 1015,
#    'humidity': 79},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 160},
#   'clouds': {'all': 75},
#   'dt': 1598998748,
#   'sys': {'type': 1,
#    'id': 5093,
#    'country': 'US',
#    'sunrise': 1598958226,
#    'sunset': 1599004153},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Jacksonville',
#   'cod': 200},
#  '33764': {'coord': {'lon': -82.73, 'lat': 27.92},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 304.33,
#    'feels_like': 308.26,
#    'temp_min': 303.15,
#    'temp_max': 305.93,
#    'pressure': 1016,
#    'humidity': 70},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 300},
#   'clouds': {'all': 40},
#   'dt': 1598998647,
#   'sys': {'type': 1,
#    'id': 5356,
#    'country': 'US',
#    'sunrise': 1598958601,
#    'sunset': 1599004316},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Clearwater',
#   'cod': 200},
#  '44202': {'coord': {'lon': -81.35, 'lat': 41.32},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.21,
#    'feels_like': 300.36,
#    'temp_min': 298.15,
#    'temp_max': 300.37,
#    'pressure': 1014,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 2.31, 'deg': 209},
#   'clouds': {'all': 1},
#   'dt': 1598999013,
#   'sys': {'type': 1,
#    'id': 5396,
#    'country': 'US',
#    'sunrise': 1598957547,
#    'sunset': 1599004708},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Aurora',
#   'cod': 200},
#  '90241': {'coord': {'lon': -118.13, 'lat': 33.94},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 299.79,
#    'feels_like': 298.31,
#    'temp_min': 296.15,
#    'temp_max': 302.59,
#    'pressure': 1014,
#    'humidity': 50},
#   'visibility': 10000,
#   'wind': {'speed': 4.6, 'deg': 310},
#   'clouds': {'all': 1},
#   'dt': 1598998649,
#   'sys': {'type': 1,
#    'id': 4699,
#    'country': 'US',
#    'sunrise': 1598966807,
#    'sunset': 1599013098},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Downey',
#   'cod': 200},
#  '37922': {'coord': {'lon': -84.12, 'lat': 35.86},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 303.05,
#    'feels_like': 305.13,
#    'temp_min': 301.48,
#    'temp_max': 304.15,
#    'pressure': 1014,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 3.6, 'deg': 240},
#   'clouds': {'all': 75},
#   'dt': 1598998515,
#   'sys': {'type': 1,
#    'id': 6098,
#    'country': 'US',
#    'sunrise': 1598958537,
#    'sunset': 1599005046},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Knoxville',
#   'cod': 200},
#  '92054': {'coord': {'lon': -117.36, 'lat': 33.21},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.33,
#    'feels_like': 295.99,
#    'temp_min': 296.15,
#    'temp_max': 300.15,
#    'pressure': 1014,
#    'humidity': 57},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 250, 'gust': 9.3},
#   'clouds': {'all': 1},
#   'dt': 1598998651,
#   'sys': {'type': 1,
#    'id': 5191,
#    'country': 'US',
#    'sunrise': 1598966660,
#    'sunset': 1599012875},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Oceanside',
#   'cod': 200},
#  '43081': {'coord': {'lon': -82.91, 'lat': 40.11},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 300.85,
#    'feels_like': 303.32,
#    'temp_min': 300.37,
#    'temp_max': 301.48,
#    'pressure': 1013,
#    'humidity': 65},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 190},
#   'clouds': {'all': 75},
#   'dt': 1598998755,
#   'sys': {'type': 1,
#    'id': 3656,
#    'country': 'US',
#    'sunrise': 1598957998,
#    'sunset': 1599005005},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Westerville',
#   'cod': 200},
#  '02360': {'coord': {'lon': -70.64, 'lat': 41.91},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 293.77,
#    'feels_like': 291.14,
#    'temp_min': 292.59,
#    'temp_max': 295.15,
#    'pressure': 1021,
#    'humidity': 53},
#   'visibility': 10000,
#   'wind': {'speed': 4.1, 'deg': 110},
#   'clouds': {'all': 1},
#   'dt': 1598999018,
#   'sys': {'type': 1,
#    'id': 5456,
#    'country': 'US',
#    'sunrise': 1598954936,
#    'sunset': 1599002179},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Plymouth',
#   'cod': 200},
#  '30009': {'coord': {'lon': -84.3, 'lat': 34.08},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 303.32,
#    'feels_like': 308.5,
#    'temp_min': 302.59,
#    'temp_max': 304.26,
#    'pressure': 1015,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 1.18, 'deg': 296},
#   'clouds': {'all': 97},
#   'dt': 1598998758,
#   'sys': {'type': 3,
#    'id': 2007397,
#    'country': 'US',
#    'sunrise': 1598958676,
#    'sunset': 1599004993},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Alpharetta',
#   'cod': 200},
#  '80916': {'coord': {'lon': -104.74, 'lat': 38.81},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 296.89,
#    'feels_like': 293.91,
#    'temp_min': 295.15,
#    'temp_max': 298.15,
#    'pressure': 1018,
#    'humidity': 33},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 0},
#   'clouds': {'all': 40},
#   'dt': 1598998657,
#   'sys': {'type': 1,
#    'id': 3678,
#    'country': 'US',
#    'sunrise': 1598963320,
#    'sunset': 1599010159},
#   'timezone': -21600,
#   'id': 0,
#   'name': 'Colorado Springs',
#   'cod': 200},
#  '85715': {'coord': {'lon': -110.82, 'lat': 32.25},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 307.67,
#    'feels_like': 305.09,
#    'temp_min': 306.48,
#    'temp_max': 308.71,
#    'pressure': 1014,
#    'humidity': 32},
#   'visibility': 10000,
#   'wind': {'speed': 6.2, 'deg': 290},
#   'clouds': {'all': 20},
#   'dt': 1598998658,
#   'sys': {'type': 1,
#    'id': 3827,
#    'country': 'US',
#    'sunrise': 1598965138,
#    'sunset': 1599011259},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Tucson',
#   'cod': 200},
#  '93901': {'coord': {'lon': -121.66, 'lat': 36.67},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 293.12,
#    'feels_like': 289.65,
#    'temp_min': 291.48,
#    'temp_max': 296.15,
#    'pressure': 1016,
#    'humidity': 68},
#   'visibility': 10000,
#   'wind': {'speed': 6.7, 'deg': 330},
#   'clouds': {'all': 90},
#   'dt': 1598999024,
#   'sys': {'type': 1,
#    'id': 5885,
#    'country': 'US',
#    'sunrise': 1598967507,
#    'sunset': 1599014092},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Salinas',
#   'cod': 200},
#  '33629': {'coord': {'lon': -82.51, 'lat': 27.92},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 304.59,
#    'feels_like': 305.72,
#    'temp_min': 303.15,
#    'temp_max': 306.15,
#    'pressure': 1016,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 4.58, 'deg': 291},
#   'clouds': {'all': 1},
#   'dt': 1598998745,
#   'sys': {'type': 1,
#    'id': 6046,
#    'country': 'US',
#    'sunrise': 1598958548,
#    'sunset': 1599004263},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Tampa',
#   'cod': 200},
#  '91011': {'coord': {'lon': -118.21, 'lat': 34.22},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 301.48,
#    'feels_like': 300.63,
#    'temp_min': 299.82,
#    'temp_max': 303.15,
#    'pressure': 1013,
#    'humidity': 42},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 180},
#   'clouds': {'all': 1},
#   'dt': 1598998763,
#   'sys': {'type': 1,
#    'id': 3514,
#    'country': 'US',
#    'sunrise': 1598966811,
#    'sunset': 1599013132},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'La Canada Flintridge',
#   'cod': 200},
#  '32055': {'coord': {'lon': -82.63, 'lat': 30.27},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.03,
#    'feels_like': 305.23,
#    'temp_min': 299.15,
#    'temp_max': 301.15,
#    'pressure': 1016,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 1.5, 'deg': 220},
#   'clouds': {'all': 1},
#   'dt': 1598998662,
#   'sys': {'type': 1,
#    'id': 4685,
#    'country': 'US',
#    'sunrise': 1598958467,
#    'sunset': 1599004402},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Lake City',
#   'cod': 200},
#  '31206': {'coord': {'lon': -83.68, 'lat': 32.79},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 306.89,
#    'feels_like': 309.87,
#    'temp_min': 306.15,
#    'temp_max': 307.59,
#    'pressure': 1014,
#    'humidity': 49},
#   'visibility': 10000,
#   'wind': {'speed': 2.1, 'deg': 220},
#   'clouds': {'all': 20},
#   'dt': 1598998640,
#   'sys': {'type': 1,
#    'id': 4849,
#    'country': 'US',
#    'sunrise': 1598958594,
#    'sunset': 1599004778},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Macon',
#   'cod': 200},
#  '85210': {'coord': {'lon': -111.84, 'lat': 33.39},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 311.06,
#    'feels_like': 309.34,
#    'temp_min': 309.15,
#    'temp_max': 312.04,
#    'pressure': 1010,
#    'humidity': 27},
#   'visibility': 10000,
#   'wind': {'speed': 5.1, 'deg': 260, 'gust': 9.3},
#   'clouds': {'all': 1},
#   'dt': 1598998521,
#   'sys': {'type': 1,
#    'id': 4084,
#    'country': 'US',
#    'sunrise': 1598965325,
#    'sunset': 1599011561},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Mesa',
#   'cod': 200},
#  '46131': {'coord': {'lon': -86.06, 'lat': 39.49},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 298.71,
#    'feels_like': 301.73,
#    'temp_min': 298.15,
#    'temp_max': 299.26,
#    'pressure': 1013,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.75, 'deg': 180},
#   'clouds': {'all': 40},
#   'dt': 1598998665,
#   'sys': {'type': 1,
#    'id': 4345,
#    'country': 'US',
#    'sunrise': 1598958793,
#    'sunset': 1599005722},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Franklin',
#   'cod': 200},
#  '98374': {'coord': {'lon': -122.27, 'lat': 47.14},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 300.01,
#    'feels_like': 298.73,
#    'temp_min': 298.71,
#    'temp_max': 300.93,
#    'pressure': 1021,
#    'humidity': 42},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 0},
#   'clouds': {'all': 1},
#   'dt': 1598998666,
#   'sys': {'type': 1,
#    'id': 5366,
#    'country': 'US',
#    'sunrise': 1598966958,
#    'sunset': 1599014933},
#   'timezone': -25200,
#   'id': 0,
#   'name': 'Puyallup',
#   'cod': 200},
#  '79936': {'coord': {'lon': -106.3, 'lat': 31.77},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 306.62,
#    'feels_like': 300.63,
#    'temp_min': 305.93,
#    'temp_max': 307.15,
#    'pressure': 1013,
#    'humidity': 20},
#   'visibility': 10000,
#   'wind': {'speed': 7.7, 'deg': 300, 'gust': 12.3},
#   'clouds': {'all': 20},
#   'dt': 1598998770,
#   'sys': {'type': 1,
#    'id': 3974,
#    'country': 'US',
#    'sunrise': 1598964077,
#    'sunset': 1599010151},
#   'timezone': -21600,
#   'id': 0,
#   'name': 'El Paso',
#   'cod': 200},
#  '28805': {'coord': {'lon': -82.49, 'lat': 35.6},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 298.93,
#    'feels_like': 300.29,
#    'temp_min': 297.04,
#    'temp_max': 301.15,
#    'pressure': 1017,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 3.1, 'deg': 210},
#   'clouds': {'all': 90},
#   'dt': 1598999033,
#   'sys': {'type': 1,
#    'id': 3351,
#    'country': 'US',
#    'sunrise': 1598958160,
#    'sunset': 1599004641},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'Asheville',
#   'cod': 200},
#  '74012': {'coord': {'lon': -95.81, 'lat': 36.04},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 297.64,
#    'feels_like': 299.25,
#    'temp_min': 297.04,
#    'temp_max': 298.71,
#    'pressure': 1011,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 2.24, 'deg': 248, 'gust': 4.92},
#   'clouds': {'all': 100},
#   'dt': 1598998504,
#   'sys': {'type': 3,
#    'id': 2002717,
#    'country': 'US',
#    'sunrise': 1598961335,
#    'sunset': 1599007859},
#   'timezone': -18000,
#   'id': 0,
#   'name': 'Broken Arrow',
#   'cod': 200},
#  '41503': {'coord': {'lon': -82.29, 'lat': 37.67},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 301.42,
#    'feels_like': 306.08,
#    'temp_min': 299.15,
#    'temp_max': 303.15,
#    'pressure': 1015,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 2.6, 'deg': 0},
#   'clouds': {'all': 90},
#   'dt': 1598998671,
#   'sys': {'type': 1,
#    'id': 3082,
#    'country': 'US',
#    'sunrise': 1598957996,
#    'sunset': 1599004709},
#   'timezone': -14400,
#   'id': 0,
#   'name': 'South Williamson',
#   'cod': 200}}

# %%
json.dump(weather_by_zip, open('/home/sharefolder/Weather/Json_data/daily/%s.json'%datetime.datetime.now().strftime('%Y-%m-%d: %H'), 'w'))

# %%
forcast_weather_by_zip = dict()
i_counter=0
for zip_code in zip_list:
    url = 'http://api.openweathermap.org/data/2.5/forecast?zip=%s,us&appid=931f5e95a5c3b97de1c2fccdff056857'%zip_code
    time.sleep(1)
    try:
        req = request.urlopen(url)
        # response = urllib2.urlopen(req)
        result = req.read()

        forcast_weather_by_zip[zip_code] = eval(result)
        
        #logging.info('%s suceeded.'%zip_code)
    except Exception as e:
        logging.info('%s %s'%(zip_code, e))
    i_counter+=1
    if i_counter==100:
        break

json.dump(forcast_weather_by_zip, open('/home/sharefolder/Weather/Json_data/forecast/%s.json'%datetime.datetime.now().strftime('%Y-%m-%d: %H'), 'w'))
