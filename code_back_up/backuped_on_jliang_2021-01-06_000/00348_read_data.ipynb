# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/home/jian/Projects/Big_Lots/Analysis/2018_Q4/Mattress'

# %%
mattress_data=pd.read_table("/home/jian/Projects/Big_Lots/Analysis/2018_Q4/Mattress/MediaStorm Matress Sales (subclasses 61501 - 61505) by Subclass 2017-06-03 - 2018-02-03.txt",
                           dtype=str,sep="|")

mattress_data.shape
# Out:
# (1103929, 8)

# %%
mattress_data['class_code_id'].unique()
# Out:
# array(['61501', '61503', '61504', '61502', '61505'], dtype=object)

# %%
daily_data=pd.read_table("/home/jian/BigLots/MediaStorm_2018-10-27/MediaStormDailySales20181030-112403-266.txt",
                         dtype=str,sep="|")
daily_data.head(2)
# Out:
#   location_id transaction_dt transaction_id  \
# 0        4644     2018-10-23           2398
# 1        1831     2018-10-27           8849
#
#                                   customer_id_hashed class_code_id  \
# 0                                                NaN         12009
# 1  f6c4cf6d10be912f9bea2066c9e011f2871f41c1d76525...         61203
#
#   subclass_id subclass_transaction_units subclass_transaction_amt
# 0           4                          1      00000000000003.0000
# 1           3                          1      00000000000099.9900

# %%
sorted(mattress_data['transaction_dt'].unique())
# Out:
# ['2017-06-03',
#  '2017-06-04',
#  '2017-06-05',
#  '2017-06-06',
#  '2017-06-07',
#  '2017-06-08',
#  '2017-06-09',
#  '2017-06-10',
#  '2017-06-11',
#  '2017-06-12',
#  '2017-06-13',
#  '2017-06-14',
#  '2017-06-15',
#  '2017-06-16',
#  '2017-06-17',
#  '2017-06-18',
#  '2017-06-19',
#  '2017-06-20',
#  '2017-06-21',
#  '2017-06-22',
#  '2017-06-23',
#  '2017-06-24',
#  '2017-06-25',
#  '2017-06-26',
#  '2017-06-27',
#  '2017-06-28',
#  '2017-06-29',
#  '2017-06-30',
#  '2017-07-01',
#  '2017-07-02',
#  '2017-07-03',
#  '2017-07-04',
#  '2017-07-05',
#  '2017-07-06',
#  '2017-07-07',
#  '2017-07-08',
#  '2017-07-09',
#  '2017-07-10',
#  '2017-07-11',
#  '2017-07-12',
#  '2017-07-13',
#  '2017-07-14',
#  '2017-07-15',
#  '2017-07-16',
#  '2017-07-17',
#  '2017-07-18',
#  '2017-07-19',
#  '2017-07-20',
#  '2017-07-21',
#  '2017-07-22',
#  '2017-07-23',
#  '2017-07-24',
#  '2017-07-25',
#  '2017-07-26',
#  '2017-07-27',
#  '2017-07-28',
#  '2017-07-29',
#  '2017-07-30',
# ...

# %%
daily_data.shape
# Out:
# (11275984, 8)
