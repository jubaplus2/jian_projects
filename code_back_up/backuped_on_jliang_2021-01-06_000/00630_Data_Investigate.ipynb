# %%
import pandas as pd
import os
os.getcwd()

# Notes: posible 0 impression but >0 clicks from SEM and FB
# Frequency might be calculated by the simple sum of impressions and clicks
# Out:
# '/home/jian/Projects/Big_Lots/Loyal_members/Exposed_Jul_Aug_From_Sp'

# %%
data=pd.read_csv("/home/jian/Projects/Big_Lots/Loyal_members/Exposed_Jul_Aug_From_Sp/exposedid_0701_0831.csv",
                dtype=str,nrows=1000)
data.head(2)
# Out:
#                                   customer_id_hashed impressions clicks
# 0  00000135f48c68690ad3d5fc9ada41bb5cd687452007e8...         1.0    0.0
# 1  000003066bafc6b19c55d3be5fc646a253c659e9e6baea...        11.0    0.0

# %%
data
# Out:
#                                     customer_id_hashed impressions clicks
# 0    00000135f48c68690ad3d5fc9ada41bb5cd687452007e8...         1.0    0.0
# 1    000003066bafc6b19c55d3be5fc646a253c659e9e6baea...        11.0    0.0
# 2    000006aa196c7510ca3b4617e7e52d9527e0190e9152fb...         5.0    0.0
# 3    00000950dea4a869e9fe70d823444d418c5abebbd8e830...         8.0    0.0
# 4    0000315b59c901cedb92ad22f49ba94e9928361783144f...         2.0    0.0
# 5    00003392ce114df090b0da2b7dba90655addbdec734e4c...         2.0    0.0
# 6    00003fc72a34ad01bc9eecffc0c7b8a802094382f531fd...         0.0    1.0
# 7    000049ce82140eb143bc0fda3ac2d62a206f1e340ff937...         2.0    0.0
# 8    00005d44634de09d36aaa5ccb20b67223ec9406c532335...         3.0    0.0
# 9    000066790167ec5fe384e8299a4342d4cea864e3f491d9...         1.0    0.0
# 10   0000695b2c3685a48e7a4474ee28477cb12b77e3c06eb0...         1.0    0.0
# 11   00006eaa62efa47b0e7637f7d768890464edd6608bc1c2...        25.0    1.0
# ...
