# %%
import pandas as pd
import logging
import sqlalchemy
import datetime

logging.basicConfig(filename='/home/jian/celery/BL_MySQL/Weekly_Update_MySQL/create_index_on_DCM_BL_table.log', 
                    level=logging.INFO)

BL_SQL_CONNECTION= 'mysql+pymysql://jian:JubaPlus-2017@localhost/BigLots' 
BL_engine = sqlalchemy.create_engine(
        BL_SQL_CONNECTION, 
        pool_recycle=1800
    )

print(datetime.datetime.now())
# Out:
# 2020-04-22 10:49:58.130688

# %%
# list_index=['customer_id_hashed','date_est','impressions','clicks','week_end_dt']
list_index=['week_end_dt']
# others can be added once in need

# %%
pd.read_sql("desc Pred_ExposureV2_BL_id;",con=BL_engine)
# Out:
#                  Field          Type Null  Key Default Extra
# 0              User_ID   varchar(64)  YES         None
# 1        Customer_Link  varchar(128)  YES         None
# 2   customer_id_hashed   varchar(64)  YES  MUL    None
# 3             date_est          date  YES  MUL    None
# 4        Advertiser_ID   varchar(16)  YES         None
# 5          Campaign_ID   varchar(16)  YES         None
# 6                Ad_ID   varchar(16)  YES         None
# 7              Site_ID   varchar(16)  YES         None
# 8         Placement_ID   varchar(16)  YES         None
# 9          impressions       int(11)  YES  MUL    None
# 10              clicks       int(11)  YES  MUL    None
# 11         week_end_dt          date  YES         None

# %%
# pd.read_sql error without return, to change to call the query in other curser

for col in list_index:
    query="create index %s on Pred_ExposureV2_BL_id(%s);" %(col,col)
    print(query)
    print("start_run",col,datetime.datetime.now())
    pd.read_sql(query,con=BL_engine)
    print("done_of_index",col,datetime.datetime.now())
    
print("all indexes created",datetime.datetime.now())
# Out:
# create index week_end_dt on Pred_ExposureV2_BL_id(week_end_dt);
# start_run week_end_dt 2020-04-22 11:49:26.571820
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1069         try:
# -> 1070             return self.cursor.fetchall()
#    1071         except AttributeError:
#
# AttributeError: 'NoneType' object has no attribute 'fetchall'
#
# During handling of the above exception, another exception occurred:
#
# ResourceClosedError                       Traceback (most recent call last)
# <ipython-input-17-0cd6d1a6f4e9> in <module>
#       5     print(query)
#       6     print("start_run",col,datetime.datetime.now())
# ----> 7     pd.read_sql(query,con=BL_engine)
#       8     print("done_of_index",col,datetime.datetime.now())
#       9
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     434             coerce_float=coerce_float,
#     435             parse_dates=parse_dates,
# --> 436             chunksize=chunksize,
#     437         )
#     438
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1229             )
#    1230         else:
# -> 1231             data = result.fetchall()
#    1232             frame = _wrap_result(
#    1233                 data,
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1123             self.connection._handle_dbapi_exception(
#    1124                 e, None, None,
# -> 1125                 self.cursor, self.context)
#    1126
#    1127     def fetchmany(self, size=None):
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1403                 )
#    1404             else:
# -> 1405                 util.reraise(*exc_info)
#    1406
#    1407         finally:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/result.py in fetchall(self)
#    1117
#    1118         try:
# -> 1119             l = self.process_rows(self._fetchall_impl())
#    1120             self._soft_close()
#    1121             return l
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/result.py in _fetchall_impl(self)
#    1070             return self.cursor.fetchall()
#    1071         except AttributeError:
# -> 1072             return self._non_result([])
#    1073
#    1074     def _non_result(self, default):
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/result.py in _non_result(self, default)
#    1075         if self._metadata is None:
#    1076             raise exc.ResourceClosedError(
# -> 1077                 "This result object does not return rows. "
#    1078                 "It has been closed automatically.",
#    1079             )
#
# ResourceClosedError: This result object does not return rows. It has been closed automatically.
