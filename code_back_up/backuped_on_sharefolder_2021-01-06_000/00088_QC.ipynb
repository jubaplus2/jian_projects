# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/home/jian/Projects/Big_Lots/Live_Ramp/Quarterly_Update_2019Q2/output_2019-04-12'

# %%
detail_data=pd.read_csv("/home/jian/Projects/Big_Lots/Live_Ramp/Quarterly_Update_2019Q2/output_2019-04-12/dfrfm_final_details_wemail_zip_StoreQuad.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-d5a2fe13c05c> in <module>()
#       1 detail_data=pd.read_csv("/home/jian/Projects/Big_Lots/Live_Ramp/Quarterly_Update_2019Q2/output_2019-04-12/dfrfm_final_details_wemail_zip_StoreQuad.csv")
# ----> 2 df_min=detail_data.groupby(['D01'])['transactions'].min().to_frame().reset_index().rename(columns={"transactions":"trans_min"})
#       3 df_max=detail_data.groupby(['D01'])['transactions'].min().to_frame().reset_index().rename(columns={"transactions":"trans_max"})
#       4
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# ...

# %%
detail_data.head(2)
# Out:
#   frmindex                                 customer_id_hashed    RFM  recency  \
# 0      D01  b78dccfd64ce659af7061c5743b6b9305814336bc9ddec...  111.0      1.0
# 1      D01  14b78c9088ecdbde7a771c49664157cfe588f86ae5ce5c...  111.0      1.0
#
#    transactions     sales  active  \
# 0          1979  31812.53  active
# 1          1919  42819.02  active
#
#                                   email_address_hash customer_zip_code  \
# 0  4836bfc632a2a5987d47fa6bf0637c21c4466a0e99ddee...             28607
# 1  d72cf03e94da3a0f89abc29df597ff699420ab1c2671b3...             87501
#
#   zipcodegroup  location_id     Quadrant
# 0            P       1684.0   Quadrant I
# 1            P       4147.0  Quadrant IV

# %%
df_min=detail_data.groupby(['frmindex','RFM'])['transactions'].max().to_frame().reset_index().rename(columns={"transactions":"trans_max"})
df_max=detail_data.groupby(['frmindex','RFM'])['transactions'].min().to_frame().reset_index().rename(columns={"transactions":"trans_min"})
x=pd.merge(df_min,df_max,on=['frmindex','RFM'])
x
# Out:
#    frmindex    RFM  trans_max  trans_min
# 0       D01  111.0       4210          3
# 1       D01  112.0         83          6
# 2       D02  112.0         59          3
# 3       D02  113.0         59          4
# 4       D02  114.0         34          4
# 5       D02  115.0        119          4
# 6       D02  121.0          3          2
# 7       D02  122.0          3          2
# 8       D02  123.0          3          2
# 9       D02  124.0          3          2
# 10      D02  125.0          3          2
# 11      D02  131.0          1          1
# 12      D02  132.0          1          1
# 13      D02  133.0          1          1
# 14      D02  134.0          1          1
# 15      D02  135.0          1          1
# 16      D03  135.0          1          1
# 17      D03  211.0       1343          4
# 18      D03  212.0         57          4
# 19      D03  213.0         25          4
# 20      D03  214.0         21          4
# 21      D03  215.0         26          4
# ...

# %%
df_min=detail_data.groupby(['frmindex'])['recency'].max().to_frame().reset_index().rename(columns={"transactions":"trans_max"})
df_max=detail_data.groupby(['frmindex'])['recency'].min().to_frame().reset_index().rename(columns={"transactions":"trans_min"})
y=pd.merge(df_min,df_max,on=['frmindex'])
y
# Out:
#   frmindex  recency_x  recency_y
# 0      D01        2.0        1.0
# 1      D02        2.0        1.0
# 2      D03        4.0        1.0
# 3      D04        7.0        2.0
# 4      D05        9.0        4.0
# 5      D06       19.0        4.0
# 6      D07       19.0       10.0
# 7      D08       34.0        9.0
# 8      D09       34.0       19.0
# 9      D10       34.0       19.0

# %%
detail_data.head(2)
# Out:
#   frmindex                                 customer_id_hashed    RFM  recency  \
# 0      D01  b78dccfd64ce659af7061c5743b6b9305814336bc9ddec...  111.0      1.0
# 1      D01  14b78c9088ecdbde7a771c49664157cfe588f86ae5ce5c...  111.0      1.0
#
#    transactions     sales  active  \
# 0          1979  31812.53  active
# 1          1919  42819.02  active
#
#                                   email_address_hash customer_zip_code  \
# 0  4836bfc632a2a5987d47fa6bf0637c21c4466a0e99ddee...             28607
# 1  d72cf03e94da3a0f89abc29df597ff699420ab1c2671b3...             87501
#
#   zipcodegroup  location_id     Quadrant
# 0            P       1684.0   Quadrant I
# 1            P       4147.0  Quadrant IV

# %%
len(test_2['customer_id_hashed'].unique())
# Out:
# 2587810
