# %%
from shutil import copyfile
import os
import pandas as pd
os.getcwd()
# Out:
# '/mnt/clients/juba/hqjubaapp02/sharefolder/Automation/Audience_No_Shop/Quarterly_Decile_Detail'

# %%
original_file_path="/mnt/clients/juba/hqjubaapp02/sharefolder/Live_Ramp/Quarterly_Update_2020Q4/output_2020-10-08/dftotal_details_full.csv"
destinated_file_path="/mnt/clients/juba/hqjubaapp02/sharefolder/Automation/Audience_No_Shop/Quarterly_Decile_Detail/df_detail_2020Q4.csv"

# remind to change the quarter number

# %%
# check previous quarter layout
df_q1=pd.read_csv("/mnt/clients/juba/hqjubaapp02/sharefolder/Automation/Audience_No_Shop/Quarterly_Decile_Detail/df_detail_2020Q1.csv",nrows=10)
df_q1
# Out:
#   frmindex                                 customer_id_hashed    sales  \
# 0      D01  1a50ebb983ad2140ad3ca66313845364bc13317863fdbe...   991.18
# 1      D01  3db1227444df33635a1e54b4849e4295e1027a53581fe9...   990.82
# 2      D01  1b89b0f890de65cfbea09999b02eba0bf3f0cb106b1c87...   989.24
# 3      D01  82d9277708537553e2faf924bf89c6f61298e78a1d2b3e...   986.71
# 4      D01  9a5b2b9d9fe2765aab03fa8ff30f54d3e1fab1cbc46754...  9809.36
# 5      D01  b3797cfc26f23ae119cdcf5e2b05bf183f845ea4973237...   980.21
# 6      D01  444a7d2537b526f32a95aa9a65b977433a03ff1595f1c0...   977.91
# 7      D01  ca1392b387a7a15a0fe218a178a0c7ac4545f52955d9df...   972.15
# 8      D01  4f25213edaa9838a63fd14e5f8c31cef1e0963acdce4cc...   969.88
# 9      D01  1f20cc42139c88748429cf546772de4a23788047d3f27e...   969.82
#
#    transactions  recency last_transaction_date    RFM  \
# 0            99      1.0            2019-12-16  111.0
# 1            99      1.0            2020-01-11  111.0
# ...

# %%
df_q3=pd.read_csv(original_file_path,nrows=10)
df_q3
# Out:
#   frmindex                                 customer_id_hashed max_trans_date  \
# 0      D01  b78dccfd64ce659af7061c5743b6b9305814336bc9ddec...     2020-10-03
# 1      D01  02cdd41af5ee82b39607416b74290152b00183fbce3068...     2020-10-01
# 2      D01  681869d76dbbf47685b2e2b2c247064ae83194cc5c5f80...     2020-10-03
# 3      D01  653da115e69c7483b704afd0b59aa6bb1b7985622c1e6e...     2020-10-03
# 4      D01  3efc4531caf1e69c86e49f007901c143d81df33086abe7...     2020-10-03
# 5      D01  84e657f1f656952fb9412a63022017769d59a70cc36883...     2020-10-03
# 6      D01  af1a67def27b7a4812c299f88c9128d1f1471df969ee7c...     2020-10-03
# 7      D01  8f9005dc30f9fb129b21dec1ca9e329eaba3cc43dbd8a9...     2020-10-03
# 8      D01  5b9138f003d812e2a908bd405239be7723eb13329e8c29...     2020-10-03
# 9      D01  155ec31d15d73bd900fdc7e194a703f6975afe86a930bb...     2020-10-03
#
#        sales  transactions  recency    RFM  \
# 0  122361.15          7529      1.0  111.0
# ...

# %%
copyfile(original_file_path,destinated_file_path)
# Out:
# '/mnt/clients/juba/hqjubaapp02/sharefolder/Automation/Audience_No_Shop/Quarterly_Decile_Detail/df_detail_2020Q4.csv'
