# %%
# to charles for example
import datetime
import sqlalchemy
import pandas as pd

BL_SQL_CONNECTION= 'mysql+pymysql://jian:JubaPlus-2017@localhost/BigLots' 
BL_engine = sqlalchemy.create_engine(
        BL_SQL_CONNECTION, 
        pool_recycle=1800
    )

print(datetime.datetime.now())
# Out:
# 2020-02-27 17:30:34.609803

# %%
# the con is the connection to the sql enviroment
# note: interrupt/shutdown for the runing query in python will not kill the process in MySQL
# please kill in mysql if you believe needed to save resource

df_sample=pd.read_sql("select * from Pred_POS_Department limit 100;",con=BL_engine)

# sql query in the "" above
# Out:
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)

# %%
df_sample
# Out:
#     location_id transaction_dt transaction_id  \
# 0          5137     2018-02-08           3863
# 1          5137     2018-02-08           3863
# 2          1875     2018-02-07            583
# 3          1875     2018-02-07            583
# 4           822     2018-02-09           5775
# ..          ...            ...            ...
# 95         1520     2018-02-05           5057
# 96         1520     2018-02-05           5058
# 97         1908     2018-02-05           7377
# 98         1628     2018-02-06           5895
# 99         1628     2018-02-06           5895
#
#                                    customer_id_hashed department_id   sales  \
# 0   0000355c755ac22a52bdcd0ff7bd29b87df5191a9c6a07...           108    2.00
# 1   0000355c755ac22a52bdcd0ff7bd29b87df5191a9c6a07...           111    5.40
# 2   00004d161929f36dc892fae11bff1c106d699e51daf5e0...           109    6.18
# 3   00004d161929f36dc892fae11bff1c106d699e51daf5e0...           120    5.82
# ...

# %%
# Let me know for more question if you have
