# %%
# week end range 2016-07-02 to 2018-08-04

import pandas as pd
import numpy as np
import os
import glob
import datetime
import gc
import hashlib
import gc
from sqlalchemy import create_engine
import sqlalchemy
import logging


os.getcwd()
# Out:
# '/home/jian/celery/BL_MySQL/Initial_Tables'

# %%
logging.basicConfig(filename='/home/jian/celery/BL_MySQL/Initial_Tables/POS_subclass_save_to_MySQL.log',level="INFO")

# DB name: BigLots
BL_SQL_CONNECTION= 'mysql+pymysql://jian:JubaPlus-2017@localhost/BigLots' 
BL_engine = create_engine(
        BL_SQL_CONNECTION, 
        pool_recycle=1800
    )

# %%
samplerows=None

def recursive_file_gen(root_path):
    for root, dirs, files in os.walk(root_path):
        for file in files:
            yield os.path.join(root,file)

# %%
existing_tables=pd.read_sql("show tables;",con=BL_engine)
existing_tables
# Out:
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
#    Tables_in_BigLots
# 0        BL_POS_Item
# 1    BL_POS_Subclass
# 2  BL_Rewards_Master

# %% [markdown]
# # Create POS Subclass Table

# %%
import pymysql.cursors
engine_pymysql_db_BL = pymysql.connect(host='localhost',user='jian',
                         password='JubaPlus-2017',db='BigLots',
                         charset='utf8mb4',cursorclass=pymysql.cursors.DictCursor)

# %%
def create_BL_POS_Subclass_table():
    with engine_pymysql_db_BL.cursor() as cur:
        cur.execute("DROP TABLE IF EXISTS BL_POS_Subclass")
        cur.execute("CREATE TABLE BL_POS_Subclass \
        (\
        location_id int, \
        transaction_dt Date, \
        transaction_id varchar(16), \
        customer_id_hashed char(64), \
        class_code_id varchar(16), \
        subclass_id varchar(16), \
        subclass_transaction_units int, \
        subclass_transaction_amt decimal(10,2) \
        );")
    print("1:An empty TABLE BL_POS_Subclass has been created.",datetime.datetime.now())
    logging.info("1:An empty TABLE BL_POS_Subclass has been created."+str(datetime.datetime.now()))
 
 
create_BL_POS_Subclass_table()
# Out:
# 1:An empty TABLE BL_POS_Subclass has been created. 2019-12-21 18:22:29.254937

# %% [markdown]
# # Write into MySQL

# %%
list_df_POS_files_daily=list(recursive_file_gen("/home/jian/BigLots/2018_by_weeks/"))
list_df_POS_files_daily=[x for x in list_df_POS_files_daily if "daily" in x.lower() and x[-4:]==".txt" and "2018-" in x]

list_df_POS_files_daily=[x for x in list_df_POS_files_daily if x.split("/MediaStorm_")[1][:10]<="2018-08-04"]
list_df_POS_files_daily.sort()
#######

list_df_POS_files_hist=glob.glob("/home/jian/BigLots/hist_daily_data_subclasslevel/*.txt")
list_df_POS_files_hist.sort()

list_all_item_POS_files=list_df_POS_files_hist+list_df_POS_files_daily
# list_all_item_POS_files # since 20180811

# %%
def Subclass_POS_df_clean_type(df):    
    
    # All fields to keep as str not changed
    df['location_id']=df['location_id'].astype(int)
    df['transaction_dt']=pd.to_datetime(df['transaction_dt'],format="%Y-%m-%d").dt.date
    # df['transaction_id']=df['transaction_id'].astype(str) varchar(16)
    # df['customer_id_hashed']=   char(64)
    # df['class_code_id']=df['class_code_id'].astype(str) varchar(16)
    # df['subclass_id']=df['subclass_id'].astype(str) varchar(16)
    # df['item_id']=df['item_id'].astype(str) varchar(16)
    df['subclass_transaction_units']=df['subclass_transaction_units'].astype(int)
    df['subclass_transaction_amt']=df['subclass_transaction_amt'].astype(float)
    
    
    # printthe len of str cols
    # print('transaction_id',df['transaction_id'].apply(len).max())
    # print('class_code_id',df['class_code_id'].apply(len).max())
    # print('subclass_id',df['subclass_id'].apply(len).max())
    
    return df

# %%
col_list=pd.read_table(list_all_item_POS_files[0],dtype=str,sep="|",nrows=10).columns.tolist()

for file in list_all_item_POS_files:
    df=pd.read_table(file,dtype=str,sep="|",nrows=samplerows)
    print(df.columns.tolist()==col_list, datetime.datetime.now(), os.path.basename(file))
    print(df.shape,df['transaction_dt'].min(),df['transaction_dt'].max())
    
    logging.info(str(df.columns.tolist()==col_list)+", "+str(datetime.datetime.now())+", "+str(os.path.basename(file)))
    logging.info(str(df.shape)+", "+str(df['transaction_dt'].min())+", "+str(df['transaction_dt'].max()))
    
    df=Subclass_POS_df_clean_type(df)
    df.to_sql('BL_POS_Subclass',if_exists='append',con=BL_engine,index=False)
print("All_Done: ",datetime.datetime.now())
logging.info("All_Done: "+str(datetime.datetime.now()))
# Out:
# True 2019-12-21 18:22:50.567248 MediaStormDailySales_week_ending_2016-07-02.txt
# (10, 8) 2016-06-26 2016-07-02
# True 2019-12-21 18:22:50.608203 MediaStormDailySales_week_ending_2016-07-09.txt
# (10, 8) 2016-07-03 2016-07-09
# True 2019-12-21 18:22:50.632248 MediaStormDailySales_week_ending_2016-07-16.txt
# (10, 8) 2016-07-10 2016-07-16
# True 2019-12-21 18:22:50.647318 MediaStormDailySales_week_ending_2016-07-23.txt
# (10, 8) 2016-07-17 2016-07-23
# True 2019-12-21 18:22:50.662328 MediaStormDailySales_week_ending_2016-07-30.txt
# (10, 8) 2016-07-24 2016-07-30
# True 2019-12-21 18:22:50.677526 MediaStormDailySales_week_ending_2016-08-06.txt
# (10, 8) 2016-07-31 2016-08-06
# True 2019-12-21 18:22:50.692590 MediaStormDailySales_week_ending_2016-08-13.txt
# (10, 8) 2016-08-08 2016-08-13
# True 2019-12-21 18:22:50.707627 MediaStormDailySales_week_ending_2016-08-20.txt
# (10, 8) 2016-08-14 2016-08-20
# True 2019-12-21 18:22:50.722824 MediaStormDailySales_week_ending_2016-08-27.txt
# (10, 8) 2016-08-22 2016-08-26
# True 2019-12-21 18:22:50.737933 MediaStormDailySales_week_ending_2016-09-03.txt
# (10, 8) 2016-08-28 2016-09-03
# True 2019-12-21 18:22:50.752839 MediaStormDailySales_week_ending_2016-09-10.txt
# (10, 8) 2016-09-04 2016-09-10
# True 2019-12-21 18:22:50.767740 MediaStormDailySales_week_ending_2016-09-17.txt
# (10, 8) 2016-09-11 2016-09-17
# True 2019-12-21 18:22:50.783281 MediaStormDailySales_week_ending_2016-09-24.txt
# (10, 8) 2016-09-18 2016-09-24
# True 2019-12-21 18:22:50.798420 MediaStormDailySales_week_ending_2016-10-01.txt
# (10, 8) 2016-09-25 2016-10-01
# True 2019-12-21 18:22:50.813568 MediaStormDailySales_week_ending_2016-10-08.txt
# (10, 8) 2016-10-02 2016-10-08
# True 2019-12-21 18:22:50.828478 MediaStormDailySales_week_ending_2016-10-15.txt
# (10, 8) 2016-10-10 2016-10-15
# True 2019-12-21 18:22:50.843548 MediaStormDailySales_week_ending_2016-10-22.txt
# (10, 8) 2016-10-16 2016-10-21
# True 2019-12-21 18:22:50.858393 MediaStormDailySales_week_ending_2016-10-29.txt
# (10, 8) 2016-10-23 2016-10-29
# True 2019-12-21 18:22:50.873539 MediaStormDailySales_week_ending_2016-11-05.txt
# (10, 8) 2016-10-30 2016-11-05
# True 2019-12-21 18:22:50.888418 MediaStormDailySales_week_ending_2016-11-12.txt
# (10, 8) 2016-11-06 2016-11-12
# True 2019-12-21 18:22:50.903444 MediaStormDailySales_week_ending_2016-11-19.txt
# (10, 8) 2016-11-13 2016-11-19
# True 2019-12-21 18:22:50.918434 MediaStormDailySales_week_ending_2016-11-26.txt
# (10, 8) 2016-11-20 2016-11-26
# True 2019-12-21 18:22:50.933853 MediaStormDailySales_week_ending_2016-12-03.txt
# (10, 8) 2016-11-27 2016-12-03
# True 2019-12-21 18:22:50.951334 MediaStormDailySales_week_ending_2016-12-10.txt
# (10, 8) 2016-12-05 2016-12-10
# True 2019-12-21 18:22:50.966356 MediaStormDailySales_week_ending_2016-12-17.txt
# (10, 8) 2016-12-11 2016-12-17
# True 2019-12-21 18:22:50.981164 MediaStormDailySales_week_ending_2016-12-24.txt
# (10, 8) 2016-12-18 2016-12-24
# True 2019-12-21 18:22:50.996612 MediaStormDailySales_week_ending_2016-12-31.txt
# (10, 8) 2016-12-26 2016-12-31
# True 2019-12-21 18:22:51.011592 MediaStormDailySales_week_ending_2017-01-07.txt
# (10, 8) 2017-01-02 2017-01-07
# True 2019-12-21 18:22:51.027095 MediaStormDailySales_week_ending_2017-01-14.txt
# (10, 8) 2017-01-08 2017-01-14
# True 2019-12-21 18:22:51.041949 MediaStormDailySales_week_ending_2017-01-21.txt
# (10, 8) 2017-01-15 2017-01-21
# True 2019-12-21 18:22:51.100611 MediaStormDailySales_week_ending_2017-01-28.txt
# (10, 8) 2017-01-22 2017-01-28
# True 2019-12-21 18:22:51.141072 MediaStormDailySales_week_ending_2017-02-04.txt
# (10, 8) 2017-01-29 2017-02-04
# True 2019-12-21 18:22:51.156161 MediaStormDailySales_week_ending_2017-02-11.txt
# (10, 8) 2017-02-07 2017-02-11
# True 2019-12-21 18:22:51.171133 MediaStormDailySales_week_ending_2017-02-18.txt
# (10, 8) 2017-02-12 2017-02-17
# True 2019-12-21 18:22:51.185957 MediaStormDailySales_week_ending_2017-02-25.txt
# (10, 8) 2017-02-19 2017-02-25
# True 2019-12-21 18:22:51.200928 MediaStormDailySales_week_ending_2017-03-04.txt
# (10, 8) 2017-02-27 2017-03-04
# True 2019-12-21 18:22:51.216545 MediaStormDailySales_week_ending_2017-03-11.txt
# (10, 8) 2017-03-05 2017-03-11
# True 2019-12-21 18:22:51.231396 MediaStormDailySales_week_ending_2017-03-18.txt
# (10, 8) 2017-03-12 2017-03-18
# True 2019-12-21 18:22:51.246335 MediaStormDailySales_week_ending_2017-03-25.txt
# (10, 8) 2017-03-20 2017-03-25
# True 2019-12-21 18:22:51.261473 MediaStormDailySales_week_ending_2017-04-01.txt
# (10, 8) 2017-03-26 2017-04-01
# True 2019-12-21 18:22:51.276303 MediaStormDailySales_week_ending_2017-04-08.txt
# (10, 8) 2017-04-02 2017-04-07
# True 2019-12-21 18:22:51.291224 MediaStormDailySales_week_ending_2017-04-15.txt
# (10, 8) 2017-04-09 2017-04-15
# True 2019-12-21 18:22:51.306114 MediaStormDailySales_week_ending_2017-04-22.txt
# (10, 8) 2017-04-16 2017-04-22
# True 2019-12-21 18:22:51.321278 MediaStormDailySales_week_ending_2017-04-29.txt
# (10, 8) 2017-04-23 2017-04-29
# True 2019-12-21 18:22:51.336125 MediaStormDailySales_week_ending_2017-05-06.txt
# (10, 8) 2017-04-30 2017-05-06
# True 2019-12-21 18:22:51.350966 MediaStormDailySales_week_ending_2017-05-13.txt
# (10, 8) 2017-05-07 2017-05-13
# True 2019-12-21 18:22:51.366008 MediaStormDailySales_week_ending_2017-05-20.txt
# (10, 8) 2017-05-16 2017-05-20
# True 2019-12-21 18:22:51.381921 MediaStormDailySales_week_ending_2017-05-27.txt
# (10, 8) 2017-05-21 2017-05-27
# True 2019-12-21 18:22:51.396892 MediaStormDailySales_week_ending_2017-06-03.txt
# (10, 8) 2017-05-28 2017-06-03
# True 2019-12-21 18:22:51.411792 MediaStormDailySales_week_ending_2017-06-10.txt
# (10, 8) 2017-06-04 2017-06-08
# True 2019-12-21 18:22:51.427183 MediaStormDailySales_week_ending_2017-06-17.txt
# (10, 8) 2017-06-11 2017-06-17
# True 2019-12-21 18:22:51.442773 MediaStormDailySales_week_ending_2017-06-24.txt
# (10, 8) 2017-06-18 2017-06-24
# True 2019-12-21 18:22:51.457724 MediaStormDailySales_week_ending_2017-07-01.txt
# (10, 8) 2017-06-25 2017-07-01
# True 2019-12-21 18:22:51.472571 MediaStormDailySales_week_ending_2017-07-08.txt
# (10, 8) 2017-07-02 2017-07-08
# True 2019-12-21 18:22:51.487436 MediaStormDailySales_week_ending_2017-07-15.txt
# (10, 8) 2017-07-09 2017-07-15
# True 2019-12-21 18:22:51.523363 MediaStormDailySales_week_ending_2017-07-22.txt
# (10, 8) 2017-07-16 2017-07-22
# True 2019-12-21 18:22:51.538285 MediaStormDailySales_week_ending_2017-07-29.txt
# (10, 8) 2017-07-24 2017-07-29
# True 2019-12-21 18:22:51.674964 MediaStormDailySales_week_ending_2017-08-05.txt
# (10, 8) 2017-07-31 2017-08-05
# True 2019-12-21 18:22:51.690065 MediaStormDailySales_week_ending_2017-08-12.txt
# (10, 8) 2017-08-06 2017-08-12
# True 2019-12-21 18:22:51.705289 MediaStormDailySales_week_ending_2017-08-19.txt
# (10, 8) 2017-08-13 2017-08-19
# True 2019-12-21 18:22:51.733694 MediaStormDailySales_week_ending_2017-08-26.txt
# (10, 8) 2017-08-21 2017-08-26
# True 2019-12-21 18:22:51.748608 MediaStormDailySales_week_ending_2017-09-02.txt
# (10, 8) 2017-08-27 2017-09-02
# True 2019-12-21 18:22:51.763492 MediaStormDailySales_week_ending_2017-09-09.txt
# (10, 8) 2017-09-04 2017-09-09
# True 2019-12-21 18:22:51.778575 MediaStormDailySales_week_ending_2017-09-16.txt
# (10, 8) 2017-09-10 2017-09-16
# True 2019-12-21 18:22:51.801472 MediaStormDailySales_week_ending_2017-09-23.txt
# (10, 8) 2017-09-17 2017-09-23
# True 2019-12-21 18:22:51.816377 MediaStormDailySales_week_ending_2017-09-30.txt
# (10, 8) 2017-09-24 2017-09-30
# True 2019-12-21 18:22:51.831322 MediaStormDailySales_week_ending_2017-10-07.txt
# (10, 8) 2017-10-01 2017-10-07
# True 2019-12-21 18:22:51.846505 MediaStormDailySales_week_ending_2017-10-14.txt
# (10, 8) 2017-10-08 2017-10-14
# True 2019-12-21 18:22:51.867407 MediaStormDailySales_week_ending_2017-10-21.txt
# (10, 8) 2017-10-15 2017-10-21
# True 2019-12-21 18:22:51.882525 MediaStormDailySales_week_ending_2017-10-28.txt
# (10, 8) 2017-10-22 2017-10-28
# True 2019-12-21 18:22:51.897484 MediaStormDailySales_week_ending_2017-11-04.txt
# (10, 8) 2017-10-30 2017-11-04
# True 2019-12-21 18:22:51.912725 MediaStormDailySales_week_ending_2017-11-11.txt
# (10, 8) 2017-11-05 2017-11-11
# True 2019-12-21 18:22:51.927626 MediaStormDailySales_week_ending_2017-11-18.txt
# (10, 8) 2017-11-12 2017-11-18
# True 2019-12-21 18:22:51.942477 MediaStormDailySales_week_ending_2017-11-25.txt
# (10, 8) 2017-11-19 2017-11-25
# True 2019-12-21 18:22:51.957362 MediaStormDailySales_week_ending_2017-12-02.txt
# (10, 8) 2017-11-26 2017-12-02
# True 2019-12-21 18:22:51.972428 MediaStormDailySales_week_ending_2017-12-09.txt
# (10, 8) 2017-12-03 2017-12-09
# True 2019-12-21 18:22:52.006951 MediaStormDailySales_week_ending_2017-12-16.txt
# (10, 8) 2017-12-10 2017-12-16
# True 2019-12-21 18:22:52.021837 MediaStormDailySales_week_ending_2017-12-23.txt
# (10, 8) 2017-12-18 2017-12-22
# True 2019-12-21 18:22:52.036724 MediaStormDailySales_week_ending_2017-12-30.txt
# (10, 8) 2017-12-24 2017-12-30
# True 2019-12-21 18:22:52.051941 MediaStormDailySales_week_ending_2018-01-06.txt
# (10, 8) 2017-12-31 2018-01-06
# True 2019-12-21 18:22:52.066806 MediaStormDailySales_week_ending_2018-01-13.txt
# (10, 8) 2018-01-08 2018-01-13
# True 2019-12-21 18:22:52.081755 MediaStormDailySales_week_ending_2018-01-20.txt
# (10, 8) 2018-01-15 2018-01-20
# True 2019-12-21 18:22:52.097283 MediaStormDailySales_week_ending_2018-01-27.txt
# (10, 8) 2018-01-21 2018-01-27
# True 2019-12-21 18:22:52.112821 MediaStormDailySales_week_ending_2018-02-03.txt
# (10, 8) 2018-01-29 2018-02-03
# True 2019-12-21 18:22:52.127727 MediaStormDailySales_week_ending_2018-02-10.txt
# (10, 8) 2018-02-04 2018-02-09
# True 2019-12-21 18:22:52.142557 MediaStormDailySales_week_ending_2018-02-17.txt
# (10, 8) 2018-02-11 2018-02-17
# True 2019-12-21 18:22:52.157467 MediaStormDailySales_week_ending_2018-02-24.txt
# (10, 8) 2018-02-18 2018-02-24
# True 2019-12-21 18:22:52.172564 MediaStormDailySales_week_ending_2018-03-03.txt
# (10, 8) 2018-02-27 2018-03-03
# True 2019-12-21 18:22:52.187340 MediaStormDailySales_week_ending_2018-03-10.txt
# (10, 8) 2018-03-06 2018-03-10
# True 2019-12-21 18:22:52.202249 MediaStormDailySales_week_ending_2018-03-17.txt
# (10, 8) 2018-03-11 2018-03-17
# True 2019-12-21 18:22:52.217093 MediaStormDailySales_week_ending_2018-03-24.txt
# (10, 8) 2018-03-18 2018-03-24
# True 2019-12-21 18:22:52.232237 MediaStormDailySales_week_ending_2018-03-31.txt
# (10, 8) 2018-03-25 2018-03-31
# True 2019-12-21 18:22:52.247111 MediaStormDailySales_week_ending_2018-04-07.txt
# (10, 8) 2018-04-01 2018-04-07
# True 2019-12-21 18:22:52.261984 MediaStormDailySales_week_ending_2018-04-14.txt
# (10, 8) 2018-04-08 2018-04-14
# True 2019-12-21 18:22:52.276828 MediaStormDailySales_week_ending_2018-04-21.txt
# (10, 8) 2018-04-16 2018-04-21
# True 2019-12-21 18:22:52.292418 MediaStormDailySales_week_ending_2018-04-28.txt
# (10, 8) 2018-04-22 2018-04-28
# True 2019-12-21 18:22:52.307634 MediaStormDailySales_week_ending_2018-05-05.txt
# (10, 8) 2018-04-29 2018-05-05
# True 2019-12-21 18:22:52.322528 MediaStormDailySales_week_ending_2018-05-12.txt
# (10, 8) 2018-05-06 2018-05-12
# True 2019-12-21 18:22:52.337322 MediaStormDailySales_week_ending_2018-05-19.txt
# (10, 8) 2018-05-13 2018-05-19
# True 2019-12-21 18:22:52.352348 MediaStormDailySales_week_ending_2018-05-26.txt
# (10, 8) 2018-05-20 2018-05-25
# True 2019-12-21 18:22:52.367481 MediaStormDailySales_week_ending_2018-06-02.txt
# (10, 8) 2018-05-28 2018-06-02
# True 2019-12-21 18:22:52.382268 MediaStormDailySales_week_ending_2018-06-09.txt
# (10, 8) 2018-06-03 2018-06-09
# True 2019-12-21 18:22:52.397214 MediaStormDailySales.txt
# (10, 8) 2018-06-10 2018-06-16
# True 2019-12-21 18:22:52.412214 MediaStormDailySales.txt
# (10, 8) 2018-06-18 2018-06-23
# True 2019-12-21 18:22:52.427127 MediaStormDailySales.txt
# (10, 8) 2018-06-24 2018-06-30
# True 2019-12-21 18:22:52.442130 MediaStormDailySales.txt
# (10, 8) 2018-07-01 2018-07-07
# True 2019-12-21 18:22:52.456950 MediaStormDailySales20180717-113630-767.txt
# (10, 8) 2018-07-08 2018-07-14
# True 2019-12-21 18:22:52.478233 MediaStormDailySales20180724-113327-741.txt
# (10, 8) 2018-07-15 2018-07-21
# True 2019-12-21 18:22:52.494731 MediaStormDailySales20180731-111804-489.txt
# (10, 8) 2018-07-22 2018-07-28
# True 2019-12-21 18:22:52.509454 MediaStormDailySales20180807-111637-702.txt
# (10, 8) 2018-07-29 2018-08-04
# All_Done:  2019-12-21 18:22:52.522165
