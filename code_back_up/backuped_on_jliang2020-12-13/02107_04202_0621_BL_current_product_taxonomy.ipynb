# %%
import pandas as pd
import datetime
import os
os.getcwd()
# Out:
# '/home/jian/Projects/Big_Lots/Analysis/2019_Q1/Planner_Request/Bruce_BL_Taxonomy_20190219'

# %%
monthly_taxonomy=pd.read_table("/home/jian/BigLots/static_files/ProductTaxonomy/MediaStormProductTaxonomy20190201-133832-059.txt",dtype=str,sep='|')

# %%
early_taxonomy=pd.read_table("/home/jian/BigLots/static_files/MediaStorm Data Extract - Product Taxonomy.txt",sep="|",dtype=str)
early_division_description=pd.read_table("/home/jian/BigLots/static_files/MediaStorm Data Extract - Division Names.txt",sep="|",dtype=str)
early_department_description=pd.read_table("/home/jian/BigLots/static_files/MediaStorm Data Extract - Department Names.txt",sep="|",dtype=str)
early_class_description=pd.read_table("/home/jian/BigLots/static_files/MediaStorm Data Extract - Class Names.txt",sep="|",dtype=str,encoding="ISO-8859-1")
early_subclass_description=pd.read_table("/home/jian/BigLots/static_files/MediaStorm Data Extract - Subclass Names.txt",sep="|",dtype=str,encoding="ISO-8859-1")

# %%
writer=pd.ExcelWriter("/home/jian/Projects/Big_Lots/Analysis/2019_Q1/Planner_Request/Bruce_BL_Taxonomy_20190219/BL_current_taxonomy_JL_"+str(datetime.datetime.now().date())+".xlsx",engine="xlsxwriter")
monthly_taxonomy.to_excel(writer,"current_monthly_taxonomy",index=False)
early_division_description.to_excel(writer,"Division_Desc_recevied_early",index=False)
early_department_description.to_excel(writer,"Department_Desc_recevied_early",index=False)
early_class_description.to_excel(writer,"Class_Desc_recevied_early",index=False)
early_subclass_description.to_excel(writer,"SubClass_Desc_recevied_early",index=False)
writer.save()

# %%
new_daily_data_sameple=pd.read_table("/home/jian/BigLots/2019_by_weeks/MediaStorm_2019-02-09/item_level_sample.txt",nrows=10,sep="|",dtype=str)
new_daily_data_sameple
# Out:
#   location_id transaction_dt transaction_id  \
# 0        4340     2019-02-09           1235
# 1        1650     2019-02-06           1219
# 2        1535     2019-02-08           7170
# 3        5100     2019-02-09           6072
# 4        1995     2019-02-04           7022
# 5        1389     2019-02-07           5092
# 6        5214     2019-02-09           7895
# 7          32     2019-02-07           9010
# 8        4127     2019-02-09           9258
# 9          82     2019-02-08           5359
#
#                                   customer_id_hashed class_code_id  \
# 0  4d814aa2f7a1122542b7421e5ad2c621ff4939b4db5f7a...         16002
# 1  6689a5fc1bdabd1ef214cf0aaa604d9ff018101df5a9b4...         14001
# 2  0222a342fe88aadcd32e459bb33a91143c95304703a458...         11009
# 3                                                NaN         11006
# 4                                                NaN         16002
# 5                                                NaN         11005
# ...
