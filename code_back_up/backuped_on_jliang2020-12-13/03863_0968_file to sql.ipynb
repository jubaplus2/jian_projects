# %%
import glob
import pandas as pd
from sqlalchemy import create_engine

# %%
import logging
logging.basicConfig(filename='impr_to_sql.log', 
                    level=logging.INFO, 
                    format='%(asctime)s %(message)s')

import json
files_in_mysql = json.load(open('impr_files_in_mysql.json', 'r'))

files = glob.glob('/home/jubauser1/jzou/dcm_account7252/impression/*')
files = [x for x in files if x not in files_in_mysql]
files.sort()

engine = create_engine('mysql://root:JubaPlus-2017@localhost/dcm_account7252')

for f in files:
    try:
        df = pd.read_csv(f, index_col=['Campaign ID', 'Event Time'])
        df['file_name'] = f

        df.to_sql('impression', con=engine, if_exists='append')

        files_in_mysql.append(f)
        logging.info(f)
        del df
    except Exception as e:
        logging.warning('file: %s, warning:%s'%(f, e))

json.dump(files_in_mysql, open('impr_files_in_mysql.json', 'w'))

# %%
pd.options.display.max_rows=6

# %%
f = '/home/jubauser1/jzou/dcm_account7252/impression/dcm_account7252_impression_2017082022_20170821_001749_599244388.csv.gz'
df = pd.read_csv(f)
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df = df[df['Campaign ID'] == 11527750]
df
# Out:
#               Event Time                       User ID  Advertiser ID  \
# 0       1503267418945400                             0        6171870
# 3       1503267047139806                             0        6171870
# 7       1503269529693207                             0        6171870
# ...                  ...                           ...            ...
# 413122  1503269077188607  AMsySZacnnPmE1khDBXeHGbx9AsV        6171870
# 413125  1503270329335807  AMsySZb-0D-t92If0aJp15daFV88        6171870
# 413130  1503269139471297                             0        6171870
#
#         Campaign ID      Ad ID  Rendering ID  Creative Version  Site ID (DCM)  \
# 0          11527750  403334882      91990901                 1        2991547
# 3          11527750  403284425      92056578                 1        2991547
# 7          11527750  403334882      91990907                 1        2991547
# ...             ...        ...           ...               ...            ...
# ...

# %%
df['file_name'] = f

# %%
df
# Out:
#               Event Time                       User ID  Advertiser ID  \
# 0       1503267418945400                             0        6171870
# 3       1503267047139806                             0        6171870
# 7       1503269529693207                             0        6171870
# ...                  ...                           ...            ...
# 413122  1503269077188607  AMsySZacnnPmE1khDBXeHGbx9AsV        6171870
# 413125  1503270329335807  AMsySZb-0D-t92If0aJp15daFV88        6171870
# 413130  1503269139471297                             0        6171870
#
#         Campaign ID      Ad ID  Rendering ID  Creative Version  Site ID (DCM)  \
# 0          11527750  403334882      91990901                 1        2991547
# 3          11527750  403284425      92056578                 1        2991547
# 7          11527750  403334882      91990907                 1        2991547
# ...             ...        ...           ...               ...            ...
# ...

# %%
import sys
sys.getsizeof(df)
# Out:
# 264550706

# %%
engine = create_engine('mysql://root:JubaPlus-2017@localhost/dcm7252?unix_socket=/home/mysql/mysql/mysql.sock')

# %%
df.to_sql('impression_campaign_11527750', con=engine, if_exists='append', index=False)

# %%
sql = 'select `Event Time`, `User ID` from impression_campaign_11527750;'
df2 = pd.read_sql(sql, con=engine)

# %%
df2
# Out:
#               Event Time                       User ID
# 0       1503267418945400                             0
# 1       1503267047139806                             0
# 2       1503269529693207                             0
# ...                  ...                           ...
# 135849  1503269077188607  AMsySZacnnPmE1khDBXeHGbx9AsV
# 135850  1503270329335807  AMsySZb-0D-t92If0aJp15daFV88
# 135851  1503269139471297                             0
#
# [135852 rows x 2 columns]

# %%
import json
files_in_mysql = [f]#json.load(open('impr_files_in_mysql.json', 'r'))

# %%
json.dump(files_in_mysql, open('/home/jubauser1/jzou/dcm_account7252/scripts/winery/impr_files_in_mysql.json', 'w'))
