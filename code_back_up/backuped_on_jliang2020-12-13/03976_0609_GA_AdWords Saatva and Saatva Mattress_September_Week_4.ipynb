# %%
# _September_Week1 2018: 9/11/18-10/18/18

import pandas as pd
import numpy as np
import datetime
import pandas as pd
from googleads import adwords
import google_analytics_reporting_api as ga
import os

week="_September_Week4" 

Start_Date_overall='2018-09-11'
End_Data_overall='2018-10-18'

Start_Date_1='2018-09-11'
End_Date_1='2018-10-01'

Start_Date_2='2018-10-02'
End_Date_2='2018-10-18'


today_str=str(datetime.datetime.now().date())
writer_folder="/home/jian/Projects/Saatva/To_Lexie_and_Connor/output/running_on_"+today_str+"/"
try:
    os.stat(writer_folder)
except:
    os.mkdir(writer_folder)

writer_folder="/home/jian/Projects/Saatva/To_Lexie_and_Connor/output/running_on_"+today_str+"/"+week[1:]+"/"
try:
    os.stat(writer_folder)
except:
    os.mkdir(writer_folder)

# %% [markdown]
# # Google Analytics

# %%
analytics = ga.initialize_analyticsreporting('/home/jian/Projects/Saatva/GA/GA_api_jubapluscc@gmail.com.json')

def num_func_trans(df):
    if 'ga:sessions' in df.columns:
        df['ga:sessions']=df['ga:sessions'].apply(lambda x: int(x.replace(",","")))
        df['ga:sessions']=df['ga:sessions'].astype(int)

    if 'ga:adClicks' in df.columns:
        df['ga:adClicks']=df['ga:adClicks'].apply(lambda x: int(x.replace(",","")))
        df['ga:adClicks']=df['ga:adClicks'].astype(int)

    if 'ga:impressions' in df.columns:
        df['ga:impressions']=df['ga:impressions'].apply(lambda x: int(x.replace(",","")))
        df['ga:impressions']=df['ga:impressions'].astype(int)
    
    if 'ga:transactions' in df.columns:
        df['ga:transactions']=df['ga:transactions'].apply(lambda x: int(x.replace(",","")))
        df['ga:transactions']=df['ga:transactions'].astype(int)
    
    if 'ga:transactionRevenue' in df.columns:
        df['ga:transactionRevenue']=df['ga:transactionRevenue'].apply(lambda x: float(x.replace(",","")))
        df['ga:transactionRevenue']=df['ga:transactionRevenue'].astype(float)

    
    return df

# %%
# Saatva.com
# dateHour, sourceMedium      sessions, adClicks, impressions
ga_data_1=ga.get_report_over_10000_rows(analytics=analytics, VIEW_ID='122377905',start_date=Start_Date_1, end_date=End_Date_1,
                                            ga_metrics=['ga:sessions','ga:adClicks','ga:impressions','ga:transactions','ga:transactionRevenue'],
                                            ga_dimensions=['ga:dateHour','ga:sourceMedium'])

ga_data_2=ga.get_report_over_10000_rows(analytics=analytics, VIEW_ID='122377905',start_date=Start_Date_2, end_date=End_Date_2,
                                            ga_metrics=['ga:sessions','ga:adClicks','ga:impressions','ga:transactions','ga:transactionRevenue'],
                                            ga_dimensions=['ga:dateHour','ga:sourceMedium'])


ga_data_saatva=ga_data_1.append(ga_data_2)
ga_data_saatva['View']="Saatva.com"
ga_data_saatva['View_ID']="122377905"
ga_data_saatva.shape
# Out:
# (8046, 9)

# %%
ga_data_saatva.head(2)
# Out:
#   ga:adClicks ga:dateHour ga:impressions ga:sessions    ga:sourceMedium  \
# 0           0  2018091100              0           5  (direct) / (none)
# 1           0  2018091100              0           3         bing / cpc
#
#   ga:transactionRevenue ga:transactions        View    View_ID
# 0                   0.0               0  Saatva.com  122377905
# 1                   0.0               0  Saatva.com  122377905

# %%
# Saatvamattress.com
# dateHour, sourceMedium      sessions, adClicks, impressions
ga_data_1=ga.get_report_over_10000_rows(analytics=analytics, VIEW_ID='33605697',start_date=Start_Date_1, end_date=End_Date_1,
                                            ga_metrics=['ga:sessions','ga:adClicks','ga:impressions','ga:transactions','ga:transactionRevenue'],
                                            ga_dimensions=['ga:dateHour','ga:sourceMedium'])

ga_data_2=ga.get_report_over_10000_rows(analytics=analytics, VIEW_ID='33605697',start_date=Start_Date_2, end_date=End_Date_2,
                                            ga_metrics=['ga:sessions','ga:adClicks','ga:impressions','ga:transactions','ga:transactionRevenue'],
                                            ga_dimensions=['ga:dateHour','ga:sourceMedium'])


ga_data_SM=ga_data_1.append(ga_data_2)
ga_data_SM['View']="Saatvamattress.com"
ga_data_SM['View_ID']="33605697"
ga_data_SM.shape
# Out:
# (48160, 9)

# %%
ga_data=ga_data_SM.append(ga_data_saatva)
ga_data=num_func_trans(ga_data)

# %%
ga_data['Source']=ga_data['ga:sourceMedium'].apply(lambda x: x.split(" / ")[0])
ga_data['Medium']=ga_data['ga:sourceMedium'].apply(lambda x: x.split(" / ")[1])

# %%
# msn in 'social'
# mail.yahoo.com / referral in 'referral'
# Social: 'msn','instagram','pinterest','facebook
                                                
ga_data['Defined_Media']=np.nan
ga_data['Defined_Media']=np.where(((ga_data['ga:sourceMedium'].str.contains('youtube.')) | (ga_data['Medium']=="social")),"Social",
                                  np.where(((ga_data['Source'].isin(['msn','instagram','Instagram','pinterest','facebook'])) & (ga_data['Medium']=='cpc')),"Social",
                                           np.where(ga_data['ga:sourceMedium'].str.contains('criteo'),"Retarget",
                                                    np.where(ga_data['Source']=="(direct)","Direct",
                                                             np.where(((ga_data['Source'].isin(['google','bing','yahoo'])) & (ga_data['Medium']=='cpc')),"SEM",
                                                                      np.where(((ga_data['Source'].isin(['google','bing','yahoo'])) & (ga_data['Medium']=='organic')),"SEO",
                                                                               np.where(ga_data['Source']=="powerInbox","Email",
                                                                                        np.where((ga_data['ga:sourceMedium'].str.contains('email')) & (~ga_data['ga:sourceMedium'].isin(["taboola / townnews-wvgazettemail","query.hemailaccessonline.com / referral"]) | (ga_data['ga:sourceMedium'].str.contains("mail.") )),"Email",
                                                                                                 np.where(ga_data['ga:sourceMedium'].str.contains('taboola'),"Video",
                                                                                                          np.where(ga_data['Medium']=="referral","Referral",
                                                                                                                   np.where(ga_data['Medium'].isin(["partner","partners"]),"partner",
                                                                                                                            np.where(ga_data['ga:sourceMedium'].str.contains('display'),"Display","Others")
                                                                                                                            )
                                                                                                                   )
                                                                                                          )
                                                                                                )
                                                                                       )
                                                                              )
                                                                     )
                                                            )
                                                   )
                                          )
                                 )

# %%
GA_taxonomy=ga_data[['ga:sourceMedium','Source','Medium','Defined_Media']].drop_duplicates()
GA_taxonomy.reset_index(inplace=True)
GA_taxonomy=GA_taxonomy.sort_values('Defined_Media')
del GA_taxonomy['index']

# %%
ga_data.head(2)
# Out:
#    ga:adClicks ga:dateHour  ga:impressions  ga:sessions      ga:sourceMedium  \
# 0            0  2018091100               0           58    (direct) / (none)
# 1            0  2018091100               0           28  (not set) / partner
#
#    ga:transactionRevenue  ga:transactions                View   View_ID  \
# 0                    0.0                0  Saatvamattress.com  33605697
# 1                 1108.0                1  Saatvamattress.com  33605697
#
#       Source   Medium Defined_Media
# 0   (direct)   (none)        Direct
# 1  (not set)  partner       partner

# %%
ga_agg_session=ga_data.groupby(['ga:dateHour','Defined_Media'])['ga:sessions'].sum().to_frame()
ga_agg_session.reset_index(inplace=True)
ga_agg_wide_session=ga_agg_session.pivot('ga:dateHour','Defined_Media','ga:sessions')
ga_agg_wide_session.reset_index(inplace=True)
ga_agg_wide_session['time_hour']=ga_agg_wide_session['ga:dateHour'].apply(lambda x:datetime.datetime.strptime(x,"%Y%m%d%H"))

# %%
ga_agg_transaction=ga_data.groupby(['ga:dateHour','Defined_Media'])['ga:transactions'].sum().to_frame()
ga_agg_transaction.reset_index(inplace=True)
ga_agg_wide_trans=ga_agg_transaction.pivot('ga:dateHour','Defined_Media','ga:transactions')
ga_agg_wide_trans.reset_index(inplace=True)
ga_agg_wide_trans['time_hour']=ga_agg_wide_trans['ga:dateHour'].apply(lambda x:datetime.datetime.strptime(x,"%Y%m%d%H"))

# %%
ga_agg_Revenue=ga_data.groupby(['ga:dateHour','Defined_Media'])['ga:transactionRevenue'].sum().to_frame()
ga_agg_Revenue.reset_index(inplace=True)
ga_agg_wide_Revenue=ga_agg_Revenue.pivot('ga:dateHour','Defined_Media','ga:transactionRevenue')
ga_agg_wide_Revenue.reset_index(inplace=True)
ga_agg_wide_Revenue['time_hour']=ga_agg_wide_Revenue['ga:dateHour'].apply(lambda x:datetime.datetime.strptime(x,"%Y%m%d%H"))

# %%
writer=pd.ExcelWriter(writer_folder+'/Saatva_S_and_SM_GA_by_Media_'+Start_Date_1+'_to_'+End_Date_2+week+'.xlsx', engine='xlsxwriter')

# %%
# Combined both Saatva.com and Saatvamattress.com
ga_agg_wide_session.to_excel(writer,"Session_hour_media",index=False)
ga_agg_wide_trans.to_excel(writer,"Trans_hour_media",index=False)
ga_agg_wide_Revenue.to_excel(writer,"Revenue_hour_media",index=False)

ga_data.to_excel(writer,"data",index=False)
GA_taxonomy.to_excel(writer,"taxonomy",index=False)
writer.save()
GA_taxonomy.to_csv(writer_folder+'/Saatva_S_and_SM_GA_taxonomy_'+Start_Date_1+'_to_'+End_Date_2+week+'.csv',index=False)
# Out:
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress&gca_campaignid=1016369000&gca_adgroupid=51320554757&gca_matchtype=p&gca_network=s&gca_device=c&gca_adposition=1t4&gca_loc_interest_ms=&gca_loc_physical_ms=9061285&gclid=EAIaIQobChMI6ObC9u-y3QIVQrXACh379gBNEAAYBCAAEgJgMfD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1s1&gca_loc_interest_ms=&gca_loc_physical_ms=9016899&gclid=EAIaIQobChMI0P7lhfGy3QIVELnACh3rTAr1EAEYASAAEgKzQPD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-7464603423034882&output=html&h=600&slotname=LastLook1.30&adk=1291117007&adf=3653028389&w=300&guci=2.2.0.0.2.2.0&url=drudgereport.com&ea=0&flash=30.0.0&wgl=1&dt=1536668311162&bpp=31&bdt=113&fdt=133&idt=135&shv=r20180906&cbv=r20180604&saldr=sa&correlator=1851791906157&frm=23&ife=5&pv=1&ga_vid=2066100243.1525381122&ga_sid=1536668311&ga_hid=1115028069&ga_fc=0&iag=15&icsg=42&nhd=2&dssz=6&mdo=0&mso=0&u_tz=-360&u_his=2&u_java=0&u_h=900&u_w=1440&u_ah=798&u_aw=1440&u_cd=24&u_nplug=4&u_nmime=6&adx=942&ady=2288&biw=1402&bih=701&isw=300&ish=600&ifk=3550955996&scr_x=0&scr_y=2518&eid=21060853&oid=3&ref=https://drudgereport.com/&loc=EMPTY&top=https://drudgereport.com/&rx=0&eae=2&fc=528&brdim=0,23,0,23,1440,22,1417,798,300,600&vis=1&rsz=d|d|eE|n&abl=XS&ppjl=u&pfx=0&fu=20&bc=7&ifi=1&fsb=1&dtd=144%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-5272231826652365&output=html&h=600&slotname=1041074596&adk=2185478631&adf=3845768392&w=160&lmt=1536672199&loeid=40993911&guci=2.2.0.0.2.2.0&url=https://www.contestgirl.com/&flash=30.0.0&wgl=1&dt=1536672199704&bpp=37&bdt=316&fdt=45&idt=110&shv=r20180906&cbv=r20180604&saldr=sa&abxe=1&correlator=6395288885935&frm=20&pv=2&ga_vid=558599028.1535900486&ga_sid=1536671801&ga_hid=1196413328&ga_fc=1&icsg=2090&dssz=11&mdo=0&mso=0&u_tz=-300&u_his=7&u_java=1&u_h=900&u_w=1600&u_ah=860&u_aw=1600&u_cd=24&u_nplug=1&u_nmime=2&adx=1108&ady=234&biw=1600&bih=900&scr_x=0&scr_y=0&eid=21060853,40993901&oid=3&rx=0&eae=0&fc=528&docm=11&brdim=0,0,0,0,1600,,1600,900,1600,900&vis=1&rsz=||eE|&abl=CS&ppjl=f&pfx=0&fu=16&bc=1&ifi=1&xpc=EmNAvDZoCD&p=https://www.contestgirl.com&dtd=145%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-8633514863566290&output=html&h=250&slotname=5018388632&adk=1953506957&adf=4266711080&w=300&lmt=1536671955&pucrd=CgYgACgAOAESAhgHeAM&guci=2.2.0.0.2.2.0&format=300x250&url=https://www.litscape.com/word_tools/contains_only.php&flash=0&avail_w=300&wgl=1&adsid=ADfwbujh5TB5IlZme7_RjiuJnWX87M3rF5pEIHqGPv9gqq26cVSN72oI7DuUA_Ullvwj&dt=1536671953314&bpp=14&bdt=582&fdt=1767&idt=1773&shv=r20180906&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=0x0,320x100,375x60,336x280,250x250,375x90,375x60&nras=1&correlator=386126813710&frm=20&pv=1&ga_vid=1867146630.1536671954&ga_sid=1536671954&ga_hid=1038220370&ga_fc=0&iag=0&icsg=36007406381736&dssz=39&mdo=0&mso=0&u_tz=-240&u_his=1&u_java=0&u_h=667&u_w=375&u_ah=667&u_aw=375&u_cd=32&u_nplug=0&u_nmime=0&adx=39&ady=711&biw=375&bih=535&scr_x=0&scr_y=0&eid=10573697,21060853,21061395,368226501,21061796&oid=3&ref=https://www.google.com/&rx=0&eae=0&fc=1936&brdim=0,0,0,0,375,0,0,0,375,535&vis=1&rsz=||aeEbr|&abl=CA&ppjl=f&pfx=0&fu=1040&bc=7&jar=2018-09-11-13&ifi=7&fsb=1&xpc=LXgxKA682r&p=https://www.litscape.com&dtd=1798%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Reviews%20(Exact)&pt_adgroup=mattress%20reviews&pt_keyword=mattress%20reviews&gclid=EAIaIQobChMI6vHq64Kz3QIViZ6zCh0z2QRsEAAYASAAEgLGpfD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-5833136623198638&output=html&h=266&slotname=1202694908&adk=3351565075&adf=2541534019&w=320&lmt=1536674712&rafmt=1&guci=2.2.0.0.2.2.0&format=320x266&url=https://freebiemom.com/deal/free-metal-lid-free-shipping/&flash=0&fwr=1&rh=0&rw=285&resp_fmts=3&sfro=1&wgl=1&adsid=NT&dt=1536674712712&bpp=52&bdt=3158&fdt=57&idt=73&shv=r20180906&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=0x0,320x100,320x267&nras=1&correlator=4511733695770&frm=20&pv=1&ga_vid=695901980.1533979390&ga_sid=1536674711&ga_hid=474914378&ga_fc=0&iag=0&icsg=171812028416&dssz=31&mdo=0&mso=0&u_tz=-240&u_his=1&u_java=0&u_h=570&u_w=320&u_ah=570&u_aw=320&u_cd=24&u_nplug=0&u_nmime=0&adx=0&ady=768&biw=320&bih=448&scr_x=0&scr_y=0&eid=21060853,828064257,828064255&oid=3&ref=https://freebiemom.com/deal-category/freebies/&rx=0&eae=0&fc=1940&brdim=0,0,0,0,320,0,320,448,320,448&vis=1&rsz=o||eEbr|&abl=CS&ppjl=f&pfx=0&fu=144&bc=7&jar=2018-09-09-20&osw_key=4137052936&ifi=3&xpc=8o7LBRTBn7&p=https://freebiemom.com&dtd=141%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-7360490653670591&output=html&h=90&slotname=7578028045&adk=4175624763&adf=3637762483&w=768&fwrn=4&fwrnh=100&lmt=1536677151&loeid=201222031&rafmt=1&guci=2.2.0.0.2.2.0&format=768x90&url=http://crosswordheaven.com/search/result?clue=March+Madness+gp.&answer=&flash=0&fwr=0&rh=0&rw=768&resp_fmts=3&wgl=1&dt=1536677151590&bpp=9&bdt=498&fdt=10&idt=18&shv=r20180906&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=0x0,768x90&nras=1&correlator=7853644607586&frm=20&pv=1&ga_vid=1692007334.1498313405&ga_sid=1536677100&ga_hid=1314025646&ga_fc=1&iag=0&icsg=10920&dssz=13&mdo=0&mso=0&u_tz=-300&u_his=2&u_java=0&u_h=1024&u_w=768&u_ah=1024&u_aw=768&u_cd=32&u_nplug=0&u_nmime=0&adx=0&ady=627&biw=768&bih=960&scr_x=0&scr_y=0&eid=21060853,201222021&oid=2&ref=http://crosswordheaven.com/search&rx=0&eae=0&fc=1812&brdim=0,0,0,0,768,0,0,0,768,960&vis=1&rsz=||eE|&abl=CS&ppjl=f&pfx=0&fu=144&bc=1&ifi=2&xpc=UkTUR4SI0o&p=http://crosswordheaven.com&dtd=48%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-7698699613857784&output=html&h=250&slotname=4076192049&adk=2105397965&adf=4107827999&w=300&lmt=1536677760&loeid=10583696&guci=2.2.0.0.2.2.0&url=https://www.njtransit.com/sf/sf_servlet.srv?hdnPageAction=TripPlannerItineraryFrom&flash=0&wgl=1&dt=1536677760573&bpp=19&bdt=193&fdt=24&idt=28&shv=r20180906&cbv=r20180604&saldr=sa&abxe=1&prev_slotnames=8595990808&correlator=6464361773373&frm=20&pv=1&ga_vid=2025313478.1536677635&ga_sid=1536677635&ga_hid=843152773&ga_fc=1&iag=0&icsg=44023414666&dssz=22&mdo=0&mso=0&u_tz=-240&u_his=6&u_java=0&u_h=900&u_w=1600&u_ah=860&u_aw=1600&u_cd=24&u_nplug=3&u_nmime=4&adx=318&ady=518&biw=1583&bih=763&scr_x=0&scr_y=0&eid=10593696,21060853,480596784&oid=3&ref=https://www.njtransit.com/sf/sf_servlet.srv?hdnPageAction=TripPlannerItineraryFrom&rx=0&eae=0&fc=528&brdim=0,0,0,0,1600,0,1600,860,1600,763&vis=1&rsz=d||eE|&abl=CS&ppjl=t&pfx=0&fu=16&bc=7&osw_key=3100322608&ifi=2&fsb=1&xpc=FFDFAXAAcy&p=https://www.njtransit.com&dtd=45%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-7064439419818173&output=html&h=250&slotname=3973267123&adk=846291638&adf=2586783428&w=970&guci=2.2.0.0.2.2.0&format=970x250&url=https://www.msn.com/en-xl/northamerica?pc=EUPP_&ea=0&flash=29.0.0&wgl=1&dt=1536678675322&bpp=100&bdt=-M&fdt=108&idt=443&shv=r20180906&cbv=r20180604&saldr=aa&correlator=7519365320115&frm=23&ife=5&pv=2&ga_vid=1863981128.1516670961&ga_sid=1536678676&ga_hid=1473806582&ga_fc=0&icsg=43525&nhd=1&dssz=13&mdo=0&mso=32&u_tz=-240&u_his=1&u_java=1&u_h=720&u_w=1280&u_ah=680&u_aw=1280&u_cd=24&u_nplug=2&u_nmime=4&adx=147&ady=155&biw=1263&bih=526&isw=970&ish=250&ifk=3007693117&scr_x=0&scr_y=0&eid=21060853,370204034&oid=3&rx=0&eae=2&fc=528&docm=11&brdim=118,228,-7,-7,1280,,1294,694,970,250&vis=1&rsz=o||oeE|&abl=CS&ppjl=u&pfx=0&fu=20&bc=1&ifi=1&dtd=534%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress%20reviews&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1t1&gca_loc_interest_ms=&gca_loc_physical_ms=9031334&gclid=EAIaIQobChMIn4qlpKKz3QIVhYzICh1YAgb-EAAYASAAEgJ9CPD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-6736552601239305&output=html&h=280&slotname=1703302132&adk=1192465472&adf=932170190&w=336&lmt=1536684513&pucrd=CgwIABAAGAMgACgAOAESAhgHeAM&guci=2.2.0.0.2.2.0&format=336x280&url=https://healthprep.com/mental-health/different-types-of-bipolar-disorder/4/?utm_source=google&utm_medium=search&utm_campaign=1469409580&utm_content=55707192183&utm_term=what%20is%20bipolar%20mood%20disorder&flash=0&wgl=1&adsid=ADfwbugfKnFFpph6Bea6K05zNHdwBCWTdPwpy9JZWL8bAkRL0NuRDcSBIA&dt=1536684510657&bpp=35&bdt=3606&fdt=3281&idt=3287&shv=r20180906&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=336x280&correlator=1585019176067&rume=1&frm=20&pv=1&ga_vid=714267940.1536072546&ga_sid=1536684510&ga_hid=805767248&ga_fc=0&iag=0&icsg=640&dssz=213&mdo=0&mso=0&u_tz=-300&u_his=5&u_java=0&u_h=640&u_w=360&u_ah=640&u_aw=360&u_cd=24&u_nplug=0&u_nmime=0&adx=20&ady=1549&biw=360&bih=516&scr_x=0&scr_y=777&eid=4089042,21060549,21060853&oid=3&ref=https://healthprep.com/mental-health/different-types-of-bipolar-disorder/3/?utm_source=google&utm_medium=search&utm_campaign=1469409580&utm_content=55707192183&utm_term=what%20is%20bipolar%20mood%20disorder&rx=0&eae=0&fc=656&brdim=0,0,0,0,360,0,360,516,360,516&vis=1&rsz=||poeEbr|&abl=CS&ppjl=f&pfx=0&fu=16&bc=7&jar=2018-09-09-21&osw_key=2253205646&ifi=27&xpc=x7c6DyIxLy&p=https://healthprep.com&dtd=3337 / partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Reviews%20(Exact)&pt_adgroup=mattress%20reviews&pt_keyword=mattress%20reviews&gclid=Cj0KCQjwz93cBRCrARIsAEFbWsj9LV23UZUREEKL64jtfpUuGXkE6wiKwHRXxLA4fQ8byPWwtsKjDB0aAipNEALw_wcB%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress&gca_campaignid=1016369000&gca_adgroupid=51320554757&gca_matchtype=p&gca_network=s&gca_device=c&gca_adposition=1t1&gca_loc_interest_ms=&gca_loc_physical_ms=9021585&gclid=EAIaIQobChMIrM_Xu7uz3QIVFLbACh3HZQCqEAAYASAAEgJfufD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Reviews%20(Exact)&pt_adgroup=mattress%20reviews&pt_keyword=mattress%20reviews&gclid=EAIaIQobChMIhpDQ2MKz3QIVUQOGCh1DrAJJEAAYASAAEgIHgvD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.topmattressesonline.com/?utm_source=google&utm_term=mattresses&externalcreative=287668291408&p=&utm_content=1t3&utm_ad=60785435991&utm_medium=kwd-24455140&externalcampaign=1506069980&matchtype=e&gclid=EAIaIQobChMIkYuXlrmz3QIVCIvICh3KGAbfEAAYAyAAEgLzlvD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Reviews%20(Exact)&pt_adgroup=mattress%20reviews&pt_keyword=mattress%20reviews&gclid=Cj0KCQjwz93cBRCrARIsAEFbWsgB9UQDcteQkEspdHKzZBya1EavKg3_1fuoUNvKPdlkU71tgO6DtrEaAlB1EALw_wcB%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.googleadservices.com/pagead/aclk?sa=L&ai=DChcSEwjr_uSK2rPdAhWLNGkKHSEKCfoYABAAGgJpcQ&ohost=www.google.com&cid=CAASE-RoZOYit6ej4cnfL3fXgE53U40&sig=AOD64_3yn5BpzsJifCwVYc8iQBM-c-VSNw&rct=j&q=&ved=2ahUKEwjNpt-K2rPdAhVGYK0KHToGCVoQ0Qx6BAgDEAI&adurl=%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Reviews%20(Exact)&pt_adgroup=mattress%20reviews&pt_keyword=mattress%20reviews&gclid=EAIaIQobChMI1N233e2z3QIVkLXACh2ASQuvEAAYASAAEgJDPfD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMI_oGVr_Sz3QIVCtVkCh3d6wRJEAAYAiAAEgLrcfD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMI3tHjlfGr3QIV0sDACh0xLgldEAAYASAAEgJoUfD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMI9uf7q86x3QIVC4B-Ch3CBgqHEAAYAiAAEgKDDPD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Superlatives%20(Exact)&pt_adgroup=best%20mattress&pt_keyword=best%20mattress&gclid=EAIaIQobChMI9Jir3NCx3QIVx1cNCh3StAgeEAAYASAAEgJBk_D_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.googleadservices.com/pagead/aclk?sa=L&ai=DChcSEwjPpIOYnLTdAhUEL2kKHY1-BbEYABAAGgJpcQ&ohost=www.google.com&cid=CAASEuRoa5z9lKyjfCjsGzl3MMQgJw&sig=AOD64_2tyHL9v752hAD2lR0QEds6B0CStw&rct=j&q=&ved=2ahUKEwi13_uXnLTdAhVQX60KHcoeDB8Q0Qx6BAgCEAI&adurl=%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMI1YL-6p-03QIVg47ICh2w4gvoEAAYAiAAEgI7ZPD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=mattress%20in%20a%20box&gca_campaignid=1016369000&gca_adgroupid=51724296869&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1s2&gca_loc_interest_ms=&gca_loc_physical_ms=9016832&gclid=EAIaIQobChMI2c7ZnaO03QIVCJ7ACh3JagAREAEYAiAAEgKryfD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-1408961244894751&output=html&h=600&slotname=4684228588&adk=537891195&adf=2870696103&w=300&lmt=1536745633&loeid=201222032&guci=2.2.0.0.2.2.0&format=300x600&url=https://sweepstakesfanatics.com/&flash=30.0.0&wgl=1&adsid=NT&dt=1536745632933&bpp=4&bdt=324&fdt=887&idt=914&shv=r20180906&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=0x0,1140x90,350x280&nras=1&correlator=1529787625679&frm=20&pv=1&ga_vid=1137954532.1536574524&ga_sid=1536745633&ga_hid=566360358&ga_fc=0&icsg=175975726490623&dssz=43&mdo=0&mso=0&u_tz=-240&u_his=2&u_java=1&u_h=1080&u_w=1920&u_ah=1040&u_aw=1920&u_cd=24&u_nplug=2&u_nmime=3&adx=1200&ady=345&biw=1920&bih=855&scr_x=0&scr_y=0&eid=21060853,201222022&oid=3&rx=0&eae=0&fc=1808&docm=11&brdim=0,162,-8,-8,1920,,1936,1056,1920,855&vis=1&rsz=||eE|&abl=CS&ppjl=f&pfx=0&fu=16&bc=1&jar=2018-9-12-9&ifi=3&xpc=f2NfOsk0UW&p=https://sweepstakesfanatics.com&dtd=937%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-3328288004736655&output=html&h=150&slotname=2023046360&adk=1577061384&adf=3708914033&w=180&fwrn=6&fwrnh=100&lmt=1536749718&rafmt=1&guci=2.2.0.0.2.2.0&format=180x150&url=https://www.tropicaltidbits.com/analysis/models/?model=gem&region=us&pkg=z500_mslp&runtime=2018091200&fh=240&flash=0&fwr=0&rh=0&rw=180&resp_fmts=3&sfro=1&wgl=1&dt=1536749718107&bpp=31&bdt=324&fdt=37&idt=48&shv=r20180906&cbv=r20180604&saldr=aa&abxe=1&correlator=6471710986708&frm=20&pv=2&ga_vid=15180091.1535118504&ga_sid=1536749718&ga_hid=1867309353&ga_fc=0&iag=0&icsg=570&dssz=13&mdo=0&mso=0&u_tz=-240&u_his=3&u_java=0&u_h=640&u_w=360&u_ah=640&u_aw=360&u_cd=32&u_nplug=0&u_nmime=0&adx=175&ady=387&biw=360&bih=616&scr_x=0&scr_y=0&eid=21060853&oid=3&ref=https://www.tropicaltidbits.com/analysis/models/?model=ecmwf&region=us&pkg=mslp_pcpn_frzn&runtime=2018091200&fh=150&rx=0&eae=0&fc=660&brdim=0,0,0,0,360,0,360,616,360,616&vis=1&rsz=||oeE|&abl=CS&ppjl=f&pfx=0&fu=144&bc=5&osw_key=3606580881&ifi=1&xpc=iMGwBmffuu&p=https://www.tropicaltidbits.com&dtd=112%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-2204647492261709&output=html&h=280&slotname=3834989184&adk=4183127210&adf=49690011&w=375&fwrnh=101&lmt=1536751586&pucrd=CgwIABAAGAMgACgAOAESAhgHeAM&rafmt=1&guci=2.2.0.0.2.2.0&format=375x280&url=https://freebiemom.com/sweepstakes/newport-payday-everyday-pick-3-instant-win-game/&flash=0&fwr=1&rh=0&rw=340&resp_fmts=3&sfro=1&wgl=1&adsid=ADfwbugrIWc5MBeUvHLHHbCsatWFYT76MA4DJdb8k2WBtYjOdrv5Nm_abA&dt=1536751586012&bpp=15&bdt=548&fdt=15&idt=17&shv=r20180906&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=0x0&nras=1&correlator=992459728683&frm=20&pv=1&ga_vid=315931397.1535454380&ga_sid=1536751586&ga_hid=912335719&ga_fc=0&iag=0&icsg=687254405120&dssz=33&mdo=0&mso=0&u_tz=-240&u_his=1&u_java=0&u_h=667&u_w=375&u_ah=667&u_aw=375&u_cd=32&u_nplug=0&u_nmime=0&adx=0&ady=299&biw=375&bih=559&scr_x=0&scr_y=0&eid=21060853&oid=3&ref=http://m.facebook.com&rx=0&eae=0&fc=1940&brdim=0,0,0,0,375,0,0,0,375,559&vis=1&rsz=o||eE|&abl=CS&ppjl=f&pfx=0&fu=144&bc=1&jar=2018-09-12-02&ifi=1&xpc=mH2F7ejeZ8&p=https://freebiemom.com&dtd=27%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-6693783526341236&output=html&h=280&slotname=6363572308&adk=2956080580&adf=3738656147&w=336&lmt=1536747255&guci=2.2.0.0.2.2.0&format=336x280&url=http://7boom.net/luxury/herbert_samuel/&flash=0&wgl=1&dt=1536747255650&bpp=9&bdt=446&fdt=10&idt=12&shv=r20180906&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=282x600&correlator=660170006138&frm=20&pv=1&ga_vid=2138712578.1514892095&ga_sid=1536747255&ga_hid=1553107803&ga_fc=0&iag=0&icsg=2688548010&dssz=22&mdo=0&mso=0&u_tz=180&u_his=4&u_java=0&u_h=1050&u_w=1680&u_ah=1050&u_aw=1680&u_cd=24&u_nplug=3&u_nmime=4&adx=481&ady=4468&biw=1663&bih=984&scr_x=0&scr_y=0&eid=21060853,26835105&oid=3&ref=http://7boom.net/luxury/&rx=0&eae=0&fc=528&brdim=1920,30,1920,30,1680,30,1680,1050,1680,984&vis=1&rsz=||leEbr|&abl=CS&ppjl=f&pfx=0&fu=16&bc=7&ifi=2&fsb=1&xpc=fQBfJ7lOyx&p=http://7boom.net&dtd=17%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-5536307433379466&output=html&h=600&twa=1&slotname=6066977941&adk=1395979640&adf=2802373691&w=246&fwrn=4&fwrnh=100&lmt=1536757988&guci=2.2.0.0.2.2.0&format=246x600&url=http://www.blabbermouth.net/&flash=0&fwr=0&rh=600&rw=246&wgl=1&adsid=ADfwbujD2RnabQStYEUMPPs9W1G5hS4242-fp-1v0os7b_oyEjlmSzujaaKFvBHhiHLa&dt=1536757988806&bpp=10&bdt=1617&fdt=11&idt=16&shv=r20180906&cbv=r20180604&saldr=sa&abxe=1&prev_fmts=752x90&correlator=7228107915747&frm=20&pv=1&ga_vid=21595199.1520207539&ga_sid=1536757845&ga_hid=104924474&ga_fc=1&iag=0&icsg=14098519760&dssz=51&mdo=0&mso=2&u_tz=-360&u_his=4&u_java=0&u_h=1024&u_w=768&u_ah=1024&u_aw=768&u_cd=32&u_nplug=0&u_nmime=0&adx=521&ady=791&biw=768&bih=928&scr_x=0&scr_y=0&eid=4089042,21060853,828064255&oid=3&ref=https://www.google.com/&rx=0&eae=0&fc=528&brdim=0,0,0,0,768,0,0,0,768,928&vis=1&rsz=||eE|&abl=CS&ppjl=f&pfx=0&fu=16&bc=1&jar=2018-09-12-13&ifi=2&xpc=PmZpRBSjBV&p=http://www.blabbermouth.net&dtd=32%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-5833136623198638&output=html&h=300&slotname=1202694908&adk=3481193701&adf=2541534019&w=360&lmt=1536757204&pucrd=CgwIABAAGAIgACgAOAESAhgHeAM&rafmt=1&guci=2.2.0.0.2.2.0&format=360x300&url=https://freebiemom.com/deal/free-homfy-bedding-curtains/&flash=0&fwr=1&rh=0&rw=325&resp_fmts=3&sfro=1&wgl=1&adsid=NT&dt=1536757204687&bpp=33&bdt=3611&fdt=36&idt=47&shv=r20180906&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=0x0,360x280,360x300&nras=1&correlator=8077665951167&frm=20&pv=1&ga_vid=72273675.1532912773&ga_sid=1536757203&ga_hid=1707178701&ga_fc=0&iag=0&icsg=584130412544&dssz=31&mdo=0&mso=0&u_tz=-240&u_his=1&u_java=0&u_h=640&u_w=360&u_ah=640&u_aw=360&u_cd=24&u_nplug=0&u_nmime=0&adx=0&ady=1839&biw=360&bih=560&scr_x=0&scr_y=0&eid=21060853&oid=3&ref=android-app://m.facebook.com&rx=0&eae=0&fc=1940&brdim=0,0,0,0,360,0,360,560,360,560&vis=1&rsz=o||eEbr|&abl=CS&ppjl=u&pfx=0&fu=144&bc=7&jar=2018-09-12-00&osw_key=1813812913&ifi=3&xpc=8AVyQbLNGu&p=https://freebiemom.com&dtd=89%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=CjwKCAjw8uLcBRACEiwAaL6MSTEIdWJ0C92Ca4BLarJUd6TIuIvR9DNWEr6f5yHGJmSAcmiTn-6mWhoCvwMQAvD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMI46CHpNe13QIVi_5kCh1J4w8nEAAYAiAAEgKKR_D_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-4669759041027576&output=html&h=100&adk=1012969818&adf=4134371643&w=320&fwrnh=101&lmt=1536779508&loeid=40993910&pucrd=CgwIABAAGAMgACgAOAESAhgHeAM&rafmt=1&guci=2.2.0.0.2.2.0&ad_type=text_image&format=320x100&color_bg=FFFFFF&color_border=FFFFFF&color_link=0088CC&color_text=555555&color_url=AAAAAA&url=https://sbenny.com/&flash=0&fwr=1&rh=0&rw=320&resp_fmts=3&sfro=1&wgl=1&adsid=ADfwbug9PstxdDj_NM7Vb2ZrcG-3O46dv9o65S5wQs36swxTXADtFErYQw&dt=1536765100031&bpp=2757&bdt=11497&fdt=2839&idt=7767&shv=r20180815&cbv=r20180604&saldr=aa&abxe=1&correlator=7340221878273&frm=20&pv=2&ga_vid=1085545680.1522433873&ga_sid=1536765108&ga_hid=2024054306&ga_fc=0&iag=0&icsg=142&dssz=4&mdo=0&mso=0&u_tz=-240&u_his=24&u_java=1&u_h=570&u_w=320&u_ah=570&u_aw=320&u_cd=32&u_nplug=0&u_nmime=0&adx=0&ady=121&biw=320&bih=496&scr_x=0&scr_y=0&eid=20195143,21060853,40993900,368226401&oid=3&rx=0&eae=0&fc=660&brdim=0,0,0,0,320,0,320,496,320,496&vis=1&rsz=||eE|&abl=CS&ppjl=f&pfx=0&fu=1168&bc=1&jar=2018-09-10-06&ifi=1&xpc=FQDCNce1KP&p=https://sbenny.com&dtd=8742%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress&gca_campaignid=1016369000&gca_adgroupid=51320554757&gca_matchtype=p&gca_network=s&gca_device=c&gca_adposition=1t2&gca_loc_interest_ms=&gca_loc_physical_ms=9003743&gclid=EAIaIQobChMI-ZKC3-K13QIVk4jICh1KXAiLEAAYAiAAEgJwyfD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-3430841406405112&output=html&h=90&slotname=9322984868&adk=1745076811&adf=3530038681&w=728&lmt=1536771201&pucrd=CgYgASgBOAF4Aw&guci=2.2.0.0.2.2.0&url=https://abcnews.go.com/assets/static/ads/adHelper.html?adloc=https://2912a.v.fwmrm.net/ad/g/1?nw=168234&sfid=109523&csid=nws_homepage&caid=display&pvrn=440579012-951663013&resp=ad;pageType=homepage&abcn_id=banner-0;ptgt=s&envp=g_js&slid=leaderboard&w=728&h=90&slau=Leaderboard%20728x90&ea=0&flash=0&alternate_ad_url=http://2912a.v.fwmrm.net/ad/g/1?nw=168234&sfid=109523&csid=abcnews_marketing&caid=&pvrn=1355050309&resp=ad;;ptgt=s&envp=g_iframe_js&slid=leaderboard&w=728&h=90&slau=Leaderboard%20728x90&wgl=1&adsid=NT&dt=1536771199434&bpp=70&bdt=926&fdt=76&idt=1794&shv=r20180906&cbv=r20180604&saldr=sa&correlator=1193704407872&frm=23&ife=1&pv=2&ga_vid=1110334513.1536771201&ga_sid=1536771201&ga_hid=2128579712&ga_fc=0&iag=15&icsg=42&nhd=2&dssz=5&mdo=0&mso=0&u_tz=-360&u_his=4&u_java=0&u_h=1080&u_w=1920&u_ah=1040&u_aw=1920&u_cd=24&u_nplug=3&u_nmime=4&adx=588&ady=1289&biw=1903&bih=974&isw=728&ish=90&ifk=3904719467&scr_x=0&scr_y=82&eid=4089040,21060853,21061795&oid=3&loc=EMPTY&top=https://abcnews.go.com/&rx=0&eae=2&fc=528&brdim=0,0,0,0,1920,0,1920,1040,728,90&vis=1&rsz=|o|eoEbr|&abl=NS&ppjl=f&pfx=0&fu=20&bc=7&jar=2018-9-12-16&osw_key=1258972642&ifi=1&fsb=1&dtd=1866 / partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMIiJf8_IC23QIV2LbACh1rZQH3EAAYASAAEgLmpvD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress%20reviews&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1t1&gca_loc_interest_ms=&gca_loc_physical_ms=9007461&gclid=EAIaIQobChMIkdOPr5623QIVSVqGCh2U6wdEEAAYASAAEgKuTvD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMIrI7owai23QIVkV5-Ch16lQgsEAAYASAAEgKvdPD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=CjwKCAjw8uLcBRACEiwAaL6MSUHmZaY031RNR_xekv1_5ZyJ032Ki5Q3MVkPGsILS8kxyyzYLrbUWhoCg8cQAvD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMI0O2Kib-23QIVkoqzCh2rqwKzEAAYASAAEgKAoPD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress%20reviews&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1t1&gca_loc_interest_ms=&gca_loc_physical_ms=1025202&gclid=EAIaIQobChMI4MO67ci23QIVG7jACh1ivQqaEAAYASAAEgK2gPD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20rated%20mattress&gca_campaignid=1016369000&gca_adgroupid=49799121022&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1t1&gca_loc_interest_ms=&gca_loc_physical_ms=1012954&gclid=EAIaIQobChMI5sTo2c223QIVAUOGCh1S0wc_EAAYASAAEgLMG_D_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=CjwKCAjw8uLcBRACEiwAaL6MSdZ8UN3E6cdayakNF1AQHoINVg1mO06AWawO-0BcYoCX98uM9RSOChoC7XQQAvD_BwE%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?ad_block=2&client=ca-pub-6219811747049371&output=html&h=250&adk=749603272&loeid=23745798,9471239,23754122,23763475,23764471,23755832,23756714&pucrd=CggIABAAGAM4AXgC&guci=2.2.0.0.2.2.0&channel=0854550288+Vertical_16+Vertical_184+Vertical_3+Vertical_507+afv_user_id_TnFdC5jhEClcYhTn9wo-VQ+afv_user_thehollywoodfix+yt_cid_22452789+yt_gp+yt_mpvid_PKl9uK35nCgpag84+yt_no_ap+yt_no_wa+ytdevice_1+ytdevicever_2.20180912+ytel_detailpage+ytps_default&ad_type=image&format=300x250_as&url=http://www.youtube.com/video/1pDqWYOtaqU&ea=0&flash=0&host=ca-yt-host-pub-3953862990132394&targeting=content&alternate_ad_url=https://www.youtube.com/ad_frame?action=auto-collapse-kevlar-companion&cust_age=1002&cust_gender=1&hl=en&video_doc_id=yt_1pDqWYOtaqU&wgl=1&dbp=ChZHaGZjQnlael9PRzJ6QWJjUlBzbWpBEAEgASgA&lact=3811&scs=false&yt_pt=APb3F29XDbzTys_YA8d8SXUCNjg41LQKosmyZh3rYaLp5MXQMrGKAGcklSBXSKIDgEsh3R9OCIGjNbD0t1lqvO4Ol3yWcHwc2k_cSoycp7MSSQF5pAuVu0FsRz6Hn0fKY-RQT6bipJVURGXBjU-Wku7tOjeQi9K60grj5YSq2y3RV3nuB7ewEfoX-4BwD-bMX7kBfNfhUTreLsZaJyhQ&dt=1536830556667&bdt=119021&idt=0&shv=r20180910&cbv=r20110914&saldr=ca&abxe=1&correlator=7203208743890&frm=20&pv=2&ga_vid=1152404262.1536830557&ga_sid=1536830557&ga_hid=2101860408&ga_fc=0&iag=0&icsg=618206870184&dssz=41&mdo=0&mso=0&u_tz=180&u_his=3&u_java=0&u_h=800&u_w=1280&u_ah=722&u_aw=1280&u_cd=24&u_nplug=3&u_nmime=4&adx=828&ady=560&biw=1265&bih=648&scr_x=0&scr_y=0&eid=40509081&oid=3&loc=https://www.youtube.com/watch?v=1pDqWYOtaqU&rx=0&eae=2&brdim=0,22,0,22,1280,22,1280,722,1280,648&vis=1&rsz=||ape|&abl=CA&ppjl=u&pfx=0&alvm=none&fu=4176&bc=7&ifi=1&fsb=1&dtd=28%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-8244771960023779&output=html&h=60&slotname=1675301113&adk=1251612880&adf=2369281301&w=656&fwrn=4&fwrnh=100&lmt=1536842477&pucrd=CgwIABAAGAMgACgAOAESAhgHeAM&rafmt=5&guci=2.2.0.0.2.2.0&format=656x60&url=https://www.upcitemdb.com/upc/71121956149&flash=0&fwr=0&rh=0&rw=656.46875&resp_fmts=3&wgl=1&adsid=ADfwbuje0eyrbxGTGD0GkVQsu9jMTKfV-StQ4eUh7rGkTjK0HEhgMCy3zOINWk3ZDWb1Es90_5PFjg&dt=1536842476797&bpp=11&bdt=968&fdt=248&idt=250&shv=r20180910&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=0x0&nras=1&correlator=1497800937012&frm=20&pv=1&ga_vid=268971046.1517806674&ga_sid=1536842477&ga_hid=1629415957&ga_fc=0&iag=0&icsg=42994499390&dssz=27&mdo=0&mso=0&u_tz=-240&u_his=2&u_java=0&u_h=1024&u_w=768&u_ah=768&u_aw=1024&u_cd=32&u_nplug=0&u_nmime=0&adx=19&ady=227&biw=694&bih=653&scr_x=0&scr_y=0&eid=21060853,21062174&oid=3&ref=https://www.google.com/&rx=0&eae=0&fc=1812&brdim=0,0,0,0,1024,0,0,0,694,653&vis=1&rsz=||eE|&abl=CS&ppjl=f&pfx=0&fu=144&bc=5&jar=2018-09-13-12&osw_key=3049559534&ifi=1&xpc=KvxrfAV1mX&p=https://www.upcitemdb.com&dtd=262%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-2003873426348785&output=html&h=280&slotname=7019590105&adk=1189223330&adf=3121220848&w=366&fwr_io=true&fwrn=4&fwrnh=100&lmt=1536846182&loeid=10583696&ifsl=4&pucrd=CgYgASgBOAF4Aw&rafmt=1&guci=2.2.0.0.2.2.0&format=366x280&url=https://freeprizesonline.com/2018/08/22/novamex-uncap-the-jackpot-instant-win-game/&region=responsive_resize&flash=0&fwr=0&fwrattr=true&pra=3&rh=0&rw=366&resp_fmts=3&sfro=1&wgl=1&fa=16&adsid=NT&dt=1536846182124&bpp=8&bdt=67062&fdt=10&idt=15&shv=r20180910&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=366x280&nras=4&correlator=6185166143807&frm=20&pv=1&ga_vid=1446058377.1536846117&ga_sid=1536846117&ga_hid=535926091&ga_fc=0&iag=0&icsg=46170876607&dssz=32&mdo=0&mso=0&u_tz=-420&u_his=1&u_java=0&u_h=736&u_w=414&u_ah=736&u_aw=414&u_cd=32&u_nplug=0&u_nmime=0&adx=38&ady=815&biw=736&bih=370&scr_x=0&scr_y=676&eid=10593696,21060853&oid=3&ref=http://m.facebook.com&loc=https://freeprizesonline.com/2018/08/22/novamex-uncap-the-jackpot-instant-win-game/&rx=0&eae=0&fc=1808&brdim=0,0,0,0,414,0,0,0,414,370&vis=1&rsz=||s|&abl=NS&ppjl=f&fu=144&bc=7&jar=2018-08-25-05&ifi=7&xpc=aWs33EZCFf&p=https://freeprizesonline.com&dtd=32%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-5247847789508527&output=html&h=600&slotname=5100343098&adk=1430831679&adf=509555274&w=160&fwrn=4&fwrnh=100&lmt=1521561237&pucrd=CgwIABAAGAMgACgAOAF4Aw&rafmt=1&guci=2.2.0.0.2.2.0&format=160x600&url=https://www.solitr.com/&flash=0&fwr=0&rh=0&rw=160&resp_fmts=4&wgl=1&adsid=ADfwbuhydbJwAafnT8fxHOhFW-U8EhpXYsHUxk99bnVxLGSjmxwnWXQ23Q&dt=1536856402241&bpp=71&bdt=729&fdt=86&idt=811&shv=r20180910&cbv=r20180604&saldr=aa&abxe=1&correlator=3598272053058&frm=20&pv=2&ga_vid=1598073814.1536036993&ga_sid=1536856403&ga_hid=1513298366&ga_fc=0&iag=0&icsg=8250&dssz=14&mdo=0&mso=0&u_tz=-480&u_his=2&u_java=0&u_h=601&u_w=962&u_ah=601&u_aw=962&u_cd=24&u_nplug=0&u_nmime=0&adx=836&ady=90&biw=1024&bih=546&scr_x=0&scr_y=0&eid=21060853&oid=3&ref=android-app://com.google.android.googlequicksearchbox&rx=0&eae=0&fc=532&brdim=0,0,0,0,962,0,962,513,1024,547&vis=1&rsz=||aE|&abl=CA&ppjl=f&pfx=0&fu=144&bc=7&jar=2018-09-12-20&osw_key=3563418579&ifi=1&xpc=4ICoF8Qx7f&p=https://www.solitr.com&dtd=968%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-7426812248534774&output=html&h=100&slotname=5052093241&adk=2566884786&adf=3832496942&w=320&lmt=1536845007&pucrd=CgwIABAAGAMgACgAOAF4Aw&guci=2.2.0.0.2.2.0&format=320x100&url=https://www.freebieshark.com/2018/08/miller-lite-nfl-instant-win-game-select-states.html&flash=0&wgl=1&adsid=ADfwbuhLQSul5Aft_yNajcoy7w7MTKlhBqJAhYHrm_okXFgFp8H1DTBbIw&dt=1536845005626&bpp=117&bdt=1557&fdt=137&idt=1868&shv=r20180910&cbv=r20180604&saldr=aa&abxe=1&correlator=6989255904092&frm=20&pv=2&ga_vid=1091662156.1497387412&ga_sid=1536843278&ga_hid=870090902&ga_fc=1&iag=0&icsg=4436163272114175&dssz=45&mdo=0&mso=0&u_tz=-300&u_his=16&u_java=0&u_h=640&u_w=360&u_ah=640&u_aw=360&u_cd=32&u_nplug=0&u_nmime=0&adx=15&ady=171&biw=360&bih=560&scr_x=0&scr_y=0&eid=10573697,21060853,368226501,21062175&oid=3&rx=0&eae=0&fc=656&brdim=0,0,0,0,360,0,360,560,360,560&vis=1&rsz=||eE|&abl=CS&ppjl=f&pfx=0&fu=1040&bc=5&jar=2018-09-13-13&osw_key=744396273&ifi=1&xpc=ezN4LrevSl&p=https://www.freebieshark.com&dtd=2178%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-1120050670892722&output=html&h=90&slotname=0564009145&adk=575331095&adf=187793001&w=728&lmt=1536847260&guci=2.2.0.0.2.2.0&format=728x90&url=http://www.wikiorgcharts.com/search&flash=0&wgl=1&adsid=NT&dt=1536847259233&bpp=16&bdt=127&fdt=21&idt=1003&shv=r20180910&cbv=r20180604&saldr=aa&abxe=1&correlator=7201479265506&frm=20&pv=2&ga_vid=1273428870.1536294873&ga_sid=1536846905&ga_hid=1261991558&ga_fc=1&iag=0&icsg=577530&dssz=17&mdo=0&mso=0&u_tz=-240&u_his=8&u_java=0&u_h=800&u_w=1280&u_ah=709&u_aw=1280&u_cd=24&u_nplug=3&u_nmime=4&adx=351&ady=42&biw=1200&bih=612&scr_x=0&scr_y=0&eid=21060853&oid=3&ref=http://www.wikiorgcharts.com/&rx=0&eae=0&fc=528&brdim=22,23,22,23,1280,23,1200,709,1200,612&vis=1&rsz=||leE|&abl=CS&ppjl=u&pfx=0&fu=16&bc=7&jar=2018-09-13-13&ifi=1&fsb=1&xpc=fez7upsraY&p=http://www.wikiorgcharts.com&dtd=1026%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-2003873426348785&output=html&h=345&slotname=5295444892&adk=3475420938&adf=1277830825&w=414&fwr_io=true&lmt=1536849481&loeid=40993911&pucrd=CgwIABAAGAMgACgAOAESAhgHeAM&rafmt=1&guci=2.2.0.0.2.2.0&format=414x345&url=https://freeprizesonline.com/2018/09/13/double-camping-hammock-17/&flash=0&fwr=1&fwrattr=true&rh=0&rw=366&resp_fmts=3&sfro=1&wgl=1&adsid=ADfwbuiYLkZ1CitfVxobTJjcAVnlVMG3ZnSfG4do1yiFXIHvgNnm-A97ww&dt=1536849480957&bpp=3&bdt=132&fdt=135&idt=137&shv=r20180910&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=0x0,414x345,414x345&nras=1&correlator=4018467744424&frm=20&pv=1&ga_vid=476218472.1536849481&ga_sid=1536849481&ga_hid=1196997393&ga_fc=0&iag=0&icsg=11811138239&dssz=31&mdo=0&mso=0&u_tz=-300&u_his=1&u_java=0&u_h=736&u_w=414&u_ah=736&u_aw=414&u_cd=32&u_nplug=0&u_nmime=0&adx=0&ady=1330&biw=414&bih=628&scr_x=0&scr_y=0&eid=21060853,40993901,188690903&oid=3&ref=http://m.facebook.com&rx=0&eae=0&fc=1940&brdim=0,0,0,0,414,0,0,0,414,628&vis=1&rsz=||eEbr|&abl=CS&ppjl=f&pfx=0&fu=144&bc=7&ifi=3&xpc=4xNh5giImc&p=https://freeprizesonline.com&dtd=144%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www-washingtonpost-com.cdn.ampproject.org/v/s/www.washingtonpost.com/amphtml/lifestyle/style/ask-amy-social-media-makes-family-members-less-social/2018/09/13/f78a78cc-aca1-11e8-b1da-ff7faa680710_story.html?amp_js_v=a2&amp_gsa=1&usqp=mq331AQCCAE=%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.googleadservices.com/pagead/aclk?sa=L&ai=DChcSEwiv1d_gmrjdAhWXi7MKHSK1BhQYABAFGgJxbg&ohost=www.google.com&cid=CAASEuRoVjwMGGoEvHhZyNwCc3tv0w&sig=AOD64_0EQX5lxpPMxpgpLOSRjAPSL9yx-g&rct=j&q=&ved=2ahUKEwjvo9vgmrjdAhVEMd8KHaSOD-gQ0Qx6BAgAEAo&adurl=%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://googleads.g.doubleclick.net/pagead/ads?client=ca-pub-2003873426348785&output=html&h=266&slotname=1631101824&adk=1842180871&adf=923172044&w=320&fwr_io=true&lmt=1536851888&pucrd=CgwIABAAGAMgACgAOAF4Aw&rafmt=1&guci=2.2.0.0.2.2.0&format=320x266&url=https://lastminutegiveaways.com/2018/09/11/enter-to-win-an-amazon-gift-card/&flash=0&fwr=1&fwrattr=true&rh=0&rw=272&resp_fmts=3&sfro=1&wgl=1&adsid=ADfwbujgCS3lHX4eRpFXaLSAkh54FK3ky-JgsbBZde7L_hYTeWJlAAGabg&dt=1536851886836&bpp=51&bdt=2638&fdt=1799&idt=1883&shv=r20180910&cbv=r20180604&saldr=aa&abxe=1&prev_fmts=0x0,320x266&nras=1&correlator=3526962588711&frm=20&pv=1&ga_vid=687899997.1536851888&ga_sid=1536851888&ga_hid=204373143&ga_fc=0&iag=0&icsg=11811138239&dssz=32&mdo=0&mso=0&u_tz=-240&u_his=1&u_java=0&u_h=570&u_w=320&u_ah=570&u_aw=320&u_cd=24&u_nplug=0&u_nmime=0&adx=0&ady=837&biw=320&bih=498&scr_x=0&scr_y=164&eid=10573695,21060853&oid=3&ref=http://m.facebook.com/&rx=0&eae=0&fc=1940&brdim=0,0,0,0,320,0,320,498,320,498&vis=1&rsz=||eEbr|&abl=CS&ppjl=f&pfx=0&fu=144&bc=7&osw_key=1225945751&ifi=2&xpc=Y6si8xnFvp&p=https://lastminutegiveaways.com&dtd=2017%20/%20partner' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# ...
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress%20reviews&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=g&gca_device=c&gca_adposition=1t1&gca_loc_interest_ms=&gca_loc_physical_ms=9052456&gclid=EAIaIQobChMI062nzqyO3gIVBZ7ACh3c_AP2EAAYASAAEgJF0vD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?gclsrc=aw.ds&&pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Reviews%20(Exact)&pt_adgroup=mattress%20ratings%202018&pt_keyword=mattress%20ratings%202018&gclid=EAIaIQobChMIiYnzj7aO3gIVTF8NCh0uMA6ZEAAYASAAEgJ_e_D_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1s1&gca_loc_interest_ms=&gca_loc_physical_ms=9012430&gclid=EAIaIQobChMIx-C6zs-O3gIVz4CfCh1DqwLjEAEYASAAEgIvKfD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=online%20mattress%20company%20reviews&gca_campaignid=1016369000&gca_adgroupid=49897173085&gca_matchtype=e&gca_network=g&gca_device=c&gca_adposition=1t3&gca_loc_interest_ms=&gca_loc_physical_ms=9007578&gclid=CjwKCAjwu5veBRBBEiwAFTqDwdfDIlASo7CdOmaVHj2T8jFWzrqLZqkO6kcJZ-4i9JTfCheaPiotexoCJxMQAvD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress%20reviews&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=g&gca_device=c&gca_adposition=1t1&gca_loc_interest_ms=&gca_loc_physical_ms=9005291&gclid=CjwKCAjwu5veBRBBEiwAFTqDwbIig7OwOsulRN28YOYygxTcn0SY01afsqsHqTWHL3TDoFIXA5OWtxoCZUsQAvD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?gclsrc=aw.ds&&pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Superlatives%20(Exact)&pt_adgroup=best%20mattress%202017&pt_keyword=best%20mattress%202018&gclid=CjwKCAjwu5veBRBBEiwAFTqDwUKjQ4oDqT-F0JIfDkDgoP--xYTWojpfgOO9b8CFNrs061cg6SZa5xoC4KwQAvD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=mattress%20reviews&gca_campaignid=1016369000&gca_adgroupid=50955604065&gca_matchtype=p&gca_network=s&gca_device=c&gca_adposition=1s3&gca_loc_interest_ms=&gca_loc_physical_ms=9031108&gclid=EAIaIQobChMIuqSxiYqP3gIVDZ9-Ch3hjA41EAEYAyAAEgLHgfD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?gclsrc=aw.ds&&pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Superlatives%20(Exact)&pt_adgroup=best%20latex%20mattress&pt_keyword=best%20latex%20mattress&gclid=EAIaIQobChMIkIez_ZCP3gIVirbACh05pwFsEAAYASAAEgIXnPD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=review%20mattresses&gca_campaignid=1016369000&gca_adgroupid=50955604065&gca_matchtype=p&gca_network=g&gca_device=c&gca_adposition=1t2&gca_loc_interest_ms=&gca_loc_physical_ms=9029011&gclid=CjwKCAjwu5veBRBBEiwAFTqDwYzgFqEZWlcbpl-POYgSHLlwW85r_wrepDE8HR47oxbz3FbZCkBLYhoCTwYQAvD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20online%20mattress&gca_campaignid=1016369000&gca_adgroupid=49897173085&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1s3&gca_loc_interest_ms=&gca_loc_physical_ms=9007840&gclid=EAIaIQobChMI6a3li92P3gIVSF8NCh0-TgbhEAEYAyAAEgI___D_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.topmattressesonline.com/?utm_source=google&utm_term=mattresses&externalcreative=291062368009&p=&utm_content=1o1&utm_ad=60785435991&utm_medium=kwd-24455140&externalcampaign=1506069980&matchtype=e&gclid=CjwKCAjw3qDeBRBkEiwAsqeO7q23KmikcDPt6uIu-3GcNS4c175sLX_cXE_ouXry9HnmQ4MVfwMc4hoC2igQAvD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?gclsrc=aw.ds&&pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMIsr_Q2ZKQ3gIV2EsNCh3CUg4aEAAYASAAEgIGPPD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress%20reviews&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1t1&gca_loc_interest_ms=&gca_loc_physical_ms=9021625&gclid=EAIaIQobChMIx_aE1JSQ3gIVl0oNCh0-YwxAEAAYASAAEgLGVvD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?gclsrc=aw.ds&&pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Superlatives%20(Exact)&pt_adgroup=best%20mattress%202017&pt_keyword=best%20mattress%202018&gclid=EAIaIQobChMIiLbsl56Q3gIVDlgNCh2wsggZEAAYASAAEgK_LvD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'http://r.srvtrck.com/v2/go?ai=765d1b25cc094dd4a4e88a5630fb989f&t=6tdpc:1/er4c3i1gbi5ubefw1r5.aob/3f7_1?0f4e3_vdb6s9f&af6_6d=2i9f&af1_5u==i0r0f0o0c0f7aemccce3i2s8b4ce.an6kaa8td/7s1t6h&u=https://prf.hn/click/camref:1100l3QvX&w=4&s=http://thisisyourshop.com/&e=1&ykuid=2f22eb9f80714e8c884ea87fc3e0b99e&sc=1' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1s2&gca_loc_interest_ms=&gca_loc_physical_ms=9019675&gclid=EAIaIQobChMIq_XD3raQ3gIVDIhpCh217gZaEAEYAiAAEgKFR_D_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.consumersadvocate.org/mattress/a/best-mattress?&pd=true&keyword=best%20mattress%20reviews&gca_campaignid=1016369000&gca_adgroupid=51627636938&gca_matchtype=e&gca_network=s&gca_device=c&gca_adposition=1t3&gca_loc_interest_ms=&gca_loc_physical_ms=9014986&gclid=EAIaIQobChMIk6WFjdKQ3gIVksDICh0raQQHEAAYAyAAEgKjP_D_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?gclsrc=aw.ds&&pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=CjwKCAjw3qDeBRBkEiwAsqeO7hySTF9rt1DHhPjtzJGoiLZPxW2vejS7-3vcKWPJ0wsqrB0XV0adjRoCX8oQAvD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.googleadservices.com/pagead/aclk?sa=L&ai=DChcSEwjXlqeojZHeAhXHn7MKHVU1AzUYABAGGgJxbg&ohost=www.google.com&cid=CAASE-RoPpnhDxIQGqR4zfPXZ4JUTqM&sig=AOD64_0N1IWJNgzUmfS26so160-9y6zSqg&rct=j&q=&ved=2ahUKEwjBt6GojZHeAhVCheAKHbf5C_MQ0Qx6BAgEEAw&adurl=' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.topmattressesonline.com/?strategy=fixed_saatva&utm_source=google&utm_term=saatva%20vs%20purple&externalcreative=289004298401&p=&utm_content=1t2&utm_ad=57116043966&utm_medium=kwd-413038913209&externalcampaign=1506069980&matchtype=p&gclid=EAIaIQobChMI2YGSt5OR3gIVVrbACh1CFwSlEAAYAiAAEgIJE_D_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.topmattressesonline.com/?utm_source=google&utm_term=mattresses&externalcreative=291062368009&p=&utm_content=1t2&utm_ad=60785435991&utm_medium=kwd-24455140&externalcampaign=1506069980&matchtype=e&gclid=CjwKCAjw3qDeBRBkEiwAsqeO7kLdOz-Df2Tb9Iw_1trCWmEZ2G0Rk5t-GUHjNGVfF8KNjDeWuxzTeBoC60sQAvD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?gclsrc=aw.ds&&pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20-%20Superlatives%20(Exact)&pt_adgroup=best%20mattress%202017&pt_keyword=2018%20best%20mattress&gclid=EAIaIQobChMImsTclquR3gIVnIizCh1dRgk0EAAYASAAEgJoo_D_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.thesleepjudge.com/editors-choice/?gclsrc=aw.ds&&pt_source=googleleads&pt_medium=cpc&pt_campaign=%5bADL%5d%20%5bNon-Brand%5d%20%5bUS%5d%20Mattresses%20(Exact)&pt_adgroup=best%20mattresses%202018&pt_keyword=best%20mattresses%202018&gclid=EAIaIQobChMIwZu_yqmR3gIVlY-zCh3roguEEAMYASAAEgI36PD_BwE' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'https://www.googleadservices.com/pagead/aclk?sa=L&ai=DChcSEwjy_KKSzJHeAhUO1sAKHStMBE4YABAAGgJpbQ&num=1&ohost=www.google.com&cid=CAASEuRo2CqBOuvjgQbM4bxoYiYo0A&sig=AOD64_1JilMctoY9aMU1pJzUO87-UkaEog&adurl=&rct=j&q=&nb=0&res_url=https://www.yelp.com/search?cflt=mattresses&find_loc=Manhattan%2C+KS&rurl=https://www.google.com/&nm=2&nx=98&ny=35&is=298x488&clkt=3&bg=!n5ylnIREX7CDdF_-7tgCAAAAPFIAAAAJCgAEoZmQlZkBJYFvMoeIbdX3I_OHrReV-0TjjnhtUg_tl1pzU1qZ7MAqkm-TitTmawz37CGpjk_Pwj8umi6IQqEX1k1p0cyBdu5X7jHTxJhRAlYQkTh2yoPBluKBCbZ_7O_HacEOV8f5eALC6_lfXtn_AU5vaqHlbpj4pqinEMOLoMk4NXIeav3Ha-K1smbH1ihRuoQy2R9irRq9qta5kV14tLnStqud6vo6J7Tp92Iica_1IlZ2AAbZW9VmJ2yG_tS_Tl33KfkL3oNgzdP_yC4fs5VTnsfT0IXT6lLXMDvOt2VM5r_IzRP5lbATmlLAAuzgH1DIx_sOWreA2GkqNrRr9ZC8uRGpFAbC5vEd6AdiFHR-KCXu2qflcJJ5yNLS7bOqplDEQq2yDTTe-xuy' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'http://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=8&ved=0CCEQfjcnVkSDdXdGRvV1k4R0Vv&url=http://click.communications.onekingslane.com/?qs=1ef0eff5a76d9ac3885268803a71adff349ae0896a140c25e845377bee47798bf34bcda8cba839f6ce05d18f90c9f8889c094ee0cea792b5261da9c596042b70&ei=TWpQWlQydjZuRFcx&usg=AFQjaEhJOE5yN0VpRVly' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /usr/local/lib/python3.6/site-packages/xlsxwriter/worksheet.py:831: UserWarning: Ignoring URL 'http://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=10&ved=0CCEQfjVzkxNHQybUVpQU54Z25xaVNs&url=http://click.communications.onekingslane.com/?qs=88c6817ecc0ab0402e71eabf3c188ece015fd0397b6ce7971f275b94328572a30e283b607f4f02af01b1c1838a0f9859d85aeb7dd049a1de49185862e2a6635a&ei=Y3hpOGR0aE83TUhj&usg=AFQjRk1DbFM0S3N1R2Fq' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))

# %%
GA_taxonomy.to_csv(writer_folder+'/Saatva_S_and_SM_GA_by_Media_Taxonomy_'+Start_Date_1+'_to_'+End_Date_2+week+'.csv')

# %%
media_col=ga_agg_wide_session.columns.tolist()[1:(len(ga_agg_wide_session.columns)-1)]

# %%
def write_csv_output(df,Matrics):
    ga_output_csv=df.copy()
    ga_output_csv['Date']=ga_output_csv['ga:dateHour'].apply(lambda x:int(x[0:8]))
    ga_output_csv['Hour']=ga_output_csv['ga:dateHour'].apply(lambda x:int(x[8:10]))
    del ga_output_csv['ga:dateHour']
    ga_output_csv=ga_output_csv.sort_values(['Date','Hour'],ascending=True)
    ga_output_csv=ga_output_csv[['Date','Hour']+media_col]
    ga_output_csv=ga_output_csv.fillna(0)
    ga_output_csv.to_csv(writer_folder+'/Saatva_S_and_SM_GA_by_Media_'+Start_Date_1+'_to_'+End_Date_2+week+"_"+Matrics+'.csv',index=False)

# %%
write_csv_output(ga_agg_wide_session,"Session")
write_csv_output(ga_agg_wide_trans,"Trans")
write_csv_output(ga_agg_wide_Revenue,"Revenue")

# %%
ga_agg_session_by_View=ga_data.groupby(['View','View_ID','ga:dateHour','Defined_Media'])['ga:sessions'].sum().unstack('Defined_Media')
ga_agg_session_by_View.reset_index(inplace=True)
ga_agg_session_by_View=ga_agg_session_by_View.fillna(0)
ga_agg_session_by_View.to_csv(writer_folder+'/Saatva_S_and_SM_GA_by_Media_by_View'+Start_Date_1+'_to_'+End_Date_2+week+"_Sessions"+'.csv',index=False)

# %% [markdown]
# # AdWords keywords from GA

# %%
from fuzzywuzzy import fuzz
# fuzz 60 ratio score thredhold
writer=pd.ExcelWriter(writer_folder+"KeyWords_From_GA+"+Start_Date_1+'_to_'+End_Date_2+week+".xlsx")
# Out:
# /usr/local/lib/python3.6/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Saatva.com
# ga:date ga:keyword ga:impressions ga:adClicks
ga_data_Ads_Saatva_1=ga.get_report_over_10000_rows(analytics=analytics, VIEW_ID='122377905',start_date=Start_Date_1, end_date=End_Date_1,
                                            ga_metrics=['ga:adClicks','ga:impressions'],
                                            ga_dimensions=['ga:date','ga:keyword'])
ga_data_Ads_Saatva_2=ga.get_report_over_10000_rows(analytics=analytics, VIEW_ID='122377905',start_date=Start_Date_2, end_date=End_Date_2,
                                            ga_metrics=['ga:adClicks','ga:impressions'],
                                            ga_dimensions=['ga:date','ga:keyword'])
ga_data_Ads_Saatva=ga_data_Ads_Saatva_1.append(ga_data_Ads_Saatva_2)
ga_data_Ads_Saatva['key_word_list']=ga_data_Ads_Saatva['ga:keyword'].apply(lambda x: x.split(" "))
ga_data_Ads_Saatva['Brand_Ratio']=ga_data_Ads_Saatva['key_word_list'].apply(lambda x: max([fuzz.ratio("saatva",z) for z in x]))
ga_data_Ads_Saatva['key_words_group']=np.where(ga_data_Ads_Saatva['Brand_Ratio']>60,"Brand","Non_Brand")

taxonomy_Saatva=ga_data_Ads_Saatva[['ga:keyword','key_words_group']].drop_duplicates()
taxonomy_Saatva['website']="Saatva.com"
ga_data_Ads_Saatva['ga:adClicks']=ga_data_Ads_Saatva['ga:adClicks'].astype(int)
ga_data_Ads_Saatva['ga:impressions']=ga_data_Ads_Saatva['ga:impressions'].astype(int)
output_Saatva=ga_data_Ads_Saatva.groupby(["ga:date","ga:keyword","key_words_group"])['ga:adClicks','ga:impressions'].sum().reset_index()
output_Saatva_Brand=output_Saatva[output_Saatva['key_words_group']=="Brand"].sort_values('ga:date').reset_index()
del output_Saatva_Brand['index']

output_Saatva_Brand.to_excel(writer,"Saatva_Brand",index=False)
output_Saatva.to_excel(writer,"Saatva_Keywords",index=False)

# %%
# SaatvaMattress.com
# ga:date ga:keyword ga:impressions ga:adClicks
ga_data_Ads_SaatvaMattress_1=ga.get_report_over_10000_rows(analytics=analytics, VIEW_ID='33605697',start_date=Start_Date_1, end_date=End_Date_1,
                                            ga_metrics=['ga:adClicks','ga:impressions'],
                                            ga_dimensions=['ga:date','ga:keyword'])
ga_data_Ads_SaatvaMattress_2=ga.get_report_over_10000_rows(analytics=analytics, VIEW_ID='33605697',start_date=Start_Date_2, end_date=End_Date_2,
                                            ga_metrics=['ga:adClicks','ga:impressions'],
                                            ga_dimensions=['ga:date','ga:keyword'])
ga_data_Ads_SaatvaMattress=ga_data_Ads_SaatvaMattress_1.append(ga_data_Ads_SaatvaMattress_2)
ga_data_Ads_SaatvaMattress['key_word_list']=ga_data_Ads_SaatvaMattress['ga:keyword'].apply(lambda x: x.split(" "))
ga_data_Ads_SaatvaMattress['Brand_Ratio']=ga_data_Ads_SaatvaMattress['key_word_list'].apply(lambda x: max([fuzz.ratio("saatva",z) for z in x]))
ga_data_Ads_SaatvaMattress['key_words_group']=np.where(ga_data_Ads_SaatvaMattress['Brand_Ratio']>60,"Brand","Non_Brand")

taxonomy_SaatvaMattress=ga_data_Ads_SaatvaMattress[['ga:keyword','key_words_group']].drop_duplicates()
taxonomy_SaatvaMattress['website']="SaatvaMattress.com"
ga_data_Ads_SaatvaMattress['ga:adClicks']=ga_data_Ads_SaatvaMattress['ga:adClicks'].astype(int)
ga_data_Ads_SaatvaMattress['ga:impressions']=ga_data_Ads_SaatvaMattress['ga:impressions'].astype(int)
output_SaatvaMattress=ga_data_Ads_SaatvaMattress.groupby(["ga:date","ga:keyword","key_words_group"])['ga:adClicks','ga:impressions'].sum().reset_index()
output_SaatvaMattress_Brand=output_SaatvaMattress[output_SaatvaMattress['key_words_group']=="Brand"].sort_values('ga:date').reset_index()
del output_SaatvaMattress_Brand['index']

output_SaatvaMattress_Brand.to_excel(writer,"SaatvaMattress_Brand",index=False)
output_SaatvaMattress.to_excel(writer,"SaatvaMattress_Keywords",index=False)

# %%
taxonomy=taxonomy_Saatva.append(taxonomy_SaatvaMattress)
taxonomy.to_excel(writer,"taxonomy",index=False)
writer.save()

# %% [markdown]
# # Google AdWords

# %%
def get_client(config_path='googleads_saatva.yaml'):
    return adwords.AdWordsClient.LoadFromStorage(config_path)

def download_report_as_stream(client, report_type, fields, start_date, end_date):
    '''Download Adwords report, then save as csv file to base_dir
    Args:
        client: adwords.AdWordsClient.LoadFromStorage()
        report_type: str eg. 'KEYWORDS_PERFORMANCE_REPORT'
        fields: list eg. ["CampaignId", "CampaignName", ... ]
        start_date: str, eg. '2018-02-11'
        end_date: str, eg.
    Return:
        str, path to csv file
    '''
    report_downloader = client.GetReportDownloader(version='v201802')
    # Create report definition.
    report = {
        'reportName': report_type,
        'dateRangeType': 'CUSTOM_DATE',
        'reportType': report_type,
        'downloadFormat': 'CSV',
        'selector': {
            'fields': fields,
            'dateRange': {
                'min': start_date,
                'max': end_date}
        }
    }

    # save output
    return report_downloader.DownloadReportAsStream(report, 
        skip_report_header=True, skip_column_header=False,
        skip_report_summary=True)

# %%
client_Saatva = get_client(config_path='/home/jian/Projects/Saatva/To_Lexie_and_Connor/googleads_saatva_JL_Saatva.yaml')
report_type = 'CAMPAIGN_PERFORMANCE_REPORT'
fields = ["AccountDescriptiveName","CampaignName","Date","HourOfDay","AdvertisingChannelType","AdNetworkType1","AdNetworkType2","Impressions", "Clicks", "Cost"]
response_Saatva = download_report_as_stream(client_Saatva, report_type, fields, Start_Date_overall, End_Data_overall)
Saatva_Click = pd.read_csv(response_Saatva)
Saatva_Click['Cost']=Saatva_Click['Cost'].apply(lambda x: x/1000000)
Saatva_Click['Channel_Network']=Saatva_Click['Advertising Channel']+"|"+Saatva_Click['Network']+"|"+Saatva_Click['Network (with search partners)']

# %%
client_Saatva_Branding = get_client(config_path='/home/jian/Projects/Saatva/To_Lexie_and_Connor/googleads_saatva_JL_Saatva_Branding.yaml')
report_type = 'CAMPAIGN_PERFORMANCE_REPORT'
fields = ["AccountDescriptiveName","CampaignName","Date","HourOfDay","AdvertisingChannelType","AdNetworkType1","AdNetworkType2","Impressions", "Clicks", "Cost"]
response_Saatva_Branding = download_report_as_stream(client_Saatva_Branding, report_type, fields, Start_Date_overall, End_Data_overall)
Saatva_Brand_Click = pd.read_csv(response_Saatva_Branding)
Saatva_Brand_Click['Cost']=Saatva_Brand_Click['Cost'].apply(lambda x: x/1000000)
Saatva_Brand_Click['Channel_Network']=Saatva_Brand_Click['Advertising Channel']+"|"+Saatva_Brand_Click['Network']+"|"+Saatva_Brand_Click['Network (with search partners)']
Saatva_Brand_Click['Channel_Network'].unique()
# Out:
# array(['Display|Display Network|Display Network',
#        'Video|YouTube Search|YouTube Search'], dtype=object)

# %%
client_Saatva_Competitors = get_client(config_path='/home/jian/Projects/Saatva/To_Lexie_and_Connor/googleads_saatva_JL_Saatva_Competitors.yaml')
report_type = 'CAMPAIGN_PERFORMANCE_REPORT'
fields = ["AccountDescriptiveName","CampaignName","Date","HourOfDay","AdvertisingChannelType","AdNetworkType1","AdNetworkType2","Impressions", "Clicks", "Cost"]
response_Saatva_Competitor = download_report_as_stream(client_Saatva_Competitors, report_type, fields, Start_Date_overall, End_Data_overall)
Saatva_Competitor_Click = pd.read_csv(response_Saatva_Competitor)
Saatva_Competitor_Click['Cost']=Saatva_Competitor_Click['Cost'].apply(lambda x: x/1000000)
Saatva_Competitor_Click['Channel_Network']=Saatva_Competitor_Click['Advertising Channel']+"|"+Saatva_Competitor_Click['Network']+"|"+Saatva_Competitor_Click['Network (with search partners)']

# %%
client_TheSaatvaCompany = get_client(config_path='/home/jian/Projects/Saatva/To_Lexie_and_Connor/googleads_saatva_JL_TheSaatvaCompany.yaml')
report_type = 'CAMPAIGN_PERFORMANCE_REPORT'
fields = ["AccountDescriptiveName","CampaignName","Date","HourOfDay","AdvertisingChannelType","AdNetworkType1","AdNetworkType2","Impressions", "Clicks", "Cost"]
response_TheSaatvaCompany = download_report_as_stream(client_TheSaatvaCompany, report_type, fields, Start_Date_overall, End_Data_overall)
TheSaatvaCompany_Click = pd.read_csv(response_TheSaatvaCompany)
TheSaatvaCompany_Click['Cost']=TheSaatvaCompany_Click['Cost'].apply(lambda x: x/1000000)
TheSaatvaCompany_Click['Channel_Network']=TheSaatvaCompany_Click['Advertising Channel']+"|"+TheSaatvaCompany_Click['Network']+"|"+TheSaatvaCompany_Click['Network (with search partners)']

# %%
client_TheSaatvaCompanyBranding = get_client(config_path='/home/jian/Projects/Saatva/To_Lexie_and_Connor/googleads_saatva_JL_TheSaatvaCompanyBranding.yaml')
report_type = 'CAMPAIGN_PERFORMANCE_REPORT'
fields = ["AccountDescriptiveName","CampaignName","Date","HourOfDay","AdvertisingChannelType","AdNetworkType1","AdNetworkType2","Impressions", "Clicks", "Cost"]
response_TheSaatvaCompanyBranding = download_report_as_stream(client_TheSaatvaCompanyBranding, report_type, fields, Start_Date_overall, End_Data_overall)
TheSaatvaCompanyBranding_Click = pd.read_csv(response_TheSaatvaCompanyBranding)
TheSaatvaCompanyBranding_Click['Cost']=TheSaatvaCompanyBranding_Click['Cost'].apply(lambda x: x/1000000)
TheSaatvaCompanyBranding_Click['Channel_Network']=TheSaatvaCompanyBranding_Click['Advertising Channel']+"|"+TheSaatvaCompanyBranding_Click['Network']+"|"+TheSaatvaCompanyBranding_Click['Network (with search partners)']

# %%
Saatva_Competitor_Click=Saatva_Competitor_Click[Saatva_Competitor_Click['Campaign'].apply(lambda x: x[len(x)-4:len(x)+1])=="[SM]"]
Saatva_Competitor_Click.reset_index(inplace=True)
del Saatva_Competitor_Click['index']
# Keep only campaign labeled as "[SM]" in Saatva Competitor account
# Broad and Exact ADL Non-Brand Search Partners are not included

# %%
set(Saatva_Click['Channel_Network'].unique().tolist()+Saatva_Brand_Click['Channel_Network'].unique().tolist()+Saatva_Competitor_Click['Channel_Network'].unique().tolist()+\
    TheSaatvaCompany_Click['Channel_Network'].unique().tolist()+TheSaatvaCompanyBranding_Click['Channel_Network'].unique().tolist())
# Out:
# {'Display|Display Network|Display Network',
#  'Search|Search Network|Google search',
#  'Search|Search Network|Search partners',
#  'Shopping|Search Network|Google search',
#  'Shopping|Search Network|Search partners',
#  'Video|Display Network|Display Network',
#  'Video|YouTube Search|YouTube Search',
#  'Video|YouTube Videos|YouTube Videos'}

# %%
df_all_adwords=Saatva_Click.append(Saatva_Brand_Click).append(Saatva_Competitor_Click)
df_all_adwords=df_all_adwords.append(TheSaatvaCompany_Click).append(TheSaatvaCompanyBranding_Click)

# %%
df_s=df_all_adwords.groupby(['Channel_Network'])[['Impressions','Clicks','Cost']].sum().reset_index()
df_s[df_s['Channel_Network'].apply(lambda x: "Video" in x)]
# Out:
#                          Channel_Network  Impressions  Clicks           Cost
# 5  Video|Display Network|Display Network         6540      17      34.395750
# 6    Video|YouTube Search|YouTube Search       592242      34    2049.600000
# 7    Video|YouTube Videos|YouTube Videos     18480762   81658  240075.153754

# %%
df_all_adwords.head(2)
# Out:
#   Account                                    Campaign         Day  \
# 0  Saatva  [ADL Shopping] Saatva - {Brand} - (Mobile)  2018-10-06
# 1  Saatva  [ADL Shopping] Saatva - {Brand} - (Mobile)  2018-10-11
#
#    Hour of day Advertising Channel         Network  \
# 0           17            Shopping  Search Network
# 1            2            Shopping  Search Network
#
#   Network (with search partners)  Impressions  Clicks  Cost  \
# 0                Search partners           13       0   0.0
# 1                  Google search           38       0   0.0
#
#                            Channel_Network
# 0  Shopping|Search Network|Search partners
# 1    Shopping|Search Network|Google search

# %%
df_all_adwords[df_all_adwords['Channel_Network']=="Video|Display Network|Display Network"]['Cost'].sum()
# Out:
# 34.39575

# %%
df_all_adwords[df_all_adwords['Channel_Network']=="Video|YouTube Search|YouTube Search"]['Cost'].sum()
# Out:
# 2049.5999999999999

# %%
df_all_adwords[df_all_adwords['Channel_Network']=="Video|YouTube Videos|YouTube Videos"]['Cost'].sum()
# Out:
# 240075.15375400003

# %%
df_all_adwords[df_all_adwords['Channel_Network']=="Video|Display Network|Display Network"]['Day'].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d").date()).min()
# Out:
# datetime.date(2018, 9, 11)

# %%
df_all_adwords[df_all_adwords['Channel_Network']=="Video|Display Network|Display Network"]['Day'].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d").date()).max()
# Out:
# datetime.date(2018, 9, 19)

# %%
df_all_adwords[df_all_adwords['Channel_Network']=="Video|YouTube Search|YouTube Search"]['Day'].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d").date()).min()
# Out:
# datetime.date(2018, 9, 11)

# %%
df_all_adwords[df_all_adwords['Channel_Network']=="Video|YouTube Search|YouTube Search"]['Day'].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d").date()).max()
# Out:
# datetime.date(2018, 10, 18)

# %%
df_all_adwords[df_all_adwords['Channel_Network']=="Video|YouTube Videos|YouTube Videos"]['Day'].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d").date()).min()
# Out:
# datetime.date(2018, 9, 11)

# %%
df_all_adwords[df_all_adwords['Channel_Network']=="Video|YouTube Videos|YouTube Videos"]['Day'].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d").date()).max()
# Out:
# datetime.date(2018, 10, 18)

# %%
df_x=df_all_adwords[df_all_adwords['Channel_Network']=="Video|YouTube Videos|YouTube Videos"]
df_x['Day']=df_x['Day'].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d").date())
df_x[df_x['Day']<datetime.date(2018,9,19)]['Cost'].sum()
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 9427.5978470000009

# %%
df_x[df_x['Day']<datetime.date(2018,9,19)]
# Out:
#       Account                                           Campaign         Day  \
# 762    Saatva  [ADL] [Video] [Trueview for Shopping] [US] Rem...  2018-09-13
# 763    Saatva  [ADL] [Video] [Trueview for Shopping] [US] Rem...  2018-09-14
# 800    Saatva  [ADL] [Video] [Trueview for Shopping] [US] Rem...  2018-09-17
# ...       ...                                                ...         ...
# 89802  Saatva  [ADL] [Video] [In-Stream] [US] Remarketing - [...  2018-09-14
# 89827  Saatva  [ADL] [Video] [In-Stream] [US] Remarketing - [...  2018-09-17
# 89829  Saatva  [ADL] [Video] [In-Stream] [US] Remarketing - [...  2018-09-13
#
#        Hour of day Advertising Channel         Network  \
# 762             17               Video  YouTube Videos
# 763              3               Video  YouTube Videos
# 800             11               Video  YouTube Videos
# ...            ...                 ...             ...
# 89802            1               Video  YouTube Videos
# 89827           15               Video  YouTube Videos
# 89829           21               Video  YouTube Videos
#
#       Network (with search partners)  Impressions  Clicks       Cost  \
# 762                   YouTube Videos          877       3  30.694530
# 763                   YouTube Videos          159       0   5.966301
# 800                   YouTube Videos          565       3  31.152575
# ...                              ...          ...     ...        ...
# 89802                 YouTube Videos          326       2   7.178965
# 89827                 YouTube Videos          531       2  11.963967
# 89829                 YouTube Videos          701       9  12.687650
#
#                            Channel_Network
# 762    Video|YouTube Videos|YouTube Videos
# 763    Video|YouTube Videos|YouTube Videos
# 800    Video|YouTube Videos|YouTube Videos
# ...                                    ...
# 89802  Video|YouTube Videos|YouTube Videos
# 89827  Video|YouTube Videos|YouTube Videos
# 89829  Video|YouTube Videos|YouTube Videos
#
# [706 rows x 11 columns]

# %%
'''
Saatva_Click=Saatva_Click[~((Saatva_Click['Campaign'].str.contains("Loom")) | (Saatva_Click['Campaign'].str.contains("Leaf")) | (Saatva_Click['Campaign'].str.contains("Zenhaven")))]
TheSaatvaCompany_Click=TheSaatvaCompany_Click[~((TheSaatvaCompany_Click['Campaign'].str.contains("Loom")) | (TheSaatvaCompany_Click['Campaign'].str.contains("Leaf")) | (TheSaatvaCompany_Click['Campaign'].str.contains("Zenhaven")))]
TheSaatvaCompanyBranding_Click=TheSaatvaCompanyBranding_Click[~((TheSaatvaCompanyBranding_Click['Campaign'].str.contains("Loom")) | (TheSaatvaCompanyBranding_Click['Campaign'].str.contains("Leaf")) | (TheSaatvaCompanyBranding_Click['Campaign'].str.contains("Zenhaven")))]
'''
# No need to exclude the compaigns because of the small pctg

Saatva_Click['Campaign_Type']=Saatva_Click['Advertising Channel'].apply(lambda x: x.replace("Search","SEM").replace("Shopping","PLA"))
Saatva_Brand_Click['Campaign_Type']=Saatva_Brand_Click['Advertising Channel'].apply(lambda x: x.replace("Search","SEM_Brand").replace("Shopping","PLA"))
Saatva_Competitor_Click['Campaign_Type']="SEM_Non_Brand" # Because it's all labeled as Non-Brand in Campaign and in Search Only Campaign Type
TheSaatvaCompany_Click['Campaign_Type']=TheSaatvaCompany_Click['Advertising Channel'].apply(lambda x: x.replace("Search","SEM").replace("Shopping","PLA"))
TheSaatvaCompanyBranding_Click['Campaign_Type']=TheSaatvaCompanyBranding_Click['Advertising Channel'].apply(lambda x: x.replace("Search","SEM").replace("Shopping","PLA"))

# %%
# Split Saatva
# 'Search Network with Display Select' Campaign Type all 0 Impr and Clicks
Saatva_Click_Search=Saatva_Click[Saatva_Click['Advertising Channel']=='Search']
Saatva_Click_Others=Saatva_Click[Saatva_Click['Advertising Channel']!='Search']

Saatva_Click_Search['Campaign_Type']=np.where((Saatva_Click_Search['Campaign'].str.contains("Branded")) | (Saatva_Click_Search['Campaign'].str.contains(" Brand ")) | (Saatva_Click_Search['Campaign'].str.contains("Co-Brand")) | (Saatva_Click_Search['Campaign'].str.contains("\[Brand\]")),"SEM_Brand",
                                                 np.where((Saatva_Click_Search['Campaign'].str.contains("Non-Brand")) | (Saatva_Click_Search['Campaign'].str.contains("Dynamic Search Ads")),"SEM_Non_Brand","NA"))
Saatva_Click_Search_1=Saatva_Click_Search[Saatva_Click_Search['Campaign_Type']!="NA"]
Saatva_Click_Search_2=Saatva_Click_Search[Saatva_Click_Search['Campaign_Type']=="NA"]
len(Saatva_Click_Search_2) # Make sure it's 0
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# 0

# %%
# Split TheSaatvaCompany

TheSaatvaCompany_Click_Search=TheSaatvaCompany_Click[TheSaatvaCompany_Click['Advertising Channel']=='Search']
TheSaatvaCompany_Click_Others=TheSaatvaCompany_Click[TheSaatvaCompany_Click['Advertising Channel']!='Search']

TheSaatvaCompany_Click_Search['Campaign_Type']=np.where((TheSaatvaCompany_Click_Search['Campaign'].str.contains("Branded")) | (TheSaatvaCompany_Click_Search['Campaign'].str.contains(" Brand ")) | (TheSaatvaCompany_Click_Search['Campaign'].str.contains("Co-Brand")) | (TheSaatvaCompany_Click_Search['Campaign'].str.contains("\[Brand\]")),"SEM_Brand",
                                                 np.where((TheSaatvaCompany_Click_Search['Campaign'].str.contains("Non-Brand")) | (TheSaatvaCompany_Click_Search['Campaign'].str.contains("Dynamic Search Ads")),"SEM_Non_Brand","NA"))
TheSaatvaCompany_Click_Search_1=TheSaatvaCompany_Click_Search[TheSaatvaCompany_Click_Search['Campaign_Type']!="NA"]
TheSaatvaCompany_Click_Search_2=TheSaatvaCompany_Click_Search[TheSaatvaCompany_Click_Search['Campaign_Type']=="NA"]
len(TheSaatvaCompany_Click_Search_2) # Make sure it's 0
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# 0

# %%
# All campaing is able to differentiate from the name about brand and non-brand, so no need to go to keywords level
'''
Saatva_keywords=pd.read_csv("/home/jian/Projects/Saatva/To_Lexie_and_Connor/AdWords/saatva_keywords.csv",dtype=str,skiprows=2)
Saatva_Brand_keywords=pd.read_csv("/home/jian/Projects/Saatva/To_Lexie_and_Connor/AdWords/saatva branding_keywords.csv",dtype=str)
Saatva_Competitor_keywords=pd.read_csv("/home/jian/Projects/Saatva/To_Lexie_and_Connor/AdWords/saatva competitors_keywords.csv",dtype=str,skiprows=2)

Saatva_keywords=Saatva_keywords[~((Saatva_keywords['Campaign'].str.contains("Loom")) | (Saatva_keywords['Campaign'].str.contains("Leaf")) | (Saatva_keywords['Campaign'].str.contains("Zenhaven")))]
Saatva_keywords['Campaign_Type']=np.where(Saatva_keywords['Search keyword'].str.contains("aatva"),"SEM_Brand","SEM_Non_Brand")
Saatva_keywords['Impressions']=Saatva_keywords['Impressions'].apply(lambda x: int(x.replace(",","")))
Saatva_keywords['Impressions']=Saatva_keywords['Impressions'].astype(int)
Saatva_keywords['Clicks']=Saatva_keywords['Clicks'].apply(lambda x: int(x.replace(",","")))
Saatva_keywords['Clicks']=Saatva_keywords['Clicks'].astype(int)
Saatva_keywords=Saatva_keywords.groupby(['Campaign','Campaign_Type'])['Impressions','Clicks'].sum()
Saatva_keywords.reset_index(inplace=True)
Saatva_keywords=Saatva_keywords.sort_values(['Campaign','Impressions'])
Saatva_keywords=Saatva_keywords.drop_duplicates('Campaign')
Saatva_Campaign_Type=Saatva_keywords[['Campaign','Campaign_Type']]

del Saatva_Click_Search_2['Campaign_Type']
Saatva_Click_Search_2=pd.merge(Saatva_Click_Search_2,Saatva_Campaign_Type,on="Campaign",how="left")

Saatva_Search_Click=Saatva_Click_Search_1.append(Saatva_Click_Search_2)
Saatva_Search_Click['Campaign_Type']=Saatva_Search_Click['Campaign_Type'].fillna("All_0_Values_and_No_Kws")
'''
# Out:
# '\nSaatva_keywords=pd.read_csv("/home/jian/Projects/Saatva/To_Lexie_and_Connor/AdWords/saatva_keywords.csv",dtype=str,skiprows=2)\nSaatva_Brand_keywords=pd.read_csv("/home/jian/Projects/Saatva/To_Lexie_and_Connor/AdWords/saatva branding_keywords.csv",dtype=str)\nSaatva_Competitor_keywords=pd.read_csv("/home/jian/Projects/Saatva/To_Lexie_and_Connor/AdWords/saatva competitors_keywords.csv",dtype=str,skiprows=2)\n\nSaatva_keywords=Saatva_keywords[~((Saatva_keywords[\'Campaign\'].str.contains("Loom")) | (Saatva_keywords[\'Campaign\'].str.contains("Leaf")) | (Saatva_keywords[\'Campaign\'].str.contains("Zenhaven")))]\nSaatva_keywords[\'Campaign_Type\']=np.where(Saatva_keywords[\'Search keyword\'].str.contains("aatva"),"SEM_Brand","SEM_Non_Brand")\nSaatva_keywords[\'Impressions\']=Saatva_keywords[\'Impressions\'].apply(lambda x: int(x.replace(",","")))\nSaatva_keywords[\'Impressions\']=Saatva_keywords[\'Impressions\'].astype(int)\nSaatva_keywords[\'Clicks\']=Saatva_keywords[\'Clicks\'].apply(lambda x: int(x.replace(",","")))\nSaatva_keywords[\'Clicks\']=Saatva_keywords[\'Clicks\'].astype(int)\nSaatva_keywords=Saatva_keywords.groupby([\'Campaign\',\'Campaign_Type\'])[\'Impressions\',\'Clicks\'].sum()\nSaatva_keywords.reset_index(inplace=True)\nSaatva_keywords=Saatva_keywords.sort_values([\'Campaign\',\'Impressions\'])\nSaatva_keywords=Saatva_keywords.drop_duplicates(\'Campaign\')\nSaatva_Campaign_Type=Saatva_keywords[[\'Campaign\',\'Campaign_Type\']]\n\ndel Saatva_Click_Search_2[\'Campaign_Type\']\nSaatva_Click_Search_2=pd.merge(Saatva_Click_Search_2,Saatva_Campaign_Type,on="Campaign",how="left")\n\nSaatva_Search_Click=Saatva_Click_Search_1.append(Saatva_Click_Search_2)\nSaatva_Search_Click[\'Campaign_Type\']=Saatva_Search_Click[\'Campaign_Type\'].fillna("All_0_Values_and_No_Kws")\n'

# %%
Saatva_Click_Search_2.head(2)
# Out:
# Empty DataFrame
# Columns: [Account, Campaign, Day, Hour of day, Advertising Channel, Network, Network (with search partners), Impressions, Clicks, Cost, Channel_Network, Campaign_Type]
# Index: []

# %%
Saatva_Click=Saatva_Click_Search.append(Saatva_Click_Others)
TheSaatvaCompany_Click=TheSaatvaCompany_Click_Search.append(TheSaatvaCompany_Click_Others)

# %%
writer=pd.ExcelWriter(writer_folder+"/Saatva_AdWords_"+Start_Date_overall+"_to_"+End_Data_overall+week+"_cost.xlsx",engine='xlsxwriter')

# %%
Saatva_Agg=Saatva_Click.append(Saatva_Brand_Click).append(Saatva_Competitor_Click).append(TheSaatvaCompany_Click).append(TheSaatvaCompanyBranding_Click)
Saatva_Agg['Day']=Saatva_Agg['Day'].apply(lambda x: datetime.datetime.strptime(x,"%Y-%m-%d").date())
Saatva_Agg.reset_index(inplace=True)
del Saatva_Agg['index']
Saatva_Agg['Hour of day']=Saatva_Agg['Hour of day'].astype(int)
Saatva_Agg_Category=Saatva_Agg[['Campaign','Account','Advertising Channel','Campaign_Type']].drop_duplicates()
Saatva_Agg_Category.to_excel(writer,"Campaign Category",index=False)

# %%
Saatva_Agg=Saatva_Agg.groupby(["Campaign_Type","Day","Hour of day"])['Impressions','Clicks', 'Cost'].apply(sum)
Saatva_Agg.reset_index(inplace=True)
Saatva_Agg['CTR']=Saatva_Agg['Clicks']/Saatva_Agg['Impressions']
Saatva_Agg.to_excel(writer,"reshaped by hour day",index=False)

Saatva_Agg_No_NA=Saatva_Agg[(Saatva_Agg['Campaign_Type']!="NA") & (Saatva_Agg['Campaign_Type']!="Search Network with Display Select")]

Saatva_Agg_No_NA.to_excel(writer,"clean data by hour day",index=False)

# %%
writer.save()

# %%
AdWords_output=Saatva_Agg.copy()
AdWords_output['Date']=AdWords_output['Day'].apply(lambda x: str(x)[0:4]+str(x)[5:7]+str(x)[8:10])
AdWords_output=AdWords_output[['Campaign_Type','Date','Hour of day','Impressions','Clicks','Cost']]
AdWords_output=AdWords_output.rename(columns={"Hour of day":"Hour","Impressions":"IMP"})
AdWords_output=AdWords_output.sort_values(["Campaign_Type","Date","Hour"],ascending=[True,True,True])
AdWords_output.to_csv(writer_folder+"/Saatva_AdWords_"+Start_Date_overall+"_to_"+End_Data_overall+week+"_cost.csv",index=False)

# %%
Saatva_Agg_Category.to_csv(writer_folder+"/Saatva_AdWords_Taxonomy_"+Start_Date_overall+"_to_"+End_Data_overall+week+"_cost.csv",index=False)
