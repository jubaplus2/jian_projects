# %%
import pymysql.cursors
engine = pymysql.connect(host='localhost',user='root',
                         password='TDb-u)sI6|p$9;hh',db='Geographic_and_Demographic',
                         charset='utf8mb4',cursorclass=pymysql.cursors.DictCursor)

# %%
def create_business_main():
    with engine.cursor() as cur:
        cur.execute("DROP TABLE IF EXISTS business_main")
        cur.execute("CREATE TABLE business_main(PostalCode VarChar(7),\
                        City VarChar(45),\
                        Province VarChar(2),\
                        ProvinceName VarChar(45),\
                        AreaCode VarChar(3),\
                        CityFlag VarChar(1),\
                        TimeZone Integer ,\
                        DST VarChar(1),\
                        Latitude Decimal,\
                        Longitude Decimal,\
                        Elevation Integer,\
                        Population Integer,\
                        Dwellings Integer,\
                        AreaName VarChar(45),\
                        StreetName VarChar(45),\
                        StreetTypeCode VarChar (6),\
                        StreetDirCode VarChar (2) ,\
                        StreetSuffix VarChar (3),\
                        CityMixedCase VarChar (45),\
                        AreaNameMixedCase VarChar (45),\
                        MunicipalityName VarChar (45),\
                        CensusMetropolitanAreaUID VarChar (3),\
                        CensusMetropolitanAreaName VarChar (100),\
                        CensusDivisionUID VarChar (45),\
                        CensusDivisionName VarChar (255),\
                        CensusSubDivisionUID VarChar (7),\
                        CensusSubDivisionName VarChar (255),\
                        RecordType VarChar(1),\
                        AddressType VarChar(1),\
                        StreetNameMixedCase Varchar(45),\
                        FederalElectoralDistrictUID VarChar(5),\
                        FederalElectoralDistrictName  VarChar (255),\
                        DesignatedPlaceUID VarChar(6),\
                        DesignatedPlaceName VarChar(255),\
                        EconomicRegionUID VarChar(4),\
                        EconomicRegionName VarChar (255),\
                        CensusDisseminationAreaUID VarChar (8) ,\
                        CensusConsolidatedSubdivisionUID VarChar (7),\
                        CensusConsolidatedSubdivisionName VarChar (255),\
                        CensusTractUID VarChar (10),\
                        CensusTractName VarChar (255),\
                        PopulationCentreUID VarChar (4),\
                        PopulationCentreName VarChar (255))")
    print("1:An empty TABLE onair_postgrosstable has been created.")

# %%
create_business_main()
# Out:
# 1:An empty TABLE onair_postgrosstable has been created.

# %%
import pandas as pd
import numpy as np
import os
import glob
import sqlalchemy
from sqlalchemy import create_engine

canada_zip_SQL_CONNECTION = 'mysql+pymysql://root:TDb-u%29sI6%7Cp%249%3Bhh@localhost/Geographic_and_Demographic'
cz_engine = create_engine(canada_zip_SQL_CONNECTION,pool_recycle=1800)

# %%
df = pd.read_csv('canada-postal-code-database-BUSINESS.csv', encoding = "ISO-8859-1")
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         PostalCode                City Province               ProvinceName  \
# 0          A0A 0A1            AVONDALE       NL  Newfoundland and Labrador
# 1          A0A 0A2            HOLYROOD       NL  Newfoundland and Labrador
# 2          A0A 0A3           TREPASSEY       NL  Newfoundland and Labrador
# 3          A0A 0A4         SOUTH RIVER       NL  Newfoundland and Labrador
# 4          A0A 0A5        NORTHERN BAY       NL  Newfoundland and Labrador
# 5          A0A 0A6       CLARKES BEACH       NL  Newfoundland and Labrador
# 6          A0A 0A7  CONCEPTION HARBOUR       NL  Newfoundland and Labrador
# 7          A0A 0A8        HARBOUR MAIN       NL  Newfoundland and Labrador
# 8          A0A 0A9           JOBS COVE       NL  Newfoundland and Labrador
# 9          A0A 0B1           ST SHOTTS       NL  Newfoundland and Labrador
# 10         A0A 0B2         CAPE BROYLE       NL  Newfoundland and Labrador
# ...

# %%
df.to_sql('business_main' , if_exists='append', con=cz_engine, index=False)
# Out:
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'Latitude' at row 1")
#   result = self._query(query)
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'Longitude' at row 1")
#   result = self._query(query)
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'Latitude' at row 2")
#   result = self._query(query)
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'Longitude' at row 2")
#   result = self._query(query)
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'Latitude' at row 3")
#   result = self._query(query)
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:165: Warning: (1265, "Data truncated for column 'Longitude' at row 3")
#   result = self._query(query)
# ...

# %%
pd.read_sql(("select * from business_main "),con=cz_engine)
# Out:
#    PostalCode                 City Province               ProvinceName  \
# 0     A0A 0A1             AVONDALE       NL  Newfoundland and Labrador
# 1     A0A 0A2             HOLYROOD       NL  Newfoundland and Labrador
# 2     A0A 0A3            TREPASSEY       NL  Newfoundland and Labrador
# 3     A0A 0A4          SOUTH RIVER       NL  Newfoundland and Labrador
# 4     A0A 0A5         NORTHERN BAY       NL  Newfoundland and Labrador
# 5     A0A 0A6        CLARKES BEACH       NL  Newfoundland and Labrador
# 6     A0A 0A7   CONCEPTION HARBOUR       NL  Newfoundland and Labrador
# 7     A0A 0A8         HARBOUR MAIN       NL  Newfoundland and Labrador
# 8     A0A 0A9            JOBS COVE       NL  Newfoundland and Labrador
# 9     A0A 0B1            ST SHOTTS       NL  Newfoundland and Labrador
# 10    A0A 0B2          CAPE BROYLE       NL  Newfoundland and Labrador
# 11    A0A 0B3            AQUAFORTE       NL  Newfoundland and Labrador
# ...
