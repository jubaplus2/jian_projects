# %%
# Transfer to 64 for Charles to do the migration

import paramiko
import os
import glob
os.getcwd()
# Out:
# '/home/jian/celery/Audience_No_Shop/Quarterly_Decile_Detail'

# %%
host = "64.237.51.251" #hard-coded
port = 22
transport = paramiko.Transport((host, port))

password = "jian@juba2017" #hard-coded
username = "jian" #hard-coded
transport.connect(username = username, password = password)
sftp = paramiko.SFTPClient.from_transport(transport)

# %%
local_path_list='/home/jian/celery/Audience_No_Shop/Quarterly_Decile_Detail/*.csv'
local_path_list=glob.glob(local_path_list)
local_path_list
# Out:
# ['/home/jian/celery/Audience_No_Shop/Quarterly_Decile_Detail/df_detail_2019Q4.csv',
#  '/home/jian/celery/Audience_No_Shop/Quarterly_Decile_Detail/df_detail_2019Q3.csv']

# %%
remote_folder="/mnt/drv5/lr_biglots_data/BL_Quarterly_Detail/"
for local_file in local_path_list:
    base_name=os.path.basename(local_file)
    sftp.put(local_file,remote_folder+base_name)

# %%
sftp.close()
transport.close()

# %%
import pandas as pd
pd.options.display.max_columns=99
pd.read_csv(local_path_list[0],nrows=10,dtype=str)
# Out:
#   frmindex recencyindex Amtindex Transindex  \
# 0      D01          1.0      1.0        1.0
# 1      D01          1.0      1.0        1.0
# 2      D01          1.0      1.0        1.0
# 3      D01          1.0      1.0        1.0
# 4      D01          1.0      1.0        1.0
# 5      D01          1.0      1.0        1.0
# 6      D01          1.0      1.0        1.0
# 7      D01          1.0      1.0        1.0
# 8      D01          1.0      1.0        1.0
# 9      D01          1.0      1.0        1.0
#
#                                   customer_id_hashed               sales  \
# 0  b78dccfd64ce659af7061c5743b6b9305814336bc9ddec...            76267.32
# 1  bfd2e98c3c7cccf2f0d432f8d02d951479311150e4a540...   69187.84999999995
# 2  ba00b08e0ecda5f850d28c55bcce69191bc8c24a811bb6...   77656.46999999994
# 3  af1a67def27b7a4812c299f88c9128d1f1471df969ee7c...   75384.22999999997
# 4  8f9005dc30f9fb129b21dec1ca9e329eaba3cc43dbd8a9...   58431.37000000001
# 5  982e2d92ca94e2ba3cb397a49dd73909553f532dcd84bb...   51889.73000000001
# 6  f7cab1ae0e1ea0b677b736b89d07e4d05fe700006f9fc0...   81440.95000000004
# 7  471553e2f541b0216ea2e6b07181852612479f4ee93535...   58755.30999999997
# 8  66e7d4ce52c8a452a0584f17b0e85c3cfb09279b1dc093...   61831.09999999997
# 9  35dcc382752f26376dab0b63f146fe77cf027a04257c34...  56942.729999999974
#
#   transactions recency last_transaction_date    RFM  \
# 0         4922     1.0            2019-10-11  111.0
# 1         4167     1.0            2019-10-12  111.0
# 2         3765     1.0            2019-10-12  111.0
# 3         3710     1.0            2019-10-12  111.0
# 4         3137     1.0            2019-10-11  111.0
# 5         3075     1.0            2019-09-25  111.0
# 6         3038     1.0            2019-10-12  111.0
# 7         2830     1.0            2019-10-12  111.0
# 8         2605     1.0            2019-10-11  111.0
# 9         2323     1.0            2019-10-11  111.0
#
#                                   email_address_hash cleaned_zip_cd  \
# 0  4836bfc632a2a5987d47fa6bf0637c21c4466a0e99ddee...          28607
# 1  bff5e20f383626e52c464341ad29b3b4e161b8b35de99d...          79938
# 2  ff42f56047a09441444582bb3f23eec007869ea4aec58f...          01702
# 3  d48d9bde483e3a6524f75f41209df8b6848c1cd6714aff...          47250
# 4  089cc0883c4184de4534e6e5f9cbeba535aed590e9ba64...          91342
# 5  21ced089d5370d961feaa053059cfe5559ac6ebfb09694...          28607
# 6  5b90e6ebf6c36b91d799605b036f557c36600d98352c48...          18447
# 7  baf7211d49b344816153f2b5ec5e5b591617f7243812f5...          93309
# 8  4054daaecc722f3203ecae26872f6442bab09fe50b78bd...          50266
# 9  1adda6c484f1399e0b088e58ee7db0c84ded21c938f90c...          50320
#
#   closest_store zip_type shopper_store final_store_for_id Recency_Status  \
# 0        1684.0        P        1684.0               1684  Active (0-12)
# 1        1926.0        P        1926.0               1926  Active (0-12)
# 2        5194.0        P        5194.0               5194  Active (0-12)
# 3         255.0        P         255.0                255  Active (0-12)
# 4        4447.0        P        4447.0               4447  Active (0-12)
# 5        1684.0        P        1684.0               1684  Active (0-12)
# 6        1166.0        P        5188.0               5188  Active (0-12)
# 7        4655.0        P        4655.0               4655  Active (0-12)
# 8        1732.0        P        1732.0               1732  Active (0-12)
# 9        1732.0        S        1732.0               1732  Active (0-12)
#
#   nearest_store Density_Tier    SOTF HML_Group  ExperianCluster  \
# 0          1684            M  Legacy         H           Others
# 1          1926            M  Legacy         H           Others
# 2          5194            M  Legacy         H           Others
# 3           255            M  Legacy         H           Others
# 4          4447            M  Legacy         H           Others
# 5          1684            M  Legacy         H           Others
# 6          1166            M    SOTF         H           Others
# 7          4655            M  Legacy         H           Others
# 8          1732            M  Legacy         H  HolidayShoppers
# 9          1732            M  Legacy         H           Others
#
#                                segment_Decile_Active  \
# 0  Active (0-12)_D01_Density(M)_Legacy_Others_P_2...
# 1  Active (0-12)_D01_Density(M)_Legacy_Others_P_2...
# 2  Active (0-12)_D01_Density(M)_Legacy_Others_P_2...
# 3  Active (0-12)_D01_Density(M)_Legacy_Others_P_2...
# 4  Active (0-12)_D01_Density(M)_Legacy_Others_P_2...
# 5  Active (0-12)_D01_Density(M)_Legacy_Others_P_2...
# 6  Active (0-12)_D01_Density(M)_SOTF_Others_P_2019Q4
# 7  Active (0-12)_D01_Density(M)_Legacy_Others_P_2...
# 8  Active (0-12)_D01_Density(M)_Legacy_HolidaySho...
# 9  Active (0-12)_D01_Density(M)_Legacy_Others_S_2...
#
#                                segment_Decile_Lapsed  \
# 0  Active (0-12)_D01_Density(M)_Legacy_AllExpClus...
# 1  Active (0-12)_D01_Density(M)_Legacy_AllExpClus...
# 2  Active (0-12)_D01_Density(M)_Legacy_AllExpClus...
# 3  Active (0-12)_D01_Density(M)_Legacy_AllExpClus...
# 4  Active (0-12)_D01_Density(M)_Legacy_AllExpClus...
# 5  Active (0-12)_D01_Density(M)_Legacy_AllExpClus...
# 6  Active (0-12)_D01_Density(M)_SOTF_AllExpCluste...
# 7  Active (0-12)_D01_Density(M)_Legacy_AllExpClus...
# 8  Active (0-12)_D01_Density(M)_Legacy_AllExpClus...
# 9  Active (0-12)_D01_Density(M)_Legacy_AllExpClus...
#
#                                 segment_Score_Active  \
# 0  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 1  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 2  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 3  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 4  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 5  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 6  Active (0-12)_Score(H)_Density(M)_SOTF_Others_...
# 7  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 8  Active (0-12)_Score(H)_Density(M)_Legacy_Holid...
# 9  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
#
#                                 segment_Score_Lapsed  \
# 0  Active (0-12)_Score(H)_Density(M)_Legacy_AllEx...
# 1  Active (0-12)_Score(H)_Density(M)_Legacy_AllEx...
# 2  Active (0-12)_Score(H)_Density(M)_Legacy_AllEx...
# 3  Active (0-12)_Score(H)_Density(M)_Legacy_AllEx...
# 4  Active (0-12)_Score(H)_Density(M)_Legacy_AllEx...
# 5  Active (0-12)_Score(H)_Density(M)_Legacy_AllEx...
# 6  Active (0-12)_Score(H)_Density(M)_SOTF_AllExpC...
# 7  Active (0-12)_Score(H)_Density(M)_Legacy_AllEx...
# 8  Active (0-12)_Score(H)_Density(M)_Legacy_AllEx...
# 9  Active (0-12)_Score(H)_Density(M)_Legacy_AllEx...
#
#                                              segment
# 0  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 1  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 2  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 3  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 4  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 5  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 6  Active (0-12)_Score(H)_Density(M)_SOTF_Others_...
# 7  Active (0-12)_Score(H)_Density(M)_Legacy_Other...
# 8  Active (0-12)_Score(H)_Density(M)_Legacy_Holid...
# 9  Active (0-12)_Score(H)_Density(M)_Legacy_Other...

# %%
pd.read_csv(local_path_list[1],nrows=10,dtype=str)
# Out:
#   frmindex                                 customer_id_hashed    RFM recency  \
# 0      D01  b78dccfd64ce659af7061c5743b6b9305814336bc9ddec...  111.0     1.0
# 1      D01  bfd2e98c3c7cccf2f0d432f8d02d951479311150e4a540...  111.0     1.0
# 2      D01  ba00b08e0ecda5f850d28c55bcce69191bc8c24a811bb6...  111.0     1.0
# 3      D01  d59f8aa96f4d6943b77c1e1e1dd5deda7dedb7b3f74a07...  111.0     1.0
# 4      D01  14b78c9088ecdbde7a771c49664157cfe588f86ae5ce5c...  111.0     1.0
# 5      D01  8f9005dc30f9fb129b21dec1ca9e329eaba3cc43dbd8a9...  111.0     1.0
# 6      D01  af1a67def27b7a4812c299f88c9128d1f1471df969ee7c...  111.0     1.0
# 7      D01  471553e2f541b0216ea2e6b07181852612479f4ee93535...  111.0     1.0
# 8      D01  66e7d4ce52c8a452a0584f17b0e85c3cfb09279b1dc093...  111.0     1.0
# 9      D01  628f22631a2c713c156e49c8e532f324c1d66b304de34d...  111.0     1.0
#
#   transactions               sales  active  \
# 0         3539  54922.140000000036  active
# 1         3263   54903.20000000009  active
# 2         3011   63740.17999999986  active
# 3         2735  58336.779999999875  active
# 4         2644   58005.28999999994  active
# 5         2487   46953.99999999993  active
# 6         2346  51865.810000000034  active
# 7         2337   49507.26999999989  active
# 8         2098   52755.58999999996  active
# 9         1838  48072.239999999976  active
#
#                                   email_address_hash customer_zip_code  \
# 0  4836bfc632a2a5987d47fa6bf0637c21c4466a0e99ddee...             28607
# 1  bff5e20f383626e52c464341ad29b3b4e161b8b35de99d...             79938
# 2  ff42f56047a09441444582bb3f23eec007869ea4aec58f...             01702
# 3  f64545146b973492bc4a6c32ff119d6ab8f6d78931c5d4...             00nan
# 4  d72cf03e94da3a0f89abc29df597ff699420ab1c2671b3...             87501
# 5  089cc0883c4184de4534e6e5f9cbeba535aed590e9ba64...             91342
# 6  d48d9bde483e3a6524f75f41209df8b6848c1cd6714aff...             47250
# 7  baf7211d49b344816153f2b5ec5e5b591617f7243812f5...             93309
# 8  4054daaecc722f3203ecae26872f6442bab09fe50b78bd...             50266
# 9  b2af6837f7baa3e271d54c82f873ad7286007cb11fe5e6...             32609
#
#   location_id      Quadrant zipcodegroup HML_Group             segment_Decile  \
# 0        1684    Quadrant I            P         H    Quadrant I_P_D01_2019Q3
# 1        1926    Quadrant I            P         H    Quadrant I_P_D01_2019Q3
# 2        5194    Quadrant I            P         H    Quadrant I_P_D01_2019Q3
# 3        1753    Quadrant I            T         H    Quadrant I_T_D01_2019Q3
# 4        4147   Quadrant IV            S         H   Quadrant IV_S_D01_2019Q3
# 5        4447    Quadrant I            P         H    Quadrant I_P_D01_2019Q3
# 6         255  Quadrant III            P         H  Quadrant III_P_D01_2019Q3
# 7        4655    Quadrant I            P         H    Quadrant I_P_D01_2019Q3
# 8        1732   Quadrant IV            P         H   Quadrant IV_P_D01_2019Q3
# 9        5152  Quadrant III            P         H  Quadrant III_P_D01_2019Q3
#
#             segment_2019Q3
# 0    Quadrant I_P_H_2019Q3
# 1    Quadrant I_P_H_2019Q3
# 2    Quadrant I_P_H_2019Q3
# 3    Quadrant I_T_H_2019Q3
# 4   Quadrant IV_S_H_2019Q3
# 5    Quadrant I_P_H_2019Q3
# 6  Quadrant III_P_H_2019Q3
# 7    Quadrant I_P_H_2019Q3
# 8   Quadrant IV_P_H_2019Q3
# 9  Quadrant III_P_H_2019Q3
