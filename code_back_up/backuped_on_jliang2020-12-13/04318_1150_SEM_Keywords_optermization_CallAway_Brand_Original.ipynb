# %%
import pandas as pd
import numpy as np
pd.options.display.max_rows = 6
import os
os.chdir('/Users/JayLiang/Desktop/Media Storm/PEI/CallAway/SEM_ Optimization/Sep 5')
import argparse
import httplib2
import pprint
import time
import datetime
from io import StringIO

from apiclient.discovery import build
from oauth2client import GOOGLE_TOKEN_URI
from oauth2client.client import OAuth2Credentials
from googleapiclient.errors import HttpError


def create_credentials():
    """Create Google OAuth2 credentials.

    Args:
        client_id: Client id of a Google Cloud console project.
        client_secret: Client secret of a Google Cloud console project.
        refresh_token: A refresh token authorizing the Google Cloud console project
          to access the DS data of some Google user.
    Returns:
        OAuth2Credentials
    """
    return OAuth2Credentials(access_token=None,
                           client_id='549790627766-qnth4m8qvuimg87pnsp4b82lhte7dk5a.apps.googleusercontent.com',
                           client_secret='Vta4lQLOL49vVYvktkcPGRNb',
                           refresh_token='1/ab7pCGMu3K5AveG0UOUpQ0J08vCp6uM357O8qmoPDMs',
                           token_expiry=None,
                           token_uri="https://accounts.google.com/o/oauth2/token",
                           user_agent=None)

def get_service(credentials):
    """Set up a new DoubleClick Search service.

    Args:
        credentials: An OAuth2Credentials generated with create_credentials, or
        flows in the oatuh2client.client package.
    Returns:
        An authorized Doubleclicksearch serivce.
    """
    # Use the authorize() function of OAuth2Credentials to apply necessary credential
    # headers to all requests.
    http = credentials.authorize(http = httplib2.Http())

    # Construct the service object for the interacting with the DoubleClick Search API.
    service = build('doubleclicksearch', 'v2', http=http)
    return service

def poll_report(service, report_id):
    """Poll the API with the reportId until the report is ready, up to ten times.

    Args:
        service: An authorized Doublelcicksearch service.
        report_id: The ID DS has assigned to a report.
    Returns:
        pd.DataFrame, report file
    """
    for _ in range(10):
        try:
            request = service.reports().get(reportId=report_id)
            json_data = request.execute()
            if json_data['isReportReady']:
                pprint.pprint('The report is ready.')

                # For large reports, DS automatically fragments the report into multiple
                # files. The 'files' property in the JSON object that DS returns contains
                # the list of URLs for file fragment. To download a report, DS needs to
                # know the report ID and the index of a file fragment.
                report = pd.DataFrame()
                for i in range(len(json_data['files'])):
                    pprint.pprint('Downloading fragment ' + str(i) + ' for report ' + report_id)
                    report = report.append(download_files(service, report_id, str(i)), ignore_index = True) # See Download the report.
                return report

            else:
                pprint.pprint('Report is not ready. I will try again.')
                time.sleep(10)
        except HttpError as e:
            error = simplejson.loads(e.content)['error']['errors'][0]

            # See Response Codes
            pprint.pprint('HTTP code %d, reason %s' % (e.resp.status, error['reason']))
            break
        
def download_files(service, report_id, report_fragment):
    """Generate and print sample report.

    Args:
        service: An authorized Doublelcicksearch service.
        report_id: The ID DS has assigned to a report.
        report_fragment: The 0-based index of the file fragment from the files array.
    Returns:
        pd.DataFrame report file
    """
    request = service.reports().getFile(reportId=report_id, reportFragment=report_fragment)
    return pd.read_csv(StringIO(request.execute().decode('utf-8')))

def request_report(service, start_date, end_date, columns):
    """Request sample report and print the report ID that DS returns. See Set Up Your Application.

    Args:
        service: An authorized Doublelcicksearch service.
        columns: list of columns will be in the report
    Returns:
        The report id.
    """
    request = service.reports().request(
        body={
                "reportScope": {
                    "agencyId": "20100000000000932",
                    "advertiserId": "21700000001406447", # Callaway Apparel - Perry Ellis International
                    #"engineAccountId": "700000001564770" # Google - Callaway Apparel
                    #"advertiserId": "21700000001131725", # Celebrity Cruise
                    #"engineAccountId": "700000001217833" # Celebrity Cruise
                    #"engineAccountId": "700000001561242" # Celebrity Cruise - Juba Plus
                },
                "reportType": "keyword",
                "columns": [{'columnName': column} for column in columns],   
                "timeRange" : {
                    "startDate" : start_date,
                    "endDate" : end_date
                    },
                
                #"filters": [
                #    {
                #        "column" : { "columnName": "keywordLabels" },
                #        "operator" : "containsElement",
                #        "values" : ["JubaNovTest",]
                #    }
                #],
                
                "downloadFormat": "csv",
                "maxRowsPerFile": 100000000,
                "statisticsCurrency": "agency",
                "verifySingleTimeZone": "false",
                "includeRemovedEntities": "false"
            }
    )
    json_data = request.execute()
    return json_data['id']

# %%
# download reports
creds = create_credentials()

service = get_service(creds)

end_date = "2017-09-04"
start_date = "2017-04-02"

print(start_date, end_date)
REPORTID_nonHVA = request_report(service, start_date, end_date, 
                                 ['campaign', 'adGroup', 'keywordText', 'keywordMatchType', 'status', 
                                  'effectiveKeywordMaxCpc', 'keywordMaxCpc', 'topOfPageBidCurrent',
                                  'topOfPageBidAvg', 'impr', 'clicks', 'cost', 
                                  'avgCpc', 'avgPos', 'dfaRevenue'])
REPORTID_HVA = request_report(service, start_date, end_date, 
                              ['campaign', 'adGroup', 'keywordText', 'keywordMatchType', 
                               'floodlightActivity', 'dfaActions'])

non_hva = poll_report(service, REPORTID_nonHVA)
hva = poll_report(service, REPORTID_HVA)
# Out:
# 2017-04-02 2017-09-04
# 'Report is not ready. I will try again.'
# 'The report is ready.'
# 'Downloading fragment 0 for report AAAnutf_GRPJ_nJn'
# 'The report is ready.'
# 'Downloading fragment 0 for report AAAnnc_MP960U8jG'

# %%
non_hva
# Out:
#                                                 campaign  \
# 0                                           (ROI) Shirts
# 1                                           (ROI) Shirts
# 2                                           (ROI) Shirts
# ...                                                  ...
# 141894  G_Brand_Callaway Apparel_Callaway Test_ EST-2773
# 141895  G_Brand_Callaway Apparel_Callaway Test_ EST-2773
# 141896  G_Brand_Callaway Apparel_Callaway Test_ EST-2773
#
#                                             adGroup  \
# 0       CA || B | Callaway > Shirts > Poplin  > Men
# 1       CA || B | Callaway > Shirts > Poplin  > Men
# 2       CA || B | Callaway > Shirts > Poplin  > Men
# ...                                             ...
# 141894                              Men Vests - BMM
# 141895                   Women Shorts & Skorts- BMM
# 141896                           Best Sellers - BMM
#
#                                keywordText keywordMatchType  status  \
# 0            +callaway +man +poplin +shirt            Broad  Paused
# 1            +man +poplin +callaway +shirt            Broad  Paused
# 2                callaway man poplin shirt           Phrase  Paused
# ...                                    ...              ...     ...
# 141894                +callaway +men +vest            Broad  Active
# 141895                    +callaway +skort            Broad  Active
# 141896  +callaway +clothing +best +sellers            Broad  Active
#
#         effectiveKeywordMaxCpc  keywordMaxCpc  topOfPageBidCurrent  \
# 0                         0.96           0.96                  NaN
# 1                         0.96           0.96                  NaN
# 2                         0.96           0.96                  NaN
# ...                        ...            ...                  ...
# 141894                    3.00           3.00                  NaN
# 141895                    3.00           3.00                 0.41
# 141896                    3.00           3.00                  NaN
#
#         topOfPageBidAvg  impr  clicks   cost    avgCpc    avgPos  dfaRevenue
# 0                   NaN     0       0   0.00       NaN       NaN        0.00
# 1                   NaN     0       0   0.00       NaN       NaN        0.00
# 2                   NaN     0       0   0.00       NaN       NaN        0.00
# ...                 ...   ...     ...    ...       ...       ...         ...
# 141894              NaN     8       0   0.00       NaN  1.125000        0.00
# 141895         0.257229  2688      35  43.03  1.229429  1.110119      617.26
# 141896              NaN     0       0   0.00       NaN       NaN        0.00
#
# [141897 rows x 15 columns]

# %%
hva
# Out:
#                                                 campaign  \
# 0                                  CA_US || B | Leggings
# 1                                  CA_US || B | Leggings
# 2                                  CA_US || B | Leggings
# ...                                                  ...
# 165368  G_Brand_Callaway Apparel_Callaway Test_ EST-2773
# 165369  G_Brand_Callaway Apparel_Callaway Test_ EST-2773
# 165370  G_Brand_Callaway Apparel_Callaway Test_ EST-2773
#
#                                           adGroup               keywordText  \
# 0       CA || B | Callaway > Leggings > Mock > ZZ  +leggins +callaway +mock
# 1       CA || B | Callaway > Leggings > Mock > ZZ     callaway mock leggins
# 2       CA || B | Callaway > Leggings > Mock > ZZ    leggings callaway mock
# ...                                           ...                       ...
# 165368                      General Polos - Exact             callaway polo
# 165369                      General Polos - Exact         callaway t shirts
# 165370                      Shoes General - Exact     Display Network Stats
#
#        keywordMatchType               floodlightActivity  dfaActions
# 0                 Broad                              NaN           0
# 1                 Exact                              NaN           0
# 2                Phrase                              NaN           0
# ...                 ...                              ...         ...
# 165368            Exact  Callaway - Big & Tall_Outerwear           1
# 165369            Exact                              NaN           0
# 165370              NaN                              NaN           0
#
# [165371 rows x 6 columns]

# %%
hva['floodlightActivity'].unique()
# Out:
# array([nan, 'Callaway - Homepage', 'Callaway - Search - HVA 2',
#        'Callaway - Products - Polo', 'Callaway - Products - Polos',
#        'Callaway - All Pages - FB', 'Callaway - Check Out',
#        'Do Not Use - Callaway - Secure Checkout', 'Callaway - Men',
#        'Callaway - Features_Opti-Series',
#        'Callaway - Clearance_Mens Clearance', 'Callaway - Women_Pants',
#        'Callaway - Men_Polos', 'Callaway - Men_Outerwear',
#        'Callaway - Women_Polos', 'Callaway - Women_Skorts & Shorts',
#        'Callaway - Features_New Arrivals', 'Callaway - Women',
#        'Callaway - Clearance',
#        'DO Not Use - Callaway - Contact Us (Help, Support)',
#        'Callaway - Products - Shorts', 'Callaway - Products - Short',
#        'Callaway - Products - Jackets',
#        'Callaway - Subscription (Join Our Email List)',
#        'Callaway - Subscription Success', 'Callaway - Size Charts',
#        'Callaway - Big & Tall_Outerwear', 'Callaway - Products - Pants',
#        'Callaway - Products - Vests', 'Callaway - Add to Cart - HVA 3',
#        'Callaway - Thank You Page Transactions', 'Callaway - Paypal',
#        'Callaway - Order Review - All', 'Callaway - Shipping - All',
#        'Callaway - Men_Pants', 'Callaway - Men_Shorts',
#        'Callaway - Men_Standard Collection', 'Callaway - Men_Belts',
#        'Callaway - Products - Jacket',
#        'Callaway - Clearance_Big & Tall Clearance',
#        'Callaway - Big & Tall_Polos', 'Callaway - Features_Callaway X',
#        'Callaway - Products - Skorts', 'Callaway - Products - Belts',
#        'Callaway - Big & Tall', 'Callaway - News + Media',
#        'Callaway  - Products - Universal',
#        'Callaway - Clearance_Womens Clearance',
#        'Perry Ellis - Clothing_Tops_Sweaters',
#        'Perry Ellis - Products - Sweaters',
#        'Perry Ellis - Products - Universal', 'Perry Ellis - Homepage',
#        'Perry Ellis - Products - Polo-Knits',
#        'Callaway - Billing_Payment - All',
#        'Callaway - Products - Men Golf Shoes', 'Perry Ellis - Search',
#        'Callaway - Women Golf Shoes', 'Callaway - Features_Best-Sellers',
#        'Callaway - Products - Sunglasses', 'Callaway - Logo',
#        'Do Not Use - Callaway - Features', 'Callaway - Accessories_Hats',
#        'Callaway - Features_Gifts for Dads',
#        'Callaway - Big & Tall_Pants-Shorts', 'Perry Ellis - New Arrivals',
#        'Perry Ellis - Clothing_Tops_Polo-Knits',
#        'Perry Ellis - Products - Sunglasses',
#        'Callaway - Shipping - Guest', 'Callaway - Order Review - Guest',
#        'Callaway - Billing_Payment - Guest', 'Callaway - Basket',
#        'Callaway - Create Account', 'Callaway - Log In (My Account)',
#        'Callaway - Women_Belts', 'Callaway - Women_Standard Collection',
#        'Callaway - Big & Tall_Belts', 'Callaway - Men Golf Shoes',
#        'Callaway - Accessories_Belts', 'Callaway - Products - Hats',
#        'Callaway - Products - Women Golf Shoes',
#        'Callaway - Order Review - Registered',
#        'Callaway - Shipping - Registered',
#        'Callaway - Billing_Payment - Registered', 'Peony - Homepage',
#        'Peony - Tops', 'Peony - last-chance',
#        'Callaway - Shipping & Handling',
#        'Callaway - Accessories_Sunglasses', 'Callaway - Women_Outerwear',
#        'Callaway - Thank You Page Items Sold',
#        'Callaway - Products - Sweaters', 'Callaway - Returns',
#        'Perry Ellis - Basket', 'Perry Ellis - Size Chart',
#        'Perry Ellis - Clothing_Pants_Dress-Pants',
#        'Perry Ellis - Products - Dress-Pants', 'Perry Ellis - Add to Cart',
#        'Original Penguin - Products - Polos',
#        'Original Penguin - Products - Shoes',
#        'Original Penguin - Clothing_Tees and Tanks',
#        'Original Penguin - Clothing_Polos',
#        'Original Penguin - Clothing_Swim',
#        'Original Penguin - Clothing_Suit-Separates',
#        'Cubavera - Products - Pants', 'Cubavera - Products - Universal',
#        'Cubavera - Check Out', 'Cubavera - Shipping - All',
#        'Cubavera - Order Review - All', 'Cubavera - Add to Cart',
#        'Cubavera - Billing/Payment - All', 'Cubavera - Secure Checkout',
#        'Cubavera - Thank You Page - Transactions',
#        'Cubavera - Thank You Page - Items Sold', 'Cubavera - Big-Tall',
#        'Callaway - Order Status (Orders)', 'Cubavera - Mens/Tops',
#        'Cubavera - Homepage', 'Callaway - Payment Options',
#        'Callaway - About Us (Who We Are)',
#        'Perry Ellis - Accessories_Accessories_Grooming-Kits',
#        'Perry Ellis - Accessories_Accessories_Suiting-Essentials',
#        'Perry Ellis - Accessories_Accessories_Hats',
#        'Perry Ellis - Big-Tall_Casual-Shirts', 'Perry Ellis - Sale',
#        'Perry Ellis - Underwear', 'Perry Ellis - Accessories_Accessories',
#        'Perry Ellis - Products - Underwear',
#        'Perry Ellis - Clothing_Features_Perry Goes West',
#        'Original Penguin - Subscription (Join Our Email List)',
#        'Original Penguin - Features_New-Arrivals',
#        'Original Penguin - Clothing_Big-And-Tall',
#        'Original Penguin - Shoes',
#        'Original Penguin - Accessories_Sunglasses',
#        'Original Penguin - Accessories_Bags',
#        'Perry Ellis - Billing Payment - All',
#        'Perry Ellis - Billing Payment - Guest',
#        'Perry Ellis - Order Review - Guest',
#        'Perry Ellis - Shipping - All', 'Perry Ellis - Shipping - Guest',
#        'Perry Ellis - Check Out',
#        'Perry Ellis - Thank You Page - Transactions',
#        'Perry Ellis - Thank You Page - Items Sold',
#        'Perry Ellis - Underwear_Boxer-Briefs',
#        'Perry Ellis - Underwear_Boxers',
#        'Perry Ellis - Clothing_Features_Perry Goes West 2_LOOK 6',
#        'Original Penguin - Sale', 'Original Penguin - Clothing_Shirts',
#        'Original Penguin - Products - Shirts',
#        'Original Penguin - Products - Tees',
#        'Original Penguin - Products - Sweaters',
#        'Original Penguin - Products - Pants',
#        'Original Penguin - Products - Dress Shirts',
#        'Original Penguin - Products - Underwear',
#        'Original Penguin - Products - Universal', 'Perry Ellis - Shipping',
#        'Perry Ellis - Products - Casual-Shirts',
#        'Perry Ellis - Order Review - All', 'Perry Ellis - Account',
#        'Original Penguin - Search', 'Cubavera - Mens/Bottoms',
#        'Callaway - International FAQs',
#        'Original Penguin - Subscription Successful Page',
#        'Original Penguin - Logo', 'Original Penguin - Homepage',
#        'Original Penguin - Accessories_Underwear',
#        'Original Penguin - Outlet', 'Cubavera - Blog - The Good Life',
#        'Perry Ellis - Clothing_Tops_Dress-Shirts', 'Callaway - Social',
#        'Perry Ellis - Clothing_Pants_Casual Pants',
#        'Original Penguin - Products - Fragrances',
#        'Perry Ellis - Clothing_Tops',
#        'Perry Ellis - Products - Dress-Shirts',
#        'Perry Ellis - Clothing_Tops_Casual-Shirts',
#        'Perry Ellis - Clothing_Suit-Separates',
#        'Perry Ellis - Clothing_Suit-Separates_Suits',
#        'Original Penguin - Check Out', 'Original Penguin - My Cart',
#        'Original Penguin - Secure Checkout',
#        'Original Penguin - Products - Swim', 'Perry Ellis - Sale_Clothing',
#        'Perry Ellis - Products - Shoes',
#        'Perry Ellis - Accessories_Fragrance_Mens-Fragrance',
#        'Perry Ellis - Products - Belts', 'Cubavera - Guayaberas',
#        'Cubavera - Weddings', 'Cubavera - Accessories',
#        'Original Penguin - Clothing_Shorts',
#        'Perry Ellis - Products - Casual-Pants',
#        'Perry Ellis - Clothing_Pants',
#        'Callaway - International Order Status',
#        'Laundry - Features_New Arrivals', 'Laundry - Homepage',
#        'Original Penguin - Size Chart',
#        'Original Penguin - Features_Fit-Guide',
#        'Perry Ellis - Big-Tall_New-Arrivals',
#        'Callaway - Accessibility Statement', 'Callaway - California Act',
#        'Perry Ellis - Products - Wallets',
#        'Perry Ellis - Accessories_Accessories_Wallets',
#        'Original Penguin - Accessories_Hats',
#        'Original Penguin - Products - Hats',
#        'Original Penguin - Shoes_Sneakers',
#        'Original Penguin - Shoes_Casual',
#        'Original Penguin - Clothing_Pants and Denim',
#        'Original Penguin - Products - Gloves', 'Cubavera - Create Account',
#        'Cubavera - Login (My account)',
#        'Cubavera - Guayaberas/Island-Slim-Fit',
#        'Cubavera - Guayaberas/Mens',
#        'Cubavera - Products - Drawstring-Linen-Pants', 'Cubavera - Basket',
#        'Cubavera - Products - Casual-Shirts',
#        'Cubavera - Order Review - Guest',
#        'Callaway - eGift Terms & Conditions',
#        'Perry Ellis - Products - Denim',
#        'Perry Ellis - Clothing_Pants_Denim',
#        'Perry Ellis - Clothing_Pants_Shorts',
#        'Callaway - Terms & Conditions', 'Callaway - Unsubscribe - HVA 2',
#        'Original Penguin - Sale_Men',
#        'Perry Ellis - Products - Suit-Jackets',
#        'Original Penguin - Products - Outerwear',
#        'Cubavera - Big-Tall/Bottoms', 'Cubavera - Big-Tall/Suit-Separates',
#        'Cubavera - Features/New-Arrivals', 'Cubavera - Mens',
#        'Peony - Check Out', 'Peony - Add to bag',
#        'Peony - step1: Shipping - All', 'Peony - Basket',
#        'Peony - step1: Shipping - Guest', 'Peony -looks-we-love',
#        'Peony - New arrival', 'Peony - Products - leggings',
#        'Peony - Products - Sports bra', 'Peony - Products - Universal',
#        'Perry Ellis - Big-Tall_Polos-Knits',
#        'Cubavera - Accessories/Gifts', 'Cubavera - Weddings/Mens',
#        'Cubavera - Accessories/Fedoras', 'Cubavera - Mens/Suit-Separates',
#        'Cubavera - Shoes (Shop Shoes)', 'Cubavera - Features/Exclusives',
#        'Perry Ellis - Clothing_Features_The-Slim-Shop',
#        'Perry Ellis - Sale_Accessories', 'Cubavera - Products - Shorts',
#        'Cubavera - Big-Tall/Tops',
#        'Cubavera - Subscription (Join Our Email List)',
#        'Original Penguin - Features_Indigo Shop',
#        'Perry Ellis - Sale_Big-and-Tall', 'Perry Ellis - Big-Tall_Pants',
#        'Perry Ellis - Guest Checkout', 'Perry Ellis - Secure Checkout',
#        'Original Penguin - Shipping - All',
#        'Original Penguin - Billing_Payment - All',
#        'Original Penguin - Order Review - All',
#        'Original Penguin - Thank You Page Transactions',
#        'Original Penguin - Thank You Page Items Sold',
#        'Original Penguin - Clothing_Dress-Shirts',
#        'Original Penguin - Basket', 'Original Penguin - Add to Cart',
#        'Do Not Use_Perry Ellis - Customer Service-Contact Us',
#        'Perry Ellis - Store Locator', 'Perry Ellis - Email Sign Up',
#        'Perry Ellis - About Us', 'Perry Ellis - Payment',
#        'Perry Ellis - Supreme Perks', 'Perry Ellis - Order History',
#        'Perry Ellis - Clothing_Tops_Outerwear',
#        'Perry Ellis - Clothing_Suit-Separates_Pants',
#        'Perry Ellis - Accessories_Fragrance_Womens-Fragrance',
#        'Perry Ellis - Accessories_Accessories_Watches',
#        'Perry Ellis - Accessories_Accessories_Dress-Socks',
#        'Perry Ellis - Clothing_Features_360-Performance-Collection',
#        'Perry Ellis - Clothing_Features_The-Travel-Luxe-Collection',
#        'Perry Ellis - Accessories_Accessories_Athletic-Socks',
#        'Perry Ellis - Accessories_Shoes_Casual-Shoes',
#        'Perry Ellis - Accessories_Fragrance',
#        'Perry Ellis - Accessories_Fragrance_Gift-Sets',
#        'Perry Ellis - Accessories_Accessories_Cufflinks',
#        'Perry Ellis - Clothing_Suit-Separates_Jackets',
#        'Perry Ellis - Clothing_Suit-Separates_Vests',
#        'Perry Ellis - Accessories_Accessories_Belts',
#        'Perry Ellis - Accessories_Accessories_Ties_Pocket-Squares',
#        'Perry Ellis - Accessories_Accessories_Sunglasses',
#        'Perry Ellis - Accessories_Shoes',
#        'Perry Ellis - Accessories_Accessories_Bags_Luggage',
#        'Perry Ellis - Accessories_Shoes_Dress-Shoes',
#        'Perry Ellis - Big-Tall_Suits',
#        'Original Penguin - Accessories_Fragrance', 'Cubavera - Sale',
#        'Cubavera - Affiliates', 'Cubavera - Logo (Ship to)',
#        'Peony - Affiliates', 'Cubavera - Products - Guayaberas',
#        'Cubavera - Search', 'Peony - Accessories- Tech',
#        'Cubavera - Features/100-Percent-Linen (Shop - 100% Linen)',
#        'Peony -Press', 'Perry Ellis - Clothing_Features_The Wedding Shop',
#        'Original Penguin - Sale_New-To-Sale',
#        'Cubavera -Features/Drawstring-Pant (The Drawstring Linen Pant)',
#        'Original Penguin - Features_The-Earl-Shop',
#        'Perry Ellis - Underwear_Sleepwear',
#        'Perry Ellis - Underwear_Multipacks',
#        'Original Penguin - Accessories',
#        'Original Penguin - Join Supreme Perks',
#        'Original Penguin - Features_The-Spring-Break-Shop',
#        'Original Penguin - Features_Original-Penguin-Blue',
#        'Callaway - Privacy Policy', 'Perry Ellis - Products - Bags',
#        'Original Penguin - Kids', 'Original Penguin - Sale_Accessories',
#        'Perry Ellis - Get Happy Giveaway',
#        'Original Penguin - Find A Store',
#        'Perry Ellis - Products - Suit-Vests',
#        'Perry Ellis - Products - Shorts',
#        'Perry Ellis - Products - Jackets-Outerwear',
#        'Original Penguin - Products - Suit Jacket',
#        'Original Penguin - Paypal', 'Perry Ellis - Products - Cologne',
#        'Original Penguin - Products - Vest',
#        'Perry Ellis - Products - Watches', 'Perry Ellis - Big-Tall_Sale',
#        'Original Penguin - Create Account',
#        'Original Penguin - Login (My Account)',
#        'Cubavera - Products - Polo', 'Cubavera - Products - Swim',
#        'Cubavera - Products - Suit', 'Cubavera - Supreme Perks',
#        'Perry Ellis - Buzzfeed City Quiz',
#        'Perry Ellis - Clothing_Features_Fathers Day Gift Guide',
#        'Original Penguin - Features_Original-Tracks',
#        'Peony - Accessories', 'Peony - Shop', 'Peony - bottoms -leggings',
#        'Peony - Products - accessories',
#        'Original Penguin - Kids_Toddlers 2T-4T',
#        'Original Penguin - Sales_Kids',
#        'Perry Ellis - Clothing_Features_Gifts For Dads Under 25',
#        'Original Penguin - Kids_Boys 4-7', 'Original Penguin - Kids_Youth',
#        'Perry Ellis - Products - Socks',
#        'Perry Ellis - Products - Cufflinks',
#        'Original Penguin - Shipping - Guest', 'Cubavera - Sale/Mens-Sale',
#        'Peony -Subscribe', 'Peony - Top- Sweaters jackets',
#        'Peony - Top- Knits tanks', 'Peony - Products - Shirts',
#        'Original Penguin - Order History',
#        'Original Penguin - Products - Bags', 'Cubavera - Shipping - Guest',
#        'Cubavera - Products - Slip-Ons',
#        'Original Penguin - Students Discount',
#        'Original Penguin - Order Review - Registered',
#        'Original Penguin - Shipping - Registered',
#        'Original Penguin - Billing_Payment - Registered',
#        'Cubavera - Guayaberas/Big-Tall', 'Peony - activewear-shorts',
#        'Peony - Bottoms', 'Original Penguin - Clothing_Sweaters',
#        'Cubavera - Sale/Big-Tall-Sale', 'Cubavera - Products - Suit-Pants',
#        'Cubavera - Products - Suit-Jacket', 'Peony - Products - shorts',
#        'Peony -Lookbook', 'Cubavera - Products - Accessories',
#        'Perry Ellis - Products - Perfume',
#        'Original Penguin - Products - Wallets',
#        'Original Penguin - Payment Options',
#        'Original Penguin - Shipping & Handling',
#        'Original Penguin - Order Review - Guest',
#        'Original Penguin - Billing_Payment - Guest',
#        'Original Penguin - Accessories_Tech-Accessories',
#        'Original Penguin - Bedding_Decorative Pillows',
#        'Original Penguin - Products - Bedding',
#        'Original Penguin - Bedding_Sheet Sets',
#        'Original Penguin - Bedding_Comforter Sets',
#        'Cubavera - Size Chart', 'Laundry - Features',
#        'Laundry - Dresses_Dress by Occasion_Cocktail',
#        'Laundry - Dresses_Dress by Occasion_Little Black Dress',
#        'Laundry - Dresses_Dress by Occasion_Formal', 'Laundry - Bottoms',
#        'Laundry - Tops_Sleeveless', 'Laundry - Products - Dresses',
#        'Laundry - Tops_Short Sleeve', 'Laundry - Products - Universal',
#        'Laundry - Check Out', 'Laundry - Add to Cart',
#        'Original Penguin - Clothing_Outerwear',
#        'Cubavera - Products - Vest', 'Cubavera - Products - Sandals',
#        'Cubavera - Features/Tropical Prints',
#        'Cubavera - Features/Island-Slim-Fit (Shop - Island Slim Fit)',
#        'Original Penguin - Products - Sunglasses', 'Perry Ellis - Blog',
#        'Perry Ellis - Wedding Shop Look 1',
#        'Original Penguin - Products - Socks',
#        'Laundry - Features_Best Sellers', 'Laundry - Dresses',
#        'Laundry - Social', 'Laundry - Basket', 'Laundry - Tops',
#        'Laundry - Join Our Email List',
#        'Peony - Step2: Billing_Payment - All',
#        'Peony - Step2: Billing_Payment - Guest', 'Peony -Account',
#        'Perry Ellis - Clothing_Features_Perry Goes West_LOOK 7',
#        'Perry Ellis - Clothing_Features_Perry Goes West_LOOK 5',
#        'Perry Ellis - Email Sign Up Thank You Page',
#        'Perry Ellis - Products - Gifables', 'Peony - about us',
#        'Peony - activewear- Active leggings', 'Peony - Activewear',
#        'Peony - Accessories- Headbands', 'Cubavera - Weddings/Big-Tall',
#        'Peony - activewear-Sports bras',
#        'Perry Ellis - Clothing_Features_Perry Goes West_LOOK 3',
#        'Peony -press-as seen on show', 'Peony -lookbook-2017-summer',
#        'Original Penguin - Features_Gifts for Dads Grads',
#        'Original Penguin - Blog', 'Original Penguin - Returns',
#        'Original Penguin - Affiliate Program',
#        'Original Penguin - Check Balance',
#        'Perry Ellis - Clothing_Features_Perry Goes West_LOOK 2',
#        'Perry Ellis - Clothing_Features_Perry Goes West_LOOK 1',
#        'Perry Ellis - Clothing_Features_Perry Goes West_LOOK 4',
#        'Original Penguin - Accessories_Ties',
#        'Original Penguin - Shoes_Sandals', 'Cubavera - Products - Hats',
#        'Peony - Step3: Order Review - All',
#        'Peony - Step 3: Order Review - Guest',
#        'Peony - Thank You Page Items Sold',
#        'Peony - Thank You Page Transactions', 'Original Penguin - About Us'], dtype=object)

# %% [markdown]
# # merge reports

# %%
def merge_hva_and_non_hva(hva, non_hva):
    '''merge two reports downloaded by download_reports().
    Args:
        hva: pd.DataFrame
        non_hva: pd.DataFrame
        columns_hva: list of string
    Returns:
        pd.DataFrame
    '''   
    columns_hva= ['Callaway - Big & Tall', 'Callaway - Clearance,Callaway - Unsubscribe - HVA 2', 
                'Callaway - Search - HVA2', 'Callaway - Big & Tall_Belts', 'Callaway - Big & Tall_Outerwear', 
                'Callaway - Big & Tall_Pants-Shorts', 'Callaway - Big & Tall_Polos', 
                'Callaway - Clearance_Big & Tall Clearance', 'Callaway - Clearance_Mens Clearance', 
                'Callaway - Clearance_Womens Clearance', 'Callaway - Features_Best-Sellers', 
                'Callaway - Features_Callaway X', 'Callaway - Features_New Arrivals', 
                'Callaway - Features_Opti-Series', 'Callaway - Men Golf Shoes', 'Callaway - Men_Belts', 
                'Callaway - Men_Outerwear', 'Callaway - Men_Pants', 'Callaway - Men_Polos', 
                'Callaway - Men_Shorts', 'Callaway - Men_Standard Collection', 'Callaway - Products - Belts', 
                'Callaway - Products - Jacket', 'Callaway - Products - Jackets', 
                'Callaway - Products - Men Golf Shoes', 'Callaway - Products - Pants', 
                'Callaway - Products - Polo', 'Callaway - Products - Polos', 'Callaway - Products - Short', 
                'Callaway - Products - Shorts', 'Callaway - Products - Skorts', 'Callaway - Products - Sweaters', 
                'Callaway - Products - Vests', 'Callaway - Products - Women Golf Shoes', 
                'Callaway - Women Golf Shoes', 'Callaway - Women_Belts', 'Callaway - Women_Outerwear', 
                'Callaway - Women_Pants', 'Callaway - Women_Polos', 'Callaway - Women_Skorts & Shorts', 
                'Callaway - Women_Standard Collection',
                'Callaway - Add to Cart - HVA 3', 'Callaway - Order Status (Orders)', 'Callaway - Billing_Payment',
                'Callaway - Check Out', 'Callaway - Order Review', 'Callaway - Paypal', 'Callaway - Secure Checkout',
                'Callaway - Shipping']
    
    result = pd.DataFrame(columns=['campaign', 'adGroup', 'keywordText', 'keywordMatchType']+columns_hva)
    
    for (campaign, ad_group, keyword, keyword_match_type), group in hva.groupby(['campaign', 'adGroup', 
                                                                                 'keywordText', 'keywordMatchType']):
        df = pd.DataFrame([{
            'campaign': campaign,
            'adGroup': ad_group,
            'keywordText' : keyword,
            'keywordMatchType': keyword_match_type
        }])

        for column in columns_hva:
            if column in group['floodlightActivity'].values:
                df[column] = group[group['floodlightActivity'] == column]['dfaActions'].values[0]
            else:
                df[column] = 0
                
        result = result.append(df, ignore_index = True)

    # combine hva and non_hva
    merged = non_hva.merge(result, 
                           on = ['campaign', 'adGroup', 'keywordText', 'keywordMatchType'], 
                           how = 'left')

    # generate baseline and resid compare
    merged = merged.fillna(value = 0)
    
    # generate new fields
    merged['HVA'] = merged[columns_hva].sum(axis=1).apply(int)   
    merged['ROI'] = merged['dfaRevenue'] / merged['cost']
    merged['ROI'] = merged['ROI'].fillna(0)
    return merged[['campaign', 'adGroup', 'keywordText', 'keywordMatchType', 
                   'status', 'keywordMaxCpc', 'effectiveKeywordMaxCpc', 
                   'topOfPageBidCurrent', 'topOfPageBidAvg', 'impr', 'clicks', 
                   'HVA', 'avgCpc', 'avgPos', 'cost', 'dfaRevenue', 'ROI']]

# %%
writer = pd.ExcelWriter('/Users/JayLiang/Desktop/Media Storm/PEI/CallAway/SEM_ Optimization/Sep 5/Brand_CallawaySEM_optimization_April_2_to_Sep_4.xlsx', engine='xlsxwriter')
campaigns = {
    'G_Brand BigTall': 'G_Brand_Callaway Apparel_Big & Tall Clothing_EST-2773',
    'G_Brand Men': 'G_Brand_Callaway Apparel_Mens Clothing_EST-2773',
    'G_Brand Women': 'G_Brand_Callaway Apparel_Womens Clothing_EST-2773',
    'B_Brand BigTall': 'B_Brand_Callaway Apparel_Big & Tall Clothing_EST-2773',
    'B_Brand Men': 'B_Brand_Callaway Apparel_Mens Clothing_EST-2773',
    'B_Brand Women': 'B_Brand_Callaway Apparel_Womens Clothing_EST-2773',
    'Y_Brand BigTall': 'Y_Brand_Callaway Apparel_Big & Tall Clothing_EST-2773',
    'Y_Brand Men': 'Y_Brand_Callaway Apparel_Mens Clothing_EST-2773',
    'Y_Brand women': 'Y_Brand_Callaway Apparel_Womens Clothing_EST-2773'
}


for tab in campaigns:
    CAMPAIGN = campaigns[tab]
    hva_1 = hva[hva['campaign'] == CAMPAIGN]
    non_hva_1 = non_hva[non_hva['campaign'] == CAMPAIGN]
    df = merge_hva_and_non_hva(hva_1, non_hva_1)
    df = df[(df['keywordText'] != 'Display Network Stats') & (df['status'] == 'Active')]

    df['group'] = None

    # group1
    df.loc[(df['ROI'] > 0)&(df['clicks'] < 30), 'group'] = 'group1_lowClick'
    df.loc[(df['ROI'] > 0)&(df['clicks'] >= 30), 'group'] = 'group1'

    # group2
    HVA_mean = df['HVA'].mean()
    if HVA_mean < 10:
        HVA_mean = df[df['HVA'] > 0]['HVA'].mean()
    impr_75 = sorted(list(df['impr']))[int(len(df)*3/4)]

    df.loc[(df['ROI'] == 0)&
           (df['HVA'] >= HVA_mean)&
           (df['clicks'] >= 30)&
           (df['impr']>=impr_75), 'group'] = 'group2'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] >= HVA_mean)&
           (df['clicks'] >= 30)&
           (df['impr']<impr_75), 'group'] = 'group2_highImpr'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] >= HVA_mean)&
           (df['clicks'] < 30), 'group'] = 'group2_lowClick'

    impr_mean = df[df['group'].isnull()]['impr'].mean() #Not allocated group 'impr' mean

    # group3
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] >= impr_mean)&
           (df['cost'] > 0)&
           (df['clicks'] >= 30), 'group'] = 'group3'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] >= impr_mean)&
           (df['cost'] > 0)&
           (df['clicks'] < 30), 'group'] = 'group3_lowClick'

    # group4
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] >= impr_mean)&
           (df['avgPos'] <= 2)&
           (df['cost'] == 0), 'group'] = 'group4'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] >= impr_mean)&
           (df['avgPos'] > 2)&
           (df['cost'] == 0), 'group'] = 'group4_lowPosition'

    # group5
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] < impr_mean)&
           (df['clicks'] >= 30), 'group'] = 'group5'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] < impr_mean)&
           (df['clicks'] < 30), 'group'] = 'group5_lowClick'

    applications_FB_Programatic = {
        'group1': 'Add Products',
        'group1_lowClick': 'keep_running',
        'group2': 'Add Products',
        'group2_highImpr': 'Add Products',
        'group2_lowClick': 'keep_running',
        'group3': 'n.a',
        'group3_lowClick': 'keep_running',
        'group4': 'n.a',
        'group4_lowPosition': 'n.a',
        'group5': 'n.a',
        'group5_lowClick': 'keep_running'}
    applications_SEM = {
        'group1': 'Maintain',
        'group1_lowClick': 'keep_running',
        'group2': '75% Desktop, 25% Mobile',
        'group2_highImpr': 'Type= Exact, add ngatiove KWs',
        'group2_lowClick': 'keep_running',
        'group3': 'pause/ Add to sitelinkes in other ad-groups',
        'group3_lowClick': 'keep_running',
        'group4': 'keep_running',
        'group4_lowPosition': 'improve position to 1-2 (increase CPC)',
        'group5': 'pause',
        'group5_lowClick': 'keep_running'}
    applications_PLA = {
        'group1': 'Maintain/add Products',
        'group1_lowClick': 'keep_running',
        'group2': 'Filter by Zips',
        'group2_highImpr': 'Add Products',
        'group2_lowClick': 'keep_running',
        'group3': 'pause',
        'group3_lowClick': 'keep_running',
        'group4': 'keep running',
        'group4_lowPosition': 'improve position to 1-2 (increase CPC)',
        'group5': 'n.a',
        'group5_lowClick': 'keep_running'}
    applications_Display = {
        'group1': 'Add Products',
        'group1_lowClick': 'keep_running',
        'group2': 'Filter by Zips/100% Desktop',
        'group2_highImpr': 'n.a',
        'group2_lowClick': 'keep_running',
        'group3': 'n.a.',
        'group3_lowClick': 'keep_running',
        'group4': 'n.a',
        'group4_lowPosition': 'n.a',
        'group5': 'n.a',
        'group5_lowClick': 'keep_running'}
    criterion = {
        'group1': 'ROI > 0',
        'group1_lowClick': 'clicks are too low to drive conclusion',
        'group2': 'ROI = 0, high HVA',
        'group2_highImpr': 'ROI = 0, high HVA, high impression',
        'group2_lowClick': 'clicks are too low to drive conclusion',
        'group3': 'ROI = 0, low HVA, high impression, cost > 0',
        'group3_lowClick': 'clicks are too low to drive conclusion',
        'group4': 'ROI = 0, low HVA, high impression, cost = 0, position already high',
        'group4_lowPosition': 'ROI = 0, low HVA, high impression, cost = 0, low position',
        'group5': 'ROI = 0, low HVA, low impression',
        'group5_lowClick': 'clicks are too low to drive conclusion'}
    
    df['criterion'] = df['group'].apply(lambda x: criterion[x])
    df['applications_FB_Programatic'] = df['group'].apply(lambda x: applications_FB_Programatic[x])
    df['applications_SEM'] = df['group'].apply(lambda x: applications_SEM[x])
    df['applications_PLA'] = df['group'].apply(lambda x: applications_PLA[x])
    df['applications_Display'] = df['group'].apply(lambda x: applications_Display[x])
    
    df.sort_values('group', inplace=True)

    df.to_excel(writer, sheet_name=tab, index=False)
################

new_kws = pd.read_csv('/Users/JayLiang/Desktop/Media Storm/PEI/CallAway/SEM_ Optimization/Callaway new kw list.csv')
new_kws = new_kws[new_kws['Brand Nonbrand'] == 'Nonbrand']
new_kws = new_kws.drop_duplicates(['Campaign', 'New KW'])

curr_kws = non_hva[non_hva['campaign'].isin(campaigns.values())][[
        'campaign', 'adGroup', 'keywordText', 'keywordMatchType', 
        'keywordMaxCpc', 'effectiveKeywordMaxCpc', 'topOfPageBidCurrent', 
        'topOfPageBidAvg', 'status', 'impr', 'clicks', 'cost', 'dfaRevenue'
    ]].copy()

campaign_abbr = {  
    'G_Brand_Callaway Apparel_Big & Tall Clothing_EST-2773': 'Big Tall',
    'B_Brand_Callaway Apparel_Big & Tall Clothing_EST-2773': 'Big Tall',
    'Y_Brand_Callaway Apparel_Big & Tall Clothing_EST-2773': 'Big Tall',
    'G_Brand_Callaway Apparel_Mens Clothing_EST-2773': 'Men',
    'B_Brand_Callaway Apparel_Mens Clothing_EST-2773': 'Men',
    'Y_Brand_Callaway Apparel_Mens Clothing_EST-2773': 'Men',
    'G_Brand_Callaway Apparel_Womens Clothing_EST-2773': 'Women',
    'B_Brand_Callaway Apparel_Womens Clothing_EST-2773': 'Women',
    'Y_Brand_Callaway Apparel_Womens Clothing_EST-2773': 'Women'
}

curr_kws['campaign_abbr'] = curr_kws['campaign'].apply(lambda x: campaign_abbr[x])
curr_kws['ROI'] = (curr_kws['dfaRevenue'] / curr_kws['cost']).fillna(0)

curr_kws = curr_kws.merge(new_kws, left_on=['campaign_abbr', 'keywordText'], right_on=['Campaign', 'New KW'], how='left')

action_to_new_kw_provided = curr_kws[curr_kws['New KW'].notnull()].copy()

def insight(row):
    if row['status'] == 'Paused':
        if row['clicks'] < 30:
            return 'status was Paused, clicks < 30'
        elif row['ROI'] == 0:
            return 'status was Paused, clicks >=30, ROI = 0, keep Paused'
        else:
            return 'status was Paused, clicks >= 30, ROI > 0'
        
    elif row['clicks'] < 30:
        return 'status was activate, clicks < 30'
    elif row['ROI'] == 0:
        return 'status was activate, clicks >= 30, ROI = 0'
    else:
        return 'status was activate, clicks >= 30, ROI > 0'

def action(row):
    if row['status'] == 'Paused':
        if row['ROI'] == 0 and row['clicks'] >=30:
            return 'No Action'
        else:
            return 'Activate'
    elif row['clicks'] < 30:
        return 'No Action'
    elif row['ROI'] == 0:
        return 'Paused'
    else:
        return 'No Action'
    
action_to_new_kw_provided['insight'] = action_to_new_kw_provided.apply(lambda row: insight(row), axis=1)       
action_to_new_kw_provided['Strategy'] = action_to_new_kw_provided.apply(lambda row: action(row), axis=1)

paused_kw_not_in_new_list = curr_kws[curr_kws['New KW'].isnull()].copy()  
paused_kw_not_in_new_list = paused_kw_not_in_new_list[paused_kw_not_in_new_list['status'] == 'Paused']
paused_kw_not_in_new_list['insight'] = paused_kw_not_in_new_list.apply(lambda row: insight(row), axis=1)
paused_kw_not_in_new_list['Strategy'] = paused_kw_not_in_new_list.apply(lambda row: action(row), axis=1)

del action_to_new_kw_provided['Campaign']
del action_to_new_kw_provided['New KW']
del action_to_new_kw_provided['campaign_abbr']
del action_to_new_kw_provided['Brand Nonbrand']
action_to_new_kw_provided.to_excel(writer, sheet_name='action_to_new_kw_provided', index=False)

del paused_kw_not_in_new_list['Campaign']
del paused_kw_not_in_new_list['New KW']
del paused_kw_not_in_new_list['campaign_abbr']
del paused_kw_not_in_new_list['Brand Nonbrand']
paused_kw_not_in_new_list.to_excel(writer, sheet_name='paused_kw_not_in_new_list', index=False)

writer.save()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     376                 result = np.empty(len(values), dtype=object)
# --> 377                 result[:] = values
#     378             except ValueError:
#
# ValueError: could not broadcast input array from shape (0,18) into shape (0)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2473             try:
# -> 2474                 value = Series(value)
#    2475             except:
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     247                 data = _sanitize_array(data, index, dtype, copy,
# --> 248                                        raise_cast_failure=True)
#     249
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3028         else:
# -> 3029             subarr = _asarray_tuplesafe(data, dtype=dtype)
#    3030
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     379                 # we have a list-of-list
# --> 380                 result[:] = [tuple(x) for x in values]
#     381
#
# ValueError: cannot copy sequence with size 18 to array axis with dimension 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-a821f9857080> in <module>()
#     210         return 'No Action'
#     211
# --> 212 action_to_new_kw_provided['insight'] = action_to_new_kw_provided.apply(lambda row: insight(row), axis=1)
#     213 action_to_new_kw_provided['Strategy'] = action_to_new_kw_provided.apply(lambda row: action(row), axis=1)
#     214
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2492         """
#    2493
# -> 2494         self._ensure_valid_index(value)
#    2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2474                 value = Series(value)
#    2475             except:
# -> 2476                 raise ValueError('Cannot set a frame with no defined index '
#    2477                                  'and a value that cannot be converted to a '
#    2478                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
writer = pd.ExcelWriter('/Users/JayLiang/Desktop/Media Storm/PEI/CallAway/SEM_ Optimization/Sep 5/Brand_CallawaySEM_optimization_April_2_to_Sep_4.xlsx', engine='xlsxwriter')
campaigns = {
    'G_Brand BigTall': 'G_Brand_Callaway Apparel_Big & Tall Clothing_EST-2773',
    'G_Brand Men': 'G_Brand_Callaway Apparel_Mens Clothing_EST-2773',
    'G_Brand Women': 'G_Brand_Callaway Apparel_Womens Clothing_EST-2773',
    'B_Brand BigTall': 'B_Brand_Callaway Apparel_Big & Tall Clothing_EST-2773',
    'B_Brand Men': 'B_Brand_Callaway Apparel_Mens Clothing_EST-2773',
    'B_Brand Women': 'B_Brand_Callaway Apparel_Womens Clothing_EST-2773',
    'Y_Brand BigTall': 'Y_Brand_Callaway Apparel_Big & Tall Clothing_EST-2773',
    'Y_Brand Men': 'Y_Brand_Callaway Apparel_Mens Clothing_EST-2773',
    'Y_Brand women': 'Y_Brand_Callaway Apparel_Womens Clothing_EST-2773'
}


for tab in campaigns:
    CAMPAIGN = campaigns[tab]
    hva_1 = hva[hva['campaign'] == CAMPAIGN]
    non_hva_1 = non_hva[non_hva['campaign'] == CAMPAIGN]
    df = merge_hva_and_non_hva(hva_1, non_hva_1)
    df = df[(df['keywordText'] != 'Display Network Stats') & (df['status'] == 'Active')]

    df['group'] = None

    # group1
    df.loc[(df['ROI'] > 0)&(df['clicks'] < 30), 'group'] = 'group1_lowClick'
    df.loc[(df['ROI'] > 0)&(df['clicks'] >= 30), 'group'] = 'group1'

    # group2
    HVA_mean = df['HVA'].mean()
    if HVA_mean < 10:
        HVA_mean = df[df['HVA'] > 0]['HVA'].mean()
    impr_75 = sorted(list(df['impr']))[int(len(df)*3/4)]

    df.loc[(df['ROI'] == 0)&
           (df['HVA'] >= HVA_mean)&
           (df['clicks'] >= 30)&
           (df['impr']>=impr_75), 'group'] = 'group2'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] >= HVA_mean)&
           (df['clicks'] >= 30)&
           (df['impr']<impr_75), 'group'] = 'group2_highImpr'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] >= HVA_mean)&
           (df['clicks'] < 30), 'group'] = 'group2_lowClick'

    impr_mean = df[df['group'].isnull()]['impr'].mean() #Not allocated group 'impr' mean

    # group3
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] >= impr_mean)&
           (df['cost'] > 0)&
           (df['clicks'] >= 30), 'group'] = 'group3'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] >= impr_mean)&
           (df['cost'] > 0)&
           (df['clicks'] < 30), 'group'] = 'group3_lowClick'

    # group4
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] >= impr_mean)&
           (df['avgPos'] <= 2)&
           (df['cost'] == 0), 'group'] = 'group4'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] >= impr_mean)&
           (df['avgPos'] > 2)&
           (df['cost'] == 0), 'group'] = 'group4_lowPosition'

    # group5
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] < impr_mean)&
           (df['clicks'] >= 30), 'group'] = 'group5'
    df.loc[(df['ROI'] == 0)&
           (df['HVA'] < HVA_mean)&
           (df['impr'] < impr_mean)&
           (df['clicks'] < 30), 'group'] = 'group5_lowClick'

    applications_FB_Programatic = {
        'group1': 'Add Products',
        'group1_lowClick': 'keep_running',
        'group2': 'Add Products',
        'group2_highImpr': 'Add Products',
        'group2_lowClick': 'keep_running',
        'group3': 'n.a',
        'group3_lowClick': 'keep_running',
        'group4': 'n.a',
        'group4_lowPosition': 'n.a',
        'group5': 'n.a',
        'group5_lowClick': 'keep_running'}
    applications_SEM = {
        'group1': 'Maintain',
        'group1_lowClick': 'keep_running',
        'group2': '75% Desktop, 25% Mobile',
        'group2_highImpr': 'Type= Exact, add ngatiove KWs',
        'group2_lowClick': 'keep_running',
        'group3': 'pause/ Add to sitelinkes in other ad-groups',
        'group3_lowClick': 'keep_running',
        'group4': 'keep_running',
        'group4_lowPosition': 'improve position to 1-2 (increase CPC)',
        'group5': 'pause',
        'group5_lowClick': 'keep_running'}
    applications_PLA = {
        'group1': 'Maintain/add Products',
        'group1_lowClick': 'keep_running',
        'group2': 'Filter by Zips',
        'group2_highImpr': 'Add Products',
        'group2_lowClick': 'keep_running',
        'group3': 'pause',
        'group3_lowClick': 'keep_running',
        'group4': 'keep running',
        'group4_lowPosition': 'improve position to 1-2 (increase CPC)',
        'group5': 'n.a',
        'group5_lowClick': 'keep_running'}
    applications_Display = {
        'group1': 'Add Products',
        'group1_lowClick': 'keep_running',
        'group2': 'Filter by Zips/100% Desktop',
        'group2_highImpr': 'n.a',
        'group2_lowClick': 'keep_running',
        'group3': 'n.a.',
        'group3_lowClick': 'keep_running',
        'group4': 'n.a',
        'group4_lowPosition': 'n.a',
        'group5': 'n.a',
        'group5_lowClick': 'keep_running'}
    criterion = {
        'group1': 'ROI > 0',
        'group1_lowClick': 'clicks are too low to drive conclusion',
        'group2': 'ROI = 0, high HVA',
        'group2_highImpr': 'ROI = 0, high HVA, high impression',
        'group2_lowClick': 'clicks are too low to drive conclusion',
        'group3': 'ROI = 0, low HVA, high impression, cost > 0',
        'group3_lowClick': 'clicks are too low to drive conclusion',
        'group4': 'ROI = 0, low HVA, high impression, cost = 0, position already high',
        'group4_lowPosition': 'ROI = 0, low HVA, high impression, cost = 0, low position',
        'group5': 'ROI = 0, low HVA, low impression',
        'group5_lowClick': 'clicks are too low to drive conclusion'}
    
    df['criterion'] = df['group'].apply(lambda x: criterion[x])
    df['applications_FB_Programatic'] = df['group'].apply(lambda x: applications_FB_Programatic[x])
    df['applications_SEM'] = df['group'].apply(lambda x: applications_SEM[x])
    df['applications_PLA'] = df['group'].apply(lambda x: applications_PLA[x])
    df['applications_Display'] = df['group'].apply(lambda x: applications_Display[x])
    
    df.sort_values('group', inplace=True)

    df.to_excel(writer, sheet_name=tab, index=False)

# %%
new_kws = pd.read_csv('/Users/JayLiang/Desktop/Media Storm/PEI/CallAway/SEM_ Optimization/Callaway new kw list.csv')
new_kws = new_kws[new_kws['Brand Nonbrand'] == 'Nonbrand']

# %%
new_kws2 = new_kws.drop_duplicates(['Campaign', 'New KW'])
new_kws2
# Out:
#      Campaign                      New KW Brand Nonbrand
# 0    Big Tall        big tall block polos       Nonbrand
# 1    Big Tall       big tall cargo shorts       Nonbrand
# 2    Big Tall   big tall golf block polos       Nonbrand
# ..        ...                         ...            ...
# 533     Women          ladies zip jackets       Nonbrand
# 535     Women  ladies golf sleeveless top       Nonbrand
# 536     Women         ladies stretch belt       Nonbrand
#
# [336 rows x 3 columns]

# %%
new_kws2
# Out:
#      Campaign                      New KW Brand Nonbrand
# 0    Big Tall        big tall block polos       Nonbrand
# 1    Big Tall       big tall cargo shorts       Nonbrand
# 2    Big Tall   big tall golf block polos       Nonbrand
# ..        ...                         ...            ...
# 533     Women          ladies zip jackets       Nonbrand
# 535     Women  ladies golf sleeveless top       Nonbrand
# 536     Women         ladies stretch belt       Nonbrand
#
# [336 rows x 3 columns]

# %%
new_kws = pd.read_csv('/Users/JayLiang/Desktop/Media Storm/PEI/CallAway/Auto_Keywords/Callaway new kw list.csv')
new_kws = new_kws[new_kws['Brand Nonbrand'] == 'Nonbrand']
new_kws = new_kws.drop_duplicates(['Campaign', 'New KW'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-cd2856e38f20> in <module>()
# ----> 1 new_kws = pd.read_csv('/Users/JayLiang/Desktop/Media Storm/PEI/CallAway/Auto_Keywords/Callaway new kw list.csv')
#       2 new_kws = new_kws[new_kws['Brand Nonbrand'] == 'Nonbrand']
#       3 new_kws = new_kws.drop_duplicates(['Campaign', 'New KW'])
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     760             self.options['has_index_names'] = kwds['has_index_names']
#     761
# --> 762         self._make_engine(self.engine)
#     763
#     764     def close(self):
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     964     def _make_engine(self, engine='c'):
#     965         if engine == 'c':
# --> 966             self._engine = CParserWrapper(self.f, **self.options)
#     967         else:
#     968             if engine == 'python':
#
# /Users/JayLiang/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1580         kwds['allow_leading_cols'] = self.index_col is not False
#    1581
# -> 1582         self._reader = parsers.TextReader(src, **kwds)
#    1583
#    1584         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'/Users/JayLiang/Desktop/Media Storm/PEI/CallAway/Auto_Keywords/Callaway new kw list.csv' does not exist
