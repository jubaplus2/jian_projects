# %%
import pandas as pd
import os
import numpy as np
import datetime
import glob

# %%
os.getcwd()
# Out:
# '/home/jian/BigLots/hist_daily_data_itemlevel_decompressed'

# %%
item_level_hist_list=glob.glob('/home/jian/BigLots/hist_daily_data_itemlevel_decompressed/*.txt')

# %%
df=pd.read_table(item_level_hist_list[1],dtype=str,nrows=10,sep="|")
df
# Out:
#   location_id transaction_dt transaction_id  \
# 0         216     2018-08-13           4734
# 1        5184     2018-08-15             86
# 2        4103     2018-08-18            213
# 3        5327     2018-08-12            438
# 4        1640     2018-08-16           7803
# 5        1388     2018-08-15            857
# 6        1055     2018-08-18           2129
# 7        1867     2018-08-15           7674
# 8        1166     2018-08-16           5762
# 9        1948     2018-08-17           2062
#
#                                   customer_id_hashed class_code_id  \
# 0  1e7538dcfa9a42d5c3c3bca373d02b8765fb55503ea274...         21002
# 1                                                NaN         12009
# 2  5f69b1cccc65e5f529abc2a4b5c582c41b6ca6393e887d...         12014
# 3  d333b7cb73f1e37e209f7ca157b0f0cfe0998fdc4905e9...         36404
# 4  b9ddb1fa200175d56cd701151b3a5cf8283fed6fc84a8c...         61002
# 5                                                NaN         13005
# ...

# %%
for file in item_level_hist_list:
    df=pd.read_table()
