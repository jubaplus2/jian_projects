# %%
import os
def recursive_file_gen(my_root_dir):
    for root, dirs, files in os.walk(my_root_dir):
        for file in files:
            yield os.path.join(root, file)

# %%
all_files_jian=list(recursive_file_gen("/home/jian/"))

# %%
all_files_jian
# Out:
# ['/home/jian/.bash_logout',
#  '/home/jian/.bash_profile',
#  '/home/jian/.bashrc',
#  '/home/jian/.bash_history',
#  '/home/jian/Programing_ScheduleFinal0507.ipynb',
#  '/home/jian/lawn_code.csv',
#  '/home/jian/.erlang.cookie',
#  '/home/jian/.viminfo',
#  '/home/jian/celery.log',
#  '/home/jian/check_TMR_Circ.csv',
#  '/home/jian/Test_Bing_Map_API.ipynb',
#  '/home/jian/Store_Quadrants_2018Q3.ipynb',
#  '/home/jian/Code_for_backing_up_codes.ipynb',
#  '/home/jian/.cache/abrt/lastnotification',
#  '/home/jian/.cache/pip/selfcheck.json',
#  '/home/jian/.cache/pip/http/a/9/6/3/0/a96306593491a3f88cd22cf2931643c4029989f4dd25a28dac4da73e',
#  '/home/jian/.cache/pip/http/a/9/5/b/0/a95b0e902dd60933384b26b868c8474aa82c1da6cb49fe724ad02c88',
#  '/home/jian/.cache/pip/http/a/5/d/f/4/a5df4c5d0e2738c2047df980b97b4024478f36302461a47f24008dbc',
#  '/home/jian/.cache/pip/http/a/c/1/0/1/ac101e8cf49601082604b02a8a13937b06fded9144495898d0d80359',
# ...
