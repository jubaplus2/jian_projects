# %%
import pandas as pd
import datetime
import numpy as np

# %%
# data1=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStorm customer transaction details - 2018-04-01 - 2018-04-15.zip",compression="zip",sep=",",nrows=20)
data2=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStorm 18 Month Customer Transaction Details.zip",compression="zip",nrows=20)
# data3=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStormLiveRampCustomerTransactionDetails_2018-02-01_2018-03-31.zip",compression="zip",sep=",",nrows=20)
# data4=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStormLiveRampCustomerTransactionDetails_2018-02-01_2018-03-31.zip",compression="zip",sep=",",nrows=20)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-10-56c534e268c0> in <module>()
#       1 # data1=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStorm customer transaction details - 2018-04-01 - 2018-04-15.zip",compression="zip",sep=",",nrows=20)
# ----> 2 data2=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStorm 18 Month Customer Transaction Details.zip",compression="zip",nrows=20)
#       3 # data3=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStormLiveRampCustomerTransactionDetails_2018-02-01_2018-03-31.zip",compression="zip",sep=",",nrows=20)
#       4 # data4=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStormLiveRampCustomerTransactionDetails_2018-02-01_2018-03-31.zip",compression="zip",sep=",",nrows=20)
#       5
#
# ...

# %%
data1.head(10)
# Out:
#                                   customer_id_hashed transaction_date  \
# 0  c99ea72e6ccb1b28c47301209e9aee706fd6a2e26c9927...       2018-04-01
# 1  1ece4af56ec3e43af26c24ede04060bf0edf2b4dd8a56f...       2018-04-08
# 2  44068e5c07002586791dbb80206876a423695c8239db95...       2018-04-04
# 3  272775cfbf66c55858ac4d3bedab5776d4ad45a5b66895...       2018-04-08
# 4  94cfd3cfa7175b263f9abc250d0a3a0dde401a2cb00f5a...       2018-04-05
# 5  8b495ff832b1d5807a0be6da4858295851e58636379841...       2018-04-02
# 6  7e95c5e66efaa440de23d2dbcf57bf9110031dbba3e16b...       2018-04-12
# 7  ac6f2b78377596f15b58b362301653137b219802e6594d...       2018-04-05
# 8  16a6e0e84be9ef92b0e49ae7a4846c7292f7394e97a216...       2018-04-15
# 9  8707ede893fff3440bc17bfe61d5dbef619e368cd2ecaf...       2018-04-05
#
#   transaction_time  transaction_id  location_id  total_transaction_amt  \
# 0            16:49             292         1255                  46.30
# ...

# %%
data2=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStorm 18 Month Customer Transaction Details.zip",compression="zip",nrows=20)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-11-718a73c54b7f> in <module>()
# ----> 1 data2=pd.read_csv("/home/jian/BigLots/Customer_Transaction_Data/MediaStorm 18 Month Customer Transaction Details.zip",compression="zip",nrows=20)
#
# ...
