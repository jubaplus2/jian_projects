# %%
import pandas as pd
import os

# %%
df=pd.read_csv("/home/jian/BigLots/Experian/data_20191016/Experian_20191001114500.txt",dtype=str,nrows=10,sep="|")
df
# Out:
#   CustomerNumber PhaseYear Geo/HH MultiCluster   MultiClusterDesc DemoCluster  \
# 0              9      2019    Geo            5       Home Focused         NaN
# 1             28      2019     HH            6   Holiday Shoppers           3
# 2             48      2019    Geo            7   Sporadic Seniors         NaN
# 3             61      2019     HH            1   Starters in Need           1
# 4             63      2019     HH            5       Home Focused           4
# 5             69      2019     HH            8  Spending Fanatics           5
# 6             82      2019     HH            7   Sporadic Seniors           3
# 7            139      2019     HH            1   Starters in Need           2
# 8            145      2019     HH            8  Spending Fanatics           4
# 9            148      2019     HH            4    Urban Affluence           5
#
#          DemoClusterDesc IncomeId              IncomeDesc AgeId  \
# ...

# %%
df=pd.read_csv("/home/jian/BigLots/Experian/data_20191016/Experian_20191001114500.txt",dtype=str,nrows=None,sep="|")
df.head(2)
# Out:
#   CustomerNumber PhaseYear Geo/HH MultiCluster  MultiClusterDesc DemoCluster  \
# 0              9      2019    Geo            5      Home Focused         NaN
# 1             28      2019     HH            6  Holiday Shoppers           3
#
#        DemoClusterDesc IncomeId              IncomeDesc AgeId  \
# 0                  NaN        2  between $50k and $100k     2
# 1  Married no Children        3                >= $100k     3
#
#              AgeDesc HomerentId HomerentDesc Child1Id Child1Desc Child2Id  \
# 0  between 35 and 50          1    own house        0        NaN        0
# 1              >= 50          1    own house        0        NaN        0
#
#   Child2Desc LivesId           LivesDesc
# 0        NaN       0  single family home
# 1        NaN       0  single family home

# %%
df['Child1Desc'].unique()
# Out:
# array([nan, 'age between 0-6'], dtype=object)

# %%
df['Child1Id'].unique()
# Out:
# array(['0', '1', '3', '2'], dtype=object)

# %%
df[['Child1Id','Child1Desc']].drop_duplicates()
# Out:
#        Child1Id       Child1Desc
# 0             0              NaN
# 3             1  age between 0-6
# 140086        3              NaN
# 217630        2              NaN

# %%
df.groupby("Child1Id")['CustomerNumber'].count().to_frame()
# Out:
#           CustomerNumber
# Child1Id
# 0               13896648
# 1                3729820
# 2                     41
# 3                     64

# %%
3729820/df.shape[0]
# Out:
# 0.21160210779486177

# %%
df.shape[0]/10**6
# Out:
# 17.626573
