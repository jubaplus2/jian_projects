# %%
import pandas as pd
census_data_B01001=pd.read_csv("/home/jian/Docs/Household_and_Population/Cencus_2019/ACS_17_5YR_B01001_with_ann.csv",dtype=str,skiprows=1,nrows=10)
print(census_data_B01001.shape)
census_data_B01001.head(2)
# Out:
# (10, 101)
#                Id    Id2    Geography Estimate; Total:  \
# 0  8600000US00601  00601  ZCTA5 00601            17599
# 1  8600000US00602  00602  ZCTA5 00602            39209
#
#   Margin of Error; Total: Estimate; Male: Margin of Error; Male:  \
# 0                     261            8809                    167
# 1                     128           19231                     58
#
#   Estimate; Male: - Under 5 years Margin of Error; Male: - Under 5 years  \
# 0                             722                                    101
# 1                             936                                      2
#
#   Estimate; Male: - 5 to 9 years                     ...                       \
# 0                            444                     ...
# 1                           1220                     ...
#
#   Estimate; Female: - 67 to 69 years  \
# 0                                313
# 1                                554
#
#   Margin of Error; Female: - 67 to 69 years  \
# ...

# %%
census_data_S0101=pd.read_csv("/home/jian/Docs/Household_and_Population/Cencus_2019/ACS_17_5YR_S0101_with_ann.csv",dtype=str,skiprows=1,nrows=10)
print(census_data_S0101.shape)
census_data_S0101.head(2)
# Out:
# ['Id',
#  'Id2',
#  'Geography',
#  'Estimate; Total:',
#  'Margin of Error; Total:',
#  'Estimate; Male:',
#  'Margin of Error; Male:',
#  'Estimate; Male: - Under 5 years',
#  'Margin of Error; Male: - Under 5 years',
#  'Estimate; Male: - 5 to 9 years',
#  'Margin of Error; Male: - 5 to 9 years',
#  'Estimate; Male: - 10 to 14 years',
#  'Margin of Error; Male: - 10 to 14 years',
#  'Estimate; Male: - 15 to 17 years',
#  'Margin of Error; Male: - 15 to 17 years',
#  'Estimate; Male: - 18 and 19 years',
#  'Margin of Error; Male: - 18 and 19 years',
#  'Estimate; Male: - 20 years',
#  'Margin of Error; Male: - 20 years',
#  'Estimate; Male: - 21 years',
#  'Margin of Error; Male: - 21 years',
#  'Estimate; Male: - 22 to 24 years',
#  'Margin of Error; Male: - 22 to 24 years',
#  'Estimate; Male: - 25 to 29 years',
#  'Margin of Error; Male: - 25 to 29 years',
#  'Estimate; Male: - 30 to 34 years',
#  'Margin of Error; Male: - 30 to 34 years',
#  'Estimate; Male: - 35 to 39 years',
# ...
