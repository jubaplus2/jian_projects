# %%
import pandas as pd
import numpy as np
import datetime
import os
import sqlalchemy
import glob
BL_SQL_CONNECTION= 'mysql+pymysql://jian:JubaPlus-2017@localhost/BigLots' 
BL_engine = sqlalchemy.create_engine(
        BL_SQL_CONNECTION, 
        pool_recycle=1800
    )
pd.read_sql("show tables;",con=BL_engine)
# Out:
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
#    Tables_in_BigLots
# 0        BL_POS_Item
# 1    BL_POS_Subclass
# 2  BL_Rewards_Master
# 3     Pred_CRM_table

# %%
def recursive_file_gen(root_path):
    for root, dirs, files in os.walk(root_path):
        for file in files:
            yield os.path.join(root,file)

# %%
date_range_POS_Subclass=pd.read_sql("select min(transaction_dt),max(transaction_dt) from BL_POS_Subclass;",con=BL_engine)
date_range_POS_Subclass
# Out:
#   min(transaction_dt) max(transaction_dt)
# 0          2016-06-26          2018-08-04

# %%
date_range_POS_Item=pd.read_sql("select min(transaction_dt),max(transaction_dt) from BL_POS_Item;",con=BL_engine)
date_range_POS_Item
# Out:
#   min(transaction_dt) max(transaction_dt)
# 0          2018-08-05          2019-12-28

# %%
pd.read_sql("desc BL_POS_Subclass;",con=BL_engine)
# Out:
#                         Field           Type Null  Key Default Extra
# 0                 location_id        int(11)  YES  MUL    None
# 1              transaction_dt           date  YES  MUL    None
# 2              transaction_id    varchar(16)  YES         None
# 3          customer_id_hashed       char(64)  YES  MUL    None
# 4               class_code_id    varchar(16)  YES  MUL    None
# 5                 subclass_id    varchar(16)  YES         None
# 6  subclass_transaction_units        int(11)  YES         None
# 7    subclass_transaction_amt  decimal(10,2)  YES         None

# %%
pd.read_sql("desc BL_POS_Item;",con=BL_engine)
# Out:
#                     Field           Type Null  Key Default Extra
# 0             location_id        int(11)  YES  MUL    None
# 1          transaction_dt           date  YES  MUL    None
# 2          transaction_id    varchar(16)  YES         None
# 3      customer_id_hashed       char(64)  YES  MUL    None
# 4           class_code_id    varchar(16)  YES  MUL    None
# 5             subclass_id    varchar(16)  YES         None
# 6                 item_id    varchar(16)  YES         None
# 7  item_transaction_units        int(11)  YES         None
# 8    item_transaction_amt  decimal(10,2)  YES         None

# %% [markdown]
# # 2018

# %%
# Start around 1:32 pm

df_historical_from_Subclass_POS_2018=pd.read_sql("select * from BL_POS_Subclass \
where transaction_dt>='2018-01-01';",con=BL_engine)
print("df_historical_from_Subclass_POS_2018.shape",df_historical_from_Subclass_POS_2018.shape)

# around 2 hours
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     165
# --> 166         result = self._query(query)
#     167         self._executed = query
#
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     321         self._last_executed = q
# --> 322         conn.query(q)
#     323         self._do_get_result()
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     855         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 856         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     857         return self._affected_rows
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1056             result = MySQLResult(self)
# -> 1057             result.read()
#    1058         self._result = result
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1346             else:
# -> 1347                 self._read_result_packet(first_packet)
#    1348         finally:
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_result_packet(self, first_packet)
#    1412         self._get_descriptions()
# -> 1413         self._read_rowdata_packet()
#    1414
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_rowdata_packet(self)
#    1446         while True:
# -> 1447             packet = self.connection._read_packet()
#    1448             if self._check_packet_is_eof(packet):
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1003
# -> 1004             recv_data = self._read_bytes(bytes_to_read)
#    1005             if DEBUG: dump_packet(recv_data)
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#    1032             raise err.OperationalError(
# -> 1033                 CR.CR_SERVER_LOST, "Lost connection to MySQL server during query")
#    1034         return data
#
# OperationalError: (2013, 'Lost connection to MySQL server during query')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-9-7b62c881dafb> in <module>
#       1 df_historical_from_Subclass_POS_2018=pd.read_sql("select * from BL_POS_Subclass \
# ----> 2 where transaction_dt>='2018-01-01';",con=BL_engine)
#       3 print("df_historical_from_Subclass_POS_2018.shape",df_historical_from_Subclass_POS_2018.shape)
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     434             coerce_float=coerce_float,
#     435             parse_dates=parse_dates,
# --> 436             chunksize=chunksize,
#     437         )
#     438
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~/.local/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    2062
#    2063         connection = self.contextual_connect(close_with_result=True)
# -> 2064         return connection.execute(statement, *multiparams, **params)
#    2065
#    2066     def scalar(self, statement, *multiparams, **params):
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     937         """
#     938         if isinstance(object, util.string_types[0]):
# --> 939             return self._execute_text(object, multiparams, params)
#     940         try:
#     941             meth = object._execute_on_connection
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_text(self, statement, multiparams, params)
#    1095             statement,
#    1096             parameters,
# -> 1097             statement, parameters
#    1098         )
#    1099         if self._has_events or self.engine._has_events:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1187                 parameters,
#    1188                 cursor,
# -> 1189                 context)
#    1190
#    1191         if self._has_events or self.engine._has_events:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1400                 util.raise_from_cause(
#    1401                     sqlalchemy_exception,
# -> 1402                     exc_info
#    1403                 )
#    1404             else:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1180                         statement,
#    1181                         parameters,
# -> 1182                         context)
#    1183         except BaseException as e:
#    1184             self._handle_dbapi_exception(
#
# /usr/local/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     468
#     469     def do_execute(self, cursor, statement, parameters, context=None):
# --> 470         cursor.execute(statement, parameters)
#     471
#     472     def do_execute_no_params(self, cursor, statement, context=None):
#
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     164         query = self.mogrify(query, args)
#     165
# --> 166         result = self._query(query)
#     167         self._executed = query
#     168         return result
#
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     320         conn = self._get_db()
#     321         self._last_executed = q
# --> 322         conn.query(q)
#     323         self._do_get_result()
#     324         return self.rowcount
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     854                 sql = sql.encode(self.encoding, 'surrogateescape')
#     855         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 856         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     857         return self._affected_rows
#     858
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#    1055         else:
#    1056             result = MySQLResult(self)
# -> 1057             result.read()
#    1058         self._result = result
#    1059         if result.server_status is not None:
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in read(self)
#    1345                 self._read_load_local_packet(first_packet)
#    1346             else:
# -> 1347                 self._read_result_packet(first_packet)
#    1348         finally:
#    1349             self.connection = None
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_result_packet(self, first_packet)
#    1411         self.field_count = first_packet.read_length_encoded_integer()
#    1412         self._get_descriptions()
# -> 1413         self._read_rowdata_packet()
#    1414
#    1415     def _read_rowdata_packet_unbuffered(self):
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_rowdata_packet(self)
#    1445         rows = []
#    1446         while True:
# -> 1447             packet = self.connection._read_packet()
#    1448             if self._check_packet_is_eof(packet):
#    1449                 self.connection = None  # release reference to kill cyclic reference.
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#    1002             self._next_seq_id = (self._next_seq_id + 1) % 256
#    1003
# -> 1004             recv_data = self._read_bytes(bytes_to_read)
#    1005             if DEBUG: dump_packet(recv_data)
#    1006             buff += recv_data
#
# /usr/local/lib/python3.6/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#    1031             self._force_close()
#    1032             raise err.OperationalError(
# -> 1033                 CR.CR_SERVER_LOST, "Lost connection to MySQL server during query")
#    1034         return data
#    1035
#
# OperationalError: (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query') [SQL: "select * from BL_POS_Subclass where transaction_dt>='2018-01-01';"]

# %%
import glob

# %%
# Read from each file

list_file_subclass=glob.glob("/home/jian/BigLots/hist_daily_data_subclasslevel/*.txt")
list_file_subclass=[x for x in list_file_subclass if x.split("_ending_")[1][:10]>="2018-01-01"]
list_file_subclass.sort()
print(list_file_subclass[0])
print(list_file_subclass[-1])

# %%
list_file_subclass_weekly=list(recursive_file_gen("/home/jian/BigLots/2018_by_weeks/"))
list_file_subclass_weekly=[x for x in list_file_subclass_weekly if "dailysales" in x.lower()]
list_file_subclass_weekly=[x for x in list_file_subclass_weekly if x[-4:]==".txt"]
# list_file_subclass_weekly=[x for x in list_file_subclass_weekly if x.split("")<="2018-08-04"]
list_file_subclass_weekly

# %%
print(datetime.datetime.now())
