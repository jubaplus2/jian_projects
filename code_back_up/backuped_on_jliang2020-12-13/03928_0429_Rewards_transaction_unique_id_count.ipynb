# %%
import pandas as pd
import os
import glob

# %%
data=pd.read_table('/home/jian/Projects/Big_Lots/Loyal_members/loyalty_sales_data/MediaStormCustDtl.txt',sep=",",header=None)

# %%
data_new=pd.read_table('/home/jian/Projects/Big_Lots/Loyal_members/loyalty_sales_data/MediaStormSalesBiWeekly20180731-131255-894.txt',nrows=100,sep="|")

# %%
data_new.head(2)
# Out:
#                                   customer_id_hashed transaction_dt  \
# 0  a0d6dd8fb4ba42257bafdc385e7a221a71673e29ffc012...     2018-07-19
# 1  198e267bc14e80510aec480dd6177ff94b59c27aaa0620...     2018-07-22
#
#   transaction_time  transaction_id  location_id  total_transaction_amt  \
# 0            17:51             876           58                  38.39
# 1            20:04            3496         4049                  22.00
#
#    total_transaction_units  merch_cat
# 0                      4.0   35039004
# 1                      4.0   32004002

# %%
data.tail(100)
# Out:
#                  0           1      2     3     4       5   6         7
# 95682622  36954116  2017-12-23  10:48  6032  5281   18.83  14  11104002
# 95682623  26767902  2017-12-23  18:33   367  1158   14.00   3  47007002
# 95682624  38003711  2017-12-23  14:58  1690  5155   25.00  13  11003002
# 95682625  30014753  2017-12-23  11:39  1489  1719   75.36  20  51014004
# 95682626   8104158  2017-12-23  14:46  6040   838   13.90   6  11403006
# 95682627  46691181  2017-12-23  21:25  7333  5191   88.75  17  51019002
# 95682628  18195361  2017-12-23  13:48  6659  4458    4.50   4  14001004
# 95682629   1681465  2017-12-23  10:42  8521   410   31.00   9  51019003
# 95682630  11659609  2017-12-23  10:14  9331  1191   39.75  11  34501002
# 95682631  32226274  2017-12-23  13:55  2660  5152   94.50  11  35018002
# 95682632   9193313  2017-12-23  17:34  8626  1729    2.75   1  11008004
# 95682633   7944282  2017-12-23  14:09  8497  1910   11.05   4  14003015
# ...
