# %%
import pandas as pd
import os

os.getcwd()
# Out:
# '/home/jian/Projects/Big_Lots/Analysis/2019_Q2/Planner_Requests/temp'

# %%
my_output=pd.read_csv("./outputV2_JL_20190810.csv",dtype=str,header=None)
my_output
# Out:
#             0         1         2         3         4         5         6   \
# 0      1000334   7997453   7896512  10297695   4966364   1127291    963928
# 1      1000927   9872494   9795641  11198853   1817366   9694472   8522050
# 2      1001120   5486335   8218037  10669382   8088006   5955505   2149834
# 3      1001479   1147187   8982073   3936545   6126584    779705    773659
# 4      1001921  12569449  12485298   7431033   6089604  12653622  12626807
# 5       100195   5595070   7673354   3866632   3227771  11680535  11140901
# 6      1002016   1555732   1711144   4926406   7806392  12956362  10835630
# 7      1002061  10319378   6421455  10991299   5503949   6352094   1138550
# 8      1002334  10305741   6771020   5193037   4094799   7933616   6632745
# 9      1002426   8061477   6408732   9574451   7849185   7365033   8489304
# 10     1002641   8820011   3684519   8590983  11774737   9995563   3563382
# ...

# %%
submit_example=pd.read_csv("./data/Antai_AE_round1_submit_20190715.csv",dtype=str,header=None)

# %%
submit_example[submit_example[0]=="1000334"]
# Out:
#            0        1        2        3        4        5         6        7   \
# 4518  1000334  4098232  9745461  7668726  1617636  4558139  11190515  9104983
#
#            8        9    ...          21      22       23       24       25  \
# 4518  8301186  5886962   ...     2435144  743728  7407264  8429333  9352418
#
#            26       27       28       29       30
# 4518  8141641  5260503  8886944  4643748  7840737
#
# [1 rows x 31 columns]
