# %%
import pandas as pd
input_file_path="/home/jian/Projects/Big_Lots/Predictive_Model/Tables_for_modeling/POS_from_mysql/table_2020-07-05/df_data_up_to_2020-01-18_With_DCM_JL_2020-07-05.csv"

df=pd.read_csv(input_file_path,nrows=100)

# %%
df[[x for x in df.columns.tolist() if x.strip()[:4].lower()=="week"]]
# Out:
#     weeks_since_sign_up  week_diff  week_1st_trans  week_recent_one_trans  \
# 0                    69         49      2018-09-22             2019-11-10
# 1                    61         40      2018-11-20             2019-05-03
# 2                    58         38      2018-12-08             2019-02-16
# 3                    96         75      2018-03-23             2018-10-19
# 4                    80         60      2018-07-07             2019-11-23
# ..                  ...        ...             ...                    ...
# 95                   84         63      2018-06-13             2019-12-16
# 96                   26          5      2019-07-22             2019-07-25
# 97                   49         28      2019-02-15             2019-02-15
# 98                   89         68      2018-05-09             2018-05-09
# 99                   80         60      2018-07-07             2018-07-07
#
#      week_counts_to_now_recent_one  week_recent_two_trans  \
# 0                              -10             2019-10-12
# 1                               18             2019-02-27
# 2                               28             2018-12-12
# 3                               46             2018-03-23
# 4                              -12             2018-07-07
# ..                             ...                    ...
# 95                             -15             2019-08-17
# 96                               6             2019-07-22
# 97                              29                    NaN
# 98                              69                    NaN
# 99                              60             2018-07-07
#
#      week_counts_to_now_recent_two  week_recent_three_trans  \
# 0                             -6.0               2019-10-11
# 1                             27.0               2018-11-26
# 2                             38.0               2018-12-08
# 3                             76.0               2018-03-23
# 4                             60.0                      NaN
# ..                             ...                      ...
# 95                             2.0               2018-11-20
# 96                             6.0                      NaN
# 97                             NaN                      NaN
# 98                             NaN                      NaN
# 99                            60.0                      NaN
#
#      week_counts_to_now_recent_three  week_recent_four_trans  \
# 0                               -5.0              2018-12-21
# 1                               40.0              2018-11-23
# 2                               38.0                     NaN
# 3                               76.0                     NaN
# 4                                NaN                     NaN
# ..                               ...                     ...
# 95                              41.0              2018-09-12
# 96                               NaN                     NaN
# 97                               NaN                     NaN
# 98                               NaN                     NaN
# 99                               NaN                     NaN
#
#      week_counts_to_now_recent_four  week_recent_five_trans  \
# 0                              37.0              2018-10-27
# 1                              41.0              2018-11-22
# 2                               NaN                     NaN
# 3                               NaN                     NaN
# 4                               NaN                     NaN
# ..                              ...                     ...
# 95                             51.0              2018-06-13
# 96                              NaN                     NaN
# 97                              NaN                     NaN
# 98                              NaN                     NaN
# 99                              NaN                     NaN
#
#      week_counts_to_now_recent_five
# 0                              44.0
# 1                              41.0
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ..                              ...
# 95                             64.0
# 96                              NaN
# 97                              NaN
# 98                              NaN
# 99                              NaN
#
# [100 rows x 13 columns]

# %%
import datetime
datetime.date(2018,3,31)+datetime.timedelta(days=7*94)
# Out:
# datetime.date(2020, 1, 18)
