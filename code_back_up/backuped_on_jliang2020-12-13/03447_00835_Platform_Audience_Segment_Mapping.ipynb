# %%
import pandas as pd
import os
import datetime
import gc
import numpy as np

os.getcwd()
# Out:
# '/home/jian/Projects/Big_Lots/Analysis/2019_Q1/Planner_Request/Bruce_2019Q1_by_Platform_Audience_20190808'

# %%
excel_file_KL=pd.ExcelFile("./BL 2019Q1 Media Delivery by Reward Segment KL 20190807.xlsx")
excel_file_KL.sheet_names
# Out:
# ['Audience report (7)',
#  'Segment Key',
#  'TTD_YT',
#  'TTD Partners',
#  'YouTube',
#  'Facebook',
#  'Pinterest',
#  'Twitter',
#  'Pandora',
#  'serta raw',
#  'Sheet3']

# %%
df_mapping_segment_platform_seg=excel_file_KL.parse("Segment Key",dtype=str)
df_mapping_segment_platform_seg.shape
# Out:
# (90, 6)

# %%
df_all_partner_audience_seg=pd.DataFrame()
for col in df_mapping_segment_platform_seg.columns.tolist():
    if "Segment" in col:
        df=df_mapping_segment_platform_seg[['Partner',"Audience Name"]+[col]].rename(columns={col:"segment"})
        df_all_partner_audience_seg=df_all_partner_audience_seg.append(df)

df_all_partner_audience_seg=df_all_partner_audience_seg[df_all_partner_audience_seg['segment']!="nan"]    
df_all_partner_audience_seg=df_all_partner_audience_seg[pd.notnull(df_all_partner_audience_seg['segment'])]    
df_all_partner_audience_seg['cleaned_segment']=df_all_partner_audience_seg['segment'].apply(lambda x: x.replace("segment=","").strip())
df_all_partner_audience_seg=df_all_partner_audience_seg.rename(columns={"Audience Name":"Audience"})

# %%
tab_list=["TTD_YT","Facebook","Pinterest","Twitter","Pandora"]

df_TTD_YT=excel_file_KL.parse("TTD_YT",skiprows=2,dtype=str).rename(columns={"Row Labels":"Audience","Sum of Impressions ":"imprs","Sum of Media Cost":"cost"})
df_TTD_YT['Partner']="TTD_YT"

df_Facebook=excel_file_KL.parse("Facebook",dtype=str).rename(columns={"Ad Sets":"Audience","Impressions":"imprs","Media Cost":"cost"})
df_Facebook['Partner']="Facebook"

df_Pinterest=excel_file_KL.parse("Pinterest",dtype=str).rename(columns={"Ad group name":"Audience","Total impressions":"imprs","Media Cost":"cost"})
df_Pinterest['Partner']="Pinterest"

df_Twitter=excel_file_KL.parse("Twitter",dtype=str).rename(columns={"Ad Sets":"Audience","Impressions":"imprs","Media Cost":"cost"})
df_Twitter['Partner']="Twitter"

df_Pandora=excel_file_KL.parse("Pandora",dtype=str).rename(columns={"Placement":"Audience","IMPs":"imprs","Media Cost":"cost"})
df_Pandora['Partner']="Pandora"

# %%
df_all_media=pd.concat([df_TTD_YT,df_Facebook,df_Pinterest,df_Twitter,df_Pandora])
df_all_media['imprs']=df_all_media['imprs'].astype(float)
df_all_media['cost']=df_all_media['cost'].astype(float)

# %%
df_all_media.head(10)
# Out:
#                               Audience      imprs          cost Partner
# 0                             Patio AP  1077126.0  18242.000000  TTD_YT
# 1                             Patio AS   288974.0   5032.280000  TTD_YT
# 2                      Patio Quad 2 AP   519024.0   9180.080000  TTD_YT
# 3                      Patio Quad 2 AS    94307.0   1656.410000  TTD_YT
# 4                      Patio Quad 3 AP   476265.0   8091.810000  TTD_YT
# 5                      Patio Quad 3 AS    82673.0   1427.020000  TTD_YT
# 6                      Patio Quad 4 AP   678249.0  10582.660000  TTD_YT
# 7  segment=Experian_T_Holiday Shoppers   700977.0   7020.199710  TTD_YT
# 8  segment=Experian_T_Holiday_Shoppers   375220.0   5376.030000  TTD_YT
# 9      segment=Experian_T_Home Focused   995168.0  10206.479124  TTD_YT

# %%
df_output=pd.merge(df_all_partner_audience_seg,df_all_media,on=["Partner","Audience"],how="left")

# %%
df_output[pd.isnull(df_output['imprs'])]
# Out:
#                     Partner                  Audience  \
# 73   Pinterest, FB, Twitter      P_Grow_LR_NewRewards
# 74   Pinterest, FB, Twitter  Quad1_P_Defend_LR_Active
# 75   Pinterest, FB, Twitter  Quad1_S_Defend_LR_Active
# 76   Pinterest, FB, Twitter  Quad2_P_Defend_LR_Active
# 77   Pinterest, FB, Twitter  Quad2_S_Defend_LR_Active
# 78   Pinterest, FB, Twitter  Quad3_P_Defend_LR_Active
# 79   Pinterest, FB, Twitter    Quad3_P_Grow_LR_Lapsed
# 80   Pinterest, FB, Twitter  Quad3_S_Defend_LR_Active
# 81   Pinterest, FB, Twitter    Quad3_S_Grow_LR_Lapsed
# 82   Pinterest, FB, Twitter    Quad4_P_Grow_LR_Active
# 83   Pinterest, FB, Twitter    Quad4_P_Grow_LR_Lapsed
# 84   Pinterest, FB, Twitter    Quad4_S_Grow_LR_Active
# 85   Pinterest, FB, Twitter    Quad4_S_Grow_LR_Lapsed
# 86   Pinterest, FB, Twitter      S_Grow_LR_NewRewards
# 87                  YouTube                  Patio AP
# 88                  YouTube                  Patio AS
# 89                  YouTube           Patio Quad 2 AP
# 90                  YouTube           Patio Quad 2 AS
# 91                  YouTube           Patio Quad 3 AP
# 92                  YouTube           Patio Quad 3 AS
# 93                  YouTube           Patio Quad 4 AP
# 159  Pinterest, FB, Twitter  Quad1_P_Defend_LR_Active
# 160  Pinterest, FB, Twitter  Quad1_S_Defend_LR_Active
# 161  Pinterest, FB, Twitter  Quad2_P_Defend_LR_Active
# 162  Pinterest, FB, Twitter  Quad2_S_Defend_LR_Active
# 163  Pinterest, FB, Twitter  Quad3_P_Defend_LR_Active
# 164  Pinterest, FB, Twitter  Quad3_S_Defend_LR_Active
# 165  Pinterest, FB, Twitter    Quad4_P_Grow_LR_Active
# 166  Pinterest, FB, Twitter    Quad4_S_Grow_LR_Active
# 167                 YouTube                  Patio AP
# 168                 YouTube                  Patio AS
# 169                 YouTube           Patio Quad 2 AP
# 170                 YouTube           Patio Quad 2 AS
# 171                 YouTube           Patio Quad 3 AP
# 172                 YouTube           Patio Quad 3 AS
# 173                 YouTube           Patio Quad 4 AP
# 191                 YouTube                  Patio AP
# 192                 YouTube                  Patio AS
#
#                                segment              cleaned_segment  imprs  \
# 73               New Rewards Sign Ups          New Rewards Sign Ups    NaN
# 74     segment=T_Quadrant I_P_H_2019Q1      T_Quadrant I_P_H_2019Q1    NaN
# 75     segment=T_Quadrant I_S_H_2019Q1      T_Quadrant I_S_H_2019Q1    NaN
# 76    segment=T_Quadrant II_P_H_2019Q1     T_Quadrant II_P_H_2019Q1    NaN
# 77    segment=T_Quadrant II_S_H_2019Q1     T_Quadrant II_S_H_2019Q1    NaN
# 78   segment=T_Quadrant III_P_H_2019Q1    T_Quadrant III_P_H_2019Q1    NaN
# 79   segment=T_Quadrant III_P_L_2019Q1    T_Quadrant III_P_L_2019Q1    NaN
# 80   segment=T_Quadrant III_S_H_2019Q1    T_Quadrant III_S_H_2019Q1    NaN
# 81   segment=T_Quadrant III_S_L_2019Q1    T_Quadrant III_S_L_2019Q1    NaN
# 82    segment=T_Quadrant IV_P_H_2019Q1     T_Quadrant IV_P_H_2019Q1    NaN
# 83    segment=T_Quadrant IV_P_L_2019Q1     T_Quadrant IV_P_L_2019Q1    NaN
# 84    segment=T_Quadrant IV_S_H_2019Q1     T_Quadrant IV_S_H_2019Q1    NaN
# 85    segment=T_Quadrant IV_S_L_2019Q1     T_Quadrant IV_S_L_2019Q1    NaN
# 86               New Rewards Sign Ups          New Rewards Sign Ups    NaN
# 87     segment=T_Quadrant I_P_H_2019Q1      T_Quadrant I_P_H_2019Q1    NaN
# 88     segment=T_Quadrant I_S_H_2019Q1      T_Quadrant I_S_H_2019Q1    NaN
# 89    segment=T_Quadrant II_P_H_2019Q1     T_Quadrant II_P_H_2019Q1    NaN
# 90    segment=T_Quadrant II_S_H_2019Q1     T_Quadrant II_S_H_2019Q1    NaN
# 91   segment=T_Quadrant III_P_H_2019Q1    T_Quadrant III_P_H_2019Q1    NaN
# 92   segment=T_Quadrant III_S_H_2019Q1    T_Quadrant III_S_H_2019Q1    NaN
# 93    segment=T_Quadrant IV_P_H_2019Q1     T_Quadrant IV_P_H_2019Q1    NaN
# 159    segment=T_Quadrant I_P_M_2019Q1      T_Quadrant I_P_M_2019Q1    NaN
# 160    segment=T_Quadrant I_S_M_2019Q1      T_Quadrant I_S_M_2019Q1    NaN
# 161   segment=T_Quadrant II_P_M_2019Q1     T_Quadrant II_P_M_2019Q1    NaN
# 162   segment=T_Quadrant II_S_M_2019Q1     T_Quadrant II_S_M_2019Q1    NaN
# 163  segment=T_Quadrant III_P_M_2019Q1    T_Quadrant III_P_M_2019Q1    NaN
# 164  segment=T_Quadrant III_S_M_2019Q1    T_Quadrant III_S_M_2019Q1    NaN
# 165   segment=T_Quadrant IV_P_M_2019Q1     T_Quadrant IV_P_M_2019Q1    NaN
# 166   segment=T_Quadrant IV_S_M_2019Q1     T_Quadrant IV_S_M_2019Q1    NaN
# 167    segment=T_Quadrant I_P_M_2019Q1      T_Quadrant I_P_M_2019Q1    NaN
# 168    segment=T_Quadrant I_S_M_2019Q1      T_Quadrant I_S_M_2019Q1    NaN
# 169   segment=T_Quadrant II_P_M_2019Q1     T_Quadrant II_P_M_2019Q1    NaN
# 170   segment=T_Quadrant II_S_M_2019Q1     T_Quadrant II_S_M_2019Q1    NaN
# 171  segment=T_Quadrant III_P_M_2019Q1    T_Quadrant III_P_M_2019Q1    NaN
# 172  segment=T_Quadrant III_S_M_2019Q1    T_Quadrant III_S_M_2019Q1    NaN
# 173   segment=T_Quadrant IV_P_M_2019Q1     T_Quadrant IV_P_M_2019Q1    NaN
# 191        PLUS 3rd Party Patio Target  PLUS 3rd Party Patio Target    NaN
# 192        PLUS 3rd Party Patio Target  PLUS 3rd Party Patio Target    NaN
#
#      cost
# 73    NaN
# 74    NaN
# 75    NaN
# 76    NaN
# 77    NaN
# 78    NaN
# 79    NaN
# 80    NaN
# 81    NaN
# 82    NaN
# 83    NaN
# 84    NaN
# 85    NaN
# 86    NaN
# 87    NaN
# 88    NaN
# 89    NaN
# 90    NaN
# 91    NaN
# 92    NaN
# 93    NaN
# 159   NaN
# 160   NaN
# 161   NaN
# 162   NaN
# 163   NaN
# 164   NaN
# 165   NaN
# 166   NaN
# 167   NaN
# 168   NaN
# 169   NaN
# 170   NaN
# 171   NaN
# 172   NaN
# 173   NaN
# 191   NaN
# 192   NaN
